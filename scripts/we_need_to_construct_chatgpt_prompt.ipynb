# %%
import pandas as pd
scr_csqa_labeled_path="/cognitive_comp/huangyongfeng/evaluate_LM_with_rationalization/few_shot_explanations/data/handwritten_cose_v1.11_examples.csv"
scr_csqa_label_df=pd.read_csv(scr_csqa_labeled_path)

# %%
scr_csqa_label_df
# Out:
#                                      id        type  \
# 0      cabdfc174953b4bdb8bdcc89d6592c74  evaluation
# 1      5d99898aa689654fe8aa3c4a9c98fb7d  evaluation
# 2    494b8316614fc64c5c27757aeaffce23_1      prompt
# 3      71519c19654251cced50c5718fd527c1  evaluation
# 4      b5fe238d45e55ca5d802b7823ad390ef  evaluation
# ..                                  ...         ...
# 110    cac490541d161f278fa0dda9958d9ed0  evaluation
# 111    e75f1e6da82e45b5d51713bbc615c52e  evaluation
# 112    47f60340b869552e795fa6782224f3d2  evaluation
# 113    ff7ca9c294f1bba7900a35669b4b6163  evaluation
# 114    ae9f6f1e17b3fdd3a86b494933809f45  evaluation
#
#                                               question  \
# 0            What is someone not legal to buy alcohol?
# 1    When you are expressing yourself by yelling af...
# 2                A cat can't talk, but a cat can what?
# 3    What do you normally get out to get yourself a...
# 4                       Where can someone get a flute?
# ...

# %%
scr_csqa_label_list = scr_csqa_label_df.to_dict('records')

# %%
scr_csqa_label_list[0].keys()
# Out:
# dict_keys(['id', 'type', 'question', 'choices', 'answer', 'orig_explanation', 'our_explanation'])

# %%
datasource = "cos-e"
explanation_sep = 'explanation'
for item in scr_csqa_label_list:
    question = item['question']
    #print(item['choices'])
    input_string = f"Give one answer of cos-e question and explain why: {question} choice: " + " choice: ".join([x[1:-1] for x in item["choices"][1:-1].split(', ')]) + f" <extra_id_0> {explanation_sep} <extra_id_1>"
    print(input_string)
    print("####")
    print("####")
# Out:
# Give one answer of cos-e question and explain why: What is someone not legal to buy alcohol? choice: underage choice: banned choice: adult choice: rules choice: black market <extra_id_0> explanation <extra_id_1>
# ####
# ####
# Give one answer of cos-e question and explain why: When you are expressing yourself by yelling after getting a bruise, what are you feeling? choice: self pity choice: communication choice: understood choice: pain choice: embarrassment <extra_id_0> explanation <extra_id_1>
# ####
# ####
# Give one answer of cos-e question and explain why: A cat can't talk, but a cat can what? choice: sleep all day choice: meow choice: shed fur choice: see king choice: live many years <extra_id_0> explanation <extra_id_1>
# ####
# ####
# Give one answer of cos-e question and explain why: What do you normally get out to get yourself a drink? choice: bucket choice: backpack choice: getting drunk choice: cup choice: cabinet <extra_id_0> explanation <extra_id_1>
# ####
# ####
# ...

# %%
" choice: ".join([x[1:-1] for x in item["choices"][1:-1].split(', ')])
# Out:
# 'office supply store choice: library choice: card catalogue choice: oral report choice: park'

# %%
item["choices"]
# Out:
# "['office supply store', 'library', 'card catalogue', 'oral report', 'park']"

# %%
# !pip3 install --upgrade revChatGPT
# Out:
# ...
#      |████████████████████████████████| 60 kB 1.8 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 6.3 MB 51.0 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 30.1 MB 22.3 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 384 kB 81.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 106 kB 62.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 1.6 MB/s  eta 0:00:01
# ...
#   Created wheel for undetected-chromedriver: filename=undetected_chromedriver-3.2.1-py3-none-any.whl size=46425 sha256=20be03cc23f568d83659eeab3a73009a0c8898de70efc3dd22bc6b40dcfe91bd
#   Stored in directory: /home/huangyongfeng/.cache/pip/wheels/78/4b/58/08949a0fd03ae036862c0d32a8e195afb27344bc1f671594ef
# Successfully built undetected-chromedriver
# ...
# WARNING: You are using pip version 21.2.4; however, version 22.3.1 is available.
# ...

# %%
key="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"

# %%
from revChatGPT.ChatGPT import Chatbot

chatbot = Chatbot({
  "session_token": key
}, conversation_id=None, parent_id=None) # You can start a custom conversation

response = chatbot.ask("Prompt", conversation_id=None, parent_id=None) # You can specify custom conversation and parent ids. Otherwise it uses the saved conversation (yes. conversations are automatically saved)

print(response)
# Out:
# Spawning browser...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/envs/py3.7pytorch1.8new/lib/python3.7/site-packages/revChatGPT/ChatGPT.py in get_cf_cookies(self)
#     403                 driver_executable_path=self.config.get("driver_exec_path"),
# --> 404                 browser_executable_path=self.config.get("browser_exec_path")
#     405             )
#
# ~/miniconda3/envs/py3.7pytorch1.8new/lib/python3.7/site-packages/undetected_chromedriver/__init__.py in __init__(self, options, user_data_dir, driver_executable_path, browser_executable_path, port, enable_cdp_events, service_args, service_creationflags, desired_capabilities, advanced_elements, service_log_path, keep_alive, log_level, headless, version_main, patcher_force_close, suppress_welcome, use_subprocess, debug, no_sandbox, **kw)
#     415                 stderr=subprocess.PIPE,
# ...
