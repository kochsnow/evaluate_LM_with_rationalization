# %%
# import wandb
# wandb.login()

# %env WANDB_PROJECT=evaluate_LM_with_rationalization

# %%
# import gpt3
import logging
import math
import os

from typing import List, Dict, Any, NewType

InputDataClass = NewType("InputDataClass", Any)
os.environ["CUDA_VISIBLE_DEVICES"] = "7"
from transformers import (
    T5Config,
    T5ForConditionalGeneration,
    T5Tokenizer,
    HfArgumentParser,
    TrainingArguments,
    set_seed,
    EarlyStoppingCallback
)
from transformers.trainer_utils import EvaluationStrategy
from transformers.integrations import TensorBoardCallback
import transformers
from transformers import Trainer

#from feature_conversion_methods import format_instance

from custom_args import (
    DataTrainingArguments,
    ModelArguments
)
from metrics import evaluate
import torch
import datasets
import git
import time
from datetime import datetime
import sys
from tqdm import trange
import random 
import pandas as pd 
import jsonlines
from copy import deepcopy 

logger = logging.getLogger(__name__)
transformers.logging.set_verbosity_info()
import re
def set_global_logging_level(level=logging.ERROR, prefices=[""]):
    """
    Override logging levels of different modules based on their name as a prefix.
    It needs to be invoked after the modules have been loaded so that their loggers have been initialized.

    Args:
        - level: desired level. e.g. logging.INFO. Optional. Default is logging.ERROR
        - prefices: list of one or more str prefices to match (e.g. ["transformers", "torch"]). Optional.
          Default is `[""]` to match all active loggers.
          The match is a case-sensitive `module_name.startswith(prefix)`
    """
    prefix_re = re.compile(fr'^(?:{ "|".join(prefices) })')
    for name in logging.root.manager.loggerDict:
        if re.match(prefix_re, name):
            logging.getLogger(name).setLevel(level)
set_global_logging_level(logging.ERROR, ["datasets"])


CONFIG_MAPPING = {"t5": T5Config}
MODEL_MAPPING = {"t5": T5ForConditionalGeneration}
TOKENIZER_MAPPING = {"t5": T5Tokenizer}


def set_other_seeds(seed):
    torch.backends.cudnn.benchmark = False
    #torch.backends.cudnn.deterministic = True
    os.environ['PYTHONHASHSEED'] = str(seed)

# inspired by DefaultDataCollator from:
# https://github.com/huggingface/transformers/blob/master/src/transformers/data/data_collator.py
# modified to perform batch-level padding.
class SequenceCollator:
    def __init__(self, model, pad_token):
        self.model = model
        self.pad_token_mapping = {
            "labels": -100,
            "attention_mask": 0,
            "decoder_attention_mask": 0,
            "input_ids": pad_token,
        }

        self.columns = [
            "input_ids",
            "attention_mask",
            "labels",
            "decoder_attention_mask",
        ]

    def __call__(self, examples: List[Dict[str, InputDataClass]]) -> Dict[str, torch.Tensor]:
        # re-format inputs for training
        batch = {}
        for key in examples[0].keys():
            if key in self.columns:
                tmp_list = []
                for item in examples:
                    tmp_list.append(item[key])

                # pad lists to max length
                if isinstance(tmp_list[0], list):
                    max_length = max(map(len, tmp_list))
                    tmp_list = [
                        el + [self.pad_token_mapping[key]] * (max_length - len(el))
                        for el in tmp_list
                    ]

                batch[key] = torch.tensor(tmp_list, dtype=torch.long)
        return batch

# %%
from collections import defaultdict
import random
"""
Example-to-Feature conversion methods
Modified from
https://github.com/salesforce/cos-e/blob/master/code/generation/train_commonsenseqa_v1.0.py and ""_v1.11.py (identical)
as well as Tensorflow code for WTF?: 
https://github.com/google-research/google-research/blob/master/wt5/wt5/preprocessors.py
"""
# This code is based on https://github.com/allenai/label_rationale_association/blob/main/feature_conversion_methods.py

unified_qa_esnli_label_mapping = {0: 'yes', 1: 'maybe', 2: 'no'}
unified_qa_esnli_label_mapping_upper = {0: 'Yes', 1: 'Maybe', 2: 'No'} 
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
unified_qa_sbic_label_mapping = {"offensive": 'Yes', "not offensive": 'No'}

def format_instance(
        example,
        tokenizer,
        explanation_sep,
        max_seq_length=None,
        datasource=None,
        io_format=None, 
):
    assert datasource in {"cos_e", "esnli", "sbic", "sensemaking", "ecqa"}

    if datasource in ["cos_e", "ecqa"]:
        input_string, answer_string = cqa_formatting(example, io_format, explanation_sep, datasource)
    elif datasource == "esnli":
        input_string, answer_string = esnli_formatting(example, io_format, explanation_sep)
    elif datasource == 'sbic':
        input_string, answer_string = sbic_formatting(example, io_format, explanation_sep)
    elif datasource == 'sensemaking':
        input_string, answer_string = sensemaking_formatting(example, io_format, explanation_sep)
    else:
        raise ValueError("Unknown task. Currently supported: esnli, cos_e, sbic, sensemaking, ecqa.")
    
    if 'unified' in io_format and 'unifew' not in io_format:
        input_string += '</s>'

    input_string = ' '.join(input_string.split())
    answer_string = ' '.join(answer_string.split())

    input_string = ' '.join(input_string.split())
    answer_string = ' '.join(answer_string.split())

    encodings = tokenizer.encode_plus(
        input_string,
        max_length=max_seq_length,
        pad_to_max_length=False,
        return_token_type_ids=False,
        return_attention_mask=True,
    )


    # note even with "lm_labels.shift_right()", the decoder attention mask length is still correct since we remove the last token
    dec = tokenizer.encode_plus(
        answer_string,
        max_length=max_seq_length,
        pad_to_max_length=False,
        return_token_type_ids=False,
        return_attention_mask=True,
    )

    encodings["labels"] = dec["input_ids"]
    encodings["decoder_attention_mask"] = dec["attention_mask"]
    encodings["question_encoding"] = encodings["input_ids"]

    #return encodings
    return {**example, **encodings}

#这里很简单 定义好输入输出string就可以的
def cqa_formatting(item, io_format, explanation_sep, datasource):
    question = item["question"]
    answer = item["answer"]
    abstr_expl = item["abstractive_explanation"].lower() if datasource == 'cos_e' else item["explanation"].lower()


    if io_format == 't5_fewshot_infilling_with_choices':
        input_string = f"explain {datasource} question: {question} choice: " + " choice: ".join(item["choices"]) + f" <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == 't5_fewshot_infilling_more_natural':
        input_string = f"explain {datasource} question: {question} choice: " + " choice: ".join(item["choices"]) + f" The answer is <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == "squad": 
        input_string = f"explain {datasource} question: {question} context: " + ', '.join(item['choices']) # explain cos_e question: When getting in shape you need to have this in between workouts? context: give up, period of recovery, jogging
        answer_string = f"{answer} {explanation_sep} {abstr_expl}" # period of recovery because without a period of recovery you will not get any gains.
    elif io_format == "record": 
        # might not work because cos_e doesn't have a passage 
        input_string = f"explain {datasource} query: {question} entities: " + ', '.join(item['choices']) # explain cos_e query: When getting in shape you need to have this in between workouts? entities: give up, period of recovery, jogging
        answer_string = f"{answer} {explanation_sep} {abstr_expl}" # period of recovery because without a period of recovery you will not get any gains.
    elif io_format == 'unifiedqa_matching':
        choice_ids = ['(A)', '(B)', '(C)', '(D)', '(E)']
        input_string = f'explain {question.lower()} \\n'
        for choice_id, choice in zip(choice_ids, item["choices"]):
            input_string += f' {choice_id} {choice.lower()}'
        answer_string = f"{answer.lower()} {explanation_sep} {abstr_expl.lower()}"
        answer_string = answer_string.lower()
    elif io_format == 't5_fewshot_infilling_without_choices_use_refined_expl':
        input_string = f"explain {datasource} question: {question} choice: " + " choice: ".join(item["choices"]) + f" <extra_id_0> {explanation_sep} <extra_id_1>"
        input_string = f"explain {datasource} question: {question} answer: {answer}" + f" {explanation_sep} <extra_id_0>"
        answer_string = f"<extra_id_0> {item['our_explanation']} <extra_id_1>"

    else:
        raise ValueError("The IO format is not supported. Choose `standard` or `masked_cause_generate`.")
    
    return input_string, answer_string


def esnli_formatting(item, io_format, explanation_sep):

    premise = item["premise"]
    hypothesis = item["hypothesis"]
    answer = unified_qa_esnli_label_mapping[item["label"]] if 'unified' in io_format else wt5_esnli_label_mapping[item["label"]]
    abstr_expl = item["explanation_1"].lower() 
    # Dev/test instances have more than one explanation annotated; merge them into one sequence separated by [SEP] 
    for k in [2,3]:
        if f"explanation_{k}" in item and item[f'explanation_{k}']!='': 
            abstr_expl += f" [SEP] {item[f'explanation_{k}'].lower()}"

    if io_format == 'standard':
        input_string = f"explain nli hypothesis: {hypothesis} premise: {premise}"
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"
    elif io_format == 't5_fewshot_infilling':
        input_string = f"explain nli hypothesis: {hypothesis} premise: {premise} <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == 't5_fewshot_infilling_more_natural':
        input_string = f"explain nli hypothesis: {hypothesis} premise: {premise} This is <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == "squad": 
        input_string = f"explain nli question: Is this entailment? context: {hypothesis} {premise}"  
        answer_ynm = unified_qa_esnli_label_mapping[item["label"]]
        answer_string = f"{answer_ynm} {explanation_sep} {abstr_expl}" 
    elif io_format == "squad_endswith_what":
        input_string = f"explain nli question: What is this? context: {hypothesis} {premise}"  
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"  
    elif io_format == "squad_nli_mix": 
        input_string = f"explain nli question: Is this entailment? context: hypothesis: {hypothesis} premise: {premise}"  
        answer_ynm = unified_qa_esnli_label_mapping[item["label"]]
        answer_string = f"{answer_ynm} {explanation_sep} {abstr_expl}"  
    elif io_format == "squad_nli_mix_endswith_what":  
        input_string = f"explain nli question: What is this? context: hypothesis: {hypothesis} premise: {premise}"  
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"   
    elif io_format == 'unifiedqa_unifew':
        hypothesis = hypothesis.lower().rstrip('.')
        unified_qa_esnli_label_mapping_upper = {0: 'Yes', 1: 'Maybe', 2: 'No'}
        answer = unified_qa_esnli_label_mapping_upper[item["label"]]
        input_string = f'explain {premise} Is {hypothesis}? \\n (A) Yes (B) Maybe (C) No'
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"  
    elif io_format == 'unifiedqa_unifew_nli_mix':
        premise = premise.lower().rstrip('.')
        unified_qa_esnli_label_mapping_upper = {0: 'Yes', 1: 'Maybe', 2: 'No'}
        input_string = f'explain hypothesis: {hypothesis} Is premise: {premise}? \\n (A) Yes (B) Maybe (C) No'
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"  
    elif io_format == 'unifiedqa_ynm': 
        input_string = f'explain is this entailment? \\n {hypothesis.lower()} {premise.lower()}'  
        answer = unified_qa_esnli_label_mapping[item["label"]]
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unifiedqa_snli_mix_ynm': 
        input_string = f'explain is this entailment? \\n hypothesis: {hypothesis.lower()} premise: {premise.lower()}' 
        answer = unified_qa_esnli_label_mapping[item["label"]]
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unifiedqa_snli_mix_ynm_with_choices': 
        input_string = f'explain is this entailment? \\n (A) yes (B) maybe (C) no \\n hypothesis: {hypothesis.lower()} premise: {premise.lower()}'  
        answer = unified_qa_esnli_label_mapping[item["label"]]
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unifiedqa_what_v2': 
        input_string = f'explain what is this? \\n {hypothesis.lower()} {premise.lower()}'  
        answer = wt5_esnli_label_mapping[item["label"]]
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unifiedqa_snli_mix_what_v2': 
        input_string = f'explain what is this? \\n hypothesis: {hypothesis.lower()} premise: {premise.lower()}'  
        answer = wt5_esnli_label_mapping[item["label"]]
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unifiedqa_snli_mix_what_with_choices_v2': 
        input_string = f'explain what is this? \\n (A) entailment (B) neutral (C) contradiction \\n hypothesis: {hypothesis.lower()} premise: {premise.lower()}'  
        answer = wt5_esnli_label_mapping[item["label"]]
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"
    elif io_format == 't5_fewshot_infilling_without_choices_use_refined_expl':
        answer = wt5_esnli_label_mapping[item["label"]]
        input_string = f'explain why the relation is {answer} between hypothesis: {hypothesis.lower()} and premise: {premise.lower()}'  
        #input_string = f"explain {datasource} question: {question} answer: {answer}" + f" {explanation_sep} <extra_id_0>"
        answer_string = f"<extra_id_0> {item['our_explanation']} <extra_id_1>"
    else:
        raise ValueError("The IO format is not supported.")

    return input_string, answer_string


def sbic_formatting(item, io_format, explanation_sep):
    # We pre-processed the SBIC dataset such that we join multiple implied statements with the [SEP] token for dev/test instances 
    # Each annotation in the training split is a separate instance
    post = item['post']
    answer = unified_qa_sbic_label_mapping[item["offensiveYN"]] if 'unified' in io_format else item["offensiveYN"].replace("not offensive", "not_offensive")
    abstr_expl = item["targetStereotype"]
    

    if io_format == 'cola':
        input_string = f"explain sbic sentence: {post}"
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"  
    elif io_format == 't5_fewshot_infilling':
        input_string = f"explain sbic sentence: {post} <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == 't5_fewshot_infilling_bool':
        answer_bool = 'True' if item["offensiveYN"] == 'offensive' else 'False'
        input_string = f"explain sbic sentence: {post} It is <extra_id_0> that this is offensive {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == 't5_fewshot_infilling_more_natural':
        input_string = f"explain sbic sentence: {post} This is <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer} <extra_id_1> {abstr_expl} <extra_id_2>"
    elif io_format == 'squad_yn': 
        input_string = f"explain sbic question: Is this offensive? context: {post}" # explain sbic question: Is this offensive? context: It's only happened to you like two times.
        answer_yn = unified_qa_sbic_label_mapping[item["offensiveYN"]] 
        answer_string = f"{answer_yn} {explanation_sep} {abstr_expl}" #  No because this post does not imply anything offensive
    elif io_format == 'squad_yn_with_tags': 
        input_string = f"explain sbic question: Is this offensive? context: post: {post}" # explain sbic question: Is this offensive? context: It's only happened to you like two times.
        answer_yn = unified_qa_sbic_label_mapping[item["offensiveYN"]] 
        answer_string = f"{answer_yn} {explanation_sep} {abstr_expl}" #  No because this post does not imply anything offensive
    elif io_format == 'squad_what': 
        input_string = f"explain sbic question: What is this? context: {post}" # explain sbic question: This is what? context: It's only happened to you like two times.
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")        
        answer_string = f"{answer} {explanation_sep} {abstr_expl}" # not_offensive because this post does not imply anything offensive    
    elif io_format == 'squad_what_with_tags': 
        input_string = f"explain sbic question: What is this? context: post: {post}" # explain sbic question: This is what? context: It's only happened to you like two times.
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")        
        answer_string = f"{answer} {explanation_sep} {abstr_expl}" # not_offensive because this post does not imply anything offensive    
    elif io_format == 'unified_qa_yn':
        input_string = f'explain is this offensive? \\n {post.lower()}'
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}" 
    elif io_format == 'unified_qa_yn_with_tags':
        input_string = f'explain is this offensive? \\n post: {post.lower()}'
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unified_qa_yn_with_choices':
        input_string = f'explain is this offensive? \\n (A) yes (B) no \\n {post.lower()}'
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"
    elif io_format == 'unified_qa_yn_with_choices_and_tags':
        input_string = f'explain is this offensive? \\n (A) yes (B) no \\n post: {post.lower()}'
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unified_qa_what':
        input_string = f'explain what is this? \\n {post.lower()}'
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unified_qa_what_with_tags':
        input_string = f'explain what is this? \\n post: {post.lower()}'
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unified_qa_what_with_choices':
        input_string = f'explain what is this? \\n (A) offensive (B) not_offensive \\n {post.lower()}'
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"
    elif io_format == 'unified_qa_what_with_choices_and_tags':
        input_string = f'explain what is this? \\n (A) offensive (B) not_offensive \\n post: {post.lower()}'
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")
        answer_string = f"{answer} {explanation_sep} {abstr_expl.lower()}"  
    elif io_format == 'unifiedqa_unifew':
        input_string = f"Topic? \\n (A) offensive (B) not_offensive \\n {post}"
        answer = item["offensiveYN"].replace("not offensive", "not_offensive")
        answer_string = f"{answer} {explanation_sep} {abstr_expl}"
    else:
        raise ValueError("The IO format is not supported. Choose `standard` or `masked_cause_generate`.")

    input_string = ' '.join(input_string.split())
    answer_string = ' '.join(answer_string.split())
    return input_string, answer_string

def sensemaking_formatting(item, io_format, explanation_sep):
    # TODO: explore whether removing periods makes difference? 
    sent0 = item['sent0']
    sent1 = item['sent1']
    nonsensical_sentence = str(int(item['label'])+1)
    explanation = item['explanation'].lower()

    if io_format == 'copa_with_question':
        input_string = f"explain sensemaking choice1: {sent0} choice2: {sent1} question: nonsensical"
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation}"
    elif io_format == 'copa_bool':  
        answer_bool = str(bool(int(item['label']))) # True if choice2 is more nonsensical    
        input_string = f"explain sensemaking choice1: {sent0} choice2: {sent1} Less common is choice2"
        answer_string = f"{answer_bool} {explanation_sep} {explanation}"
    elif io_format == 't5_fewshot_infilling':  
        input_string = f"explain sensemaking choice1: {sent0} choice2: {sent1} <extra_id_0> {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> choice{nonsensical_sentence} <extra_id_1> {explanation} <extra_id_2>"
    elif io_format == 't5_fewshot_infilling_bool':  
        answer_bool = str(bool(int(item['label']))) # True if choice2 is more nonsensical    
        input_string = f"explain sensemaking choice1: {sent0} choice2: {sent1} It is <extra_id_0> that choice2 is less common {explanation_sep} <extra_id_1>"
        answer_string = f"<extra_id_0> {answer_bool} <extra_id_1> {explanation} <extra_id_2>"
    elif io_format == "squad_yn": 
        input_string = f"explain sensemaking question: Is choice2 more nonsensical? context: choice1: {sent0} choice2: {sent1}" # explain sensemaking question: What is nonsensical, choice1 or choice2? context: choice1: All state flowers are the scarlet carnation. choice2: The New Jersey state flower is the scarlet carnation
        answer = "Yes" if bool(int(item['label'])) else "No"
        answer_string = f"{answer} {explanation_sep} {explanation}" #  choice1 because state flowers are unique to each state.  
    elif io_format == "squad_yn_no_tags": 
        input_string = f"explain sensemaking question: Is choice2 more nonsensical? context: {sent0} {sent1}" # explain sensemaking question: What is nonsensical, choice1 or choice2? context: choice1: All state flowers are the scarlet carnation. choice2: The New Jersey state flower is the scarlet carnation
        answer = "Yes" if bool(int(item['label'])) else "No"
        answer_string = f"{answer} {explanation_sep} {explanation}" #  choice1 because state flowers are unique to each state.  
    elif io_format == "squad_what": 
        input_string = f"explain sensemaking question: What is more nonsensical? context: choice1: {sent0} choice2: {sent1}" # explain sensemaking question: What is nonsensical, choice1 or choice2? context: choice1: All state flowers are the scarlet carnation. choice2: The New Jersey state flower is the scarlet carnation
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation}" #  choice1 because state flowers are unique to each state.  
    elif io_format == "squad_what_no_tags": 
        input_string = f"explain sensemaking question: What is more nonsensical? context: {sent0} {sent1}" # explain sensemaking question: What is nonsensical, choice1 or choice2? context: choice1: All state flowers are the scarlet carnation. choice2: The New Jersey state flower is the scarlet carnation
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation}" #  choice1 because state flowers are unique to each state.  
    elif io_format == "record": 
        input_string = f"explain sensemaking query: What is more nonsensical? entities: choice1, choice2 passage: choice1: {sent0} choice2: {sent1}" # explain sensemaking query: What is nonsensical? entities: choice1, choice2 passage: choice1: All state flowers are the scarlet carnation. choice2: The New Jersey state flower is the scarlet carnation.
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation}" # choice1 because state flowers are unique to each state.
    elif io_format == 'unifiedqa_yn_with_choices':
        answer = "yes" if bool(int(item['label'])) else "no"
        input_string = f'explain is choice2 more nonsensical? \\n (A) yes (B) no \\n choice1: {sent0.lower()} choice2: {sent1.lower()}'
        answer_string = f"{answer} {explanation_sep} {explanation.lower()}" 
    elif io_format == 'unifiedqa_yn':
        answer = "yes" if bool(int(item['label'])) else "no"
        input_string = f'explain is choice2 more nonsensical? \\n choice1: {sent0.lower()} choice2: {sent1.lower()}'
        answer_string = f"{answer} {explanation_sep} {explanation.lower()}"  
    elif io_format == 'unifiedqa_yn_no_tags':
        answer = "yes" if bool(int(item['label'])) else "no"
        input_string = f'explain is choice2 more nonsensical? \\n {sent0.lower()} {sent1.lower()}'
        answer_string = f"{answer} {explanation_sep} {explanation.lower()}"  
    elif io_format == 'unifiedqa_what_with_choices':
        nonsensical_sentence = str(int(item['label'])+1)
        input_string = f'explain what is more nonsensical? \\n (A) choice1 (B) choice2 \\n choice1: {sent0.lower()} choice2: {sent1.lower()}'
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation.lower()}"  # use " BECAUSE "
    elif io_format == 'unifiedqa_what':
        nonsensical_sentence = str(int(item['label'])+1)
        input_string = f'explain what is more nonsensical? \\n choice1: {sent0.lower()} choice2: {sent1.lower()}'
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation.lower()}"  # use " BECAUSE "
    elif io_format == 'unifiedqa_what_no_tags':
        nonsensical_sentence = str(int(item['label'])+1)
        input_string = f'explain what is more nonsensical? \\n {sent0.lower()} {sent1.lower()}'
        answer_string = f"choice{nonsensical_sentence} {explanation_sep} {explanation.lower()}"  # use " BECAUSE "


    input_string = ' '.join(input_string.split())
    answer_string = ' '.join(answer_string.split())
    return input_string, answer_string

# %%
og_start_time = time.time()

#parser = HfArgumentParser(
#    (ModelArguments, DataTrainingArguments, TrainingArguments)
#)
parser = HfArgumentParser(
    (ModelArguments, DataTrainingArguments, TrainingArguments)
)

model_args, data_args, training_args, unused_args = parser.parse_args_into_dataclasses(
    ["--model_type", "t5-base",
     "--tokenizer_name", "t5-base",
     "--task_name", "esnli", 
     "--output_dir", "./esnli_output_t5_base", 
     "--n_shots", "10",
     "--do_train", "True"], return_remaining_strings=True)
# training_args.set_device = "cpu"
if unused_args != []:
    raise ValueError(f"Received unused arguments: {unused_args}")
# make sure only one dataset split pick if manually specifying evaluation file

if model_args.use_gpt3:
    assert training_args.do_train
    assert not training_args.do_eval
    assert data_args.generations_filepath is None
    if data_args.gpt3_max_eval_size is not None:
        assert data_args.gpt3_max_eval_size <= data_args.fewshot_eval_size
        assert data_args.gpt3_max_eval_size % 2 == 0
        assert data_args.gpt3_max_eval_size % 3 == 0

if data_args.generations_filepath is not None:
    training_args.do_train = False
    training_args.do_eval = False
    if "train" in data_args.generations_filepath:
        data_args.train_predict = True
        data_args.test_predict = False
        data_args.dev_predict = False
    elif "test" in data_args.generations_filepath:
        data_args.train_predict = False
        data_args.test_predict = True
        data_args.dev_predict = False
    elif "validation" in data_args.generations_filepath:
        data_args.train_predict = False
        data_args.test_predict = False
        data_args.dev_predict = True

if not training_args.do_train and data_args.generations_filepath is None:
    if not model_args.pretrained_model_file:
        raise Exception(
            "if not training a model from scratch, must specify a trained model to load for evaluation"
        )

if training_args.do_train:
    # create a save directory and a logfile
    training_args.output_dir = os.path.join(
        training_args.output_dir, datetime.now().strftime("%m%d%y_%H%M%S")
    )
    training_args.logging_dir = training_args.output_dir
    assert not os.path.exists(training_args.output_dir)
    os.makedirs(training_args.output_dir)

    if (
            os.path.exists(training_args.output_dir)
            and os.listdir(training_args.output_dir)
            and training_args.do_train
            and not training_args.overwrite_output_dir
    ):
        raise ValueError(
            f"Output directory ({training_args.output_dir}) already exists and is not empty. Use --overwrite_output_dir to overcome."
        )
    handlers = [
        logging.FileHandler(os.path.join(training_args.output_dir, "logger.log")),
        logging.StreamHandler(),
    ]
else:
    # don't overwrite existing logfile or create new directory
    training_args.output_dir = model_args.pretrained_model_file
    handlers = [logging.StreamHandler()]

# Setup logging
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(name)s -   %(message)s",
    datefmt="%m/%d/%Y %H:%M:%S",
    level=logging.INFO if training_args.local_rank in [-1, 0] else logging.WARN,
    handlers=handlers,
)
logger.warning(
    "Process rank: %s, device: %s, n_gpu: %s, distributed training: %s, 16-bits training: %s",
    training_args.local_rank,
    training_args.device,
    training_args.n_gpu,
    bool(training_args.local_rank != -1),
    training_args.fp16,
)
logger.info("Save path: %s" % training_args.output_dir)

# get git hash and branch where deployed
repo = git.Repo(search_parent_directories=True)
git_hash = repo.head.object.hexsha
git_branch = repo.active_branch.name
logger.info("Git branch: %s" % git_branch)
logger.info("Git hash: %s" % git_hash)

model_class = "t5"
assert data_args.task_name in {"cos_e", "esnli", "sbic", "sensemaking", "ecqa"}

if training_args.do_train:
    # write command and args to file
    with open(
            os.path.join(training_args.output_dir, "commandline_args.txt"), "w"
    ) as f:
        f.write("Git branch: " + git_branch + "\n")
        f.write("Git hash: " + git_hash + "\n")
        f.write("Command:\n")
        f.write("\n".join(sys.argv[1:]))

# Set seed
set_seed(training_args.seed)
set_other_seeds(training_args.seed)

# Load pretrained model and tokenizer
#
# Distributed training:
# The .from_pretrained methods guarantee that only one local process can concurrently
# download model & vocab.
# Out:
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).
# 02/01/2023 20:23:10 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1, distributed training: False, 16-bits training: False
# 02/01/2023 20:23:10 - INFO - __main__ -   Save path: ./esnli_output_t5_base/020123_202310
# 02/01/2023 20:23:10 - INFO - __main__ -   Git branch: dev
# 02/01/2023 20:23:10 - INFO - __main__ -   Git hash: 1cbb5c3b4e53baf31cbafc20d9655c63f091f901

# %%
# training_args.set_device = "cpu"

# %%
import logging
logger = logging.getLogger(__name__)
CONFIG_MAPPING = {"t5": T5Config}
MODEL_MAPPING = {"t5": T5ForConditionalGeneration}
TOKENIZER_MAPPING = {"t5": T5Tokenizer}
model_class = "t5"
tokenizer_name = TOKENIZER_MAPPING[model_class]
logger.info("Loading pretrained tokenizer...")
model_args.tokenizer_name='t5-base'
tokenizer = tokenizer_name.from_pretrained(model_args.tokenizer_name)#, cache_dir=model_args.cache_dir)

model = T5ForConditionalGeneration.from_pretrained("t5-base")
# Out:
# 02/01/2023 20:23:10 - INFO - __main__ -   Loading pretrained tokenizer...
# loading file https://huggingface.co/t5-base/resolve/main/spiece.model from cache at /home/huangyongfeng/.cache/huggingface/transformers/684a47ca6257e4ca71f0037771464c5b323e945fbc58697d2fad8a7dd1a2f8ba.3b69006860e7b5d0a63ffdddc01ddcd6b7c318a6f4fd793596552c741734c62d
# loading file https://huggingface.co/t5-base/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/t5-base/resolve/main/special_tokens_map.json from cache at None
# loading file https://huggingface.co/t5-base/resolve/main/tokenizer_config.json from cache at None
# loading file https://huggingface.co/t5-base/resolve/main/tokenizer.json from cache at /home/huangyongfeng/.cache/huggingface/transformers/90de37880b5ff5ac7ab70ff0bd369f207e9b74133fa153c163d14c5bb0116207.8627f1bd5d270a9fd2e5a51c8bec3223896587cc3cfe13edeabb0992ab43c529
# loading configuration file https://huggingface.co/t5-base/resolve/main/config.json from cache at /home/huangyongfeng/.cache/huggingface/transformers/91e9fe874e06c44883b535d6c950b8b89d6eaa3298d8e7fb3b2c78039e9f8b7b.a085189636e38420df5e7bdf08ad1b86f1fe33c010079ca7f15437ff95f4fe2b
# Model config T5Config {
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.9.2",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading configuration file https://huggingface.co/t5-base/resolve/main/config.json from cache at /home/huangyongfeng/.cache/huggingface/transformers/91e9fe874e06c44883b535d6c950b8b89d6eaa3298d8e7fb3b2c78039e9f8b7b.a085189636e38420df5e7bdf08ad1b86f1fe33c010079ca7f15437ff95f4fe2b
# Model config T5Config {
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 3072,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "relu",
#   "gradient_checkpointing": false,
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "transformers_version": "4.9.2",
#   "use_cache": true,
#   "vocab_size": 32128
# }
#
# loading weights file https://huggingface.co/t5-base/resolve/main/pytorch_model.bin from cache at /home/huangyongfeng/.cache/huggingface/transformers/ab4e948915b067f5cb6e5105f6f85044fd717b133f43240db67899a8fc7b29a2.26934c75adf19ceac3c268b721ba353356b7609c45f5627550326f275a2163b4
# All model checkpoint weights were used when initializing T5ForConditionalGeneration.
#
# All the weights of T5ForConditionalGeneration were initialized from the model checkpoint at t5-base.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use T5ForConditionalGeneration for predictions without further training.

# %%
data_splits = {'train': None, 'validation': None, 'test': None}
original_data_splits = {'train': None, 'validation': None, 'test': None}  
data_args.io_format="t5_fewshot_infilling_without_choices_use_refined_expl"
data_args
# Out:
# DataTrainingArguments(task_name='esnli', early_stopping_patience=10, overwrite_cache=False, train_predict=False, test_predict=False, dev_predict=False, version_name='v1.11', generations_filepath=None, n_shots=10, fewshot_eval_size=350, io_format='t5_fewshot_infilling_without_choices_use_refined_expl', explanation_sep='explanation', data_path=None, gpt3_max_eval_size=None)

# %%
dataset = datasets.load_dataset(data_args.task_name)
# train_ids_list=[x['id'] for x in dataset["train"]]
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset.keys()
len(dataset['train']), len(dataset['validation']), len(dataset['test'])
dataset['train'][0].keys()
all_data_dict = {}
for da in dataset['train']:
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str not in all_data_dict.keys():
        all_data_dict[key_str] = da
    else:
        print("*****")
        print(da)
        print(all_data_dict[key_str])
        print("*****")
# Out:
# *****
# {'premise': 'Child in red and blue shirt painting a log.', 'hypothesis': 'The child is painting.', 'label': 0, 'explanation_1': '"Child is painting" is a simpler version of  "child painting a log".', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Child in red and blue shirt painting a log.', 'hypothesis': 'The child is painting.', 'label': 0, 'explanation_1': 'Both subjects are painting', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Two small dogs run across the green grass.', 'hypothesis': 'Two dogs are outside.', 'label': 0, 'explanation_1': 'Dogs can be small.  Grass is usually outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Two small dogs run across the green grass.', 'hypothesis': 'Two dogs are outside.', 'label': 0, 'explanation_1': 'Dogs can be small. Grass is usually outside,', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A young woman is drawing with a Sharpie marker.', 'hypothesis': 'A woman is drawing.', 'label': 0, 'explanation_1': 'A woman with a Sharpie marker can be drawing.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A young woman is drawing with a Sharpie marker.', 'hypothesis': 'A woman is drawing.', 'label': 0, 'explanation_1': 'A woman with a Sharpie marker can be drawing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A bald man is attempting to slam dunk a basketball in a game while people in the stands watch.', 'hypothesis': 'A man is playing basketball while people watch.', 'label': 0, 'explanation_1': 'People watch because people in the stands watch.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A bald man is attempting to slam dunk a basketball in a game while people in the stands watch.', 'hypothesis': 'A man is playing basketball while people watch.', 'label': 0, 'explanation_1': 'The man is playing basketball because he is trying to slam dunk a basketball.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A bald man is attempting to slam dunk a basketball in a game while people in the stands watch.', 'hypothesis': 'A hockey player gets the puck in the net.', 'label': 2, 'explanation_1': 'A basketball and a puck are two different objects.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A bald man is attempting to slam dunk a basketball in a game while people in the stands watch.', 'hypothesis': 'A hockey player gets the puck in the net.', 'label': 2, 'explanation_1': 'Hockey and basketball are not the same sport.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A bald man is attempting to slam dunk a basketball in a game while people in the stands watch.', 'hypothesis': 'Michael Jordan shows he still got it when he slam dunks for an exhibition game.', 'label': 1, 'explanation_1': 'The slam dunk in a basketball is not imply that it is an exhibition game.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A bald man is attempting to slam dunk a basketball in a game while people in the stands watch.', 'hypothesis': 'Michael Jordan shows he still got it when he slam dunks for an exhibition game.', 'label': 1, 'explanation_1': 'The bald man is not imply to be Michael Jordan.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Someone riding sideways on a motorcycle.', 'hypothesis': 'A person is on a motorcycle.', 'label': 0, 'explanation_1': 'A person refers to someone.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Someone riding sideways on a motorcycle.', 'hypothesis': 'A person is on a motorcycle.', 'label': 0, 'explanation_1': 'A person refers to the someone because both state that the subject is on a motorcycle.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man in a blue shirt preparing to take a picture of figurines on a small red table.', 'hypothesis': 'A man is getting ready to take a picture.', 'label': 0, 'explanation_1': '"Getting ready to take a pictue" is rephrasing of "preparing to take a picture"', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man in a blue shirt preparing to take a picture of figurines on a small red table.', 'hypothesis': 'A man is getting ready to take a picture.', 'label': 0, 'explanation_1': 'The man is preparing a picture with figures, so he is ready to take a picture.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man and a woman are standing in the middle of the highway looking at motorcycles on the road as traffic is passing.', 'hypothesis': 'The man and woman are outside.', 'label': 0, 'explanation_1': 'The highway is outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man and a woman are standing in the middle of the highway looking at motorcycles on the road as traffic is passing.', 'hypothesis': 'The man and woman are outside.', 'label': 0, 'explanation_1': 'The middle of the highway is outside.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'The girl in a pink shirt jumps high over the grass.', 'hypothesis': 'A girl jumps.', 'label': 0, 'explanation_1': 'Girl and jumps are the subject and verb of sentence 1.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'The girl in a pink shirt jumps high over the grass.', 'hypothesis': 'A girl jumps.', 'label': 0, 'explanation_1': 'High over the grass are descriptions of what she is doing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A little boy with a blue shirt on sitting on the ground playing with legos.', 'hypothesis': 'A boy is playing with toys.', 'label': 0, 'explanation_1': 'The toys he is playing with are legos.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A little boy with a blue shirt on sitting on the ground playing with legos.', 'hypothesis': 'A boy is playing with toys.', 'label': 0, 'explanation_1': 'Legos are toys.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man on a snowboard travels downhill towards the camera.', 'hypothesis': 'A man is snowboarding.', 'label': 0, 'explanation_1': 'Being on a snowboard implies he is snowboarding.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man on a snowboard travels downhill towards the camera.', 'hypothesis': 'A man is snowboarding.', 'label': 0, 'explanation_1': 'One on a snowboard is snowboarding.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man sits alone on a bench.', 'hypothesis': 'The man is standing.', 'label': 2, 'explanation_1': 'The man who sits on the back cannot be standing at the same time.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man sits alone on a bench.', 'hypothesis': 'The man is standing.', 'label': 2, 'explanation_1': 'A man cannot be both sitting and standing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'An Asian boy stepping on a stone next to a brick building.', 'hypothesis': 'The boy is outside.', 'label': 0, 'explanation_1': 'A person must be outside in order to be next to a brick building.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'An Asian boy stepping on a stone next to a brick building.', 'hypothesis': 'The boy is outside.', 'label': 0, 'explanation_1': 'A brick building is outside.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man in a big black coat and hat walks down the street.', 'hypothesis': 'A man walks down the street.', 'label': 0, 'explanation_1': 'If a man walks down the street then a man walks down the street.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man in a big black coat and hat walks down the street.', 'hypothesis': 'A man walks down the street.', 'label': 0, 'explanation_1': 'man in a big black coat and hat walks down the street is the same as man walks down the street.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A large brown and a small white dog play indoors on a carpet.', 'hypothesis': 'Two dogs are playing inside.', 'label': 0, 'explanation_1': 'A "large brown and a small white dog" is rephrasing "dogs" and "playing inside" is a rephrasing of "play indoors on a carpet."', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A large brown and a small white dog play indoors on a carpet.', 'hypothesis': 'Two dogs are playing inside.', 'label': 0, 'explanation_1': 'A "large brown and a small white dog" is rephrasing "dogs" and "playing inside" is a rephrasing of "play indoors on a carpet."', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Two foreign women, both wearing black, selling different types of foods.', 'hypothesis': 'Two women are selling food.', 'label': 0, 'explanation_1': 'Two women are selling food is the same as two women selling food.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Two foreign women, both wearing black, selling different types of foods.', 'hypothesis': 'Two women are selling food.', 'label': 0, 'explanation_1': 'Two women are selling food is the same as two women selling food.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A bald dark-skinned man in a purple tank top and jeans works with another man next to a blue bucket.', 'hypothesis': 'Two men are working together.', 'label': 0, 'explanation_1': 'THEY WORK TOGETHER WHEN WORKING.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A bald dark-skinned man in a purple tank top and jeans works with another man next to a blue bucket.', 'hypothesis': 'Two men are working together.', 'label': 0, 'explanation_1': 'THEY ARE WORKING.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'An attractive girl with a cigarette in one hand leaning over and showing lots of cleavage.', 'hypothesis': 'A girl is holding a cigarette.', 'label': 0, 'explanation_1': 'Holding something is done in one hand.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'An attractive girl with a cigarette in one hand leaning over and showing lots of cleavage.', 'hypothesis': 'A girl is holding a cigarette.', 'label': 0, 'explanation_1': 'Holding something is done in one hand.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Two race cars speed around a track.', 'hypothesis': 'Cars go around a track.', 'label': 0, 'explanation_1': 'rACE CARS SPEED ON THE TRACK.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Two race cars speed around a track.', 'hypothesis': 'Cars go around a track.', 'label': 0, 'explanation_1': 'Race cars go around a track..', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'An older man wearing a black jacket standing outside.', 'hypothesis': 'A man stands outside.', 'label': 0, 'explanation_1': 'The older man standing outside is the man who stands outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'An older man wearing a black jacket standing outside.', 'hypothesis': 'A man stands outside.', 'label': 0, 'explanation_1': 'The older man standing outside is the man who stands outside.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A black dog walks on the beach near the rocks.', 'hypothesis': 'A black dog walks on the beach near the rocks.', 'label': 0, 'explanation_1': 'THEY ARE BY THE ROCKS.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A black dog walks on the beach near the rocks.', 'hypothesis': 'A black dog walks on the beach near the rocks.', 'label': 1, 'explanation_1': 'The sentences are the same', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'An asian man giving a speech.', 'hypothesis': 'A man gives a speech.', 'label': 0, 'explanation_1': 'Giving a speech and gives a speech are the same thing.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'An asian man giving a speech.', 'hypothesis': 'A man gives a speech.', 'label': 0, 'explanation_1': 'Gives and giving mean the same thing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Three men and a small boy work on a green model train outside.', 'hypothesis': 'Four people are working together.', 'label': 0, 'explanation_1': 'People work on a train must mean that they are working together.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Three men and a small boy work on a green model train outside.', 'hypothesis': 'Four people are working together.', 'label': 0, 'explanation_1': 'Three men and a small boyworking on one model train implies they are working together.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man in work clothes is holding a chain.', 'hypothesis': 'A man is holding a chain.', 'label': 0, 'explanation_1': 'A man holding a chain is  a restatement of a man in work clothes holding a chain.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man in work clothes is holding a chain.', 'hypothesis': 'A man is holding a chain.', 'label': 0, 'explanation_1': 'A man holding a chain is  a restatement of a man in work clothes holding a chain.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'The teddy bear has white pads on the bottom of its feet.', 'hypothesis': 'The teddy bear has no feet.', 'label': 2, 'explanation_1': 'If a teddy beat has no feet it is impossible that the bear has white pads on the bottom of its feet.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'The teddy bear has white pads on the bottom of its feet.', 'hypothesis': 'The teddy bear has no feet.', 'label': 2, 'explanation_1': 'If a teddy beat has no feet it is impossible that the bear has white pads on the bottom of its feet.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Two girls stand in a puddle on a sidewalk.', 'hypothesis': 'Two girls are outside.', 'label': 0, 'explanation_1': 'PUDDLES ON  A SIDEWALK ARE OUTSIDE.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Two girls stand in a puddle on a sidewalk.', 'hypothesis': 'Two girls are outside.', 'label': 0, 'explanation_1': 'PUDDLES ON SIDEWALKS ARE OUTSIDE.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': '4 women laughing at a table with food on it while sitting on an orange seat', 'hypothesis': 'The women are friends.', 'label': 1, 'explanation_1': 'Laughing gathered people does not infer that they are friends.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': '4 women laughing at a table with food on it while sitting on an orange seat', 'hypothesis': 'The women are friends.', 'label': 1, 'explanation_1': 'Not all laughing women are friends.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman wearing a scarf covering her head and a long dress shops for vegetables at an open air market.', 'hypothesis': "A woman shops at the farmer's market.", 'label': 1, 'explanation_1': "Just because it's an open air market, doesn't mean it's a farmer's market.", 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman wearing a scarf covering her head and a long dress shops for vegetables at an open air market.', 'hypothesis': "A woman shops at the farmer's market.", 'label': 1, 'explanation_1': "Just because it's an open air market, doesn't mean it's a farmer's market.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman wearing a scarf covering her head and a long dress shops for vegetables at an open air market.', 'hypothesis': 'A boy plants flowers.', 'label': 2, 'explanation_1': 'They refer to a woman, not a boy.  The person shops for vegetables, not plants flowers.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman wearing a scarf covering her head and a long dress shops for vegetables at an open air market.', 'hypothesis': 'A boy plants flowers.', 'label': 2, 'explanation_1': 'They refer to a woman, not a boy.  The person shops for vegetables, not plants flowers.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman wearing a scarf covering her head and a long dress shops for vegetables at an open air market.', 'hypothesis': 'A woman shops for veggies outside.', 'label': 0, 'explanation_1': 'open air market is outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman wearing a scarf covering her head and a long dress shops for vegetables at an open air market.', 'hypothesis': 'A woman shops for veggies outside.', 'label': 0, 'explanation_1': 'open air market is outside.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A happy woman in a brown hat and green vest is taking a picture of a horse.', 'hypothesis': 'A woman takes a picture of a horse.', 'label': 0, 'explanation_1': '"Takes a picture of" is a rephrasing of "is taking a picture of".', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A happy woman in a brown hat and green vest is taking a picture of a horse.', 'hypothesis': 'A woman takes a picture of a horse.', 'label': 0, 'explanation_1': 'A happy woman is taking a picture of a horse.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Three people are walking down a dirt path.', 'hypothesis': 'Three people are walking outdoors.', 'label': 0, 'explanation_1': 'A dirt path is outdoors.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Three people are walking down a dirt path.', 'hypothesis': 'Three people are walking outdoors.', 'label': 0, 'explanation_1': 'A dirt path is outdoors.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'She is playing tennis with her blue tennis clothes on, it looks hot out there.', 'hypothesis': 'She is playing tennis with her blue tennis clothes on, it looks hot out there.', 'label': 0, 'explanation_1': 'She is playing tennis with her blue tennis clothes on, it looks hot out there is the same as she is playing tennis with her blue tennis clothes on, it looks hot out there.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'She is playing tennis with her blue tennis clothes on, it looks hot out there.', 'hypothesis': 'She is playing tennis with her blue tennis clothes on, it looks hot out there.', 'label': 1, 'explanation_1': 'How hot the weather looks cannot be inferred from how she is dressed.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A blue-eyed woman with red-hair and glasses looks up at the camera while holding a hamburger with a bite out of it, as she sits on a boat with four other young people who are drinking and eating.', 'hypothesis': 'The woman is eating a hamburger.', 'label': 0, 'explanation_1': 'A woman has been eating a hamburger if the hamburger has a bite out of it.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A blue-eyed woman with red-hair and glasses looks up at the camera while holding a hamburger with a bite out of it, as she sits on a boat with four other young people who are drinking and eating.', 'hypothesis': 'The woman is eating a hamburger.', 'label': 0, 'explanation_1': 'hamburger with a bite out of it means that she has taken a bite, and is eating a hamburger.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'a man walking down an alleyway', 'hypothesis': 'A man is walking.', 'label': 1, 'explanation_1': 'We actually do know that the man is walking. That statement can be inferred.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'a man walking down an alleyway', 'hypothesis': 'A man is walking.', 'label': 0, 'explanation_1': 'Walking down an alleyway is the same as walking.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman walks up a path that cuts through cultivated plots while balancing straw on her head.', 'hypothesis': 'The woman is outdoors.', 'label': 0, 'explanation_1': 'A woman walks up a path is the same as being outdoors.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman walks up a path that cuts through cultivated plots while balancing straw on her head.', 'hypothesis': 'The woman is outdoors.', 'label': 0, 'explanation_1': 'A woman walks up a path is the same as being outdoors.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Six people in a boat floating in the water.', 'hypothesis': 'People are in a boat.', 'label': 0, 'explanation_1': 'For people to be floating in the water, they must be in a boat.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Six people in a boat floating in the water.', 'hypothesis': 'People are in a boat.', 'label': 0, 'explanation_1': 'For people to float on the water they must be in a boat.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman in a blue blouse leans over a pool table with her cue in hand and an eight ball on the table.', 'hypothesis': 'A woman is playing pool.', 'label': 0, 'explanation_1': 'A woman is playing pool, which means that at some point, she will lean over the pool table.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman in a blue blouse leans over a pool table with her cue in hand and an eight ball on the table.', 'hypothesis': 'A woman is playing pool.', 'label': 0, 'explanation_1': 'The woman is playing pool, which means that she would need to have her cue in hand.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A young woman is playing pool.', 'hypothesis': 'A woman is playing pool.', 'label': 0, 'explanation_1': 'The woman who is playing pool is a young woman.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A young woman is playing pool.', 'hypothesis': 'A woman is playing pool.', 'label': 0, 'explanation_1': 'The woman playing pool is a young woman.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A guy in an olive-green sweater and blue jeans is playing with a blond-haired toddler in a yard using toy golf clubs.', 'hypothesis': 'A man and child are playing outside.', 'label': 0, 'explanation_1': 'Man is a synonym for guy and child is a synonym for toddler.  Yards are outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A guy in an olive-green sweater and blue jeans is playing with a blond-haired toddler in a yard using toy golf clubs.', 'hypothesis': 'A man and child are playing outside.', 'label': 0, 'explanation_1': 'It follows that the yard is outside.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman from India origin standing while making yarn.', 'hypothesis': 'A woman is making yarn.', 'label': 0, 'explanation_1': 'The woman from India origin is making yarn while standing.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman from India origin standing while making yarn.', 'hypothesis': 'A woman is making yarn.', 'label': 0, 'explanation_1': 'The woman making yarn is implied she is standing well doing so.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Guys are running in a marathon.', 'hypothesis': 'Guys are running.', 'label': 0, 'explanation_1': 'Guys are running which is what you do in a marathon.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Guys are running in a marathon.', 'hypothesis': 'Guys are running.', 'label': 0, 'explanation_1': 'If guys are runnign in a marathon then they obviously are running.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman with a brown coat and a woman with a black top stand along displays of oranges, apples, and other fruits.', 'hypothesis': 'Two women stand near displays of fruit.', 'label': 0, 'explanation_1': 'the two woman are standing along the displays is the same as them standing near one.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman with a brown coat and a woman with a black top stand along displays of oranges, apples, and other fruits.', 'hypothesis': 'Two women stand near displays of fruit.', 'label': 0, 'explanation_1': 'the woman with a brown coat and the one with the black top is the same as stating two women.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A dog running with something in its mouth', 'hypothesis': 'A dog is running.', 'label': 0, 'explanation_1': 'Dogs usually run when they have something in their mouth', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A dog running with something in its mouth', 'hypothesis': 'A dog is running.', 'label': 0, 'explanation_1': 'Dogs usually run when they have something in their mouth', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A New York Yankee holds up a bat.', 'hypothesis': 'A baseball player is holding his bat.', 'label': 0, 'explanation_1': 'A New York Yankee holding his bat is a specific description of a baseball player holding his bat.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A New York Yankee holds up a bat.', 'hypothesis': 'A baseball player is holding his bat.', 'label': 0, 'explanation_1': 'One who holds a bat must be a player.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'There is a crowd of people at an outdoor station including some men in hard hats and safety jackets.', 'hypothesis': 'The people are indoors.', 'label': 2, 'explanation_1': 'If people are at an outdoor station, they are not indoors.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'There is a crowd of people at an outdoor station including some men in hard hats and safety jackets.', 'hypothesis': 'The people are indoors.', 'label': 2, 'explanation_1': 'One can not indoors while they are at an outdoor station.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman wearing a red tank top is cutting a hamburger in half.', 'hypothesis': 'A woman is cutting some food.', 'label': 0, 'explanation_1': 'A woman is cutting a hamburger for food.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman wearing a red tank top is cutting a hamburger in half.', 'hypothesis': 'A woman is cutting some food.', 'label': 0, 'explanation_1': 'A woman is cutting a hamburger to eat.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Dour baseball players in a field, one is touching the ball to the ground and one is sliding past a base.', 'hypothesis': 'People are playing baseball.', 'label': 0, 'explanation_1': 'Baseball players are people.  Baseball players play baseball.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Dour baseball players in a field, one is touching the ball to the ground and one is sliding past a base.', 'hypothesis': 'People are playing baseball.', 'label': 0, 'explanation_1': 'Baseball players play baseball.  Baseball players are people.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Woman wearing black and kneeling on rollerskates with deer face antlers on top of her helmet.', 'hypothesis': 'Woman riding a snowboard down a mountain, as it snows heavily.', 'label': 2, 'explanation_1': 'A woman cannot ride a snowboard and kneel on rollerskates at the same time.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Woman wearing black and kneeling on rollerskates with deer face antlers on top of her helmet.', 'hypothesis': 'Woman riding a snowboard down a mountain, as it snows heavily.', 'label': 2, 'explanation_1': "Antlers are not on a deer's face. You do not kneel on rollerskates. You cannot be using rollerskates and a snowboard at the same time.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Woman wearing black and kneeling on rollerskates with deer face antlers on top of her helmet.', 'hypothesis': 'Woman in black kneeling on rollerskates.', 'label': 0, 'explanation_1': 'The woman is wearing black.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Woman wearing black and kneeling on rollerskates with deer face antlers on top of her helmet.', 'hypothesis': 'Woman in black kneeling on rollerskates.', 'label': 0, 'explanation_1': 'If a woman is in black, she is wearing black.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Woman wearing black and kneeling on rollerskates with deer face antlers on top of her helmet.', 'hypothesis': 'Woman in black kneeling at a skating rink, wearing rollerskates.', 'label': 1, 'explanation_1': 'Just because a woman is wearing rollerskates it does not mean she is at a skating rink.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Woman wearing black and kneeling on rollerskates with deer face antlers on top of her helmet.', 'hypothesis': 'Woman in black kneeling at a skating rink, wearing rollerskates.', 'label': 1, 'explanation_1': 'You can not infer she is wearing rollerskates.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A person stands in a vast field of glacial ice.', 'hypothesis': 'A person is standing outside.', 'label': 0, 'explanation_1': 'The field of glacial ice would have to be outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A person stands in a vast field of glacial ice.', 'hypothesis': 'A person is standing outside.', 'label': 0, 'explanation_1': 'A person needs to be outside to stand on glacial ice.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A bunch of birds outside of a building.', 'hypothesis': 'The birds are outside.', 'label': 0, 'explanation_1': '"Outside" is a less detailed restatement of "outside a building".', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A bunch of birds outside of a building.', 'hypothesis': 'The birds are outside.', 'label': 0, 'explanation_1': 'Birds and a bunch of birds are synonyms.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A group of young African American kids sitting on a white wall in front of a white building.', 'hypothesis': 'A group of kids are outside.', 'label': 0, 'explanation_1': 'If the group of kids are sitting on a white wall in front of a white building, they are sitting outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A group of young African American kids sitting on a white wall in front of a white building.', 'hypothesis': 'A group of kids are outside.', 'label': 0, 'explanation_1': 'young African American kids looking at outside building.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Three young musician in a band performing by female singing and two males playing guitars.', 'hypothesis': 'A band with a female and two males performe a concert.', 'label': 1, 'explanation_1': 'Musicians perform at other places than just concert s.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Three young musician in a band performing by female singing and two males playing guitars.', 'hypothesis': 'A band with a female and two males performe a concert.', 'label': 1, 'explanation_1': 'Musicians perform at other places than just concert s.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Three young musician in a band performing by female singing and two males playing guitars.', 'hypothesis': 'A group of people perform music.', 'label': 0, 'explanation_1': 'The numbers of people, female, and male usually imply more than one person and thus a group of people.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Three young musician in a band performing by female singing and two males playing guitars.', 'hypothesis': 'A group of people perform music.', 'label': 0, 'explanation_1': 'The numbers of people, female, and male usually imply more than one person and thus a group of people.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Three young musician in a band performing by female singing and two males playing guitars.', 'hypothesis': 'a group of people go swiming.', 'label': 2, 'explanation_1': 'Swimming and performing are different.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Three young musician in a band performing by female singing and two males playing guitars.', 'hypothesis': 'a group of people go swiming.', 'label': 2, 'explanation_1': 'Swimming is different than performing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A boy in a red soccer strip is holding his boots in his hand whilst stepping out of a car.', 'hypothesis': 'A boy is stepping out of a car.', 'label': 0, 'explanation_1': '"A boy stepping out of a car" is the same as "a boy is stepping out of a car".', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A boy in a red soccer strip is holding his boots in his hand whilst stepping out of a car.', 'hypothesis': 'A boy is stepping out of a car.', 'label': 0, 'explanation_1': '"A boy stepping out of a car" is the same as "a boy is stepping out of a car".', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A boy wearing a bike helmet, jeans, and a striped shirt and a girl wearing a green shirt and jeans ride bikes with training wheels down a sidewalk.', 'hypothesis': 'Two people are riding bikes.', 'label': 0, 'explanation_1': 'Riding bikes is rephrasing of ride bikes.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A boy wearing a bike helmet, jeans, and a striped shirt and a girl wearing a green shirt and jeans ride bikes with training wheels down a sidewalk.', 'hypothesis': 'Two people are riding bikes.', 'label': 0, 'explanation_1': 'Riding bikes is rephrasing of ride bikes.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': "Two people with black pants are holding on to the basket of a hot air balloon that's on the snow.", 'hypothesis': 'the pants are in the washing machine', 'label': 2, 'explanation_1': "The people can't be wearing the pants if they are in the washing machine.", 'explanation_2': '', 'explanation_3': ''}
# {'premise': "Two people with black pants are holding on to the basket of a hot air balloon that's on the snow.", 'hypothesis': 'the pants are in the washing machine', 'label': 2, 'explanation_1': "The two people can't be wearing the pants if they are in the washing machine.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': "Two people with black pants are holding on to the basket of a hot air balloon that's on the snow.", 'hypothesis': 'two black pants are outside', 'label': 0, 'explanation_1': 'People wearing black pants while holding on to an air balloon that is in the snow implies that the pants are outside since the pants are on the people and the people are implied to be outside.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': "Two people with black pants are holding on to the basket of a hot air balloon that's on the snow.", 'hypothesis': 'two black pants are outside', 'label': 0, 'explanation_1': 'If people are wearing black pants on the snow it is implied that the people are outside and therefor the pants are also.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': "Two people with black pants are holding on to the basket of a hot air balloon that's on the snow.", 'hypothesis': 'the pants are versace', 'label': 1, 'explanation_1': 'Not all black pants are versace.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': "Two people with black pants are holding on to the basket of a hot air balloon that's on the snow.", 'hypothesis': 'the pants are versace', 'label': 1, 'explanation_1': 'All black pants are not versace.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man in a blue shirt is taking a picture.', 'hypothesis': 'A man is taking a picture.', 'label': 0, 'explanation_1': '"A man is taking a picture," is rephrasing "A man in a blue shirt is taking a picture."', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man in a blue shirt is taking a picture.', 'hypothesis': 'A man is taking a picture.', 'label': 0, 'explanation_1': 'A man wearing a shirts taking a picture', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man in a blue shirt is taking a picture.', 'hypothesis': 'A man is taking a picture.', 'label': 0, 'explanation_1': '"A man is taking a picture," is rephrasing "A man in a blue shirt is taking a picture."', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man in a blue shirt is taking a picture.', 'hypothesis': 'A man is taking a picture.', 'label': 0, 'explanation_1': 'A man wearing a shirts taking a picture', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'The pain job on this craft is pleasing to the eye.', 'hypothesis': 'The craft is painted.', 'label': 0, 'explanation_1': 'Having a paint job is being painted.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'The pain job on this craft is pleasing to the eye.', 'hypothesis': 'The craft is painted.', 'label': 0, 'explanation_1': 'If the craft has a paint job then it is painted.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A boy with blue face paint sucks his thumb.', 'hypothesis': 'A boy with blue face paint sucks his thumb.', 'label': 2, 'explanation_1': 'Both paint sucks their thumb. The sentence does not contradict.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A boy with blue face paint sucks his thumb.', 'hypothesis': 'A boy with blue face paint sucks his thumb.', 'label': 1, 'explanation_1': "They're the exact same sentence. A boy with blue face paint sucks his thumb.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A boy with blue face paint sucks his thumb.', 'hypothesis': 'A boy with blue face paint sucks his thumb.', 'label': 0, 'explanation_1': 'If the boy with blue face paint sucks his thumb the he sucks his thumb.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A boy with blue face paint sucks his thumb.', 'hypothesis': 'A boy with blue face paint sucks his thumb.', 'label': 1, 'explanation_1': "They're the exact same sentence. A boy with blue face paint sucks his thumb.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A person is flying through the air attached to a board with a parachute.', 'hypothesis': 'A person is in the air.', 'label': 0, 'explanation_1': 'If a person is flying through the air then the person is in the air.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A person is flying through the air attached to a board with a parachute.', 'hypothesis': 'A person is in the air.', 'label': 0, 'explanation_1': 'A person flying through the air indicates that the person is in the air.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man with black hair is wearing a red and yellow shirt and has a yellow clown nose and face makeup on.', 'hypothesis': 'A man is dressed as a clown.', 'label': 0, 'explanation_1': 'The red and yellow shirt, yellow clown nose and face makeup are descriptive words in the first sentence that are attributes of the man being dressed as a clown.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man with black hair is wearing a red and yellow shirt and has a yellow clown nose and face makeup on.', 'hypothesis': 'A man is dressed as a clown.', 'label': 1, 'explanation_1': "Just because a man is wearing a red and yellow shirt doesn't necessarily imply he is dressed as a clown.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A person is jumping up in the woods, they are wearing a red sweater and yellow pants, they are surrounded by trees and leaves.', 'hypothesis': 'A person is jumping in the woods.', 'label': 0, 'explanation_1': 'Jumping usually involves jumping up.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A person is jumping up in the woods, they are wearing a red sweater and yellow pants, they are surrounded by trees and leaves.', 'hypothesis': 'A person is jumping in the woods.', 'label': 0, 'explanation_1': 'Jumping usually involves jumping up.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'a group of backpackers preparing for their trek.', 'hypothesis': 'a group of backpackers preparing for their trek.', 'label': 1, 'explanation_1': 'A group of backpackers preparing for their trek is the same as a group of backpackers preparing for their trek.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'a group of backpackers preparing for their trek.', 'hypothesis': 'a group of backpackers preparing for their trek.', 'label': 0, 'explanation_1': 'The two phrases are identical, preparing for their trek, so, nothing to explain', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'The fan is spinning.', 'hypothesis': 'The fan is moving.', 'label': 0, 'explanation_1': 'Moving is a higher-level description of spinning.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'The fan is spinning.', 'hypothesis': 'The fan is moving.', 'label': 0, 'explanation_1': 'Moving is a higher-level description of spinning.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'The airplane is being photographed from above.', 'hypothesis': 'The airplane is being photographed.', 'label': 0, 'explanation_1': 'A picture is taken of an airplane.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'The airplane is being photographed from above.', 'hypothesis': 'The airplane is being photographed.', 'label': 0, 'explanation_1': 'Being photographed is a rephrasing of being photographed from above.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A boy is playing in a room full of balls.', 'hypothesis': 'A boy is playing with balls.', 'label': 0, 'explanation_1': 'Playing with balls could mean that the boy is in a room full of balls.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A boy is playing in a room full of balls.', 'hypothesis': 'A boy is playing with balls.', 'label': 0, 'explanation_1': 'Balls are used for playing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A child in blue jeans with the cuffs rolled up and black socks taking a nap under a plum-colored covering decorated with large white concentric circles.', 'hypothesis': 'A child is sleeping.', 'label': 0, 'explanation_1': 'If the child is taking a nap, it is sleeping.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A child in blue jeans with the cuffs rolled up and black socks taking a nap under a plum-colored covering decorated with large white concentric circles.', 'hypothesis': 'A child is sleeping.', 'label': 0, 'explanation_1': 'Sleeping is the same as taking a nap.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A child in blue jeans with the cuffs rolled up and black socks taking a nap under a plum-colored covering decorated with large white concentric circles.', 'hypothesis': 'A child is sleeping.', 'label': 0, 'explanation_1': 'If the child is taking a nap, it is sleeping.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A child in blue jeans with the cuffs rolled up and black socks taking a nap under a plum-colored covering decorated with large white concentric circles.', 'hypothesis': 'A child is sleeping.', 'label': 0, 'explanation_1': 'Sleeping is the same as taking a nap.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Six men shielding their eyes from the sun', 'hypothesis': 'Men are shielding their eyes.', 'label': 0, 'explanation_1': 'SIX PEOPLE CAN BE MEN.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Six men shielding their eyes from the sun', 'hypothesis': 'Men are shielding their eyes.', 'label': 0, 'explanation_1': 'PEOPLE NEED TO BE SHIELDING THEIR EYES FROM THE SUN.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'The field is fenced in.', 'hypothesis': 'There is a fence around the field.', 'label': 0, 'explanation_1': 'Field is fenced in is same as a fence around the field.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'The field is fenced in.', 'hypothesis': 'There is a fence around the field.', 'label': 0, 'explanation_1': 'Field is fenced in is same as a fence around the field.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'An Asian girl wearing a white leotard and white stockings stands on her tiptoes as she dances ballet.', 'hypothesis': 'A girl is doing ballet.', 'label': 0, 'explanation_1': 'Doing ballet is another way to say dances ballet.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'An Asian girl wearing a white leotard and white stockings stands on her tiptoes as she dances ballet.', 'hypothesis': 'A girl is doing ballet.', 'label': 0, 'explanation_1': 'Doing ballet is another way to say dances ballet.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Men shovel snow while wearing shorts.', 'hypothesis': 'The men are shoveling sand.', 'label': 2, 'explanation_1': 'The men are shoveling snow, which means they cannot be shoveling sand.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Men shovel snow while wearing shorts.', 'hypothesis': 'The men are shoveling sand.', 'label': 2, 'explanation_1': 'The men are shoveling snow, which means they cannot be shoveling sand.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A
', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Two people are standing near a curb outside a store.', 'hypothesis': 'Two people are standing outside.', 'label': 0, 'explanation_1': 'two people are standing outside is the same as two people are standing outside', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Two people are standing near a curb outside a store.', 'hypothesis': 'Two people are standing outside.', 'label': 0, 'explanation_1': 'two people are standing outside is the same as two people are standing outside', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A policeman is shown working a block party.', 'hypothesis': 'The policeman is testifying in court.', 'label': 2, 'explanation_1': 'One cant be testifying in court and working a party simultaneously.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A policeman is shown working a block party.', 'hypothesis': 'The policeman is testifying in court.', 'label': 2, 'explanation_1': 'One can not be testifying in court and working a party simultaneously.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman standing outside on a sunny day looking at something wearing blue jeans and sandals and a tank top.', 'hypothesis': 'A woman stands outside.', 'label': 0, 'explanation_1': 'in a both sentence standing and outside are not same.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman standing outside on a sunny day looking at something wearing blue jeans and sandals and a tank top.', 'hypothesis': 'A woman stands outside.', 'label': 0, 'explanation_1': 'Stands outside is just rephrasing standing outside.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Boys are selling flowers, drinks, mugs, and other items on the sidewalk.', 'hypothesis': 'Boys are selling flowers.', 'label': 0, 'explanation_1': 'Selling flowers on the sidewalk is a way of selling flowers.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Boys are selling flowers, drinks, mugs, and other items on the sidewalk.', 'hypothesis': 'Boys are selling flowers.', 'label': 0, 'explanation_1': 'Flowers is one of the items the boys are selling', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Man dressed in drag pointing at his open mouth.', 'hypothesis': 'A man is dressed in drag.', 'label': 0, 'explanation_1': 'A man is dressed in drag is a simple form of sentence 1', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Man dressed in drag pointing at his open mouth.', 'hypothesis': 'A man is dressed in drag.', 'label': 0, 'explanation_1': 'drag pointing at his open mouth shows that drag', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow.', 'hypothesis': 'A kid bounces off a a yellow inflatable thing.', 'label': 1, 'explanation_1': 'Something big and yellow that child bouncing into air is not necessarily inflatable thing.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow.', 'hypothesis': 'A kid bounces off a a yellow inflatable thing.', 'label': 1, 'explanation_1': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow does not indicate that a kid bounces off a a yellow inflatable thing.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow.', 'hypothesis': 'A kid in a life jacket has been bounced by a yellow thing.', 'label': 0, 'explanation_1': 'BY BEING BOUNCED YOU WOULD GO INTO THE AIR.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow.', 'hypothesis': 'A kid in a life jacket has been bounced by a yellow thing.', 'label': 0, 'explanation_1': 'THE YELLOW THING HE IS JUMPING ON IS SOMETHING BIG.  HIS LIFE JACKET IS WHITE, RED AND BLACK.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow.', 'hypothesis': 'A kid is sitting in math class.', 'label': 2, 'explanation_1': 'If a child is bounced into the air by something it is unlikely that they are sitting in class.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A child wearing a white, red, and black life jacket was bounced into the air by something big and yellow.', 'hypothesis': 'A kid is sitting in math class.', 'label': 2, 'explanation_1': 'If a child is bounced into the air by something it is unlikely that they are sitting in class.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A person approaches a escalator while holding a bag.', 'hypothesis': 'A person approaches a escalator while holding a bag.', 'label': 1, 'explanation_1': 'You can not infer they are holding a bag.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A person approaches a escalator while holding a bag.', 'hypothesis': 'A person approaches a escalator while holding a bag.', 'label': 0, 'explanation_1': 'Zero effort.  Tautological.  Quite obviously, a person approaches a[n] escalator while holding a bag.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.', 'hypothesis': 'Two men wearing orange jumpsuits are working on the chain gang, cleaning the streets.', 'label': 2, 'explanation_1': 'The woman cannot be men.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.', 'hypothesis': 'Two men wearing orange jumpsuits are working on the chain gang, cleaning the streets.', 'label': 2, 'explanation_1': 'The woman cannot be men.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.', 'hypothesis': 'A woman is helping a man.', 'label': 0, 'explanation_1': 'A woman is helping a man despite the extra detail that we are given.', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.', 'hypothesis': 'A woman is helping a man.', 'label': 0, 'explanation_1': 'A woman is helping a man is the point of the sentence despite the extra detail that we are given.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.', 'hypothesis': 'A woman working for the city is helping a coworker clean the streets.', 'label': 1, 'explanation_1': "sweep doesn't always mean the streets.", 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A woman in orange work clothes next to a large blue trashcan is helping a man sweep some dirt and water into a dustpan.', 'hypothesis': 'A woman working for the city is helping a coworker clean the streets.', 'label': 1, 'explanation_1': "The fact that the woman is in orange work clothes does not mean that she is working for the city, and just because she is helping the man does not mean that she is the man's coworker.", 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A man kicks up dust on as he rides a four-wheeler, with a crystal blue sky in the background.', 'hypothesis': 'A man is riding a four-wheeler.', 'label': 0, 'explanation_1': 'man rides a four-wheeler is same as man is riding a four-wheeler', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'A man kicks up dust on as he rides a four-wheeler, with a crystal blue sky in the background.', 'hypothesis': 'A man is riding a four-wheeler.', 'label': 0, 'explanation_1': 'someone who rides a four-wheeler is riding a four-wheeler.', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'Group of children playing soccer with body of water in the background.', 'hypothesis': 'Kids are playing soccer.', 'label': 0, 'explanation_1': 'Group of children playing soccer simply means kids are playing soccer', 'explanation_2': '', 'explanation_3': ''}
# {'premise': 'Group of children playing soccer with body of water in the background.', 'hypothesis': 'Kids are playing soccer.', 'label': 0, 'explanation_1': 'kids is a synonym of children', 'explanation_2': '', 'explanation_3': ''}
# *****

# %%
for da in dataset['validation']:
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str not in all_data_dict.keys():
        all_data_dict[key_str] = da
    else:
        print("*****")
        print(da)
        print(all_data_dict[key_str])
        print("*****")
# Out:
# *****
# {'premise': 'A person is surfing on a large wave.', 'hypothesis': 'A person is surfing.', 'label': 0, 'explanation_1': 'There are both a person surfing in the scene.', 'explanation_2': 'Surfing on a large wave is a type of surfing.', 'explanation_3': 'A person surfing on a large wave, is surfing.'}
# {'premise': 'A person is surfing on a large wave.', 'hypothesis': 'A person is surfing.', 'label': 0, 'explanation_1': 'person is surfing simply means person is surfing', 'explanation_2': '', 'explanation_3': ''}
# *****
# *****
# {'premise': 'A dog carrying a stick in its mouth runs through a snow-covered field.', 'hypothesis': 'A animal carried a stick through a snow covered field.', 'label': 0, 'explanation_1': 'A dog is an animal.', 'explanation_2': 'Dog is animal, and carried a stick implies in its mouth.', 'explanation_3': 'a dog is an animal'}
# {'premise': 'A dog carrying a stick in its mouth runs through a snow-covered field.', 'hypothesis': 'A animal carried a stick through a snow covered field.', 'label': 0, 'explanation_1': 'A dog is an animal.', 'explanation_2': '"A animal carried a stick through a snow covered field" is a less detailed rephrasing of "A dog carrying a stick in its mouth runs through a snow-covered field".', 'explanation_3': 'The  animal is a dog who is carrying a stick in its mouth through a snow covered field.'}
# *****
# *****
# {'premise': 'A lone, 2-3 year old blond child in a blue jacket is putting a small black plastic item in his mouth as he kneels on a waiting room couch pointed toward the back while looking at something or someone not in the room.', 'hypothesis': 'The child is blonde.', 'label': 0, 'explanation_1': 'The child is blonde must be a blond child.', 'explanation_2': 'Blond child means child is blond', 'explanation_3': 'A child is looking cute in blue jacket'}
# {'premise': 'A lone, 2-3 year old blond child in a blue jacket is putting a small black plastic item in his mouth as he kneels on a waiting room couch pointed toward the back while looking at something or someone not in the room.', 'hypothesis': 'The child is blonde.', 'label': 0, 'explanation_1': 'A blond child is blonde.', 'explanation_2': 'A 2-3 year old blond child means the child is blonde.', 'explanation_3': 'A 2-3 year old blond child means there is a presence of the child in blonde as part of the total description.'}
# *****

# %%
for da in dataset['test']:
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str not in all_data_dict.keys():
        all_data_dict[key_str] = da
    else:
        print("*****")
        print(da)
        print(all_data_dict[key_str])
        print("*****")

# %%
len(all_data_dict), len(dataset['train']) + len(dataset['validation'])+ len(dataset['test'])
# Out:
# (568404, 569033)

# %%
#rationale generation labeled data construction 115
import pandas as pd
scr_csqa_labeled_path="/cognitive_comp/huangyongfeng/evaluate_LM_with_rationalization/few_shot_explanations/data/handwritten_snli_examples.csv"
scr_csqa_label_df=pd.read_csv(scr_csqa_labeled_path)
scr_csqa_label_data=datasets.load_dataset('csv', data_files=scr_csqa_labeled_path)
scr_csqa_label_data['train'][0].keys()

refine_train_data=[]
for da in scr_csqa_label_data['train']:
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str in all_data_dict.keys():
        new_da=all_data_dict[key_str]
        new_da['our_explanation'] = da['our_explanation']
        refine_train_data.append(new_da)
        
    
# for kk, (ex,da) in enumerate(zip(scr_csqa_label_data, data_splits['train'])):
# #     print(da)
#     data_splits['train'][kk]['our_explanation']=ex
#     #print(type(data_splits['train'][kk]),data_splits['train'][kk].keys())
#     da['our_explanation']=ex
#     refine_train_data.append(da)

# len(data_splits['train'])
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#rationale unlabeled data construction 991
import pdb
scr_csqa_unlabeled_test_file="/cognitive_comp/huangyongfeng/evaluate_LM_with_rationalization/few_shot_explanations/data/acceptability_annotations/snli_train.csv"
fse_csqa_dev_dataset = datasets.load_dataset('csv', data_files=scr_csqa_unlabeled_test_file)
scr_csqa_unlabeled_test_df=pd.read_csv(scr_csqa_unlabeled_test_file)
fse_csqa_dev_data_dict={}
for kk, da in enumerate(fse_csqa_dev_dataset['train']):
    #pdb.set_trace()
    id_=da['Input.id']
    if da['Answer.acceptable']:
        answer_accept=set(da['Answer.acceptable'].split('|'))
    else:
        answer_accept=set()
    explanation_list=[da['Input.explanation_1'], 
                      da['Input.explanation_2'],
                      da['Input.explanation_3'],
                      da['Input.explanation_4'],
                      da['Input.explanation_5']]
    if id_ not in fse_csqa_dev_data_dict.keys():
        fse_csqa_dev_data_dict[id_]={"index":kk,"id":id_,
                                     "premise":da["Input.premise"],
                                     "hypothesis":da["Input.hypothesis"],
                                     'answer':da['Input.gold_label'],
                                     "accept_set_list":[answer_accept],
                                     "explanation_list":explanation_list}
        #[[kk, id_, answer_accept, explanation_list]]
    else:
        fse_csqa_dev_data_dict[id_]["accept_set_list"].append(answer_accept)
    if len(fse_csqa_dev_data_dict[id_]["accept_set_list"])==3:
        fse_csqa_dev_data_dict[id_]["common_expl_list"]=[]
        common_accept_expl_sample=set.intersection(fse_csqa_dev_data_dict[id_]["accept_set_list"][0], 
                                                   fse_csqa_dev_data_dict[id_]["accept_set_list"][1], 
                                                   fse_csqa_dev_data_dict[id_]["accept_set_list"][2])
        for idx in list(common_accept_expl_sample):
            idx=int(idx)-1
            fse_csqa_dev_data_dict[id_]["common_expl_list"].append(fse_csqa_dev_data_dict[id_]["explanation_list"][idx])
            
# fse_csqa_dev_data_dict['snli_train_570']
refine_dev_data=[]
for kk, da in fse_csqa_dev_data_dict.items():
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str in all_data_dict.keys() and da["common_expl_list"]:
        new_da=all_data_dict[key_str]
        our_expl = ""
        for expl in da["common_expl_list"]:
            if len(expl) > len(our_expl):
                our_expl=expl
        new_da['our_explanation'] = our_expl#da['our_explanation']
        new_da['common_expl_list'] = da["common_expl_list"]
        refine_dev_data.append(new_da)
        #print(len(da["common_expl_list"]))
len(refine_dev_data)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 509

# %%
#rationale unlabeled data construction 991
import pdb
scr_csqa_unlabeled_test_file="/cognitive_comp/huangyongfeng/evaluate_LM_with_rationalization/few_shot_explanations/data/acceptability_annotations/snli_test.csv"
fse_csqa_dev_dataset = datasets.load_dataset('csv', data_files=scr_csqa_unlabeled_test_file)
scr_csqa_unlabeled_test_df=pd.read_csv(scr_csqa_unlabeled_test_file)
fse_csqa_dev_data_dict={}
for kk, da in enumerate(fse_csqa_dev_dataset['train']):
    #pdb.set_trace()
    id_=da['Input.id']
    if da['Answer.acceptable']:
        answer_accept=set(da['Answer.acceptable'].split('|'))
    else:
        answer_accept=set()
    explanation_list=[da['Input.explanation_1'], 
                      da['Input.explanation_2'],
                      da['Input.explanation_3'],
                      da['Input.explanation_4'],
                      da['Input.explanation_5']]
    if id_ not in fse_csqa_dev_data_dict.keys():
        fse_csqa_dev_data_dict[id_]={"index":kk,"id":id_,
                                     "premise":da["Input.premise"],
                                     "hypothesis":da["Input.hypothesis"],
                                     'answer':da['Input.gold_label'],
                                     "accept_set_list":[answer_accept],
                                     "explanation_list":explanation_list}
        #[[kk, id_, answer_accept, explanation_list]]
    else:
        fse_csqa_dev_data_dict[id_]["accept_set_list"].append(answer_accept)
    if len(fse_csqa_dev_data_dict[id_]["accept_set_list"])==3:
        fse_csqa_dev_data_dict[id_]["common_expl_list"]=[]
        common_accept_expl_sample=set.intersection(fse_csqa_dev_data_dict[id_]["accept_set_list"][0], 
                                                   fse_csqa_dev_data_dict[id_]["accept_set_list"][1], 
                                                   fse_csqa_dev_data_dict[id_]["accept_set_list"][2])
        for idx in list(common_accept_expl_sample):
            idx=int(idx)-1
            fse_csqa_dev_data_dict[id_]["common_expl_list"].append(fse_csqa_dev_data_dict[id_]["explanation_list"][idx])
            
# fse_csqa_dev_data_dict['snli_train_570']
#refine_test_data=[]
for kk, da in fse_csqa_dev_data_dict.items():
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str in all_data_dict.keys() and da["common_expl_list"]:
        new_da=all_data_dict[key_str]
        our_expl = ""
        for expl in da["common_expl_list"]:
            if len(expl) > len(our_expl):
                our_expl=expl
        new_da['our_explanation'] = our_expl#da['our_explanation']
        new_da['common_expl_list'] = da["common_expl_list"]
        refine_dev_data.append(new_da)
        #print(len(da["common_expl_list"]))
len(refine_dev_data)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 640

# %%
#rationale unlabeled data construction 991
import pdb
scr_csqa_unlabeled_test_file="/cognitive_comp/huangyongfeng/evaluate_LM_with_rationalization/few_shot_explanations/data/acceptability_annotations/snli_test.csv"
fse_csqa_dev_dataset = datasets.load_dataset('csv', data_files=scr_csqa_unlabeled_test_file)
scr_csqa_unlabeled_test_df=pd.read_csv(scr_csqa_unlabeled_test_file)
fse_csqa_dev_data_dict={}
for kk, da in enumerate(fse_csqa_dev_dataset['train']):
    #pdb.set_trace()
    id_=da['Input.id']
    if da['Answer.acceptable']:
        answer_accept=set(da['Answer.acceptable'].split('|'))
    else:
        answer_accept=set()
    explanation_list=[da['Input.explanation_1'], 
                      da['Input.explanation_2'],
                      da['Input.explanation_3'],
                      da['Input.explanation_4'],
                      da['Input.explanation_5']]
    if id_ not in fse_csqa_dev_data_dict.keys():
        fse_csqa_dev_data_dict[id_]={"index":kk,"id":id_,
                                     "premise":da["Input.premise"],
                                     "hypothesis":da["Input.hypothesis"],
                                     'answer':da['Input.gold_label'],
                                     "accept_set_list":[answer_accept],
                                     "explanation_list":explanation_list}
        #[[kk, id_, answer_accept, explanation_list]]
    else:
        fse_csqa_dev_data_dict[id_]["accept_set_list"].append(answer_accept)
    if len(fse_csqa_dev_data_dict[id_]["accept_set_list"])==3:
        fse_csqa_dev_data_dict[id_]["common_expl_list"]=[]
        common_accept_expl_sample=set.intersection(fse_csqa_dev_data_dict[id_]["accept_set_list"][0], 
                                                   fse_csqa_dev_data_dict[id_]["accept_set_list"][1], 
                                                   fse_csqa_dev_data_dict[id_]["accept_set_list"][2])
        for idx in list(common_accept_expl_sample):
            idx=int(idx)-1
            fse_csqa_dev_data_dict[id_]["common_expl_list"].append(fse_csqa_dev_data_dict[id_]["explanation_list"][idx])
            
# fse_csqa_dev_data_dict['snli_train_570']
refine_test_data=[]
for kk, da in fse_csqa_dev_data_dict.items():
    hyp=da['hypothesis']
    pre=da['premise']
    key_str = f'hypothesis: {hyp}; premise:{pre}'
    if key_str in all_data_dict.keys() and da["common_expl_list"]:
        new_da=all_data_dict[key_str]
        our_expl = ""
        for expl in da["common_expl_list"]:
            if len(expl) > len(our_expl):
                our_expl=expl
        new_da['our_explanation'] = our_expl#da['our_explanation']
        new_da['common_expl_list'] = da["common_expl_list"]
        refine_test_data.append(new_da)
        #print(len(da["common_expl_list"]))
len(refine_test_data)
# Out:
# Downloading and preparing dataset csv/default to /home/huangyongfeng/.cache/huggingface/datasets/csv/default-696f2faa8c3ac332/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a...
#   0%|          | 0/1 [00:00<?, ?it/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# Dataset csv downloaded and prepared to /home/huangyongfeng/.cache/huggingface/datasets/csv/default-696f2faa8c3ac332/0.0.0/bf68a4c4aefa545d0712b2fcbb1b327f905bbe2f6425fbc5e8c25234acb9e14a. Subsequent calls will reuse this data.
#   0%|          | 0/1 [00:00<?, ?it/s]
# 131

# %%
our_data_splits={}
our_data_splits['train']=refine_train_data
our_data_splits['dev']=refine_dev_data
our_data_splits['test']=refine_test_data
refine_dev_data[0].keys()
# Out:
# dict_keys(['premise', 'hypothesis', 'label', 'explanation_1', 'explanation_2', 'explanation_3', 'our_explanation', 'common_expl_list'])

# %% [markdown]
# # shots number

# %%
chatgpt_rationales = ["sample 0: explain why the relation is neutral between hypothesis: they are smiling at their parents and premise: children smiling and waving at camera</s>",
"The relation between the hypothesis \"they are smiling at their parents\" and the premise \"children smiling and waving at camera\" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that children are smiling and waving at the camera, but it does not specify who they are smiling and waving at, so it is possible that they are smiling and waving at their parents, but it is also possible that they are smiling and waving at someone else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.",




"sample 1: explain why the relation is contradiction between hypothesis: two people are playing cribbage. and premise: two men in safety vests walk down the road.</s>",
"The relation between the hypothesis \"two people are playing cribbage\" and the premise \"two men in safety vests walk down the road\" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that two people are playing cribbage, which implies they are in a stationary location, most likely indoors, and are engaged in a game. On the other hand, the premise states that two men are walking down the road, which implies that they are in motion, and most likely outdoors. These two statements cannot both be true at the same time as the people described in the hypothesis are not doing the same activity as the men described in the premise. Therefore, the relation between these two statements is a contradiction.",





"sample 2: explain why the relation is neutral between hypothesis: the tourists are getting a gondola ride. and premise: the tourists are out on the river in italy, the man in the black and white striped shirt will tell them about the seine.</s>",
"The relation between the hypothesis \"the tourists are getting a gondola ride\" and the premise \"the tourists are out on the river in Italy, the man in the black and white striped shirt will tell them about the Seine\" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that the tourists are out on the river in Italy and that a man in a black and white striped shirt will tell them about the Seine, but it does not specify what the tourists are doing or where they are exactly. The premise does not specify if they are in a gondola or not, so it is possible that they are getting a gondola ride, but it is also possible that they are doing something else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.",




"sample 3: explain why the relation is neutral between hypothesis: a person is training his horse for a competition. and premise: a person on a horse jumps over a broken down airplane.</s>",
"The relation between the hypothesis \"a person is training his horse for a competition\" and the premise \"a person on a horse jumps over a broken down airplane\" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that a person on a horse jumps over a broken down airplane, but it does not specify what the person and horse are doing. It could be that they are training for a competition, but it could also be that they're just doing some exercise or practicing jumping or obstacle course. The premise does not indicate if the person is training the horse for a competition or not. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.",



"sample 4: explain why the relation is contradiction between hypothesis: the man is in a desert. and premise: an man in the north pole walking on ice.</s>",
"The relation between the hypothesis \"the man is in a desert\" and the premise \"a man in the North Pole walking on ice\" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that the man is in a desert, which is a hot and dry area with little vegetation, while the premise states that the man is in the North Pole, which is a cold and icy area with no vegetation. These two statements cannot both be true at the same time as they describe two completely different environments and conditions. Therefore, the relation between these two statements is a contradiction.",




"sample 5: explain why the relation is entailment between hypothesis: a woman ropes an animal. and premise: a woman on the back of a horse ropes a cattle.</s>",
"The relation between the hypothesis \"a woman ropes an animal\" and the premise \"a woman on the back of a horse ropes a cattle\" is entailment because the premise confirms the hypothesis and provides additional information. The hypothesis states that a woman ropes an animal, which is a general statement, and the premise provides specific information that confirms the general statement, that a woman on the back of a horse ropes a cattle. The premise specifies that the woman is on the back of a horse and she ropes a cattle, which is an animal, which is the general statement that the hypothesis makes. The premise provides additional information, the woman is on the back of a horse and the animal she ropes is a cattle which is specific and confirms the general statement of the hypothesis. Therefore, the relation between these two statements is entailment.",




"sample 6: explain why the relation is contradiction between hypothesis: sports aren't played they are worn and premise: a young lacrosse player is catching his breath.</s>",
"The relation between the hypothesis \"Sports aren't played they are worn\" and the premise \"A young lacrosse player is catching his breath\" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states
ation is contradiction between hypothesis: boys are singing in the public. and premise: two male and six female dancers perform on stage.</s>",
"The relation is contradiction between hypothesis: boys are singing in the public. and premise: two male and six female dancers perform on stage, because the hypothesis states that boys are singing, while the premise states that two males and six females are dancing. These two statements cannot both be true at the same time, therefore they contradict each other.",




"sample 59: explain why the relation is contradiction between hypothesis: the kids are frowning and premise: children smiling and waving at camera</s>",
"The relation is contradiction because the hypothesis states that the kids are frowning, which is the opposite of the premise that states the children are smiling and waving at the camera. The two statements are mutually exclusive and cannot both be true at the same time.",




"sample 60: explain why the relation is neutral between hypothesis: three men in black shirts are at a table. and premise: three men, one of them standing, are at a table in a dark room.</s>",
"The relation between the hypothesis \"three men in black shirts are at a table\" and the premise \"three men, one of them standing, are at a table in a dark room\" is neutral because the premise does not provide enough information to confirm or contradict the hypothesis. The premise states that there are three men at a table, but it does not specify their clothing or the lighting conditions, so it is not possible to determine whether they match the description in the hypothesis.",





"sample 61: explain why the relation is contradiction between hypothesis: a person is at a diner, ordering an omelette. and premise: a person on a horse jumps over a broken down airplane.</s>",
"The relation is a contradiction because the premise describes a person engaging in an activity that is not consistent with the setting described in the hypothesis. In the hypothesis, the person is at a diner ordering an omelette, which implies they are in an indoor, urban setting. However, in the premise, the person is on a horse jumping over a broken down airplane, which implies they are in a rural or wilderness setting, not a diner. These two settings are not compatible and therefore the hypothesis and premise contradict each other.",





"sample 62: explain why the relation is contradiction between hypothesis: a cart is sinking in the ocean and premise: a donkey pulled cart is carrying produce down a street.</s>",
"The relation is a contradiction between the hypothesis and the premise because the hypothesis states that a cart is sinking in the ocean, which implies that it is in water and unable to be used. However, the premise states that a donkey pulled cart is carrying produce down a street, which implies that the cart is on land and being used for transportation. These two statements cannot both be true at the same time and thus, the relation between the hypothesis and the premise is a contradiction.",




"sample 63: explain why the relation is entailment between hypothesis: a basketball game is being played. and premise: a group of basketball players jump in the air for the ball.</s>",
"The relation is entailment because the premise \"a group of basketball players jump in the air for the ball\" implies that a basketball game is being played. The action described in the premise, the players jumping for the ball, is a specific aspect of a basketball game and therefore the premise supports the hypothesis \"a basketball game is being played.\"",




"sample 64: explain why the relation is neutral between hypothesis: a person is wearing his church clothes as he lays on the ground. and premise: a person wearing a blue shirt, gray pants, and black shoes is laying on the ground next to a crutch.</s>",
"The relation is neutral because the premise does not specify that the person is wearing \"church clothes\" as the hypothesis states. The premise provides a description of the person's clothing, but it does not provide enough information to confirm or contradict the hypothesis that the person is wearing \"church clothes.\"",




"sample 65: explain why the relation is entailment between hypothesis: a large brown dog is standing oustide. and premise: a large brown dog is sticking his face in the sprinkler.</s>",
"The relation is entailment because the premise provides additional information about the large brown dog in the hypothesis, specifically that it is standing outside and sticking its face in a sprinkler, which is an action that a dog standing outside may do. The premise does not contradict the hypothesis, but rather adds to it.",




"sample 66: explain why the relation is neutral between hypothesis: women are standing on the sidewalk. and premise: two women conversing on a sidewalk.</s>",
"The relation is neutral between the hypothesis \"women are standing on the sidewalk\" and the premise \"two women conversing on a sidewalk\" because the hypothesis states that the women are standing, while the premise does not specify whether they are standing or sitting. Both statements are true, but the premise doesn't give additional information to the hypothesis.",




"The relation is entailment between the hypothesis \"a woman stands at a podium\" and the premise \"a middle-aged woman stands at a green podium with the name \"sva theatre\" written on it\" because the premise provides additional information that supports the hypothesis. The hypothesis states that a woman is standing at a podium, and the premise states that a middle-aged woman is standing at a green podium with a specific name, \"sva theatre\" written on it, which confirms the hypothesis that a woman is standing at a podium. Therefore, the premise entails the hypothesis.",




"sample 84: explain why the relation is contradiction between hypothesis: a man wearing a cowboy hat swings a baseball bat. and premise: a man wearing only a cowboy hat, cowboy boots, and underwear talks to a woman on a city street.</s>",
"The relation is contradiction between the hypothesis \"a man wearing a cowboy hat swings a baseball bat\" and the premise \"a man wearing only a cowboy hat, cowboy boots, and underwear talks to a woman on a city street\" because the premise states that the man is only wearing a cowboy hat, cowboy boots, and underwear and is talking to a woman on a city street, while the hypothesis states that the man is wearing a cowboy hat and swinging a baseball bat, which are two completely different and mutually exclusive actions and scenarios. Therefore, the hypothesis and the premise are contradictory.",




"sample 85: explain why the relation is contradiction between hypothesis: the man is lying in bed. and premise: a man and woman dressed in old fashion clothing sit outside at a table.</s>",
"The relation is a contradiction because the hypothesis states that the man is lying in bed, which is an indoor and sedentary activity, while the premise describes the man and woman sitting outside at a table, which is an outdoor and active activity. These two descriptions are mutually exclusive and cannot both be true at the same time, hence the contradiction.",




"sample 86: explain why the relation is entailment between hypothesis: store has people standing around it's exterior. and premise: asian people are standing outside a store named concepts.</s>",
"The relation between the hypothesis \"store has people standing around it's exterior\" and the premise \"asian people are standing outside a store named concepts\" is entailment because the premise provides evidence that supports the hypothesis. The premise specifically states that there are people standing outside a store, and the store is named \"concepts\", which confirms that there is a store with people standing around its exterior. Therefore, the premise entails the hypothesis, meaning that the hypothesis is logically supported by the premise.",





"sample 87: explain why the relation is contradiction between hypothesis: there are people running and premise: couple walking passed a clock tower.</s>",
"The relation is a contradiction between the hypothesis \"there are people running\" and the premise \"couple walking passed a clock tower\" because the hypothesis states that people are running, while the premise states that people are walking. These two statements are incompatible and cannot both be true at the same time. The fact that people are running implies that they are moving quickly and with purpose, while the fact that people are walking implies a slower and more leisurely pace. The contradiction is that the two statements give different information about the activity of the people.",




"sample 88: explain why the relation is contradiction between hypothesis: the men are watching a movie in public theatres in different states and premise: two men handle a large telescope while one is looking through.</s>",
"The relation is contradiction because the hypothesis states that the men are watching a movie in public theatres in different states, while the premise states that two men are handling a large telescope and one is looking through it. These two statements are mutually exclusive, as it is unlikely that the men would be able to watch a movie in public theatres in different states while also handling a telescope at the same time. Therefore, the hypothesis and premise are contradictory.",




"sample 89: explain why the relation is entailment between hypothesis: people are playing. and premise: a group of native adults and children are sitting in a circle playing a game.</s>",
"The relation between the hypothesis \"people are playing\" and the premise \"a group of native adults and children are sitting in a circle playing a game\" is entailment because the premise provides specific information that supports the general idea presented in the hypothesis. The premise describes a specific instance of people playing, which is what the hypothesis states is happening. The premise provides additional details, such as that the people are native and that they are playing a game, but these details do not contradict or negate the general idea that people are playing, as stated in the hypothesis. Therefore, the premise entails the hypothesis.",




"sample 90: explain why the relation is neutral between hypothesis: the men are related and premise: a man sitting with an elderly homeless person in a park.</s>",
"The relation is neutral because the premise does not provide any information about the relationship between the two men. It only states that they are sitting together in a park. The hypothesis, on the other hand, states that they are related, but it is not specified how they are related, and there is no information from the premise that can confirm or deny this claim. Therefore, it is not possible to determine if the hypothesis is true or false based on the premise.",




"sample 91: explain why the relation is neutral between hypothesis: a man is competing on a bike. and premise: a male doing a trick in the air on his bike.</s>",
"The relation is neutral between the hypothesis \"a man is competing on a bike\" and the premise \"a male doing a trick in the air on his bike\" because the premise does not indicate whether the man is competing or not, it only describes an action of a man on a bike. The premise does not provide any information about a competition or a race, so it does not confirm or contradict the hypothesis.",




"sample 92: explain why the relation is neutral between hypothesis: some artists are painting a wall. and premise: four young women are painting in countries of a map that is painted on a wall.</s>",
"The relation is neutral between the hypothesis \"some artists are painting a wall\" and the premise \"four young women are painting in countries of a map that is painted on a wall\" because the premise describes a specific situation, but the hypothesis is more general and does not specify that the artists are women or that they are painting a map on a wall. The hypothesis is compatible with the premise, but the premise does not provide any additional information or context to confirm or deny the hypothesis.",




"sample 93: explain why the relation is contradiction between hypothesis: a woman takes a bath. and premise: three people serving food outside somewhere.</s>",
"The relation is contradiction between the hypothesis \"a woman takes a bath\" and the premise \"three people serving food outside somewhere\" because the two statements describe two completely different and unrelated actions that cannot coexist at the same time. The hypothesis describes an individual doing a solitary activity in a private setting, while the premise describes a group of individuals performing an interactive activity in a public setting. The two statements are not compatible with each other and therefore contradict each other.",




"sample 94: explain why the relation is neutral between hypothesis: the woman is trying to make a living. and premise: an asian woman is selling colorful fabrics.</s>",
"The relation is neutral between the hypothesis \"the woman is trying to make a living\" and the premise \"an asian woman is selling colorful fabrics\" because while the premise describes an action that may be associated with someone trying to make a living, it does not directly confirm or refute the hypothesis. The premise simply provides a visual image of the woman selling fabrics, without any additional context or information about her motivations or circumstances.",





"sample 95: explain why the relation is contradiction between hypothesis: the boy skates down the sidewalk. and premise: a boy is jumping on skateboard in the middle of a red bridge.</s>",
"The relation is a contradiction between the hypothesis \"the boy skates down the sidewalk\" and the premise \"a boy is jumping on a skateboard in the middle of a red bridge\" because the hypothesis suggests that the boy is moving on the sidewalk, while the premise suggests that the boy is on a skateboard in the middle of a red bridge. These two statements cannot both be true at the same time, as the sidewalk and red bridge are different locations and the boy cannot be in both places simultaneously. Additionally, the action described in the hypothesis \"skating down\" is different from the action described in the premise \"jumping on\". Therefore, the two statements contradict each other.",
]

ral_list = []
inp_list = []
ral_inp_dict = {}
for kk in range(96):
    inp_list.append(chatgpt_rationales[2*kk][chatgpt_rationales[2*kk].index("explain why the relation is"):])
    ral_list.append(chatgpt_rationales[2*kk+1])
    ral_inp_dict[chatgpt_rationales[2*kk][chatgpt_rationales[2*kk].index("explain why the relation is"):]] = chatgpt_rationales[2*kk+1]

# %%
new_refine_train_data = []
for item in refine_train_data:
    premise = item["premise"]
    hypothesis = item["hypothesis"]
    answer = wt5_esnli_label_mapping[item["label"]]
    input_string = f'explain why the relation is {answer} between hypothesis: {hypothesis.lower()} and premise: {premise.lower()}</s>'  
    print(input_string)
    if input_string in ral_inp_dict.keys():
        item['our_explanation'] = ral_inp_dict[input_string]
        new_refine_train_data.append(item)

new_refine_train_data
# Out:
# explain why the relation is neutral between hypothesis: a person is training his horse for a competition. and premise: a person on a horse jumps over a broken down airplane.</s>
# explain why the relation is contradiction between hypothesis: a person is at a diner, ordering an omelette. and premise: a person on a horse jumps over a broken down airplane.</s>
# explain why the relation is entailment between hypothesis: a person is outdoors, on a horse. and premise: a person on a horse jumps over a broken down airplane.</s>
# explain why the relation is neutral between hypothesis: they are smiling at their parents and premise: children smiling and waving at camera</s>
# explain why the relation is entailment between hypothesis: there are children present and premise: children smiling and waving at camera</s>
# explain why the relation is contradiction between hypothesis: the kids are frowning and premise: children smiling and waving at camera</s>
# explain why the relation is contradiction between hypothesis: the boy skates down the sidewalk. and premise: a boy is jumping on skateboard in the middle of a red bridge.</s>
# explain why the relation is entailment between hypothesis: the boy does a skateboarding trick. and premise: a boy is jumping on skateboard in the middle of a red bridge.</s>
# explain why the relation is neutral between hypothesis: the boy is wearing safety equipment. and premise: a boy is jumping on skateboard in the middle of a red bridge.</s>
# explain why the relation is neutral between hypothesis: an older man drinks his juice as he waits for his daughter to get off work. and premise: an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</s>
# explain why the relation is contradiction between hypothesis: a boy flips a burger. and premise: an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</s>
# explain why the relation is neutral between hypothesis: an elderly man sits in a small shop. and premise: an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</s>
# explain why the relation is neutral between hypothesis: some women are hugging on vacation. and premise: two blond women are hugging one another.</s>
# explain why the relation is contradiction between hypothesis: the women are sleeping. and premise: two blond women are hugging one another.</s>
# explain why the relation is entailment between hypothesis: there are women showing affection. and premise: two blond women are hugging one another.</s>
# explain why the relation is entailment between hypothesis: two people are by a tree. and premise: two kids stand under an area carved in a large tree.</s>
# explain why the relation is entailment between hypothesis: a woman stands at a podium. and premise: a middle-aged woman stands at a green podium with the name "sva theatre" written on it.</s>
# explain why the relation is entailment between hypothesis: two humans are having a meal. and premise: these two people are eating.</s>
# explain why the relation is neutral between hypothesis: a singer sings their most famous song. and premise: a singer entertaining the crowd.</s>
# explain why the relation is neutral between hypothesis: a couple are seated outside, feeling amorous. and premise: a man and a woman are seen through the fence seated at a table, staring into each other's eyes.</s>
# explain why the relation is neutral between hypothesis: the two men play very well. and premise: two men are playing acoustic guitars.</s>
# explain why the relation is neutral between hypothesis: the people are having a business meeting. and premise: an aerial view of a group of meeting talking to each other.</s>
# explain why the relation is neutral between hypothesis: a child waits to cross a street. and premise: a child in white shorts and a blue shirt is standing in the street.</s>
# explain why the relation is contradiction between hypothesis: the woman is cooking dinner. and premise: a woman is bending over a colorfully striped, metal couch on a sidewalk that has a bucket sitting atop it.</s>
# explain why the relation is entailment between hypothesis: the people are outside. and premise: people are walking around a park area.</s>
# explain why the relation is contradiction between hypothesis: the man is working on his car and premise: women walking down the street in jeans, black high heel boots, and a beige handbag.</s>
# explain why the relation is neutral between hypothesis: women are competing in a table tennis tournament at the beach. and premise: two females in bikinis are playing table tennis at the beach while another female in a towel watches.</s>
# explain why the relation is contradiction between hypothesis: a nurse is pushing a surgical cart and premise: a woman wearing gloves working at a meat counter.</s>
# explain why the relation is contradiction between hypothesis: two people are playing cribbage. and premise: two men in safety vests walk down the road.</s>
# explain why the relation is neutral between hypothesis: two couples are preparing dinner together. and premise: two ladies are cooking & talking and two gentlemen are talking in the opposite site of the kitchen.</s>
# explain why the relation is contradiction between hypothesis: the men are watching a movie in public theatres in different states and premise: two men handle a large telescope while one is looking through.</s>
# explain why the relation is entailment between hypothesis: a man is taking a run on the track. and premise: a man running on a track.</s>
# explain why the relation is neutral between hypothesis: the 3 people are trying to figure out what the sign on the door means and are a little worried that they may be in the wrong
male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs.</s>
# explain why the relation is neutral between hypothesis: some artists are painting a wall. and premise: four young women are painting in countries of a map that is painted on a wall.</s>
# explain why the relation is neutral between hypothesis: a band is playing a concert. and premise: this band is playing on a stage.</s>
# [{'premise': 'A person on a horse jumps over a broken down airplane.',
#   'hypothesis': 'A person is training his horse for a competition.',
#   'label': 1,
#   'explanation_1': 'the person is not necessarily training his horse',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a person is training his horse for a competition" and the premise "a person on a horse jumps over a broken down airplane" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that a person on a horse jumps over a broken down airplane, but it does not specify what the person and horse are doing. It could be that they are training for a competition, but it could also be that they\'re just doing some exercise or practicing jumping or obstacle course. The premise does not indicate if the person is training the horse for a competition or not. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'A person on a horse jumps over a broken down airplane.',
#   'hypothesis': 'A person is at a diner, ordering an omelette.',
#   'label': 2,
#   'explanation_1': 'One cannot be on a jumping horse cannot be a diner ordering food.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the premise describes a person engaging in an activity that is not consistent with the setting described in the hypothesis. In the hypothesis, the person is at a diner ordering an omelette, which implies they are in an indoor, urban setting. However, in the premise, the person is on a horse jumping over a broken down airplane, which implies they are in a rural or wilderness setting, not a diner. These two settings are not compatible and therefore the hypothesis and premise contradict each other.'},
#  {'premise': 'A person on a horse jumps over a broken down airplane.',
#   'hypothesis': 'A person is outdoors, on a horse.',
#   'label': 0,
#   'explanation_1': 'a broken down airplane is outdoors',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a person is outdoors, on a horse" and the premise "a person on a horse jumps over a broken down airplane" is entailment because the premise confirms the hypothesis. The hypothesis states that "a person is outdoors, on a horse," which implies that the person is outside and mounted on a horse. The premise describes a person on a horse jumping over a broken down airplane, which confirms the hypothesis that the person is outside and mounted on a horse. The premise provides additional information about the person\'s location and activity, but it does not contradict the main idea that the person is outside and on a horse. Therefore, the premise confirms the hypothesis "a person is outdoors, on a horse".'},
#  {'premise': 'Children smiling and waving at camera',
#   'hypothesis': 'They are smiling at their parents',
#   'label': 1,
#   'explanation_1': 'Just because they are smiling and waving at a camera does not imply their parents or anyone is anyone behind it',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "they are smiling at their parents" and the premise "children smiling and waving at camera" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that children are smiling and waving at the camera, but it does not specify who they are smiling and waving at, so it is possible that they are smiling and waving at their parents, but it is also possible that they are smiling and waving at someone else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Children smiling and waving at camera',
#   'hypothesis': 'There are children present',
#   'label': 0,
#   'explanation_1': 'The children must be present to see them smiling and waving.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "there are children present" and the premise "children smiling and waving at camera" is entailment because the premise provides evidence that supports the hypothesis. The presence of children smiling and waving in the premise confirms that there are indeed children present, as stated in the hypothesis. The hypothesis is entailed by the premise because the premise is providing visual evidence of the presence of children.'},
#  {'premise': 'Children smiling and waving at camera',
#   'hypothesis': 'The kids are frowning',
#   'label': 2,
#   'explanation_1': 'One cannot be smiling and frowning at the same time.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis states that the kids are frowning, which is the opposite of the premise that states the children are smiling and waving at the camera. The two statements are mutually exclusive and cannot both be true at the same time.'},
#  {'premise': 'A boy is jumping on skateboard in the middle of a red bridge.',
#   'hypothesis': 'The boy skates down the sidewalk.',
#   'label': 2,
#   'explanation_1': 'One cannot be in the middle of a bridge if they are on the sidewalk.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction between the hypothesis "the boy skates down the sidewalk" and the premise "a boy is jumping on a skateboard in the middle of a red bridge" because the hypothesis suggests that the boy is moving on the sidewalk, while the premise suggests that the boy is on a skateboard in the middle of a red bridge. These two statements cannot both be true at the same time, as the sidewalk and red bridge are different locations and the boy cannot be in both places simultaneously. Additionally, the action described in the hypothesis "skating down" is different from the action described in the premise "jumping on". Therefore, the two statements contradict each other.'},
#  {'premise': 'A boy is jumping on skateboard in the middle of a red bridge.',
#   'hypothesis': 'The boy does a skateboarding trick.',
#   'label': 0,
#   'explanation_1': 'jumping on skateboard is the same as doing trick on skateboard.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise "a boy is jumping on Skateboard in the middle of a red bridge" describes an action that is consistent with the hypothesis "the boy does a skateboarding trick." The premise provides additional details and context to the hypothesis, but the basic action of the boy performing a skateboarding trick is still present in the premise.'},
#  {'premise': 'An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.',
#   'hypothesis': 'An older man drinks his juice as he waits for his daughter to get off work.',
#   'label': 1,
#   'explanation_1': 'it is not necessarily true the man drinks his juice',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': "The relation is neutral between the hypothesis and premise because while the hypothesis states that the older man is drinking his juice and waiting for his daughter to get off work, the premise only describes the older man sitting with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background. The premise does not provide any information about the older man's daughter or why he is waiting. Therefore, the hypothesis and premise are not mutually exclusive or mutually dependent and do not contradict or entail each other."},
#  {'premise': 'An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.',
#   'hypothesis': 'A boy flips a burger.',
#   'label': 2,
#   'explanation_1': 'A boy is not considered an older man.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction between the hypothesis "a boy flips a burger" and the premise "an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background" because the hypothesis states that a specific action (flipping a burger) is happening in a specific setting (presumably a kitchen or grill area), while the premise describes a completely different scene with no indication of a burger-related activity. These two statements cannot both be true at the same time.'},
#  {'premise': 'Two kids stand under an area carved in a large tree.',
#   'hypothesis': 'Two people are by a tree.',
#   'label': 0,
#   'explanation_1': 'Kids are people.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "two people are by a tree" and the premise "two kids stand under an area carved in a large tree" because the premise provides additional information about the location of the two people (i.e., that they are standing under an area carved in a large tree) and confirms that the hypothesis is true. The premise also provides information about the two people being kids, which is not mentioned in the hypothesis but it is entailed by it.'},
#  {'premise': 'A middle-aged woman stands at a green podium with the name "SVA Theatre" written on it.',
#   'hypothesis': 'A woman stands at a podium.',
#   'label': 0,
#   'explanation_1': 'A middle- aged woman stands at a podium.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a woman stands at a podium" and the premise "a middle-aged woman stands at a green podium with the name "sva theatre" written on it" because the premise provides additional information that supports the hypothesis. The hypothesis states that a woman is standing at a podium, and the premise states that a middle-aged woman is standing at a green podium with a specific name, "sva theatre" written on it, which confirms the hypothesis that a woman is standing at a podium. Therefore, the premise entails the hypothesis.'},
#  {'premise': 'These two people are eating.',
#   'hypothesis': 'Two humans are having a meal.',
#   'label': 0,
#   'explanation_1': 'people are human. Eating means the same thing as having a meal.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between hypothesis: "two humans are having a meal" and premise: "these two people are eating." because the premise "these two people are eating" is a specific instance of the more general statement in the hypothesis "two humans are having a meal." The premise provides additional information that the two individuals in question are indeed people and that they are eating, which confirms the hypothesis.'},
#  {'premise': 'A singer entertaining the crowd.',
#   'hypothesis': 'A singer sings their most famous song.',
#   'label': 1,
#   'explanation_1': 'A singer is singing his favorite song ib the crowd',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a singer sings their most famous song" and the premise "a singer entertaining the crowd" because the premise does not specify what song the singer is singing, so it could be their most famous song, but it could also be a different song. Therefore, the premise does not support or contradict the hypothesis.'},
#  {'premise': 'Two men are playing acoustic guitars.',
#   'hypothesis': 'The two men play very well.',
#   'label': 1,
#   'explanation_1': 'Just because men play acoustic guitars it does not mean they play very well.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the two men play very well" and the premise "two men are playing acoustic guitars" is neutral because the premise does not confirm or deny the hypothesis. The hypothesis states that "the two men play very well," which implies that the two men have a high level of skill or proficiency in playing the guitars. The premise describes two men playing acoustic guitars, which does not confirm or deny the hypothesis. It is not specified whether the two men are playing well or not. It could be that they are playing well, poorly, or somewhere in between. The premise does not provide any information about the skill level of the men playing the guitars, making the relation neutral.'},
#  {'premise': 'An aerial view of a group of meeting talking to each other.',
#   'hypothesis': 'The people are having a business meeting.',
#   'label': 1,
#   'explanation_1': 'Not all group of meeting is business meeting.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the people are having a business meeting" and the premise "an aerial view of a group of people talking to each other" is neutral because the premise provides general information about a group of people talking to each other, but it does not specify that they are having a business meeting. The premise does not necessarily support or contradict the hypothesis.'},
#  {'premise': 'A woman is bending over a colorfully striped, metal couch on a sidewalk that has a bucket sitting atop it.',
#   'hypothesis': 'The woman is cooking dinner.',
#   'label': 2,
#   'explanation_1': 'The woman cooking dinner is contradictory to the woman in first sentence bending over a couch.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis suggests the woman is engaged in the activity of cooking dinner, which typically takes place indoors and involves the use of a kitchen, whereas the premise describes the woman as being outdoors on a sidewalk, in proximity to a couch and a bucket. These two descriptions are not consistent with each other, and therefore the hypothesis and premise contradict each other.'},
#  {'premise': 'People are walking around a park area.',
#   'hypothesis': 'The people are outside.',
#   'label': 0,
#   'explanation_1': 'park area refers to outside.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the people are outside" and the premise "people are walking around a park area" is entailment because the premise confirms the hypothesis. The hypothesis states that "the people are outside", which implies that the people are in an open-air environment and not indoors. The premise describes people walking around a park area, which implies that the people are outside in a public park where people can walk and enjoy the nature. This confirms that the people are outside, as the park area is an open-air environment. Therefore, the premise confirms the hypothesis that "the people are outside".'},
#  {'premise': 'Women walking down the street in jeans, black high heel boots, and a beige handbag.',
#   'hypothesis': 'The man is working on his car',
#   'label': 2,
#   'explanation_1': 'Women are walking in Sentence 1. In Sentence 2 a man is working.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that the man is working on his car, which suggests that he is engaged in a specific activity related to automobiles. However, the premise describes a group of women who are walking down the street, which is not related to the man working on a car and thus contradicts the hypothesis.'},
#  {'premise': 'Two females in bikinis are playing table tennis at the beach while another female in a towel watches.',
#   'hypothesis': 'Women are competing in a table tennis tournament at the beach.',
#   'label': 1,
#   'explanation_1': "We don't know that there is a tournament.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral because the hypothesis and the premise both describe women competing in a table tennis tournament at the beach, but the premise also includes additional details such as what they are wearing. The additional details do not contradict or support the statement in the hypothesis, so the relation is neutral.'},
#  {'premise': 'A woman wearing gloves working at a meat counter.',
#   'hypothesis': 'A nurse is pushing a surgical cart',
#   'label': 2,
#   'explanation_1': 'A meat counter and a surgical cart are found in completely separate places.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis and premise describe two very different scenarios. In the hypothesis, a nurse is described as pushing a surgical cart in a hospital setting, while in the premise, a woman is described as working at a meat counter in a grocery store. These two images are not consistent with each other and therefore, the relation is a contradiction.'},
#  {'premise': 'Two men in safety vests walk down the road.',
#   'hypothesis': 'Two people are playing cribbage.',
#   'label': 2,
#   'explanation_1': 'People walking down the road cannot be engaged in playing cribbage.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "two people are playing cribbage" and the premise "two men in safety vests walk down the road" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that two people are playing cribbage, which implies they are in a stationary location, most likely indoors, and are engaged in a game. On the other hand, the premise states that two men are walking down the road, which implies that they are in motion, and most likely outdoors. These two statements cannot both be true at the same time as the people described in the hypothesis are not doing the same activity as the men described in the premise. Therefore, the relation between these two statements is a contradiction.'},
#  {'premise': 'Two ladies are cooking & talking and two gentlemen are talking in the opposite site of the kitchen.',
#   'hypothesis': 'Two couples are preparing dinner together.',
#   'label': 1,
#   'explanation_1': "Just because it's two men and two women doesn't mean they're couples.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis and premise is neutral because the premise describes two couples engaging in separate activities in the kitchen, while the hypothesis states that they are preparing dinner together. The premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Two men handle a large telescope while one is looking through.',
#   'hypothesis': 'The men are watching a movie in public theatres in different states',
#   'label': 2,
#   'explanation_1': 'If the men are watching a movie, they are not handling a large telescope',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis states that the men are watching a movie in public theatres in different states, while the premise states that two men are handling a large telescope and one is looking through it. These two statements are mutually exclusive, as it is unlikely that the men would be able to watch a movie in public theatres in different states while also handling a telescope at the same time. Therefore, the hypothesis and premise are contradictory.'},
#  {'premise': 'A man running on a track.',
#   'hypothesis': 'A man is taking a run on the track.',
#   'label': 0,
#   'explanation_1': 'Running and taking a run are the same thing.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a man is taking a run on the track" and the premise "a man running on a track" is entailment because the premise provides additional information that confirms the hypothesis. The hypothesis states that a man is taking a run, which implies that he is moving, and the premise confirms that the man is indeed running, which is a specific type of movement. Therefore, the premise provides evidence that supports the hypothesis, making them consistent with each other.'},
#  {'premise': 'Two women and a man in a room that has a sign reading "Artisti" on its door.',
#   'hypothesis': 'The 3 people are trying to figure out what the sign on the door means and are a little worried that they may be in the wrong room.',
#   'label': 1,
#   'explanation_1': "Just because two women and a man in a room that has a sign reading 'Artisti' on its door does not mean they   are a little worried that they may be in the wrong room.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral because while the hypothesis suggests that the three people are trying to figure out what the sign on the door means and are a little worried that they may be in the wrong room, the premise simply states that two women and a man are in a room that has a sign reading "artisti" on its door. The premise does not provide any information about the people\'s actions or emotions, so it cannot confirm or deny the hypothesis.'},
#  {'premise': 'The tourists are out on the river in Italy, the man in the black and white striped shirt will tell them about the seine.',
#   'hypothesis': 'The tourists are getting a gondola ride.',
#   'label': 1,
#   'explanation_1': "The fact that tourists are out on the river in Italy doesn't imply that they are having a gondola ride",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the tourists are getting a gondola ride" and the premise "the tourists are out on the river in Italy, the man in the black and white striped shirt will tell them about the Seine" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that the tourists are out on the river in Italy and that a man in a black and white striped shirt will tell them about the Seine, but it does not specify what the tourists are doing or where they are exactly. The premise does not specify if they are in a gondola or not, so it is possible that they are getting a gondola ride, but it is also possible that they are doing something else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Couple walking passed a clock tower.',
#   'hypothesis': 'There are people running',
#   'label': 2,
#   'explanation_1': 'The couple cannot be running and walking at the same time.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction between the hypothesis "there are people running" and the premise "couple walking passed a clock tower" because the hypothesis states that people are running, while the premise states that people are walking. These two statements are incompatible and cannot both be true at the same time. The fact that people are running implies that they are moving quickly and with purpose, while the fact that people are walking implies a slower and more leisurely pace. The contradiction is that the two statements give different information about the activity of the people.'},
#  {'premise': 'Dog on a red leash with a woman.',
#   'hypothesis': 'A woman and dog are together.',
#   'label': 0,
#   'explanation_1': 'The leash is for the dog.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a woman and dog are together" and the premise "dog on a red leash with a woman" because the premise provides specific details that confirm the hypothesis. The premise states that there is a dog on a red leash with a woman, which implies that the woman and dog are together as stated in the hypothesis. The information in the premise supports and confirms the information in the hypothesis.'},
#  {'premise': 'A woman with brown hair wearing a red polka dot dress is singing into a microphone.',
#   'hypothesis': 'a woman singing',
#   'label': 0,
#   'explanation_1': 'A woman is singing in both examples.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a woman singing" and the premise "a woman with brown hair wearing a red polka dot dress is singing into a microphone" is entailment because the premise provides more information that supports the hypothesis. The hypothesis states that a woman is singing, which means that she is producing sound with her voice. The premise describes a woman with brown hair wearing a red polka dot dress who is singing into a microphone, which confirms the hypothesis that a woman is singing. It also gives additional information such as the woman\'s appearance, clothing and the tool she\'s using to produce the sound (microphone) which supports the hypothesis that a woman is singing. Therefore, the premise entails the hypothesis, making the relation entailment.'},
#  {'premise': 'A woman wearing a blue dress and carrying a purple umbrella is walking in parking lot.',
#   'hypothesis': 'The woman is walking back to her car after shopping.',
#   'label': 1,
#   'explanation_1': 'Walking does not imply going back to her car or that she just finished shopping.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the woman is walking back to her car after shopping" and the premise "a woman wearing a blue dress and carrying a purple umbrella is walking in a parking lot" because the premise provides some information about the woman\'s appearance and location, but does not confirm or deny the specific action of her returning to her car after shopping. The premise does not provide enough information to confirm or contradict the hypothesis.'},
#  {'premise': 'A dancer performing with her panties showing.',
#   'hypothesis': "The girl's costume is too short.",
#   'label': 1,
#   'explanation_1': 'Just because a dancer is performing with her panties showing it does not mean the costume is too short.  A dancer does not have to be a girl.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the girl\'s costume is too short" and the premise "a dancer performing with her panties showing" because the hypothesis states a specific condition about the girl\'s costume (i.e., that it is too short), while the premise describes a general situation (i.e., a dancer performing) without specifying anything about the costume. It is possible that the dancer in the premise is the girl mentioned in the hypothesis, but without more information it is not clear if that is the case. Therefore, the two statements do not directly support or contradict each other.'},
#  {'premise': 'Two Asia women are riding on a cart as a man pulls them through the street.',
#   'hypothesis': 'The two women are riding a cart outside.',
#   'label': 0,
#   'explanation_1': 'Asian women are women.  The street is outside.',
#   'explanation_2': '',
#   'explanation_3': '',
# ...
#   'hypothesis': 'Two motorcylists are driving up a mountain.',
#   'label': 2,
#   'explanation_1': 'A means one, two means 2.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that two motorcyclists are driving up a mountain, but the premise states that only one motorcyclist is driving while the other bike remains stationary. The two statements cannot both be true at the same time, as only one motorcyclist is seen to be moving in the premise, while the hypothesis states that both are moving.'},
#  {'premise': 'Four boys play in the mud.',
#   'hypothesis': 'Four boys are outside.',
#   'label': 0,
#   'explanation_1': 'The mud is found outside.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "four boys are outside" and the premise "four boys play in the mud" because the premise is a specific example of the situation described in the hypothesis. If it is known that there are four boys outside, it must be true that they are playing in the mud, as the premise states. The premise provides additional information that is entailed by the hypothesis.'},
#  {'premise': 'Two boys with unicycles stand outside of a street shop.',
#   'hypothesis': 'Two boys ride regular bicycles during a race.',
#   'label': 2,
#   'explanation_1': 'The two boys either ride a regular bicycles or a unicycles.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction between the hypothesis "two boys ride regular bicycles during a race" and the premise "two boys with unicycles stand outside of a street shop" because the hypothesis states that the boys are riding regular bicycles, while the premise states that they are riding unicycles. These two statements cannot both be true at the same time, as a regular bicycle and a unicycle are two different types of vehicles and therefore are mutually exclusive. Therefore, the relation is contradiction.'},
#  {'premise': 'The girl wears a purple outfit and swings upside down.',
#   'hypothesis': 'The girls is having fun at the park.',
#   'label': 1,
#   'explanation_1': 'The girl wears a purple outfit and swings upside down does not indicate that she is having fun at the park.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the girl is having fun at the park" and the premise "the girl wears a purple outfit and swings upside down" because the premise only describes the girl\'s appearance and actions, but it does not provide any information about the girl\'s emotional state or the context in which she is participating in those actions. The hypothesis suggests that the girl is having fun, but the premise does not confirm or deny this. It is possible that the girl is having fun at the park, but it is also possible that she is not.'},
#  {'premise': 'A man is cutting a fish.',
#   'hypothesis': 'a man wields a tool',
#   'label': 0,
#   'explanation_1': 'A man who weild tools is cutting a fish.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a man wields a tool" and the premise "a man is cutting a fish" because the premise provides specific information that supports the hypothesis. The hypothesis states that a man is using a tool and the premise specifies that the man is cutting a fish, which requires the use of a tool such as a knife. Therefore, the premise confirms that the man is indeed using a tool, and thus the two statements are logically consistent.'},
#  {'premise': 'A man and woman dressed in old fashion clothing sit outside at a table.',
#   'hypothesis': 'The man is lying in bed.',
#   'label': 2,
#   'explanation_1': "If the man and woman are sitting outside, the man can't be lying in bed at the same time.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that the man is lying in bed, which is an indoor and sedentary activity, while the premise describes the man and woman sitting outside at a table, which is an outdoor and active activity. These two descriptions are mutually exclusive and cannot both be true at the same time, hence the contradiction.'},
#  {'premise': 'A group of basketball players jump in the air for the ball.',
#   'hypothesis': 'A basketball game is being played.',
#   'label': 0,
#   'explanation_1': 'A game is played by players',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise "a group of basketball players jump in the air for the ball" implies that a basketball game is being played. The action described in the premise, the players jumping for the ball, is a specific aspect of a basketball game and therefore the premise supports the hypothesis "a basketball game is being played."'},
#  {'premise': 'A long bearded man plays a furry guitar.',
#   'hypothesis': 'A bearded man plays guitar.',
#   'label': 0,
#   'explanation_1': 'A bearded man plays guitar is the same as a bearded man plays guitar.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a bearded man plays guitar" and the premise "a long bearded man plays a furry guitar" because the premise provides additional information about the man\'s beard and the guitar that he is playing, but it does not change the fact that the man is playing a guitar, which is stated in the hypothesis. The premise is consistent with the hypothesis and adds more details to it.'},
#  {'premise': 'A guy in white shirt and black pants is running.',
#   'hypothesis': 'A guy is running from the police.',
#   'label': 1,
#   'explanation_1': "Just because a man is running, it doesn't mean he is running from the police.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a guy is running from the police" and the premise "a guy in white shirt and black pants is running" because the premise only states that a guy in a certain clothing is running, it doesn\'t specify the reason why he is running, so it could be from the police or for another reason, the premise does not support or contradict the hypothesis.'},
#  {'premise': 'A male doing a trick in the air on his bike.',
#   'hypothesis': 'A man is competing on a bike.',
#   'label': 1,
#   'explanation_1': 'Just because a male is doing a trick in the air on his bike does not necessarily mean he is competing on a bike.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a man is competing on a bike" and the premise "a male doing a trick in the air on his bike" because the premise does not indicate whether the man is competing or not, it only describes an action of a man on a bike. The premise does not provide any information about a competition or a race, so it does not confirm or contradict the hypothesis.'},
#  {'premise': 'A donkey pulled cart is carrying produce down a street.',
#   'hypothesis': 'a cart is sinking in the ocean',
#   'label': 2,
#   'explanation_1': 'street is contradictory to ocean',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction between the hypothesis and the premise because the hypothesis states that a cart is sinking in the ocean, which implies that it is in water and unable to be used. However, the premise states that a donkey pulled cart is carrying produce down a street, which implies that the cart is on land and being used for transportation. These two statements cannot both be true at the same time and thus, the relation between the hypothesis and the premise is a contradiction.'},
#  {'premise': 'Two men and a woman playing cards.',
#   'hypothesis': 'Three people play gin rummy.',
#   'label': 1,
#   'explanation_1': 'Gin rummy is not the only card game.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "three people play gin rummy" and the premise "two men and a woman playing cards" because while the premise states that there are two men and a woman playing cards, it does not specify the game they are playing. Therefore, it is possible that they could be playing gin rummy, but it is not confirmed.'},
#  {'premise': 'A young baby boy crying while wearing a shirt that says "I am the BOSS."',
#   'hypothesis': 'A boy in an ironic shirt cries.',
#   'label': 0,
#   'explanation_1': 'The boy wearing the shirt cries.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise provides additional information that the boy is crying, and also that he is wearing an ironic shirt. The hypothesis states that the boy is crying and the premise confirms this by stating that the boy is crying, while also providing additional information about the shirt he is wearing. Therefore, the premise logically follows from the hypothesis.'},
#  {'premise': 'Two women conversing on a sidewalk.',
#   'hypothesis': 'Women are standing on the sidewalk.',
#   'label': 1,
#   'explanation_1': 'Conversing does not mean they are standing.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "women are standing on the sidewalk" and the premise "two women conversing on a sidewalk" because the hypothesis states that the women are standing, while the premise does not specify whether they are standing or sitting. Both statements are true, but the premise doesn\'t give additional information to the hypothesis.'},
#  {'premise': 'A young boy wearing a tank-top is climbing a tree.',
#   'hypothesis': 'A boy was showing off for a girl.',
#   'label': 1,
#   'explanation_1': 'A boy is climbing a tree does not necessarily mean that he is showing off for a girl.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a boy was showing off for a girl" and the premise "a young boy wearing a tank-top is climbing a tree" is neutral because the premise doesn\'t provide enough information to confirm or contradict the hypothesis. The hypothesis states that the boy was showing off for a girl, which implies that there is a girl present and the boy is doing something to impress her. The premise describes a young boy wearing a tank-top climbing a tree, which doesn\'t provide enough information to confirm or contradict the hypothesis. The premise doesn\'t tell us if there is a girl present or not and doesn\'t tell us if the boy is doing something to impress her or not. Therefore, the premise doesn\'t give enough information to confirm or contradict the hypothesis "a boy was showing off for a girl" thus the relation is neutral.'},
#  {'premise': 'There is a red truck behind the horses.',
#   'hypothesis': 'The horses are becoming suspicious of my apples.',
#   'label': 2,
#   'explanation_1': 'There can be either a truck or apples.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the premise ("there is a red truck behind the horses") does not match the hypothesis ("the horses are becoming suspicious of my apples"). The horse\'s behavior is described as being suspicious of apples, not having any relation with a red truck. The two statements are not related and cannot both be true at the same time.'},
#  {'premise': 'A black truck and a red car parked on the street in front of a grocery store painted red.',
#   'hypothesis': 'Two vehicles were parked next to a Toyota.',
#   'label': 1,
#   'explanation_1': 'It is not mandatory to park near to a Toyota',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "two vehicles were parked next to a toyota" and the premise "a black truck and a red car parked on the street in front of a grocery store painted red" because while the premise provides information about two specific vehicles (a black truck and a red car) being parked on the street, it does not specify the location of the vehicles in relation to one another. The hypothesis implies that there is a Toyota parked next to the two vehicles, but this information is not provided in the premise. Therefore, the premise does not confirm or deny the claim made in the hypothesis.'},
#  {'premise': 'A large brown dog is sticking his face in the sprinkler.',
#   'hypothesis': 'A large brown dog is standing oustide.',
#   'label': 0,
#   'explanation_1': 'Sprinklers are usually outside not inside so the dog sticking his face in the sprinkler must be standing outside',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise provides additional information about the large brown dog in the hypothesis, specifically that it is standing outside and sticking its face in a sprinkler, which is an action that a dog standing outside may do. The premise does not contradict the hypothesis, but rather adds to it.'},
#  {'premise': 'A male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs.',
#   'hypothesis': 'A surgeon performs open heart surgery.',
#   'label': 1,
#   'explanation_1': 'Not all surgery is open heart surgery.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a surgeon performs open heart surgery" and the premise "a male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The hypothesis states that a surgeon performs open heart surgery, which is a specific type of surgery, and the premise provides information about a male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs. The premise does not specify what type of surgery is being performed, and it only describes the attire and appearance of the surgeons and the fact that they are performing surgery. It does not indicate whether the surgery is open heart surgery or not. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Four young women are painting in countries of a map that is painted on a wall.',
#   'hypothesis': 'Some artists are painting a wall.',
#   'label': 1,
#   'explanation_1': 'Four young women painting are not necessarily artists.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "some artists are painting a wall" and the premise "four young women are painting in countries of a map that is painted on a wall" because the premise describes a specific situation, but the hypothesis is more general and does not specify that the artists are women or that they are painting a map on a wall. The hypothesis is compatible with the premise, but the premise does not provide any additional information or context to confirm or deny the hypothesis.'},
#  {'premise': 'This band is playing on a stage.',
#   'hypothesis': 'A band is playing a concert.',
#   'label': 1,
#   'explanation_1': 'Playing on stage does not imply playing a concert.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a band is playing a concert" and the premise "this band is playing on a stage" because both the hypothesis and the premise mention the band playing, but do not provide any information that would indicate whether the band is playing a concert or not. The premise only states that the band is playing on a stage, which could be part of a concert, but it does not confirm or deny the hypothesis that the band is playing a concert.'}]

# %%
new_refine_train_data
# Out:
# [{'premise': 'A person on a horse jumps over a broken down airplane.',
#   'hypothesis': 'A person is training his horse for a competition.',
#   'label': 1,
#   'explanation_1': 'the person is not necessarily training his horse',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a person is training his horse for a competition" and the premise "a person on a horse jumps over a broken down airplane" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that a person on a horse jumps over a broken down airplane, but it does not specify what the person and horse are doing. It could be that they are training for a competition, but it could also be that they\'re just doing some exercise or practicing jumping or obstacle course. The premise does not indicate if the person is training the horse for a competition or not. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'A person on a horse jumps over a broken down airplane.',
#   'hypothesis': 'A person is at a diner, ordering an omelette.',
#   'label': 2,
#   'explanation_1': 'One cannot be on a jumping horse cannot be a diner ordering food.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the premise describes a person engaging in an activity that is not consistent with the setting described in the hypothesis. In the hypothesis, the person is at a diner ordering an omelette, which implies they are in an indoor, urban setting. However, in the premise, the person is on a horse jumping over a broken down airplane, which implies they are in a rural or wilderness setting, not a diner. These two settings are not compatible and therefore the hypothesis and premise contradict each other.'},
#  {'premise': 'A person on a horse jumps over a broken down airplane.',
#   'hypothesis': 'A person is outdoors, on a horse.',
#   'label': 0,
#   'explanation_1': 'a broken down airplane is outdoors',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a person is outdoors, on a horse" and the premise "a person on a horse jumps over a broken down airplane" is entailment because the premise confirms the hypothesis. The hypothesis states that "a person is outdoors, on a horse," which implies that the person is outside and mounted on a horse. The premise describes a person on a horse jumping over a broken down airplane, which confirms the hypothesis that the person is outside and mounted on a horse. The premise provides additional information about the person\'s location and activity, but it does not contradict the main idea that the person is outside and on a horse. Therefore, the premise confirms the hypothesis "a person is outdoors, on a horse".'},
#  {'premise': 'Children smiling and waving at camera',
#   'hypothesis': 'They are smiling at their parents',
#   'label': 1,
#   'explanation_1': 'Just because they are smiling and waving at a camera does not imply their parents or anyone is anyone behind it',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "they are smiling at their parents" and the premise "children smiling and waving at camera" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that children are smiling and waving at the camera, but it does not specify who they are smiling and waving at, so it is possible that they are smiling and waving at their parents, but it is also possible that they are smiling and waving at someone else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Children smiling and waving at camera',
#   'hypothesis': 'There are children present',
#   'label': 0,
#   'explanation_1': 'The children must be present to see them smiling and waving.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "there are children present" and the premise "children smiling and waving at camera" is entailment because the premise provides evidence that supports the hypothesis. The presence of children smiling and waving in the premise confirms that there are indeed children present, as stated in the hypothesis. The hypothesis is entailed by the premise because the premise is providing visual evidence of the presence of children.'},
#  {'premise': 'Children smiling and waving at camera',
#   'hypothesis': 'The kids are frowning',
#   'label': 2,
#   'explanation_1': 'One cannot be smiling and frowning at the same time.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis states that the kids are frowning, which is the opposite of the premise that states the children are smiling and waving at the camera. The two statements are mutually exclusive and cannot both be true at the same time.'},
#  {'premise': 'A boy is jumping on skateboard in the middle of a red bridge.',
#   'hypothesis': 'The boy skates down the sidewalk.',
#   'label': 2,
#   'explanation_1': 'One cannot be in the middle of a bridge if they are on the sidewalk.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction between the hypothesis "the boy skates down the sidewalk" and the premise "a boy is jumping on a skateboard in the middle of a red bridge" because the hypothesis suggests that the boy is moving on the sidewalk, while the premise suggests that the boy is on a skateboard in the middle of a red bridge. These two statements cannot both be true at the same time, as the sidewalk and red bridge are different locations and the boy cannot be in both places simultaneously. Additionally, the action described in the hypothesis "skating down" is different from the action described in the premise "jumping on". Therefore, the two statements contradict each other.'},
#  {'premise': 'A boy is jumping on skateboard in the middle of a red bridge.',
#   'hypothesis': 'The boy does a skateboarding trick.',
#   'label': 0,
#   'explanation_1': 'jumping on skateboard is the same as doing trick on skateboard.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise "a boy is jumping on Skateboard in the middle of a red bridge" describes an action that is consistent with the hypothesis "the boy does a skateboarding trick." The premise provides additional details and context to the hypothesis, but the basic action of the boy performing a skateboarding trick is still present in the premise.'},
#  {'premise': 'An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.',
#   'hypothesis': 'An older man drinks his juice as he waits for his daughter to get off work.',
#   'label': 1,
#   'explanation_1': 'it is not necessarily true the man drinks his juice',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': "The relation is neutral between the hypothesis and premise because while the hypothesis states that the older man is drinking his juice and waiting for his daughter to get off work, the premise only describes the older man sitting with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background. The premise does not provide any information about the older man's daughter or why he is waiting. Therefore, the hypothesis and premise are not mutually exclusive or mutually dependent and do not contradict or entail each other."},
#  {'premise': 'An older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.',
#   'hypothesis': 'A boy flips a burger.',
#   'label': 2,
#   'explanation_1': 'A boy is not considered an older man.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction between the hypothesis "a boy flips a burger" and the premise "an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background" because the hypothesis states that a specific action (flipping a burger) is happening in a specific setting (presumably a kitchen or grill area), while the premise describes a completely different scene with no indication of a burger-related activity. These two statements cannot both be true at the same time.'},
#  {'premise': 'Two kids stand under an area carved in a large tree.',
#   'hypothesis': 'Two people are by a tree.',
#   'label': 0,
#   'explanation_1': 'Kids are people.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "two people are by a tree" and the premise "two kids stand under an area carved in a large tree" because the premise provides additional information about the location of the two people (i.e., that they are standing under an area carved in a large tree) and confirms that the hypothesis is true. The premise also provides information about the two people being kids, which is not mentioned in the hypothesis but it is entailed by it.'},
#  {'premise': 'A middle-aged woman stands at a green podium with the name "SVA Theatre" written on it.',
#   'hypothesis': 'A woman stands at a podium.',
#   'label': 0,
#   'explanation_1': 'A middle- aged woman stands at a podium.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a woman stands at a podium" and the premise "a middle-aged woman stands at a green podium with the name "sva theatre" written on it" because the premise provides additional information that supports the hypothesis. The hypothesis states that a woman is standing at a podium, and the premise states that a middle-aged woman is standing at a green podium with a specific name, "sva theatre" written on it, which confirms the hypothesis that a woman is standing at a podium. Therefore, the premise entails the hypothesis.'},
#  {'premise': 'These two people are eating.',
#   'hypothesis': 'Two humans are having a meal.',
#   'label': 0,
#   'explanation_1': 'people are human. Eating means the same thing as having a meal.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between hypothesis: "two humans are having a meal" and premise: "these two people are eating." because the premise "these two people are eating" is a specific instance of the more general statement in the hypothesis "two humans are having a meal." The premise provides additional information that the two individuals in question are indeed people and that they are eating, which confirms the hypothesis.'},
#  {'premise': 'A singer entertaining the crowd.',
#   'hypothesis': 'A singer sings their most famous song.',
#   'label': 1,
#   'explanation_1': 'A singer is singing his favorite song ib the crowd',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a singer sings their most famous song" and the premise "a singer entertaining the crowd" because the premise does not specify what song the singer is singing, so it could be their most famous song, but it could also be a different song. Therefore, the premise does not support or contradict the hypothesis.'},
#  {'premise': 'Two men are playing acoustic guitars.',
#   'hypothesis': 'The two men play very well.',
#   'label': 1,
#   'explanation_1': 'Just because men play acoustic guitars it does not mean they play very well.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the two men play very well" and the premise "two men are playing acoustic guitars" is neutral because the premise does not confirm or deny the hypothesis. The hypothesis states that "the two men play very well," which implies that the two men have a high level of skill or proficiency in playing the guitars. The premise describes two men playing acoustic guitars, which does not confirm or deny the hypothesis. It is not specified whether the two men are playing well or not. It could be that they are playing well, poorly, or somewhere in between. The premise does not provide any information about the skill level of the men playing the guitars, making the relation neutral.'},
#  {'premise': 'An aerial view of a group of meeting talking to each other.',
#   'hypothesis': 'The people are having a business meeting.',
#   'label': 1,
#   'explanation_1': 'Not all group of meeting is business meeting.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the people are having a business meeting" and the premise "an aerial view of a group of people talking to each other" is neutral because the premise provides general information about a group of people talking to each other, but it does not specify that they are having a business meeting. The premise does not necessarily support or contradict the hypothesis.'},
#  {'premise': 'A woman is bending over a colorfully striped, metal couch on a sidewalk that has a bucket sitting atop it.',
#   'hypothesis': 'The woman is cooking dinner.',
#   'label': 2,
#   'explanation_1': 'The woman cooking dinner is contradictory to the woman in first sentence bending over a couch.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis suggests the woman is engaged in the activity of cooking dinner, which typically takes place indoors and involves the use of a kitchen, whereas the premise describes the woman as being outdoors on a sidewalk, in proximity to a couch and a bucket. These two descriptions are not consistent with each other, and therefore the hypothesis and premise contradict each other.'},
#  {'premise': 'People are walking around a park area.',
#   'hypothesis': 'The people are outside.',
#   'label': 0,
#   'explanation_1': 'park area refers to outside.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the people are outside" and the premise "people are walking around a park area" is entailment because the premise confirms the hypothesis. The hypothesis states that "the people are outside", which implies that the people are in an open-air environment and not indoors. The premise describes people walking around a park area, which implies that the people are outside in a public park where people can walk and enjoy the nature. This confirms that the people are outside, as the park area is an open-air environment. Therefore, the premise confirms the hypothesis that "the people are outside".'},
#  {'premise': 'Women walking down the street in jeans, black high heel boots, and a beige handbag.',
#   'hypothesis': 'The man is working on his car',
#   'label': 2,
#   'explanation_1': 'Women are walking in Sentence 1. In Sentence 2 a man is working.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that the man is working on his car, which suggests that he is engaged in a specific activity related to automobiles. However, the premise describes a group of women who are walking down the street, which is not related to the man working on a car and thus contradicts the hypothesis.'},
#  {'premise': 'Two females in bikinis are playing table tennis at the beach while another female in a towel watches.',
#   'hypothesis': 'Women are competing in a table tennis tournament at the beach.',
#   'label': 1,
#   'explanation_1': "We don't know that there is a tournament.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral because the hypothesis and the premise both describe women competing in a table tennis tournament at the beach, but the premise also includes additional details such as what they are wearing. The additional details do not contradict or support the statement in the hypothesis, so the relation is neutral.'},
#  {'premise': 'A woman wearing gloves working at a meat counter.',
#   'hypothesis': 'A nurse is pushing a surgical cart',
#   'label': 2,
#   'explanation_1': 'A meat counter and a surgical cart are found in completely separate places.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis and premise describe two very different scenarios. In the hypothesis, a nurse is described as pushing a surgical cart in a hospital setting, while in the premise, a woman is described as working at a meat counter in a grocery store. These two images are not consistent with each other and therefore, the relation is a contradiction.'},
#  {'premise': 'Two men in safety vests walk down the road.',
#   'hypothesis': 'Two people are playing cribbage.',
#   'label': 2,
#   'explanation_1': 'People walking down the road cannot be engaged in playing cribbage.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "two people are playing cribbage" and the premise "two men in safety vests walk down the road" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that two people are playing cribbage, which implies they are in a stationary location, most likely indoors, and are engaged in a game. On the other hand, the premise states that two men are walking down the road, which implies that they are in motion, and most likely outdoors. These two statements cannot both be true at the same time as the people described in the hypothesis are not doing the same activity as the men described in the premise. Therefore, the relation between these two statements is a contradiction.'},
#  {'premise': 'Two ladies are cooking & talking and two gentlemen are talking in the opposite site of the kitchen.',
#   'hypothesis': 'Two couples are preparing dinner together.',
#   'label': 1,
#   'explanation_1': "Just because it's two men and two women doesn't mean they're couples.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis and premise is neutral because the premise describes two couples engaging in separate activities in the kitchen, while the hypothesis states that they are preparing dinner together. The premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Two men handle a large telescope while one is looking through.',
#   'hypothesis': 'The men are watching a movie in public theatres in different states',
#   'label': 2,
#   'explanation_1': 'If the men are watching a movie, they are not handling a large telescope',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis states that the men are watching a movie in public theatres in different states, while the premise states that two men are handling a large telescope and one is looking through it. These two statements are mutually exclusive, as it is unlikely that the men would be able to watch a movie in public theatres in different states while also handling a telescope at the same time. Therefore, the hypothesis and premise are contradictory.'},
#  {'premise': 'A man running on a track.',
#   'hypothesis': 'A man is taking a run on the track.',
#   'label': 0,
#   'explanation_1': 'Running and taking a run are the same thing.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a man is taking a run on the track" and the premise "a man running on a track" is entailment because the premise provides additional information that confirms the hypothesis. The hypothesis states that a man is taking a run, which implies that he is moving, and the premise confirms that the man is indeed running, which is a specific type of movement. Therefore, the premise provides evidence that supports the hypothesis, making them consistent with each other.'},
#  {'premise': 'Two women and a man in a room that has a sign reading "Artisti" on its door.',
#   'hypothesis': 'The 3 people are trying to figure out what the sign on the door means and are a little worried that they may be in the wrong room.',
#   'label': 1,
#   'explanation_1': "Just because two women and a man in a room that has a sign reading 'Artisti' on its door does not mean they   are a little worried that they may be in the wrong room.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral because while the hypothesis suggests that the three people are trying to figure out what the sign on the door means and are a little worried that they may be in the wrong room, the premise simply states that two women and a man are in a room that has a sign reading "artisti" on its door. The premise does not provide any information about the people\'s actions or emotions, so it cannot confirm or deny the hypothesis.'},
#  {'premise': 'The tourists are out on the river in Italy, the man in the black and white striped shirt will tell them about the seine.',
#   'hypothesis': 'The tourists are getting a gondola ride.',
#   'label': 1,
#   'explanation_1': "The fact that tourists are out on the river in Italy doesn't imply that they are having a gondola ride",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the tourists are getting a gondola ride" and the premise "the tourists are out on the river in Italy, the man in the black and white striped shirt will tell them about the Seine" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that the tourists are out on the river in Italy and that a man in a black and white striped shirt will tell them about the Seine, but it does not specify what the tourists are doing or where they are exactly. The premise does not specify if they are in a gondola or not, so it is possible that they are getting a gondola ride, but it is also possible that they are doing something else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Couple walking passed a clock tower.',
#   'hypothesis': 'There are people running',
#   'label': 2,
#   'explanation_1': 'The couple cannot be running and walking at the same time.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction between the hypothesis "there are people running" and the premise "couple walking passed a clock tower" because the hypothesis states that people are running, while the premise states that people are walking. These two statements are incompatible and cannot both be true at the same time. The fact that people are running implies that they are moving quickly and with purpose, while the fact that people are walking implies a slower and more leisurely pace. The contradiction is that the two statements give different information about the activity of the people.'},
#  {'premise': 'Dog on a red leash with a woman.',
#   'hypothesis': 'A woman and dog are together.',
#   'label': 0,
#   'explanation_1': 'The leash is for the dog.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a woman and dog are together" and the premise "dog on a red leash with a woman" because the premise provides specific details that confirm the hypothesis. The premise states that there is a dog on a red leash with a woman, which implies that the woman and dog are together as stated in the hypothesis. The information in the premise supports and confirms the information in the hypothesis.'},
#  {'premise': 'A woman with brown hair wearing a red polka dot dress is singing into a microphone.',
#   'hypothesis': 'a woman singing',
#   'label': 0,
#   'explanation_1': 'A woman is singing in both examples.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a woman singing" and the premise "a woman with brown hair wearing a red polka dot dress is singing into a microphone" is entailment because the premise provides more information that supports the hypothesis. The hypothesis states that a woman is singing, which means that she is producing sound with her voice. The premise describes a woman with brown hair wearing a red polka dot dress who is singing into a microphone, which confirms the hypothesis that a woman is singing. It also gives additional information such as the woman\'s appearance, clothing and the tool she\'s using to produce the sound (microphone) which supports the hypothesis that a woman is singing. Therefore, the premise entails the hypothesis, making the relation entailment.'},
#  {'premise': 'A woman wearing a blue dress and carrying a purple umbrella is walking in parking lot.',
#   'hypothesis': 'The woman is walking back to her car after shopping.',
#   'label': 1,
#   'explanation_1': 'Walking does not imply going back to her car or that she just finished shopping.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the woman is walking back to her car after shopping" and the premise "a woman wearing a blue dress and carrying a purple umbrella is walking in a parking lot" because the premise provides some information about the woman\'s appearance and location, but does not confirm or deny the specific action of her returning to her car after shopping. The premise does not provide enough information to confirm or contradict the hypothesis.'},
#  {'premise': 'A dancer performing with her panties showing.',
#   'hypothesis': "The girl's costume is too short.",
#   'label': 1,
#   'explanation_1': 'Just because a dancer is performing with her panties showing it does not mean the costume is too short.  A dancer does not have to be a girl.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the girl\'s costume is too short" and the premise "a dancer performing with her panties showing" because the hypothesis states a specific condition about the girl\'s costume (i.e., that it is too short), while the premise describes a general situation (i.e., a dancer performing) without specifying anything about the costume. It is possible that the dancer in the premise is the girl mentioned in the hypothesis, but without more information it is not clear if that is the case. Therefore, the two statements do not directly support or contradict each other.'},
#  {'premise': 'Two Asia women are riding on a cart as a man pulls them through the street.',
#   'hypothesis': 'The two women are riding a cart outside.',
#   'label': 0,
#   'explanation_1': 'Asian women are women.  The street is outside.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "the two women are riding a cart outside" and the premise "two asia women are riding on a cart as a man pulls them through the street" because the premise provides specific details that support and expand upon the information in the hypothesis. The hypothesis states that the women are riding a cart, and the premise provides additional information that they are Asian women, and that they are being pulled through the street by a man. This additional information supports and adds to the information provided in the hypothesis, making the premise an entailment of the hypothesis.'},
#  {'premise': 'The long-haired man is balancing on a drum that is being carried by men in white shirts.',
#   'hypothesis': 'A man is being carried.',
#   'label': 0,
#   'explanation_1': 'long-haired man implies man',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise "the long-haired man is balancing on a drum that is being carried by men in white shirts" provides more information and context about the hypothesis "a man is being carried." The additional information in the premise confirms that the man is indeed being carried by other men and adds detail to the image of the scene.'},
#  {'premise': 'A man wearing only a cowboy hat, cowboy boots, and underwear talks to a woman on a city street.',
#   'hypothesis': 'A man wearing a cowboy hat swings a baseball bat.',
#   'label': 2,
#   'explanation_1': 'Talking to a woman is not the same as swinging a baseball bat.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction between the hypothesis "a man wearing a cowboy hat swings a baseball bat" and the premise "a man wearing only a cowboy hat, cowboy boots, and underwear talks to a woman on a city street" because the premise states that the man is only wearing a cowboy hat, cowboy boots, and underwear and is talking to a woman on a city street, while the hypothesis states that the man is wearing a cowboy hat and swinging a baseball bat, which are two completely different and mutually exclusive actions and scenarios. Therefore, the hypothesis and the premise are contradictory.'},
#  {'premise': 'A woman in checkered knee-highs and jean shorts walks down a city sidewalk street while smoking a cigarette.',
#   'hypothesis': 'The woman in knee-highs and jean shorts is walking down the sidewalk smoking.',
#   'label': 0,
#   'explanation_1': 'Walking down a sidewalk means that they are in the city where many sidewalks are.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise provides additional information that supports the hypothesis. The specific details provided in the premise, such as the woman wearing knee-highs and jean shorts, and smoking a cigarette, are consistent with and support the general statement made in the hypothesis that a woman is walking down the sidewalk smoking.'},
#  {'premise': 'Soccer players playing a game in front of a big crowd.',
#   'hypothesis': 'Soccer players play in the world championship in front of a sell out audience.',
#   'label': 1,
#   'explanation_1': 'A big crowd does not mean a world championship and a big crowd does not mean a sell out audience.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral because the premise provides no information about the context of the soccer game, such as whether it is a world championship or whether the audience is a sell-out crowd, while the hypothesis does. The premise only states that soccer players are playing a game in front of a big crowd, which is not necessarily enough information to determine whether the game is a world championship or not.'},
#  {'premise': 'A young boy wearing a bright yellow raincoat, jean shorts and sandals squats down as he looks at an older boy and girl who are standing next to him and looking down some railroad tracks.',
#   'hypothesis': 'It is raining',
#   'label': 1,
#   'explanation_1': 'Wearing a raincoat does not imply it is raining.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': "The relation is neutral because the premise describes a specific scene with specific details, while the hypothesis simply states that it is raining. The premise does not confirm or deny the hypothesis that it is raining, it simply describes a scene that could be happening in the rain. While the boy is wearing a yellow raincoat, it doesn't confirm that it is raining, it could be worn for protection. Thus the premise does not provide any information that would contradict the hypothesis."},
#  {'premise': 'An Asian woman is selling colorful fabrics.',
#   'hypothesis': 'The woman is trying to make a living.',
#   'label': 1,
#   'explanation_1': 'Just because there is an Asian woman selling colorful fabrics, it does not necessarily mean that she is trying to make a living.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the woman is trying to make a living" and the premise "an asian woman is selling colorful fabrics" because while the premise describes an action that may be associated with someone trying to make a living, it does not directly confirm or refute the hypothesis. The premise simply provides a visual image of the woman selling fabrics, without any additional context or information about her motivations or circumstances.'},
#  {'premise': 'A boy in colorful pants plays guitar and laughs together with his friends.',
#   'hypothesis': 'He is happy.',
#   'label': 0,
#   'explanation_1': 'Boy laughs shows that he is happy.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "he is happy" and the premise "a boy in colorful pants plays guitar and laughs together with his friends" is entailment because the premise confirms the hypothesis. The hypothesis states that "he is happy" which implies that the person is in a positive emotional state. The premise describes a boy in colorful pants who is playing guitar and laughing together with his friends, which implies that the boy is enjoying himself and having a good time. Laughter and playing guitar with friends is a strong indication of happiness. Therefore, the premise confirms the hypothesis that "he is happy".'},
#  {'premise': 'A man and two women are browsing through a market that sells vases, jewelery and other items.',
#   'hypothesis': 'There are people dancing in the rain.',
#   'label': 2,
#   'explanation_1': 'browsing through a market and dancing in the rain cannot be done simultaneously.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "there are people dancing in the rain" and the premise "a man and two women are browsing through a market that sells vases, jewelry, and other items" is a contradiction because the two statements describe completely different actions and locations. The hypothesis implies that people are actively engaging in a specific activity (dancing) in a specific weather condition (rain), while the premise describes a completely different activity (browsing through a market) and location (indoors). These two statements cannot both be true at the same time, which is why the relation between them is a contradiction.'},
#  {'premise': 'an man in the north pole walking on ice.',
#   'hypothesis': 'The man is in a desert.',
#   'label': 2,
#   'explanation_1': 'The man cannot be both at the north pole and in a desert.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the man is in a desert" and the premise "a man in the North Pole walking on ice" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that the man is in a desert, which is a hot and dry area with little vegetation, while the premise states that the man is in the North Pole, which is a cold and icy area with no vegetation. These two statements cannot both be true at the same time as they describe two completely different environments and conditions. Therefore, the relation between these two statements is a contradiction.'},
#  {'premise': 'Three people serving food outside somewhere.',
#   'hypothesis': 'A woman takes a bath.',
#   'label': 2,
#   'explanation_1': 'Three people is a group, a woman suggest one person. Also, someone does not serve food outside while taking a bath',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction between the hypothesis "a woman takes a bath" and the premise "three people serving food outside somewhere" because the two statements describe two completely different and unrelated actions that cannot coexist at the same time. The hypothesis describes an individual doing a solitary activity in a private setting, while the premise describes a group of individuals performing an interactive activity in a public setting. The two statements are not compatible with each other and therefore contradict each other.'},
#  {'premise': 'A young lacrosse player is catching his breath.',
#   'hypothesis': "Sports aren't played they are worn",
#   'label': 2,
#   'explanation_1': "The sport isn't being played if the player is catching their breath.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "Sports aren\'t played they are worn" and the premise "A young lacrosse player is catching his breath" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that sports are not played, they are worn, which implies that they are not an activity but rather a clothing or gear. On the other hand, the premise states that a young lacrosse player is catching his breath, which implies that he is engaged in an activity that requires physical effort and exertion, that is playing lacrosse. These two statements cannot both be true at the same time as the lacrosse player is playing and not wearing it. Therefore, the relation between these two statements is a contradiction.'},
#  {'premise': 'Two men chase cattle on horses.',
#   'hypothesis': 'Two men are with animals.',
#   'label': 0,
#   'explanation_1': 'In order to be chase animals, the men must be with them.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "two men are with animals" and the premise "two men chase cattle on horses" is entailment because the premise confirms the hypothesis. The hypothesis states that "two men are with animals", which implies that the two men are in the presence of or interacting with animals. The premise describes two men chasing cattle on horses, which implies that the two men are with animals as they are interacting with cattle, which are animals. Additionally, the fact that they are doing so on horses also confirms that they are with animals. Therefore, the premise confirms the hypothesis that "two men are with animals".'},
#  {'premise': 'The little boy is in the swimming pool with an adult woman.',
#   'hypothesis': 'At least two people are in the pool.',
#   'label': 0,
#   'explanation_1': 'Little boy and adult woman are both people',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise states that there is at least one adult woman and one little boy in the pool, which meets the minimum requirement stated in the hypothesis of "at least two people" being in the pool. The premise provides additional information about the specific individuals in the pool, but it does not contradict the statement in the hypothesis.'},
#  {'premise': 'A group of native adults and children are sitting in a circle playing a game.',
#   'hypothesis': 'People are playing.',
#   'label': 0,
#   'explanation_1': 'Native adults and children are just as accurately described as people.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "people are playing" and the premise "a group of native adults and children are sitting in a circle playing a game" is entailment because the premise provides specific information that supports the general idea presented in the hypothesis. The premise describes a specific instance of people playing, which is what the hypothesis states is happening. The premise provides additional details, such as that the people are native and that they are playing a game, but these details do not contradict or negate the general idea that people are playing, as stated in the hypothesis. Therefore, the premise entails the hypothesis.'},
#  {'premise': 'An giant egged shaped collection of flowers.',
#   'hypothesis': 'an giant collected flowers',
#   'label': 1,
#   'explanation_1': "There isn't necessarily any giant, and the giant didn't necessarily collect any flowers.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "an giant collected flowers" and the premise "an giant egged shaped collection of flowers" because the premise does not provide any information about whether the flowers were collected by a giant or not. The premise simply describes an object made of flowers that has an egg-shaped form, without providing any information about the action or context. Therefore, the premise does not support or contradict the hypothesis, and the relation is neutral.'},
#  {'premise': 'Several people walk up a staircase.',
#   'hypothesis': 'The people are going upstairs.',
#   'label': 0,
#   'explanation_1': 'If people are walking up a staircase, then people are going upstairs.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "the people are going upstairs" and the premise "several people walk up a staircase" is entailment, because the premise provides additional information that confirms the hypothesis. The hypothesis states that the people are going upstairs, and the premise shows that they are physically walking up a staircase, which confirms that they are indeed going upstairs.'},
#  {'premise': 'Woman sets in cage and plays with rabbits.',
#   'hypothesis': 'Man sets in cage and plays with rabbits.',
#   'label': 2,
#   'explanation_1': 'A woman and a man is two different people.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis states that a man is in the cage and playing with rabbits, while the premise states that a woman is in the cage and playing with rabbits. These statements cannot both be true at the same time, as they describe different genders of the person in the cage. This is a clear contradiction.'},
#  {'premise': 'A man sitting on a curb in a city park.',
#   'hypothesis': 'The man is standing.',
#   'label': 2,
#   'explanation_1': 'The man cannot both be sitting and standing at the same time.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that the man is standing, while the premise states that the man is sitting on a curb. These two statements cannot both be true at the same time, as standing and sitting are mutually exclusive actions. Therefore, the hypothesis and the premise are in direct opposition to each other.'},
#  {'premise': 'A man wearing a yellow coat stands at the peak of a mountain.',
#   'hypothesis': 'A man wearing a coat stands on a hill.',
#   'label': 1,
#   'explanation_1': 'Mountain does not imply hill.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a man wearing a coat stands on a hill" and the premise "a man wearing a yellow coat stands at the peak of a mountain" is neutral. This is because the hypothesis provides information about the man wearing a coat and standing on a hill, while the premise provides information about the man wearing a yellow coat and standing at the peak of a mountain. Both the hypothesis and the premise contain information about a man wearing a coat and standing on a hill, but the premise also includes additional information about the man\'s coat being yellow and him standing at the peak of a mountain. The additional information in the premise doesn\'t contradict or entail the information in the hypothesis, it\'s just supplementary information.'},
#  {'premise': 'Asian people are standing outside a store named Concepts.',
#   'hypothesis': "Store has people standing around it's exterior.",
#   'label': 0,
#   'explanation_1': "Standing outside the store is the same thing as saying that they are standing around the store's exterior.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "store has people standing around it\'s exterior" and the premise "asian people are standing outside a store named concepts" is entailment because the premise provides evidence that supports the hypothesis. The premise specifically states that there are people standing outside a store, and the store is named "concepts", which confirms that there is a store with people standing around its exterior. Therefore, the premise entails the hypothesis, meaning that the hypothesis is logically supported by the premise.'},
#  {'premise': 'A person wearing a blue shirt, gray pants, and black shoes is laying on the ground next to a crutch.',
#   'hypothesis': 'A person is wearing his church clothes as he lays on the ground.',
#   'label': 1,
#   'explanation_1': 'Not everyone wears a blue shirt, gray pants, and black shoes as church clothes',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral because the premise does not specify that the person is wearing "church clothes" as the hypothesis states. The premise provides a description of the person\'s clothing, but it does not provide enough information to confirm or contradict the hypothesis that the person is wearing "church clothes."'},
#  {'premise': 'Two men sit at a glass table with papers on it.',
#   'hypothesis': 'The table was wood.',
#   'label': 2,
#   'explanation_1': 'A table made of wood is not glass simultaneously.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the hypothesis states that the table is made of wood, while the premise states that the table is made of glass. These two statements cannot both be true at the same time, as a table cannot be made of both wood and glass. This is an example of a logical contradiction, as it is impossible for both statements to be true.'},
#  {'premise': 'A man is sitting in the middle of a room in an art gallery, and is putting some frames together, preparing a piece of art for hanging.',
#   'hypothesis': 'The man is indoors.',
#   'label': 0,
#   'explanation_1': 'if he is in the middle of a room in an art gallery, that is indoors.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "the man is indoors" and the premise "a man is sitting in the middle of a room in an art gallery, and is putting some frames together, preparing a piece of art for hanging" because the premise provides additional information that confirms that the man is indeed indoors. The hypothesis says that the man is indoors, and the premise provides evidence that supports this by describing the location of the man as being in a room in an art gallery, which is typically an indoor space.'},
#  {'premise': 'Man in sweater stacks wooden crates next to pile of plastic crates.',
#   'hypothesis': 'A man working hard.',
#   'label': 0,
#   'explanation_1': 'A man stacking a pile of crates next to another pile of crates implies that he has already created one stack and is working on another, and is therefore working hard.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise provides additional information that supports the hypothesis. The hypothesis states that the man is working hard and the premise describes the man in specific detail, stacking wooden crates next to a pile of plastic crates. This action of stacking crates is an indication that the man is indeed working hard.'},
#  {'premise': 'Several horses are running a race on a muddy track.',
#   'hypothesis': 'The horses are in their stalls in the barn.',
#   'label': 2,
#   'explanation_1': 'track  not the same as barn',
#   'explanation_2': '',
#   'explanation_3': '',
# ...
#   'hypothesis': 'Two motorcylists are driving up a mountain.',
#   'label': 2,
#   'explanation_1': 'A means one, two means 2.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that two motorcyclists are driving up a mountain, but the premise states that only one motorcyclist is driving while the other bike remains stationary. The two statements cannot both be true at the same time, as only one motorcyclist is seen to be moving in the premise, while the hypothesis states that both are moving.'},
#  {'premise': 'Four boys play in the mud.',
#   'hypothesis': 'Four boys are outside.',
#   'label': 0,
#   'explanation_1': 'The mud is found outside.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "four boys are outside" and the premise "four boys play in the mud" because the premise is a specific example of the situation described in the hypothesis. If it is known that there are four boys outside, it must be true that they are playing in the mud, as the premise states. The premise provides additional information that is entailed by the hypothesis.'},
#  {'premise': 'Two boys with unicycles stand outside of a street shop.',
#   'hypothesis': 'Two boys ride regular bicycles during a race.',
#   'label': 2,
#   'explanation_1': 'The two boys either ride a regular bicycles or a unicycles.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction between the hypothesis "two boys ride regular bicycles during a race" and the premise "two boys with unicycles stand outside of a street shop" because the hypothesis states that the boys are riding regular bicycles, while the premise states that they are riding unicycles. These two statements cannot both be true at the same time, as a regular bicycle and a unicycle are two different types of vehicles and therefore are mutually exclusive. Therefore, the relation is contradiction.'},
#  {'premise': 'The girl wears a purple outfit and swings upside down.',
#   'hypothesis': 'The girls is having fun at the park.',
#   'label': 1,
#   'explanation_1': 'The girl wears a purple outfit and swings upside down does not indicate that she is having fun at the park.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "the girl is having fun at the park" and the premise "the girl wears a purple outfit and swings upside down" because the premise only describes the girl\'s appearance and actions, but it does not provide any information about the girl\'s emotional state or the context in which she is participating in those actions. The hypothesis suggests that the girl is having fun, but the premise does not confirm or deny this. It is possible that the girl is having fun at the park, but it is also possible that she is not.'},
#  {'premise': 'A man is cutting a fish.',
#   'hypothesis': 'a man wields a tool',
#   'label': 0,
#   'explanation_1': 'A man who weild tools is cutting a fish.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a man wields a tool" and the premise "a man is cutting a fish" because the premise provides specific information that supports the hypothesis. The hypothesis states that a man is using a tool and the premise specifies that the man is cutting a fish, which requires the use of a tool such as a knife. Therefore, the premise confirms that the man is indeed using a tool, and thus the two statements are logically consistent.'},
#  {'premise': 'A man and woman dressed in old fashion clothing sit outside at a table.',
#   'hypothesis': 'The man is lying in bed.',
#   'label': 2,
#   'explanation_1': "If the man and woman are sitting outside, the man can't be lying in bed at the same time.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction because the hypothesis states that the man is lying in bed, which is an indoor and sedentary activity, while the premise describes the man and woman sitting outside at a table, which is an outdoor and active activity. These two descriptions are mutually exclusive and cannot both be true at the same time, hence the contradiction.'},
#  {'premise': 'A group of basketball players jump in the air for the ball.',
#   'hypothesis': 'A basketball game is being played.',
#   'label': 0,
#   'explanation_1': 'A game is played by players',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise "a group of basketball players jump in the air for the ball" implies that a basketball game is being played. The action described in the premise, the players jumping for the ball, is a specific aspect of a basketball game and therefore the premise supports the hypothesis "a basketball game is being played."'},
#  {'premise': 'A long bearded man plays a furry guitar.',
#   'hypothesis': 'A bearded man plays guitar.',
#   'label': 0,
#   'explanation_1': 'A bearded man plays guitar is the same as a bearded man plays guitar.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment between the hypothesis "a bearded man plays guitar" and the premise "a long bearded man plays a furry guitar" because the premise provides additional information about the man\'s beard and the guitar that he is playing, but it does not change the fact that the man is playing a guitar, which is stated in the hypothesis. The premise is consistent with the hypothesis and adds more details to it.'},
#  {'premise': 'A guy in white shirt and black pants is running.',
#   'hypothesis': 'A guy is running from the police.',
#   'label': 1,
#   'explanation_1': "Just because a man is running, it doesn't mean he is running from the police.",
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a guy is running from the police" and the premise "a guy in white shirt and black pants is running" because the premise only states that a guy in a certain clothing is running, it doesn\'t specify the reason why he is running, so it could be from the police or for another reason, the premise does not support or contradict the hypothesis.'},
#  {'premise': 'A male doing a trick in the air on his bike.',
#   'hypothesis': 'A man is competing on a bike.',
#   'label': 1,
#   'explanation_1': 'Just because a male is doing a trick in the air on his bike does not necessarily mean he is competing on a bike.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a man is competing on a bike" and the premise "a male doing a trick in the air on his bike" because the premise does not indicate whether the man is competing or not, it only describes an action of a man on a bike. The premise does not provide any information about a competition or a race, so it does not confirm or contradict the hypothesis.'},
#  {'premise': 'A donkey pulled cart is carrying produce down a street.',
#   'hypothesis': 'a cart is sinking in the ocean',
#   'label': 2,
#   'explanation_1': 'street is contradictory to ocean',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is a contradiction between the hypothesis and the premise because the hypothesis states that a cart is sinking in the ocean, which implies that it is in water and unable to be used. However, the premise states that a donkey pulled cart is carrying produce down a street, which implies that the cart is on land and being used for transportation. These two statements cannot both be true at the same time and thus, the relation between the hypothesis and the premise is a contradiction.'},
#  {'premise': 'Two men and a woman playing cards.',
#   'hypothesis': 'Three people play gin rummy.',
#   'label': 1,
#   'explanation_1': 'Gin rummy is not the only card game.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "three people play gin rummy" and the premise "two men and a woman playing cards" because while the premise states that there are two men and a woman playing cards, it does not specify the game they are playing. Therefore, it is possible that they could be playing gin rummy, but it is not confirmed.'},
#  {'premise': 'A young baby boy crying while wearing a shirt that says "I am the BOSS."',
#   'hypothesis': 'A boy in an ironic shirt cries.',
#   'label': 0,
#   'explanation_1': 'The boy wearing the shirt cries.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise provides additional information that the boy is crying, and also that he is wearing an ironic shirt. The hypothesis states that the boy is crying and the premise confirms this by stating that the boy is crying, while also providing additional information about the shirt he is wearing. Therefore, the premise logically follows from the hypothesis.'},
#  {'premise': 'Two women conversing on a sidewalk.',
#   'hypothesis': 'Women are standing on the sidewalk.',
#   'label': 1,
#   'explanation_1': 'Conversing does not mean they are standing.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "women are standing on the sidewalk" and the premise "two women conversing on a sidewalk" because the hypothesis states that the women are standing, while the premise does not specify whether they are standing or sitting. Both statements are true, but the premise doesn\'t give additional information to the hypothesis.'},
#  {'premise': 'A young boy wearing a tank-top is climbing a tree.',
#   'hypothesis': 'A boy was showing off for a girl.',
#   'label': 1,
#   'explanation_1': 'A boy is climbing a tree does not necessarily mean that he is showing off for a girl.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a boy was showing off for a girl" and the premise "a young boy wearing a tank-top is climbing a tree" is neutral because the premise doesn\'t provide enough information to confirm or contradict the hypothesis. The hypothesis states that the boy was showing off for a girl, which implies that there is a girl present and the boy is doing something to impress her. The premise describes a young boy wearing a tank-top climbing a tree, which doesn\'t provide enough information to confirm or contradict the hypothesis. The premise doesn\'t tell us if there is a girl present or not and doesn\'t tell us if the boy is doing something to impress her or not. Therefore, the premise doesn\'t give enough information to confirm or contradict the hypothesis "a boy was showing off for a girl" thus the relation is neutral.'},
#  {'premise': 'There is a red truck behind the horses.',
#   'hypothesis': 'The horses are becoming suspicious of my apples.',
#   'label': 2,
#   'explanation_1': 'There can be either a truck or apples.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is contradiction because the premise ("there is a red truck behind the horses") does not match the hypothesis ("the horses are becoming suspicious of my apples"). The horse\'s behavior is described as being suspicious of apples, not having any relation with a red truck. The two statements are not related and cannot both be true at the same time.'},
#  {'premise': 'A black truck and a red car parked on the street in front of a grocery store painted red.',
#   'hypothesis': 'Two vehicles were parked next to a Toyota.',
#   'label': 1,
#   'explanation_1': 'It is not mandatory to park near to a Toyota',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "two vehicles were parked next to a toyota" and the premise "a black truck and a red car parked on the street in front of a grocery store painted red" because while the premise provides information about two specific vehicles (a black truck and a red car) being parked on the street, it does not specify the location of the vehicles in relation to one another. The hypothesis implies that there is a Toyota parked next to the two vehicles, but this information is not provided in the premise. Therefore, the premise does not confirm or deny the claim made in the hypothesis.'},
#  {'premise': 'A large brown dog is sticking his face in the sprinkler.',
#   'hypothesis': 'A large brown dog is standing oustide.',
#   'label': 0,
#   'explanation_1': 'Sprinklers are usually outside not inside so the dog sticking his face in the sprinkler must be standing outside',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is entailment because the premise provides additional information about the large brown dog in the hypothesis, specifically that it is standing outside and sticking its face in a sprinkler, which is an action that a dog standing outside may do. The premise does not contradict the hypothesis, but rather adds to it.'},
#  {'premise': 'A male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs.',
#   'hypothesis': 'A surgeon performs open heart surgery.',
#   'label': 1,
#   'explanation_1': 'Not all surgery is open heart surgery.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation between the hypothesis "a surgeon performs open heart surgery" and the premise "a male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The hypothesis states that a surgeon performs open heart surgery, which is a specific type of surgery, and the premise provides information about a male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs. The premise does not specify what type of surgery is being performed, and it only describes the attire and appearance of the surgeons and the fact that they are performing surgery. It does not indicate whether the surgery is open heart surgery or not. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.'},
#  {'premise': 'Four young women are painting in countries of a map that is painted on a wall.',
#   'hypothesis': 'Some artists are painting a wall.',
#   'label': 1,
#   'explanation_1': 'Four young women painting are not necessarily artists.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "some artists are painting a wall" and the premise "four young women are painting in countries of a map that is painted on a wall" because the premise describes a specific situation, but the hypothesis is more general and does not specify that the artists are women or that they are painting a map on a wall. The hypothesis is compatible with the premise, but the premise does not provide any additional information or context to confirm or deny the hypothesis.'},
#  {'premise': 'This band is playing on a stage.',
#   'hypothesis': 'A band is playing a concert.',
#   'label': 1,
#   'explanation_1': 'Playing on stage does not imply playing a concert.',
#   'explanation_2': '',
#   'explanation_3': '',
#   'our_explanation': 'The relation is neutral between the hypothesis "a band is playing a concert" and the premise "this band is playing on a stage" because both the hypothesis and the premise mention the band playing, but do not provide any information that would indicate whether the band is playing a concert or not. The premise only states that the band is playing on a stage, which could be part of a concert, but it does not confirm or deny the hypothesis that the band is playing a concert.'}]

# %%
ral_inp_dict.keys()
# Out:
# dict_keys(['explain why the relation is neutral between hypothesis: they are smiling at their parents and premise: children smiling and waving at camera</s>', 'explain why the relation is contradiction between hypothesis: two people are playing cribbage. and premise: two men in safety vests walk down the road.</s>', 'explain why the relation is neutral between hypothesis: the tourists are getting a gondola ride. and premise: the tourists are out on the river in italy, the man in the black and white striped shirt will tell them about the seine.</s>', 'explain why the relation is neutral between hypothesis: a person is training his horse for a competition. and premise: a person on a horse jumps over a broken down airplane.</s>', 'explain why the relation is contradiction between hypothesis: the man is in a desert. and premise: an man in the north pole walking on ice.</s>', 'explain why the relation is entailment between hypothesis: a woman ropes an animal. and premise: a woman on the back of a horse ropes a cattle.</s>', "explain why the relation is contradiction between hypothesis: sports aren't played they are worn and premise: a young lacrosse player is catching his breath.</s>", 'explain why the relation is neutral between hypothesis: a surgeon performs open heart surgery. and premise: a male surgeon wearing a red cap and teal scrubs performing surgery with two other men wearing teal scrubs.</s>', 'explain why the relation is neutral between hypothesis: a man awaits the results of his hiv test. and premise: a man in a blue long-sleeved jacket crying out of fear.</s>', 'explain why the relation is neutral between hypothesis: the people are trying to get their ball back. and premise: people holding onto ropes while trying to get something through a window on the second floor.</s>', 'explain why the relation is entailment between hypothesis: he is happy. and premise: a boy in colorful pants plays guitar and laughs together with his friends.</s>', 'explain why the relation is entailment between hypothesis: the people are outside. and premise: people are walking around a park area.</s>', 'explain why the relation is entailment between hypothesis: two men are with animals. and premise: two men chase cattle on horses.</s>', 'explain why the relation is neutral between hypothesis: the two men play very well. and premise: two men are playing acoustic guitars.</s>', 'explain why the relation is contradiction between hypothesis: an elderly woman bathes and premise: a child is laying in a bubble bath holding a yellow scrubbing brush up to his mouth as if singing into a microphone.</s>', 'explain why the relation is entailment between hypothesis: a person is outdoors, on a horse. and premise: a person on a horse jumps over a broken down airplane.</s>', 'explain why the relation is entailment between hypothesis: a girl and a boy stick their tongues out. and premise: a girl with a little boy both rolling their tongue as they stick it out.</s>', 'explain why the relation is neutral between hypothesis: a boy was showing off for a girl. and premise: a young boy wearing a tank-top is climbing a tree.</s>', 'explain why the relation is contradiction between hypothesis: three women are walking together outside. and premise: three women sitting and waiting for something on a bench.</s>', 'explain why the relation is entailment between hypothesis: a woman singing and premise: a woman with brown hair wearing a red polka dot dress is singing into a microphone.</s>', 'explain why the relation is neutral between hypothesis: a singer sings their most famous song. and premise: a singer entertaining the crowd.</s>', 'explain why the relation is neutral between hypothesis: a guy is running from the police. and premise: a guy in white shirt and black pants is running.</s>', 'explain why the relation is contradiction between hypothesis: the man is working on his car and premise: women walking down the street in jeans, black high heel boots, and a beige hand ...

# %%
def list2dict(refine_data):
    refine_data_dict={}
    for key in refine_data[0].keys():
        refine_data_dict[key]=[x[key] for x in refine_data]
    return refine_data_dict

new_refine_train_data_dict = list2dict(new_refine_train_data)
our_data_splits['train'] = datasets.Dataset.from_dict(new_refine_train_data_dict).shuffle().select(range(96))

refine_dev_data_dict = list2dict(refine_dev_data)
our_data_splits['dev'] = datasets.Dataset.from_dict(refine_dev_data_dict)

refine_test_data_dict = list2dict(refine_test_data)
our_data_splits['test'] = datasets.Dataset.from_dict(refine_test_data_dict)

# %%
import datasets
class SequenceCollator:
    def __init__(self, pad_token):
        # self.pad_token_mapping = {
        #     "lm_labels": -100,
        #     "attention_mask": 0,
        #     "decoder_attention_mask": 0,
        #     "input_ids": pad_token,
        # }
        # self.columns = [
        #     "input_ids",
        #     "attention_mask",
        #     "lm_labels",
        #     "decoder_attention_mask",
        # ]
        self.pad_token_mapping = {
            "labels": -100,
            "attention_mask": 0,
            "decoder_attention_mask": 0,
            "input_ids": pad_token,
        }
        self.columns = [
            "input_ids",
            "attention_mask",
            "labels",
            "decoder_attention_mask",
        ]

    def collate_batch(self, examples):

        # batch inputs for training
        batch = {}
        for key in examples[0].keys():
            if key in self.columns:
                tmp_list = []
                for item in examples:
                    tmp_list.append(item[key])

                # pad lists to max length
                if isinstance(tmp_list[0], list):
                    max_length = max(map(len, tmp_list))
                    tmp_list = [
                        el + [self.pad_token_mapping[key]] * (max_length - len(el))
                        for el in tmp_list
                    ]

                batch[key] = torch.tensor(tmp_list, dtype=torch.long)
        return batch
    
    def __call__(self, examples: List[Dict[str, InputDataClass]]) -> Dict[str, torch.Tensor]:
        # re-format inputs for training
        batch = {}
        for key in examples[0].keys():
            if key in self.columns:
                tmp_list = []
                for item in examples:
                    tmp_list.append(item[key])

                # pad lists to max length
                if isinstance(tmp_list[0], list):
                    max_length = max(map(len, tmp_list))
                    tmp_list = [
                        el + [self.pad_token_mapping[key]] * (max_length - len(el))
                        for el in tmp_list
                    ]

                batch[key] = torch.tensor(tmp_list, dtype=torch.long)
        return batch
# dataset = datasets.load_dataset(data_args.task_name, data_args.version_name)

# %%
# seq_collector = SequenceCollator(0)
# train_ds = seq_collector.__call__(dataset['train'])
# train_ds
# dataset['train'][0].keys()
for split in ['train','dev','test']:
    our_data_splits[split] = our_data_splits[split].map(
            lambda x: format_instance(
                x,
                tokenizer,
                data_args.explanation_sep,
                datasource=data_args.task_name,
                io_format=data_args.io_format
            ),
            batched=False,
            load_from_cache_file=False,
        )
# Out:
#   0%|          | 0/96 [00:00<?, ?ex/s]
#   0%|          | 0/640 [00:00<?, ?ex/s]
#   0%|          | 0/131 [00:00<?, ?ex/s]

# %%
for kk, da in enumerate(our_data_splits['train']):
    input_string = tokenizer.decode(da['input_ids'])
    print(f'{input_string}')
    print(tokenizer.decode(da['labels']))
# Out:
# explain why the relation is contradiction between hypothesis: the horses are in their stalls in the barn. and premise: several horses are running a race on a muddy track.</s>
# <extra_id_0> The relation is contradiction because the hypothesis states that the horses are in their stalls in the barn, which implies that they are not moving or engaging in any activity. The premise, on the other hand, states that several horses are running a race on a muddy track, which is an activity that would not be possible if the horses were in their stalls in the barn. These two statements cannot both be true at the same time, and therefore, they contradict each other.<extra_id_1> </s>
# explain why the relation is contradiction between hypothesis: two people are playing cribbage. and premise: two men in safety vests walk down the road.</s>
# <extra_id_0> The relation between the hypothesis "two people are playing cribbage" and the premise "two men in safety vests walk down the road" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states
<extra_id_1> </s>
# explain why the relation is contradiction between hypothesis: the kids are frowning and premise: children smiling and waving at camera</s>
# <extra_id_0> The relation is contradiction because the hypothesis states that the kids are frowning, which is the opposite of the premise that states the children are smiling and waving at the camera. The two statements are mutually exclusive and cannot both be true at the same time.<extra_id_1> </s>
# explain why the relation is neutral between hypothesis: two vehicles were parked next to a toyota. and premise: a black truck and a red car parked on the street in front of a grocery store painted red.</s>
# <extra_id_0> The relation is neutral between the hypothesis "two vehicles were parked next to a toyota" and the premise "a black truck and a red car parked on the street in front of a grocery store painted red" because while the premise provides information about two specific vehicles (a black truck and a red car) being parked on the street, it does not specify the location of the vehicles in relation to one another. The hypothesis implies that there is a Toyota parked next to the two vehicles, but this information is not provided in the premise. Therefore, the premise does not confirm or deny the claim made in the hypothesis.<extra_id_1> </s>
# explain why the relation is contradiction between hypothesis: a person is at a diner, ordering an omelette. and premise: a person on a horse jumps over a broken down airplane.</s>
# <extra_id_0> The relation is a contradiction because the premise describes a person engaging in an activity that is not consistent with the setting described in the hypothesis. In the hypothesis, the person is at a diner ordering an omelette, which implies they are in an indoor, urban setting. However, in the premise, the person is on a horse jumping over a broken down airplane, which implies they are in a rural or wilderness setting, not a diner. These two settings are not compatible and therefore the hypothesis and premise contradict each other.<extra_id_1> </s>
# explain why the relation is entailment between hypothesis: people are playing. and premise: a group of native adults and children are sitting in a circle playing a game.</s>
# <extra_id_0> The relation between the hypothesis "people are playing" and the premise "a group of native adults and children are sitting in a circle playing a game" is entailment because the premise provides specific information that supports the general idea presented in the hypothesis. The premise describes a specific instance of people playing, which is what the hypothesis states is happening. The premise provides additional details, such as that the people are native and that they are playing a game, but these details do not contradict or negate the general idea that people are playing, as stated in the hypothesis. Therefore, the premise entails the hypothesis.<extra_id_1> </s>
# explain why the relation is contradiction between hypothesis: the man is lying in bed. and premise: a man and woman dressed in old fashion clothing sit outside at a table.</s>
# <extra_id_0> The relation is a contradiction because the hypothesis states that the man is lying in bed, which is an indoor and sedentary activity, while the premise describes the man and woman sitting outside at a table, which is an outdoor and active activity. These two descriptions are mutually exclusive and cannot both be true at the same time, hence the contradiction.<extra_id_1> </s>
# explain why the relation is neutral between hypothesis: women are standing on the sidewalk. and premise: two women conversing on a sidewalk.</s>
# <extra_id_0> The relation is neutral between the hypothesis "women are standing on the sidewalk" and the premise "two women conversing on a sidewalk" because the hypothesis states that the women are standing, while the premise does not specify whether they are standing or sitting. Both statements are true, but the premise doesn't give additional information to the hypothesis.<extra_id_1> </s>
# explain why the relation is neutral between hypothesis: they are smiling at their parents and premise: children smiling and waving at camera</s>
# <extra_id_0> The relation between the hypothesis "they are smiling at their parents" and the premise "children smiling and waving at camera" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that children are smiling and waving at the camera, but it does not specify who they are smiling and waving at, so it is possible that they are smiling and waving at their parents, but it is also possible that they are smiling and waving at someone else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.<extra_id_1> </s>
# explain why the relation is entailment between hypothesis: a man wields a tool and premise: a man is cutting a fish.</s>
# <extra_id_0> The relation is entailment between the hypothesis "a man wields a tool" and the premise "a man is cutting a fish" because the premise provides specific information that supports the hypothesis. The hypothesis states that a man is using a tool and the premise specifies that the man is cutting a fish, which requires the use of a tool such as a knife. Therefore, the premise confirms that the man is indeed using a tool, and thus the two statements are logically consistent.<extra_id_1> </s>
# explain why the relation is neutral between hypothesis: a boy was showing off for a girl. and premise: a young boy wearing a tank-top is climbing a tree.</s>
# <extra_id_0> The relation between the hypothesis "a boy was showing off for a girl" and the premise "a young boy wearing a tank-top is climbing a tree" is neutral because the premise doesn't provide enough information to confirm or contradict the hypothesis. The hypothesis states that the boy was showing off for a girl, which implies that there is a girl present and the boy is doing something to impress her. The premise describes a young boy wearing a tank-top climbing a tree, which doesn't provide enough information to confirm or contradict the hypothesis. The premise doesn't tell us if there is a girl present or not and doesn't tell us if the boy is doing something to impress her or not. Therefore, the premise doesn't give enough information to confirm or contradict the hypothesis "a boy was showing off for a girl" thus the relation is neutral.<extra_id_1> </s>
# explain why the relation is contradiction between hypothesis
<extra_id_1> </s>
# explain why the relation is neutral between hypothesis: three men in black shirts are at a table. and premise: three men, one of them standing, are at a table in a dark room.</s>
# <extra_id_0> The relation between the hypothesis "three men in black shirts are at a table" and the premise "three men, one of them standing, are at a table in a dark room" is neutral because the premise does not provide enough information to confirm or contradict the hypothesis. The premise states that there are three men at a table, but it does not specify their clothing or the lighting conditions, so it is not possible to determine whether they match the description in the hypothesis.<extra_id_1> </s>
# explain why the relation is contradiction between hypothesis: two boys ride regular bicycles during a race. and premise: two boys with unicycles stand outside of a street shop.</s>
# <extra_id_0> The relation is contradiction between the hypothesis "two boys ride regular bicycles during a race" and the premise "two boys with unicycles stand outside of a street shop" because the hypothesis states that the boys are riding regular bicycles, while the premise states that they are riding unicycles. These two statements cannot both be true at the same time, as a regular bicycle and a unicycle are two different types of vehicles and therefore are mutually exclusive. Therefore, the relation is contradiction.<extra_id_1> </s>
# explain why the relation is neutral between hypothesis: an older man drinks his juice as he waits for his daughter to get off work. and premise: an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</s>
# <extra_id_0> The relation is neutral between the hypothesis and premise because while the hypothesis states that the older man is drinking his juice and waiting for his daughter to get off work, the premise only describes the older man sitting with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background. The premise does not provide any information about the older man's daughter or why he is waiting. Therefore, the hypothesis and premise are not mutually exclusive or mutually dependent and do not contradict or entail each other.<extra_id_1> </s>

# %%
chatgpt_rationales = ["sample 0: explain why the relation is neutral between hypothesis: they are smiling at their parents and premise: children smiling and waving at camera</s>",
"The relation between the hypothesis \"they are smiling at their parents\" and the premise \"children smiling and waving at camera\" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that children are smiling and waving at the camera, but it does not specify who they are smiling and waving at, so it is possible that they are smiling and waving at their parents, but it is also possible that they are smiling and waving at someone else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.",




"sample 1: explain why the relation is contradiction between hypothesis: two people are playing cribbage. and premise: two men in safety vests walk down the road.</s>",
"The relation between the hypothesis \"two people are playing cribbage\" and the premise \"two men in safety vests walk down the road\" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states that two people are playing cribbage, which implies they are in a stationary location, most likely indoors, and are engaged in a game. On the other hand, the premise states that two men are walking down the road, which implies that they are in motion, and most likely outdoors. These two statements cannot both be true at the same time as the people described in the hypothesis are not doing the same activity as the men described in the premise. Therefore, the relation between these two statements is a contradiction.",





"sample 2: explain why the relation is neutral between hypothesis: the tourists are getting a gondola ride. and premise: the tourists are out on the river in italy, the man in the black and white striped shirt will tell them about the seine.</s>",
"The relation between the hypothesis \"the tourists are getting a gondola ride\" and the premise \"the tourists are out on the river in Italy, the man in the black and white striped shirt will tell them about the Seine\" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that the tourists are out on the river in Italy and that a man in a black and white striped shirt will tell them about the Seine, but it does not specify what the tourists are doing or where they are exactly. The premise does not specify if they are in a gondola or not, so it is possible that they are getting a gondola ride, but it is also possible that they are doing something else. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.",




"sample 3: explain why the relation is neutral between hypothesis: a person is training his horse for a competition. and premise: a person on a horse jumps over a broken down airplane.</s>",
"The relation between the hypothesis \"a person is training his horse for a competition\" and the premise \"a person on a horse jumps over a broken down airplane\" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise states that a person on a horse jumps over a broken down airplane, but it does not specify what the person and horse are doing. It could be that they are training for a competition, but it could also be that they're just doing some exercise or practicing jumping or obstacle course. The premise does not indicate if the person is training the horse for a competition or not. Therefore, the premise does not provide enough information to confirm or deny the hypothesis.",



"sample 4: explain why the relation is contradiction between hypothesis: the man is in a desert. and premise: an man in the north pole walking on ice.</s>",
"The relation between the hypothesis \"the man is in a desert\" and the premise \"a man in the North Pole walking on ice\" is a contradiction because the two statements cannot both be true at the same time. The hypothesis states
"sample 23: explain why the relation is entailment between hypothesis: a man wields a tool and premise: a man is cutting a fish.</s>",
"The relation is entailment between the hypothesis \"a man wields a tool\" and the premise \"a man is cutting a fish\" because the premise provides specific information that supports the hypothesis. The hypothesis states that a man is using a tool and the premise specifies that the man is cutting a fish, which requires the use of a tool such as a knife. Therefore, the premise confirms that the man is indeed using a tool, and thus the two statements are logically consistent.",





"sample 24: explain why the relation is neutral between hypothesis: a band is playing a concert. and premise: this band is playing on a stage.</s>",
"The relation is neutral between the hypothesis \"a band is playing a concert\" and the premise \"this band is playing on a stage\" because both the hypothesis and the premise mention the band playing, but do not provide any information that would indicate whether the band is playing a concert or not. The premise only states that the band is playing on a stage, which could be part of a concert, but it does not confirm or deny the hypothesis that the band is playing a concert.",




"sample 25: explain why the relation is contradiction between hypothesis: the horses are becoming suspicious of my apples. and premise: there is a red truck behind the horses.</s>",
"The relation is contradiction because the premise (\"there is a red truck behind the horses\") does not match the hypothesis (\"the horses are becoming suspicious of my apples\"). The horse's behavior is described as being suspicious of apples, not having any relation with a red truck. The two statements are not related and cannot both be true at the same time.",




"sample 26: explain why the relation is neutral between hypothesis: two african children are friends. and premise: two african children standing by a hut with their faces painted.</s>",
"The relation is neutral between the hypothesis \"two african children are friends\" and the premise \"two african children standing by a hut with their faces painted\" because the premise does not provide any information about the relationship between the children. It only describes their physical appearance and location. The hypothesis states that the children are friends, but the premise does not confirm or deny this.",





"sample 27: explain why the relation is contradiction between hypothesis: a nurse is pushing a surgical cart and premise: a woman wearing gloves working at a meat counter.</s>",
"The relation is a contradiction because the hypothesis and premise describe two very different scenarios. In the hypothesis, a nurse is described as pushing a surgical cart in a hospital setting, while in the premise, a woman is described as working at a meat counter in a grocery store. These two images are not consistent with each other and therefore, the relation is a contradiction.",





"sample 28: explain why the relation is entailment between hypothesis: there are children present and premise: children smiling and waving at camera</s>",
"The relation between the hypothesis \"there are children present\" and the premise \"children smiling and waving at camera\" is entailment because the premise provides evidence that supports the hypothesis. The presence of children smiling and waving in the premise confirms that there are indeed children present, as stated in the hypothesis. The hypothesis is entailed by the premise because the premise is providing visual evidence of the presence of children.",





"sample 29: explain why the relation is contradiction between hypothesis: a girl is sitting at the kitchen table eating lunch. and premise: a girl, about 8 years old, is sitting in front of a television, delighted with a stuffed animal, while a boy watches.</s>",
"The relation is contradiction because the hypothesis describes the girl as sitting at the kitchen table eating lunch, while the premise describes the girl as sitting in front of a television, delighted with a stuffed animal, which would suggest that she is not eating lunch at the kitchen table. These two statements cannot both be true at the same time, making the relation a contradiction.",




"sample 30: explain why the relation is neutral between hypothesis: the girls is having fun at the park. and premise: the girl wears a purple outfit and swings upside down.</s>",
"The relation is neutral between the hypothesis \"the girl is having fun at the park\" and the premise \"the girl wears a purple outfit and swings upside down\" because the premise only describes the girl's appearance and actions, but it does not provide any information about the girl's emotional state or the context in which she is participating in those actions. The hypothesis suggests that the girl is having fun, but the premise does not confirm or deny this. It is possible that the girl is having fun at the park, but it is also possible that she is not.",




and premise: a boy is jumping on skateboard in the middle of a red bridge.</s>",
"The relation is entailment because the premise \"a boy is jumping on Skateboard in the middle of a red bridge\" describes an action that is consistent with the hypothesis \"the boy does a skateboarding trick.\" The premise provides additional details and context to the hypothesis, but the basic action of the boy performing a skateboarding trick is still present in the premise.",




"sample 39: explain why the relation is contradiction between hypothesis: the horses are in their stalls in the barn. and premise: several horses are running a race on a muddy track.</s>",
"The relation is contradiction because the hypothesis states that the horses are in their stalls in the barn, which implies that they are not moving or engaging in any activity. The premise, on the other hand, states that several horses are running a race on a muddy track, which is an activity that would not be possible if the horses were in their stalls in the barn. These two statements cannot both be true at the same time, and therefore, they contradict each other.",




"sample 40: explain why the relation is neutral between hypothesis: an giant collected flowers and premise: an giant egged shaped collection of flowers.</s>",
"The relation is neutral between the hypothesis \"an giant collected flowers\" and the premise \"an giant egged shaped collection of flowers\" because the premise does not provide any information about whether the flowers were collected by a giant or not. The premise simply describes an object made of flowers that has an egg-shaped form, without providing any information about the action or context. Therefore, the premise does not support or contradict the hypothesis, and the relation is neutral.",




"sample 41: explain why the relation is neutral between hypothesis: women are competing in a table tennis tournament at the beach. and premise: two females in bikinis are playing table tennis at the beach while another female in a towel watches.</s>",
"The relation is neutral because the hypothesis and the premise both describe women competing in a table tennis tournament at the beach, but the premise also includes additional details such as what they are wearing. The additional details do not contradict or support the statement in the hypothesis, so the relation is neutral.",




"sample 42: explain why the relation is contradiction between hypothesis: the table was wood. and premise: two men sit at a glass table with papers on it.</s>",
"The relation is contradiction because the hypothesis states that the table is made of wood, while the premise states that the table is made of glass. These two statements cannot both be true at the same time, as a table cannot be made of both wood and glass. This is an example of a logical contradiction, as it is impossible for both statements to be true.",




"sample 43: explain why the relation is entailment between hypothesis: a bearded man plays guitar. and premise: a long bearded man plays a furry guitar.</s>",
"The relation is entailment between the hypothesis \"a bearded man plays guitar\" and the premise \"a long bearded man plays a furry guitar\" because the premise provides additional information about the man's beard and the guitar that he is playing, but it does not change the fact that the man is playing a guitar, which is stated in the hypothesis. The premise is consistent with the hypothesis and adds more details to it.",




"sample 44: explain why the relation is entailment between hypothesis: the woman in knee-highs and jean shorts is walking down the sidewalk smoking. and premise: a woman in checkered knee-highs and jean shorts walks down a city sidewalk street while smoking a cigarette.</s>",
"The relation is entailment because the premise provides additional information that supports the hypothesis. The specific details provided in the premise, such as the woman wearing knee-highs and jean shorts, and smoking a cigarette, are consistent with and support the general statement made in the hypothesis that a woman is walking down the sidewalk smoking.",




"sample 45: explain why the relation is contradiction between hypothesis: a boy flips a burger. and premise: an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</s>",
"The relation is contradiction between the hypothesis \"a boy flips a burger\" and the premise \"an older man sits with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background\" because the hypothesis states that a specific action (flipping a burger) is happening in a specific setting (presumably a kitchen or grill area), while the premise describes a completely different scene with no indication of a burger-related activity. These two statements cannot both be true at the same time.",




"sample 46: explain why the relation is neutral between hypothesis: two couples are preparing dinner together. and premise: two ladies are cooking & talking and two gentlemen are talking in the opposite site of the kitchen.</s>",
"The relation between the hypothesis and premise is neutral because the premise describes two couples engaging in separate activities in the kitchen, while the hypothesis states that they are preparing dinner together. The premise does not provide enough information to confirm or deny the hypothesis.",





"sample 47: explain why the relation is entailment between hypothesis: a man runs outside past a building. and premise: a man wearing blue jogging pants with 3 white stripes and a t-shirt is running past a building with graffiti on it.</s>",
"The relation is entailment between the hypothesis \"a man runs outside past a building\" and the premise \"a man wearing blue jogging pants with 3 white stripes and a t-shirt is running past a building with graffiti on it\" because the premise provides additional specific details that are consistent with the hypothesis. The hypothesis states that a man is running and the premise states that a man is running, the premise also provides specific details about the man's clothing and the building he is running past, which are all consistent with the hypothesis. Therefore, the premise entails or supports the hypothesis.",




"sample 48: explain why the relation is entailment between hypothesis: the man is indoors. and premise: a man is sitting in the middle of a room in an art gallery, and is putting some frames together, preparing a piece of art for han
"The relation is neutral between the hypothesis \"the girl's costume is too short\" and the premise \"a dancer performing with her panties showing\" because the hypothesis states a specific condition about the girl's costume (i.e., that it is too short), while the premise describes a general situation (i.e., a dancer performing) without specifying anything about the costume. It is possible that the dancer in the premise is the girl mentioned in the hypothesis, but without more information it is not clear if that is the case. Therefore, the two statements do not directly support or contradict each other.",




"sample 56: explain why the relation is contradiction between hypothesis: two boys ride regular bicycles during a race. and premise: two boys with unicycles stand outside of a street shop.</s>",
"The relation is contradiction between the hypothesis \"two boys ride regular bicycles during a race\" and the premise \"two boys with unicycles stand outside of a street shop\" because the hypothesis states that the boys are riding regular bicycles, while the premise states that they are riding unicycles. These two statements cannot both be true at the same time, as a regular bicycle and a unicycle are two different types of vehicles and therefore are mutually exclusive. Therefore, the relation is contradiction.",




"sample 57: explain why the relation is entailment between hypothesis: the two women are riding a cart outside. and premise: two asia women are riding on a cart as a man pulls them through the street.</s>",
"The relation is entailment between the hypothesis \"the two women are riding a cart outside\" and the premise \"two asia women are riding on a cart as a man pulls them through the street\" because the premise provides specific details that support and expand upon the information in the hypothesis. The hypothesis states that the women are riding a cart, and the premise provides additional information that they are Asian women, and that they are being pulled through the street by a man. This additional information supports and adds to the information provided in the hypothesis, making the premise an entailment of the hypothesis.",




"sample 58: explain why the relation is contradiction between hypothesis: boys are singing in the public. and premise: two male and six female dancers perform on stage.</s>",
"The relation is contradiction between hypothesis: boys are singing in the public. and premise: two male and six female dancers perform on stage, because the hypothesis states that boys are singing, while the premise states that two males and six females are dancing. These two statements cannot both be true at the same time, therefore they contradict each other.",




"sample 59: explain why the relation is contradiction between hypothesis: the kids are frowning and premise: children smiling and waving at camera</s>",
"The relation is contradiction because the hypothesis states that the kids are frowning, which is the opposite of the premise that states the children are smiling and waving at the camera. The two statements are mutually exclusive and cannot both be true at the same time.",




"sample 60: explain why the relation is neutral between hypothesis: three men in black shirts are at a table. and premise: three men, one of them standing, are at a table in a dark room.</s>",
"The relation between the hypothesis \"three men in black shirts are at a table\" and the premise \"three men, one of them standing, are at a table in a dark room\" is neutral because the premise does not provide enough information to confirm or contradict the hypothesis. The premise states that there are three men at a table, but it does not specify their clothing or the lighting conditions, so it is not possible to determine whether they match the description in the hypothesis.",





"sample 61: explain why the relation is contradiction between hypothesis: a person is at a diner, ordering an omelette. and premise: a person on a horse jumps over a broken down airplane.</s>",
"The relation is a contradiction because the premise describes a person engaging in an activity that is not consistent with the setting described in the hypothesis. In the hypothesis, the person is at a diner ordering an omelette, which implies they are in an indoor, urban setting. However, in the premise, the person is on a horse jumping over a broken down airplane, which implies they are in a rural or wilderness setting, not a diner. These two settings are not compatible and therefore the hypothesis and premise contradict each other.",





"sample 62: explain why the relation is contradiction between hypothesis: a cart is sinking in the ocean and premise: a donkey pulled cart is carrying produce down a street.</s>",
"The relation is a contradiction between the hypothesis and the premise because the hypothesis states that a cart is sinking in the ocean, which implies that it is in water and unable to be used. However, the premise states that a donkey pulled cart is carrying produce down a street, which implies that the cart is on land and being used for transportation. These two statements cannot both be true at the same time and thus, the relation between the hypothesis and the premise is a contradiction.",




his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background.</s>",
"The relation is neutral between the hypothesis and premise because while the hypothesis states that the older man is drinking his juice and waiting for his daughter to get off work, the premise only describes the older man sitting with his orange juice at a small table in a coffee shop while employees in bright colored shirts smile in the background. The premise does not provide any information about the older man's daughter or why he is waiting. Therefore, the hypothesis and premise are not mutually exclusive or mutually dependent and do not contradict or entail each other.",




"sample 80: explain why the relation is contradiction between hypothesis: the man is standing. and premise: a man sitting on a curb in a city park.</s>",
"The relation is a contradiction because the hypothesis states that the man is standing, while the premise states that the man is sitting on a curb. These two statements cannot both be true at the same time, as standing and sitting are mutually exclusive actions. Therefore, the hypothesis and the premise are in direct opposition to each other.",




"sample 81: explain why the relation is entailment between hypothesis: a man is taking a run on the track. and premise: a man running on a track.</s>",
"The relation between the hypothesis \"a man is taking a run on the track\" and the premise \"a man running on a track\" is entailment because the premise provides additional information that confirms the hypothesis. The hypothesis states that a man is taking a run, which implies that he is moving, and the premise confirms that the man is indeed running, which is a specific type of movement. Therefore, the premise provides evidence that supports the hypothesis, making them consistent with each other.",




"sample 82: explain why the relation is neutral between hypothesis: a person is resting. and premise: a man crouching down on some rocks in the ocean.</s>",
"The relation is neutral because the premise describes a specific action (crouching on rocks) that is not necessarily indicative of resting. The hypothesis states that the person is resting, but the premise does not provide any information to confirm or deny that statement.",




"sample 83: explain why the relation is entailment between hypothesis: a woman stands at a podium. and premise: a middle-aged woman stands at a green podium with the name \"sva theatre\" written on it.</s>",
"The relation is entailment between the hypothesis \"a woman stands at a podium\" and the premise \"a middle-aged woman stands at a green podium with the name \"sva theatre\" written on it\" because the premise provides additional information that supports the hypothesis. The hypothesis states that a woman is standing at a podium, and the premise states that a middle-aged woman is standing at a green podium with a specific name, \"sva theatre\" written on it, which confirms the hypothesis that a woman is standing at a podium. Therefore, the premise entails the hypothesis.",




"sample 84: explain why the relation is contradiction between hypothesis: a man wearing a cowboy hat swings a baseball bat. and premise: a man wearing only a cowboy hat, cowboy boots, and underwear talks to a woman on a city street.</s>",
"The relation is contradiction between the hypothesis \"a man wearing a cowboy hat swings a baseball bat\" and the premise \"a man wearing only a cowboy hat, cowboy boots, and underwear talks to a woman on a city street\" because the premise states that the man is only wearing a cowboy hat, cowboy boots, and underwear and is talking to a woman on a city street, while the hypothesis states that the man is wearing a cowboy hat and swinging a baseball bat, which are two completely different and mutually exclusive actions and scenarios. Therefore, the hypothesis and the premise are contradictory.",




"sample 85: explain why the relation is contradiction between hypothesis: the man is lying in bed. and premise: a man and woman dressed in old fashion clothing sit outside at a table.</s>",
"The relation is a contradiction because the hypothesis states that the man is lying in bed, which is an indoor and sedentary activity, while the premise describes the man and woman sitting outside at a table, which is an outdoor and active activity. These two descriptions are mutually exclusive and cannot both be true at the same time, hence the contradiction.",




"sample 86: explain why the relation is entailment between hypothesis: store has people standing around it's exterior. and premise: asian people are standing outside a store named concepts.</s>",
"The relation between the hypothesis \"store has people standing around it's exterior\" and the premise \"asian people are standing outside a store named concepts\" is entailment because the premise provides evidence that supports the hypothesis. The premise specifically states that there are people standing outside a store, and the store is named \"concepts\", which confirms that there is a store with people standing around its exterior. Therefore, the premise entails the hypothesis, meaning that the hypothesis is logically supported by the premise.",





"sample 87: explain why the relation is contradiction between hypothesis: there are people running and premise: couple walking passed a clock tower.</s>",
"The relation is a contradiction between the hypothesis \"there are people running\" and the premise \"couple walking passed a clock tower\" because the hypothesis states that people are running, while the premise states that people are walking. These two statements are incompatible and cannot both be true at the same time. The fact that people are running implies that they are moving quickly and with purpose, while the fact that people are walking implies a slower and more leisurely pace. The contradiction is that the two statements give different information about the activity of the people.",




"sample 88: explain why the relation is contradiction between hypothesis: the men are watching a movie in public theatres in different states and premise: two men handle a large telescope while one is looking through.</s>",
"The relation is contradiction because the hypothesis states that the men are watching a movie in public theatres in different states, while the premise states that two men are handling a large telescope and one is looking through it. These two statements are mutually exclusive, as it is unlikely that the men would be able to watch a movie in public theatres in different states while also handling a telescope at the same time. Therefore, the hypothesis and premise are contradictory.",




"sample 89: explain why the relation is entailment between hypothesis: people are playing. and premise: a group of native adults and children are sitting in a circle playing a game.</s>",
"The relation between the hypothesis \"people are playing\" and the premise \"a group of native adults and children are sitting in a circle playing a game\" is entailment because the premise provides specific information that supports the general idea presented in the hypothesis. The premise describes a specific instance of people playing, which is what the hypothesis states is happening. The premise provides additional details, such as that the people are native and that they are playing a game, but these details do not contradict or negate the general idea that people are playing, as stated in the hypothesis. Therefore, the premise entails the hypothesis.",




"sample 90: explain why the relation is neutral between hypothesis: the men are related and premise: a man sitting with an elderly homeless person in a park.</s>",
"The relation is neutral because the premise does not provide any information about the relationship between the two men. It only states that they are sitting together in a park. The hypothesis, on the other hand, states that they are related, but it is not specified how they are related, and there is no information from the premise that can confirm or deny this claim. Therefore, it is not possible to determine if the hypothesis is true or false based on the premise.",




"sample 91: explain why the relation is neutral between hypothesis: a man is competing on a bike. and premise: a male doing a trick in the air on his bike.</s>",
"The relation is neutral between the hypothesis \"a man is competing on a bike\" and the premise \"a male doing a trick in the air on his bike\" because the premise does not indicate whether the man is competing or not, it only describes an action of a man on a bike. The premise does not provide any information about a competition or a race, so it does not confirm or contradict the hypothesis.",




"sample 92: explain why the relation is neutral between hypothesis: some artists are painting a wall. and premise: four young women are painting in countries of a map that is painted on a wall.</s>",
"The relation is neutral between the hypothesis \"some artists are painting a wall\" and the premise \"four young women are painting in countries of a map that is painted on a wall\" because the premise describes a specific situation, but the hypothesis is more general and does not specify that the artists are women or that they are painting a map on a wall. The hypothesis is compatible with the premise, but the premise does not provide any additional information or context to confirm or deny the hypothesis.",




"sample 93: explain why the relation is contradiction between hypothesis: a woman takes a bath. and premise: three people serving food outside somewhere.</s>",
"The relation is contradiction between the hypothesis \"a woman takes a bath\" and the premise \"three people serving food outside somewhere\" because the two statements describe two completely different and unrelated actions that cannot coexist at the same time. The hypothesis describes an individual doing a solitary activity in a private setting, while the premise describes a group of individuals performing an interactive activity in a public setting. The two statements are not compatible with each other and therefore contradict each other.",




"sample 94: explain why the relation is neutral between hypothesis: the woman is trying to make a living. and premise: an asian woman is selling colorful fabrics.</s>",
"The relation is neutral between the hypothesis \"the woman is trying to make a living\" and the premise \"an asian woman is selling colorful fabrics\" because while the premise describes an action that may be associated with someone trying to make a living, it does not directly confirm or refute the hypothesis. The premise simply provides a visual image of the woman selling fabrics, without any additional context or information about her motivations or circumstances.",





"sample 95: explain why the relation is contradiction between hypothesis: the boy skates down the sidewalk. and premise: a boy is jumping on skateboard in the middle of a red bridge.</s>",
"The relation is a contradiction between the hypothesis \"the boy skates down the sidewalk\" and the premise \"a boy is jumping on a skateboard in the middle of a red bridge\" because the hypothesis suggests that the boy is moving on the sidewalk, while the premise suggests that the boy is on a skateboard in the middle of a red bridge. These two statements cannot both be true at the same time, as the sidewalk and red bridge are different locations and the boy cannot be in both places simultaneously. Additionally, the action described in the hypothesis \"skating down\" is different from the action described in the premise \"jumping on\". Therefore, the two statements contradict each other.",
]

# %%
# import wandb
# training_args.run_name=""
training_args.logging_steps=3
training_args.save_steps=10
training_args.evaluation_strategy="epoch"
training_args.num_train_epochs=15
training_args.do_eval=True

# %%
training_args
# Out:
# TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=epoch,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# greater_is_better=None,
# group_by_length=False,
# ignore_data_skip=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=./esnli_output_t5_base/020123_202310,
# logging_first_step=False,
# logging_steps=3,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=15,
# output_dir=./esnli_output_t5_base/020123_202310,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=esnli_output_t5_base,
# push_to_hub_organization=None,
# push_to_hub_token=None,
# remove_unused_columns=True,
# report_to=['tensorboard', 'wandb'],
# resume_from_checkpoint=None,
# run_name=./esnli_output_t5_base,
# save_on_each_node=False,
# save_steps=10,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %%
training_args.per_device_eval_batch_size=8
training_args.per_device_train_batch_size=8
training_args
# Out:
# TrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_pin_memory=True,
# ddp_find_unused_parameters=None,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_steps=None,
# evaluation_strategy=epoch,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# gradient_accumulation_steps=1,
# greater_is_better=None,
# group_by_length=False,
# ignore_data_skip=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=-1,
# log_level=-1,
# log_level_replica=-1,
# log_on_each_node=True,
# logging_dir=./esnli_output_t5_base/020123_202310,
# logging_first_step=False,
# logging_steps=3,
# logging_strategy=IntervalStrategy.STEPS,
# lr_scheduler_type=SchedulerType.LINEAR,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# no_cuda=False,
# num_train_epochs=15,
# output_dir=./esnli_output_t5_base/020123_202310,
# overwrite_output_dir=False,
# past_index=-1,
# per_device_eval_batch_size=8,
# per_device_train_batch_size=8,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=esnli_output_t5_base,
# push_to_hub_organization=None,
# push_to_hub_token=None,
# remove_unused_columns=True,
# report_to=['tensorboard', 'wandb'],
# resume_from_checkpoint=None,
# run_name=./esnli_output_t5_base,
# save_on_each_node=False,
# save_steps=10,
# save_strategy=IntervalStrategy.STEPS,
# save_total_limit=None,
# seed=42,
# sharded_ddp=[],
# skip_memory_metrics=True,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_legacy_prediction_loop=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )

# %%
class SequenceCollator:
    def __init__(self, model, pad_token):
        self.model = model
        self.pad_token_mapping = {
            "labels": -100,
            "attention_mask": 0,
            "decoder_attention_mask": 0,
            "input_ids": pad_token,
        }

        self.columns = [
            "input_ids",
            "attention_mask",
            "labels",
            "decoder_attention_mask",
        ]

    def __call__(self, examples: List[Dict[str, InputDataClass]]) -> Dict[str, torch.Tensor]:
        # re-format inputs for training
        batch = {}
        for key in examples[0].keys():
            if key in self.columns:
                tmp_list = []
                for item in examples:
                    tmp_list.append(item[key])

                # pad lists to max length
                if isinstance(tmp_list[0], list):
                    max_length = max(map(len, tmp_list))
                    tmp_list = [
                        el + [self.pad_token_mapping[key]] * (max_length - len(el))
                        for el in tmp_list
                    ]

                batch[key] = torch.tensor(tmp_list, dtype=torch.long)
        return batch

# %%
# os.environ["WANDB_DISABLED"] = "True"
if data_args.generations_filepath is None:
    callbacks = [TensorBoardCallback()]
    if data_args.early_stopping_patience > 0:
        callbacks.append(EarlyStoppingCallback(early_stopping_patience=data_args.early_stopping_patience))
        training_args.load_best_model_at_end = True
    else:
        training_args.load_best_model_at_end = False  # use the last model state
    training_args.metric_for_best_model = 'eval_loss'
    training_args.greater_is_better = False
    if training_args.eval_steps is None:
        training_args.evaluation_strategy = EvaluationStrategy.EPOCH
    else:
        training_args.evaluation_strategy = EvaluationStrategy.STEPS

    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=our_data_splits['train'],
        eval_dataset=our_data_splits['dev'],
        data_collator=SequenceCollator(
            model=model_class, pad_token=tokenizer.pad_token_id
        ),
        callbacks=callbacks,
    )

# Training. Don't train if it is use_gpt3
if training_args.do_train and not model_args.use_gpt3:
    start_time = time.time()
    trainer.train()
    train_time = time.time() - start_time
    model = trainer.model
    #wandb.finish()
else:
    start_time = time.time()
    train_time = time.time() - start_time
# Out:
# You are adding a <class 'transformers.integrations.TensorBoardCallback'> to the callbacks of this Trainer, but there is already one. The currentlist of callbacks is
# :DefaultFlowCallback
# TensorBoardCallback
# WandbCallback
# The following columns in the training set  don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: explanation_2, explanation_1, premise, explanation_3, hypothesis, question_encoding, our_explanation.
# ***** Running training *****
#   Num examples = 96
#   Num Epochs = 15
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 180
# Automatic Weights & Biases logging enabled, to disable set os.environ["WANDB_DISABLED"] = "true"
# wandb: Currently logged in as: dengdenghuang (cuhk_lavilab). Use `wandb login --relogin` to force relogin
# wandb version 0.13.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.5
# Run data is saved locally in <code>/cognitive_comp/huangyongfeng/evaluate_LM_with_rationalization/scripts/wandb/run-20230201_202539-3fdqig9u</code>
# Syncing run <strong><a href="https://wandb.ai/cuhk_lavilab/huggingface/runs/3fdqig9u" target="_blank">./esnli_output_t5_base</a></strong> to <a href="https://wandb.ai/cuhk_lavilab/huggingface" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
#     <div>
#
#       <progress value='180' max='180' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [180/180 01:36, Epoch 15/15]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-10
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-10/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-10/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-20
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-20/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-20/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-30
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-30/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-30/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-40
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-40/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-40/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-50
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-50/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-50/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-60
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-60/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-60/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-70
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-70/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-70/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-80
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-80/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-80/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-90
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-90/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-90/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-100
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-100/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-100/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-110
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-110/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-110/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-120
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-120/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-120/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-130
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-130/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-130/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-140
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-140/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-140/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-150
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-150/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-150/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-160
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-160/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-160/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-170
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-170/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-170/pytorch_model.bin
# Saving model checkpoint to ./esnli_output_t5_base/020123_202310/checkpoint-180
# Configuration saved in ./esnli_output_t5_base/020123_202310/checkpoint-180/config.json
# Model weights saved in ./esnli_output_t5_base/020123_202310/checkpoint-180/pytorch_model.bin
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)

# %% [markdown]
# # Rationale Discriminator

# %% [markdown]
# ## Construction of generated rationale and accepted rationale pairs

# %%
# dict_keys(['premise', 'hypothesis', 'label',
#            'explanation_1', 'explanation_2', 'explanation_3', 
#            'our_explanation', 'common_expl_list'])

# %%
from tqdm import tqdm
# fse_csqa_dev_data_dict
# fse_csqa_train_data_dict
rationale_pair_dev_data = []
cc=0
good_model = model

for da in tqdm(our_data_splits['dev'], total=len(our_data_splits['dev'])):
    print("*******")
    print("hypothesis: {}".format(da['hypothesis']))
    print("premise: {}".format(da['premise']))
    print("answer: {}".format(da['label']))
    
    #print("our_explanation: {}".format(da['our_explanation']))
    #id_ = da['id']
#     if id_ in fse_csqa_dev_data_dict.keys():
#         common_expl_list = fse_csqa_dev_data_dict[id_]['common_expl_list']
#     else:
#         common_expl_list = fse_csqa_train_data_dict[id_]['common_expl_list']
#     da["common_expl_list"] = common_expl_list
    print("common expl list: {}".format(da["common_expl_list"]))
    inp_ids = torch.tensor(da["input_ids"], device=model.device).reshape(1, -1)
    out = good_model.generate(
                    inp_ids,
                    max_length=100,
                    pad_token_id=tokenizer.pad_token_id,
                    eos_token_id=tokenizer.eos_token_id,
                )
    skip_special_tokens = False if "infilling" in data_args.io_format else True
    words = tokenizer.decode(out[0].tolist(), skip_special_tokens=skip_special_tokens)
    print("generated explanation: {}".format(words))
    da["generated_explanation"] = words
    print("########")
    rationale_pair_dev_data.append(da)
    cc += 1
#     if cc > 200:
#         break
    #pdb.set_trace()
# Out:
#   0%|                                                                                                                                                                               | 0/640 [00:00<?, ?it/s]
# *******
# hypothesis: There is a black dog.
# premise: a black dog running really fast with a blond woman running after him in the background.
# answer: 0
# common expl list: ['If the dog is black, then it is black.', "If there's a black dog running really fast, then, yes, there is a black dog."]
#   0%|▎                                                                                                                                                                      | 1/640 [00:01<15:57,  1.50s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides additional information about the dog. The hypothesis states that the dog is a black dog, which is a black dog, and the premise describes a blond woman running after him in the background, which is a black dog, running really fast, with a blond woman running after him in the background. The premise provides additional information that supports the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: people at home
# premise: a crowd of people in a subway
# answer: 2
# common expl list: ['you cannot be at home in a subway. Can you?']
#   0%|▌                                                                                                                                                                      | 2/640 [00:02<14:54,  1.40s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that "people are at home" and the premise describes a crowd of people in a subway station. The hypothesis states that "people are at home" and the premise describes a crowd of people in a crowd of people in a subway station. The premise does not confirm or contradict the hypothesis. The premise does not provide enough information to confirm or deny the hypothesis. The premise does not provide enough information
# ########
# *******
# hypothesis: A busy pizza restaurant sees a lot of people pass on its active street corner in New York City
# premise: A busy pizza shop is located on a heavily trafficked street corner.
# answer: 1
# common expl list: ["Even though that busy pizza shop may sometimes see a lot of people passing by its active street corner, it does not necessarily mean that it's located in New York City."]
#   0%|▊                                                                                                                                                                      | 3/640 [00:04<14:39,  1.38s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a busy pizza restaurant is located on a heavily trafficked street corner, while the premise states that a busy pizza shop is located on a heavily trafficked street corner. The premise describes a busy pizza restaurant, which is located on an active street corner, and the hypothesis states that people pass on its active street corner. The premise describes a busy pizza shop, which is located on a heavily trafficked
# ########
# *******
# hypothesis: The two boys  were swimming
# premise: A shirtless boy and a boy in green and white are playing on a concrete surface by a small stage.
# answer: 2
# common expl list: ['The concrete surface cannot be the one in the pool since they are playing on concrete by a stage.']
#   1%|█                                                                                                                                                                      | 4/640 [00:05<14:18,  1.35s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that the two boys are swimming and the premise states that the two boys are playing on a concrete surface by a small stage, while the premise describes a boy and a boy in green and white are playing on a concrete surface by a small stage, while the premise states that the boys are swimming, which is a different activity than the hypothesis. The hypothesis states that the two boys are swimming, but the
# ########
# *******
# hypothesis: Two dogs vie for an owners attention.
# premise: A terrier dog and a mixed breed dog playing.
# answer: 1
# common expl list: ['Dogs playing does not necessary indicate vying for attention, as dogs can play anytime, anywhere, not necessarily to get attention.', "Dogs can play with each other without the owner's attention."]
#   1%|█▎                                                                                                                                                                     | 5/640 [00:06<14:27,  1.37s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "two dogs vie for an owners attention" and the premise "a terrier dog and a mixed breed dog playing" because the premise does not confirm or confirm the hypothesis. The hypothesis states that "two dogs vie for an owners attention" and the premise does not specify whether the dog is playing or not. The premise does not specify whether the dog is playing or not. The premise does not specify whether the dog is
# ########
# *******
# hypothesis: A group of men spend time together
# premise: Several men dressed in cowboy boots and hats are hanging around, and one man is getting his shoes shined.
# answer: 0
# common expl list: ['A group of men hanging around together is spending time together. Men wearing cowboy boots and hats are a type of men. A cowboy is a kind of man.', 'If men are hanging around together, then they spend time together. Men dressed in cowboy boots and hats are a subset of all the men on the street corner.']
#   1%|█▌                                                                                                                                                                     | 6/640 [00:08<14:10,  1.34s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise describes a group of men spending time together, and the premise describes a group of men dressed in cowboy boots and hats, and one man is getting his shoes shined. The premise describes a group of men spending time together, and the premise describes a group of men spending time together, and the premise describes a group of men spending time together, and the premise describes
# ########
# *******
# hypothesis: An empty karate hall.
# premise: During karate practice, one student kicks through a wooden plank while another individual holds it at face-height.
# answer: 2
# common expl list: ['It is unlikely that a hall would be empty during karate practice, which involves using many wooden boards.']
#   1%|█▊                                                                                                                                                                     | 7/640 [00:09<13:57,  1.32s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "an empty karate hall" and the premise "a wooden plank" is a contradiction because the premise does not provide enough information to confirm or deny the hypothesis. The hypothesis states that there is no karate practice in the hall, but it does provide information about the karate practice that is being practiced. The premise states that the student is kicking through a wooden plank while the other individual holds it
# ########
# *******
# hypothesis: The man is sitting on the grass.
# premise: A woman is standing on a road.
# answer: 2
# common expl list: ['If someone is sitting on grass, they are almost certainly not on a road.']
#   1%|██                                                                                                                                                                     | 8/640 [00:10<13:43,  1.30s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that the man is sitting on the grass, while the premise states that the woman is standing on a road, which is a contradiction to the hypothesis. The hypothesis states that the man is sitting on the grass, which is a grassy area, while the hypothesis states that the woman is standing on a road, which is a road, and therefore, the premise contradicts the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: A band is playing before a large audience
# premise: Performers making music on a guitar and keyboard.
# answer: 1
# common expl list: ['Making music does not necessarily mean playing for a large audience. If a band were playing for a friend, that would also count as making music.']
#   1%|██▎                                                                                                                                                                    | 9/640 [00:11<13:36,  1.29s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a band is playing before a large audience" and the premise "music on a guitar and keyboard making music on a guitar and keyboard" because the premise does not provide any information about the band's performance or the music they are making. The hypothesis states that a band is playing before a large audience, but it does not confirm or contradict the statement that the band is playing.<extra_id_1> </s>
# ########
# *******
# hypothesis: The woman is driving a car.
# premise: A woman is reading a book on the subway.
# answer: 2
# common expl list: ["If the woman is on a subway, it isn't possible to be driving a car simultaneously.", 'If the woman is reading a book on the subway, then she is not driving a car.']
#   2%|██▌                                                                                                                                                                   | 10/640 [00:13<13:45,  1.31s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that the woman is driving a car, while the premise states that the woman is reading a book on the subway. The hypothesis states that the woman is driving a car, which implies that she is driving a car, which implies that she is driving a car, which implies that she is reading a book, which implies that she is reading a book, which implies that she is reading a book on the subway
# ########
# *******
# hypothesis: The girl is captain of the soccer team.
# premise: A young girl wearing a pink top and shin guards kicking a ball in the grass.
# answer: 1
# common expl list: ['A girl wearing a pink top and shin guards kicking a ball in the grass does not necessarily mean that she is captain of the soccer team.', 'The girl could certainly be captain of the team, but from this perspective she could also be playing with her brother.']
#   2%|██▊                                                                                                                                                                   | 11/640 [00:14<13:14,  1.26s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the girl is captain of the soccer team" and the premise "a young girl wearing a pink top and shin guards kicking a ball in the grass" because the premise provides no information about the girl's captain, but it does not provide any information about the girl's captain, besides the fact that the girl is captain of the soccer team.<extra_id_1> </s>
# ########
# *******
# hypothesis: The young girl playing in playground is lonely.
# premise: A little girl in a blue shirt and jeans, sitting on a swing smiling.
# answer: 1
# common expl list: ['Even if someone is playing on a swing all by themselves, they may not necessarily be lonely.', 'The girl is not necessarily lonely, she could be playing with other people.']
#   2%|███                                                                                                                                                                   | 12/640 [00:15<13:21,  1.28s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "the young girl playing in playground is lonely" and the premise "a little girl in a blue shirt and jeans, sitting on a swing smiling" is neutral because the premise does not provide any information about the girl's physical appearance or appearance. The premise does not provide any information about the girl's appearance or appearance, but it does provide information about the girl's physical appearance and personality. The premise does not provide any
# ########
# *******
# hypothesis: A guy is spraying paint on a brick wall.
# premise: A man is riding in a boat on the water.
# answer: 2
# common expl list: ['It could make sense to spray paint on brick walls, but it does not make sense that one would be doing that in water.', 'If a man is riding in a boat, he is not spraying paint on a brick wall.', 'It does not make sense to spray paint on a brick wall while at a boat. This especially because the brick wall is not even in the boat.']
#   2%|███▎                                                                                                                                                                  | 13/640 [00:17<13:20,  1.28s/it]
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the premise does not support the hypothesis that a guy is spraying paint on a brick wall, which implies that he is painting a brick wall, while the hypothesis states that a man is riding in a boat on the water, which implies that a man is riding in a boat on the water, which implies that a man is painting a brick wall, which implies that he is painting a brick
# ########
# *******
# hypothesis: The woman is eating from a bowl.
# premise: An Asian woman eating with a spoon.
# answer: 1
# common expl list: ['Eating with a spoon does not necessarily mean eating from a bowl.', 'Eating with a spoon could occur before or after eating from a bowl, and besides, eating with a spoon does not necessaily entail eating from a bowl.']
#   2%|███▋                                                                                                                                                                  | 14/640 [00:18<13:23,  1.28s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the woman is eating from a bowl" and the premise "an asian woman eating with a spoon" because the premise does not provide any information about the woman's eating from a bowl, which is a specific type of food, and therefore the hypothesis does not provide enough information to support or contradict the hypothesis. The premise does not provide any information about the woman's eating from a bowl, but
# ########
# *******
# hypothesis: The employee is actually a bartender.
# premise: At Maruga's diner, a male employee stands in the background behind a Coca-Cola machine.
# answer: 1
# common expl list: ['The employee could be a bartender, but he could also be a waiter, or a cook, or a dishwasher, or a busboy, or a host, or a hostess, or a manager, or a cashier, or a customer']
#   2%|███▉                                                                                                                                                                  | 15/640 [00:19<13:18,  1.28s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the employee is actually a bartender, while the premise states that the employee is a bartender, which implies that the employee is a bartender, which implies that the employee is actually a bartender. The premise does not provide any information about the employee's background or the employee's background, but it does provide information about the employee's background and background.<extra_id_1> </s>
# ########
# *******
# hypothesis: The woman is touching the harp.
# premise: A woman playing a harp.
# answer: 0
# common expl list: ["One has to touch a string in order to play a harp. Although her body doesn't necessarily have to make physical contact with the harp, since the harp has strings"]
#   2%|████▏                                                                                                                                                                 | 16/640 [00:20<13:15,  1.28s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "the woman is touching the harp" and the premise "a woman playing a harp" because the premise provides additional information about the woman's actions and actions. The premise confirms that the woman is playing a harp, which implies that the harp is touching the harp, which implies that the harp is touching the harp. The hypothesis states that
# ########
# *******
# hypothesis: The violin sounds beatuful.
# premise: A young woman is playing the violin.
# answer: 1
# common expl list: ['Someone playing the violin indicates that the violin is playing (and therefore making sounds, which might or might not be pleasing).', 'Beauty is subjective; Someone might not think the violin sounds beatiful (because taste varies). How the sound can be falsified would be if it was not making any sound at all.', 'Someone playing the violin does not necessarily mean that it is being played well, or that any sound is being made from playing the instrument. The violin might be silent.']
#   3%|████▍                                                                                                                                                                 | 17/640 [00:21<12:26,  1.20s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the violin sounds beatuful" and the premise "a young woman is playing the violin" because the premise does not provide enough information to confirm or contradict the hypothesis. The premise states that the violin sounds beatuful, which implies that the woman is playing the violin, but it does not confirm or contradict the description.<extra_id_1> </s>
# ########
# *******
# hypothesis: People are standing by a car.
# premise: Four men standing near a yellow car.
# answer: 0
# common expl list: ['People standing near a car are standing by the car.']
#   3%|████▋                                                                                                                                                                 | 18/640 [00:22<11:09,  1.08s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise entails the observation that people are standing by a car, while the premise provides additional information that confirms the hypothesis. The premise provides additional information that confirms the hypothesis, and it confirms the premise.<extra_id_1> </s>
# ########
# *******
# hypothesis: A girl in a pink swimsuit is about to do a swan dive.
# premise: A young person wearing a pink one-piece swimsuit and goggles about to complete a leap into a swimming pool.
# answer: 1
# common expl list: ['A girl in a pink swimsuit is not necessarily about to do a swan dive. She could be about to do a backflip, a handstand, or a cartwheel.']
#   3%|████▉                                                                                                                                                                 | 19/640 [00:23<11:39,  1.13s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a girl in a pink swimsuit is about to do a swan dive, but the premise states that a young person wearing a pink one-piece swimsuit and goggles is about to complete a leap into a swimming pool, which is a swan dive, which is not a swan dive. The premise states that a young person wearing a pink one
# ########
# *******
# hypothesis: The woman is moving her mouth.
# premise: A young woman in a white shirt and glasses talks to a group of people.
# answer: 0
# common expl list: ["Moving one's mouth mostly (but not only) happens when talking and communicating and is, therefore, related to talking and communicating."]
#   3%|█████▏                                                                                                                                                                | 20/640 [00:24<10:53,  1.05s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides additional information about the woman's movements and the manner in which she is speaking to a group of people. The premise provides additional information about the woman's mouth movements, which is the reason why the premise describes a specific activity that she is performing.<extra_id_1> </s>
# ########
# *******
# hypothesis: Three women with different colored shirts are sitting in an office that also has a bookshelf in it.
# premise: Three people, one with a black shirt, one with a navy blue jacket, and one with a red t-shirt, working in an office with a large messy bookshelf.
# answer: 1
# common expl list: ['Three people does not necessarily mean women, and three people']
#   3%|█████▍                                                                                                                                                                | 21/640 [00:25<10:32,  1.02s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis and the premise is neutral because the premise does not confirm or deny the hypothesis. The premise does not confirm or deny the hypothesis. The hypothesis states that three women are sitting in an office with a bookshelf, which is a large messy space in an office with a bookshelf.<extra_id_1> </s>
# ########
# *******
# hypothesis: The woman has long hair.
# premise: A woman with long dark hair standing in front of a window.
# answer: 0
# common expl list: ['Long dark hair is a good indication of having long hair.']
#   3%|█████▋                                                                                                                                                                | 22/640 [00:27<11:20,  1.10s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "the woman has long hair" and the premise "a woman with long dark hair standing in front of a window" is entailment because the premise provides additional information about the woman's long hair, which is the condition of the hypothesis and the premise. These two information are important to note, and they are important to note because the premise describes a woman with long dark hair standing in front of a window. The
# ########
# *******
# hypothesis: A chemistry teacher measures carefully to show the class how to do it.
# premise: A man uses a dropper to conduct an experiment.
# answer: 1
# common expl list: ["The dropper is used to conduct an experiment, but it doesn't necessarily mean the man is a chemistry teacher."]
#   4%|█████▉                                                                                                                                                                | 23/640 [00:28<11:16,  1.10s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a chemistry teacher measures carefully to show the class how to do it" and the premise "a man uses a dropper to conduct an experiment" because the premise provides information about the method used to conduct an experiment. The hypothesis states that the teacher measures carefully to show the class how to do it, but it does not confirm or contradict the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: The man is Asian
# premise: An Asian man is going over some paperwork that is sitting on a table with a pink carnation to two other men and a woman all of which are wearing glasses.
# answer: 0
# common expl list: ['An Asian man is a person of Asian ethnicity.']
#   4%|██████▏                                                                                                                                                               | 24/640 [00:28<09:48,  1.05it/s]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides additional information that confirms the hypothesis. The premise provides additional information that confirms the hypothesis. The premise provides additional information that confirms the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: Runner number 236 wins the marathon.
# premise: Runner number 236 races ahead while two other runners fall behind.
# answer: 1
# common expl list: ["A race is over when the race is over, so it's possible that while runner number 236 appears to be winning, he could also be losing. As there are at least two runners on the screen, it is possible for numbers 237, 238,", 'The runner could be in the lead, but it is also possible that the runner is not in the lead.']
#   4%|██████▍                                                                                                                                                               | 25/640 [00:29<09:57,  1.03it/s]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "runner number 236 wins the marathon" and the premise "runner number 236 races ahead while two other runners fall behind" because the hypothesis states that "runner number 236 races ahead" and the premise does not provide any information about the runner number 236 or the runner number 236 who is running the marathon.<extra_id_1> </s>
# ########
# *******
# hypothesis: puppy lying on the floor asleep
# premise: puppy running on the floor
# answer: 2
# common expl list: ['sleeping on the floor is different from running on the floor. The position of puppy is different.', 'A puppy cannot be running and lying down at the same time.', "A puppy can't run on the floor and be asleep simultaneously because these both require movement and sleep requires a lack of movement."]
#   4%|██████▋                                                                                                                                                               | 26/640 [00:31<10:49,  1.06s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that the puppy is lying on the floor asleep, while the premise states that the puppy is running on the floor, which contradicts the hypothesis. The hypothesis states that the puppy is lying on the floor asleep, which implies that the puppy is sleeping. The premise provides a background of information that supports the hypothesis. The premise provides a background of information that supports the hypothesis. The hypothesis states that the puppy is lying on the floor
# ########
# *******
# hypothesis: A lady reaches in a guys pocket to steal his wallet.
# premise: Middle-aged female wearing a white sunhat and white jacket, slips her hand inside a man's pants pocket.
# answer: 1
# common expl list: ['There is no way to tell the intent of the lady, since she could also be putting something, other than grabbing a wallet, in the guys pocket.', "The female's hand is slipping into the pocket, but that does not mean that she is stealing from the man.", "A lady reaching into a guy's pocket does not necessarily mean she is stealing his wallet."]
#   4%|███████                                                                                                                                                               | 27/640 [00:32<11:33,  1.13s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a lady reaches in a guys pocket to steal his wallet" and the premise "a middle-aged female wearing a white sunhat and white jacket, slips her hand into a man's pants pocket" because the premise does not provide enough information to confirm or deny the hypothesis. The hypothesis states that a lady reaches in a guys pocket to steal his wallet, which is a very unlikely scenario
# ########
# *******
# hypothesis: A woman is gathering fruit in a field.
# premise: A woman is handing out fruit.
# answer: 2
# common expl list: ['A woman handing out fruit is not gathering fruit in a field.']
#   4%|███████▎                                                                                                                                                              | 28/640 [00:33<10:36,  1.04s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that a woman is gathering fruit in a field, while the premise states that the woman is handing out fruit, which contradicts the hypothesis. The hypothesis states that a woman is gathering fruit in a field, which contradicts the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: A young person is playing soccer
# premise: A young person doing a skateboard trick on a cement raling over cement stairs.
# answer: 2
# common expl list: ['The person is doing a skateboard trick and not playing soccer.']
#   5%|███████▌                                                                                                                                                              | 29/640 [00:34<11:18,  1.11s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that a young person is playing soccer and the premise states that a young person is doing a skateboard trick on a cement raling over cement stairs. The hypothesis states that a young person is playing soccer and the premise states that a young person is doing a skateboard trick on a cement raling over cement stairs. The hypothesis states that a young person is playing soccer, which implies that
# ########
# *******
# hypothesis: The women are going to Madison Square Gardens to do finger painting.
# premise: A group of women dance on a wooden floor.
# answer: 2
# common expl list: ['Dancing is not the same as finger painting.']
#   5%|███████▊                                                                                                                                                              | 30/640 [00:35<11:49,  1.16s/it]
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the women are going to madison square gardens to do finger painting. The premise states that a group of women dance on a wooden floor, which is a wooden floor, and the hypothesis states that the women are going to do finger painting. This is because the premise does not specify whether the women are going to madison square gardens to do finger painting, which implies that they are going to do finger
# ########
# *******
# hypothesis: The firetruck is red.
# premise: a yellow firetruck is parked next to a fire with a man on a ladder pouring water on it
# answer: 2
# common expl list: ['A firetruck cannot possibly be both red and yellow at the same time.']
#   5%|████████                                                                                                                                                              | 31/640 [00:37<12:10,  1.20s/it]
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the firetruck is red, which implies that it is parked next to a fire, and the premise states that it is a yellow firetruck, which means that it is parked next to a fire, and a man on a ladder is dumping water on it. The hypothesis states that the firetruck is red, which implies that the firetruck is a yellow one, which implies that it
# ########
# *******
# hypothesis: The man is riding on a boat.
# premise: A man sits and reads a newspaper on a boat going through the water.
# answer: 0
# common expl list: ["We don't know the contextual situation of the individual, but generally seeing someone traveling on a boat means that they are indeed riding the boat.", 'If the man is sitting on a boat, and the boat is going through the water, then the man is riding on a boat.']
#   5%|████████▎                                                                                                                                                             | 32/640 [00:38<12:19,  1.22s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides information that confirms the hypothesis. The hypothesis states that the man is riding on a boat, which implies that he is reading a newspaper on a boat going through the water, which implies that he is sitting on a boat going through the water, which implies that the man is reading a newspaper on a boat going through the water, which implies that he is on a boat going through
# ########
# *******
# hypothesis: A man in a white shirt is standing in front of a tire shop.
# premise: A man in a hat standing in front of a tire shop.
# answer: 1
# common expl list: ['A man in a hat does not necessarily wear a white shirt.']
#   5%|████████▌                                                                                                                                                             | 33/640 [00:39<12:27,  1.23s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "a man in a white shirt is standing in front of a tire shop" and the premise "a man in a hat standing in front of a tire shop" is neutral because the premise describes a man in a hat standing in front of a tire shop. The hypothesis states that a man in a white shirt is standing in front of a tire shop, which implies that the man is standing in
# ########
# *******
# hypothesis: A woman likes children
# premise: A woman stands with two children near a decorated bull statue.
# answer: 1
# common expl list: ["Whether she likes children could be true or false altogether; there isn't enough information to draw any conclusions about whether she specifically likes her children that she is standing with.", "A woman enjoying the company of children does not necessarily mean that she likes children. She just enjoys a moment of a child's company.", 'Just because a woman is standing with two children near a decorated bull statue does not mean she likes children.']
#   5%|████████▊                                                                                                                                                             | 34/640 [00:40<11:22,  1.13s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the premise provides no information about the woman's liking of children, while the premise provides no information about the woman's relationship with children. The premise does not provide any information about whether or not she likes children, but it does provide some information about whether the woman likes them.<extra_id_1> </s>
# ########
# *******
# hypothesis: Two men tell a fish seller he has a great stock of fish.
# premise: A fish sellers stock is looked upon by two old men.
# answer: 1
# common expl list: ["Just because two men are looking at a fish seller's stock doesn't mean that they are telling him he has a great stock of fish. They could be looking at the fish for any number of reasons.", 'Just because two men look at fish sellers stock does not mean they are telling the fish seller that he has a great stock of fish. The sellers stock might be unimpressive, and the men might be mad at the person for something, rather than']
#   5%|█████████                                                                                                                                                             | 35/640 [00:41<11:52,  1.18s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "two men tell a fish seller he has a great stock of fish" and the premise "a fish sellers stock is looked upon by two old men" because the premise does not confirm or deny the hypothesis. The hypothesis states that two men tell a fish seller that he has a great stock of fish, which is a positive sign that he has a great stock of fish, which is not
# ########
# *******
# hypothesis: A Hispanis woman is a fashion designer.
# premise: A Hispanic woman is presenting her fabric design.
# answer: 1
# common expl list: ['The act of presenting a fabric design does not necessarily mean that the person is a fashion designer.']
#   6%|█████████▎                                                                                                                                                            | 36/640 [00:42<10:59,  1.09s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "a hispanis woman is a fashion designer" and the premise "a hispanic woman is presenting her fabric design" is neutral because the premise does not provide any information about the nature of the woman's work. The premise does not confirm or contradict the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: Two men are giving a presentation.
# premise: A man speaks into a microphone being held by another man.
# answer: 1
# common expl list: ['A man speaking into a microphone does not necessarily indicate that he is giving a presentation. He could be giving a speech, or just talking to someone.']
#   6%|█████████▌                                                                                                                                                            | 37/640 [00:43<09:26,  1.06it/s]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the premise provides no information about the man's behavior. The hypothesis states that two men are giving a presentation, but the premise does not confirm or deny the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: A girl is walking across the grass to go home.
# premise: A little girl wearing a dress walks across a green lawn on a summer day with a home and trees in the background.
# answer: 1
# common expl list: ['The girl could be walking to go to a different location, or she could be walking to go to her home.']
#   6%|█████████▊                                                                                                                                                            | 38/640 [00:44<10:28,  1.04s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a girl is walking across the grass to go home" and the premise "a little girl wearing a dress walks across a green lawn on a summer day with a home and trees in the background" because the premise provides no information about the girl's intentions or intentions, and it does not specify that she is walking to go home. The hypothesis does not specify whether she is walking home or not, but it does provide
# ########
# *******
# hypothesis: A woman sitting with her baby in a group in a bus
# premise: A woman sitting with her baby in a group, while other women breastfeed in the background.
# answer: 1
# common expl list: ["Because the only thing going on is a large group of women sitting together, it's not enough information to make a determination of a bus trip.", 'A woman sitting with her baby in a group does not necessarily mean that they are on a bus.']
#   6%|██████████                                                                                                                                                            | 39/640 [00:45<11:08,  1.11s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the premise describes a woman sitting with her baby in a group in a bus, while the premise describes a woman sitting with her baby in a group, while other women breastfeed in the background. The premise describes a woman sitting with her baby in a group, while the premise describes a woman sitting with her baby in a group, while the hypothesis describes a woman sitting with her baby in a
# ########
# *******
# hypothesis: The men are members of a rock band.
# premise: A man on the left speaks into a microphone, while a man on the right plays an unidentified instrument with a drum set in the background.
# answer: 1
# common expl list: ['The men could be members of a rock band, but they could also be members of a jazz band, or a band that plays other types of music.']
#   6%|██████████▍                                                                                                                                                           | 40/640 [00:47<11:34,  1.16s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the men are members of a rock band, while the premise describes a man on the left playing an unidentified instrument with a drum set in the background. The hypothesis states that the men are members of a rock band, but the premise states that the men are members of a rock band. The premise does not provide any information about the men's activities, and the men are not members of a rock band.
# ########
# *******
# hypothesis: A little boy is riding outside.
# premise: A little boy rides a bike down a hill on a miniature dirt bike.
# answer: 0
# common expl list: ['Riding a bike down a hill is an activity that is almost always done outside.']
#   6%|██████████▋                                                                                                                                                           | 41/640 [00:48<11:49,  1.18s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides additional information that supports the hypothesis. The premise provides additional information that supports the hypothesis that a little boy is riding outside, which is a little boy riding a bike down a hill on a miniature dirt bike. The premise also provides additional information that confirms that a little boy is riding outside, which is a specific type of activity that is not necessarily a specific type of activity.<extra_id_1>
# ########
# *******
# hypothesis: The man is wet
# premise: Man in white shirt getting sprayed by water.
# answer: 0
# common expl list: ['If the man is getting sprayed by water, then he is wet. Although two distinct events, an event of wetness is dependent on an event of getting spray by water.', 'If the man is getting sprayed by water, then he is wet.']
#   7%|██████████▉                                                                                                                                                           | 42/640 [00:49<11:58,  1.20s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that the man is wet, which implies that the man is wet, which implies that the man is getting sprayed by water, which implies that the man is wet. The premise provides additional information that confirms the hypothesis. The hypothesis states that the man is wet, which implies that the man is wet, which implies that the man is wet, which implies that the man is getting s
# ########
# *******
# hypothesis: The group is having a food fight.
# premise: A man in a black shirt is holding a microphone on stage with a drummer and guitarist.
# answer: 2
# common expl list: ["The person holding the microphone isn't standing on the floor but on the stage. People having a food fight wouldn't be on stage. The man is holding the microphone, not kicking & throwing food; & two other people (a guitarist & drummer)", 'The man is holding a microphone, not food. The group is not having a food fight, but rather performing on stage.']
#   7%|███████████▏                                                                                                                                                          | 43/640 [00:50<11:58,  1.20s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis states that the group is having a food fight, but the premise states that the group is holding a microphone on stage with a drummer and guitarist. The hypothesis states that the group is having a food fight, but the premise does not confirm or deny the hypothesis. The hypothesis states that the group is having a food fight, but the premise does not confirm or deny the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: A dog is outside.
# premise: The dog is carrying a toy through the grass.
# answer: 0
# common expl list: ['the dog is carrying a toy in the grass, which usually is an activity only done outside.']
#   7%|███████████▍                                                                                                                                                          | 44/640 [00:51<12:03,  1.21s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a dog is outside" and the premise "the dog is carrying a toy through the grass" because the premise provides more information about the dog's activity and the dog's activity in the grass. The premise provides more information about the dog's activity and the toy he is carrying. The hypothesis states that the dog is outside, but the premise does not confirm or contradict the hypothesis.
# ########
# *******
# hypothesis: A man likes dance
# premise: A Hispanic man wearing black is holding the hand of a dancing women who is dancing.
# answer: 1
# common expl list: ['Just because a man is holding the hand of a dancing woman does not mean he likes to dance.']
#   7%|███████████▋                                                                                                                                                          | 45/640 [00:52<11:27,  1.16s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the premise does not support the hypothesis "a man likes dance" which states that the man is wearing black and is holding a hand of a dancing woman who is dancing. The premise does not confirm or deny the hypothesis. It only states that the man is wearing black and holding the hand of a dancing woman who is dancing.<extra_id_1> </s>
# ########
# *******
# hypothesis: 4 players are in the grass
# premise: Three members of the red team are in the grass with a member of the yellow team.
# answer: 0
# common expl list: ['The presence of three members of the red team and one member of the yellow team indicates that there are four players in the grass.']
#   7%|███████████▉                                                                                                                                                          | 46/640 [00:54<11:43,  1.18s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides more information about the team and the grass, which is why the hypothesis states that there are 4 players in the grass, while the premise states that there are 3 players of the red team and a member of the yellow team. This is an entailment because the hypothesis states that there are 4 players in the grass, which is a condition that is consistent with the hypothesis. The premise states that there are
# ########
# *******
# hypothesis: The dog is outside
# premise: The brown and white dog is running through the grass.
# answer: 0
# common expl list: ['The dog is running through the grass, which is outside.']
#   7%|████████████▏                                                                                                                                                         | 47/640 [00:55<11:58,  1.21s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that the dog is outside, while the premise states that the dog is running through the grass. The premise describes the dog's movement through the grass, which indicates that the dog is running through the grass. The hypothesis states that the dog is outside, which indicates that the dog is running through the grass, which confirms that the dog is outside, which confirms that the dog is outside. The premise states that
# ########
# *******
# hypothesis: The woman has a black coat.
# premise: A woman in a white coat pushes a cart.
# answer: 2
# common expl list: ['If a woman is wearing a white coat, she is not necessarily wearing a black coat.', 'A woman in a white coat does not necessarily have a black coat.']
# ...
# ########
# *******
# hypothesis: The young men are in complete agreement.
# premise: Sexy young men stand on a balcony having a heated conversation.
# answer: 2
# common expl list: ['Men can have heated conversations without agreeing with each other.']
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏   | 625/640 [13:05<00:19,  1.30s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the premise provides a statement that contradicts the hypothesis "the young men are in complete agreement" because the hypothesis states that the young men are in complete agreement with the premise. The premise provides additional information about the young men standing on a balcony having a heated conversation. The premise describes a specific example of a heated conversation between two young men.<extra_id_1> </s>
# ########
# *******
# hypothesis: A woman sits outside on the dock.
# premise: A woman in a bathing suit is sitting on a dock over a body of water.
# answer: 0
# common expl list: ['If a woman is sitting on the end of a dock over the water, she is almost certainly outside.']
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍   | 626/640 [13:06<00:18,  1.36s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a woman sits outside on the dock" and the premise "a woman in a bathing suit is sitting on a dock over a body of water" because the hypothesis states that "a woman is sitting outside on the dock" and the premise states that the woman is sitting on a dock over a body of water, which implies that the woman is sitting outdoors on the dock. The premise provides
# ########
# *******
# hypothesis: Three young giraffes are playing soccer in the beach wearing shorts
# premise: Three young men are playing soccer in the beach wearing shorts and beach attire while some people watch
# answer: 2
# common expl list: ['The are not men wearing shorts and playing soccer in the beach. Giraffes cannot be men.', 'Giraffes are not people, and soccer is not played by giraffes.']
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 627/640 [13:08<00:18,  1.41s/it]
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that three young giraffes are playing soccer in the beach wearing shorts and a beach attire while the premise states that three young men are playing soccer in the beach wearing shorts and beach attire while some people watch while some people watch the giraffes and giraffes playing in the beach wearing shorts and shorts and beach attire while some people are watching the premise does not confirm or
# ########
# *******
# hypothesis: The dog is a shitzu.
# premise: A woman plays in the wind, with a furry brown dog.
# answer: 1
# common expl list: ['Being either furry or a dog is not enough to be a specific dog breed.']
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 628/640 [13:09<00:17,  1.43s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the dog is a shitzu" and the premise "a woman plays in the wind, with a furry brown dog" because the premise provides no evidence to support the hypothesis. The hypothesis states that the dog is a shitzu, but the premise states that the woman is playing in the wind, with a furry brown dog. The premise states that the dog is a s
# ########
# *******
# hypothesis: A dog runs after a squirrel.
# premise: Tan dog running through long grass in a park-like setting.
# answer: 1
# common expl list: ['A dog running through long grass does not imply that the dog is chasing a squirrel.', 'A dog could be running after a feather, chipmunk, or his master without running after a squirrel.']
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏  | 629/640 [13:11<00:15,  1.43s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "a dog runs after a squirrel" and the premise "a tan dog running through long grass in a park-like setting" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The hypothesis states that a dog is following a squirrel, but the premise does not confirm or deny the hypothesis. Therefore, the hypothesis does not match the premise.<extra_id_1> </s>
# ########
# *******
# hypothesis: Two wrestlers are competing and are brothers.
# premise: Two wrestlers in an intense match.
# answer: 1
# common expl list: ['The two wrestlers do not have to be brothers. They might be in an act together for a show, for example. People who compete do not have to be related.']
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍  | 630/640 [13:12<00:13,  1.39s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the wrestlers are competing and are brothers, but the premise does not specify whether the wrestlers are competing or are in an intense match. The hypothesis states that the wrestlers are competing and are brothers, but the premise does not specify whether they are wrestling or not. Therefore, the premise does not confirm or deny the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: The child is upside down.
# premise: The child is hanging upside down with his legs over a pole.
# answer: 0
# common expl list: ['If the child is hanging upside down, then he is upside down.', 'If a child is hanging upside down with his legs over a pole, then the child is upside down.']
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋  | 631/640 [13:13<00:11,  1.26s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise provides additional information about the child being upside down, which is a logical step to the hypothesis. The hypothesis states that the child is upside down, which is a normal step, but it does not confirm or contradict the premise.<extra_id_1> </s>
# ########
# *******
# hypothesis: A young boy is playing in the grass.
# premise: A young boy is playing in the sandy water.
# answer: 2
# common expl list: ['The boy is not playing in the grass, he is playing in the sand.']
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉  | 632/640 [13:14<00:10,  1.33s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "a young boy is playing in the grass" and the premise "a young boy is playing in the sandy water" is a contradiction because the hypothesis states that a young boy is playing in the grass, which is a grassy area, and the premise states that the boy is playing in the water, which is a sandy area, which is a sandy area, which is a sandy area, which is a sandy area
# ########
# *******
# hypothesis: a father and daughter swim together
# premise: A man and a young girl swimming.
# answer: 1
# common expl list: ['Swimming is not inherently a relationship-affirming activity between a father and daughter. It could be a parent and child, two friends, et cetera. The text "and" separates the subjects, so it cannot be a single subject.']
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 633/640 [13:16<00:09,  1.30s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a father and daughter swim together" and the premise "a man and a young girl swimming" because the premise does not confirm or contradict the hypothesis. The hypothesis states that a father and a young girl swim together, but it does not confirm or contradict the hypothesis. The premise does not confirm or deny the hypothesis.<extra_id_1> </s>
# ########
# *******
# hypothesis: Someone is sitting outside waiting for a friend to arrive.
# premise: The young man in the plaid shirt is sitting on a chair that is out in the yard.
# answer: 1
# common expl list: ['While someone could be sitting outside waiting for a friend to arrive, it is also possible that they are sitting outside for other reasons, such as to enjoy the weather.']
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍ | 634/640 [13:17<00:08,  1.35s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "someone is sitting outside waiting for a friend to arrive" and the premise "the young man in the plaid shirt is sitting on a chair that is out in the yard" is neutral because the premise does not provide any information about the person in the plaid shirt's premise. The hypothesis states that "someone is sitting outside waiting for a friend to arrive" and the premise does not provide enough information to confirm or den
# ########
# *******
# hypothesis: dog is running and being chased by another dog
# premise: Dog running with pet toy being chased by another dog.
# answer: 0
# common expl list: ['If a dog is running and being chased by another dog, then a dog is running and being chased by another dog.']
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 635/640 [13:19<00:06,  1.39s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment because the premise describes the specifics of the dog being chased by another dog. The premise describes the dog being chased by another dog, while the premise describes the dog being chased by another dog, which is a dog that is running and being chased by another dog. The premise provides additional information about the dog being chased by another dog, which is a dog that is running and being chased by another
# ########
# *******
# hypothesis: a man with glasses
# premise: An elderly man with glasses, a red ball cap and backpack is standing in front of an open doorway.
# answer: 0
# common expl list: ['The man is wearing glasses, and so he is a man with glasses.']
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 636/640 [13:20<00:05,  1.42s/it]
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a man with glasses" and the premise "an elderly man with glasses, a red ball cap and backpack is standing in front of an open doorwayway" because the premise provides additional information that confirms the hypothesis. The hypothesis states that the man is wearing glasses, while the premise states that he is wearing a red ball cap and backpack, which indicates that the man is standing in front of an open
# ########
# *******
# hypothesis: A man in pants and a t-shirt doing fire tricks.
# premise: A robed dancer holding fire stick entertains a crowd.
# answer: 2
# common expl list: ['A robed dancer is not necessarily the same as a man in pants and a t-shirt doing fire tricks.']
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏| 637/640 [13:22<00:04,  1.44s/it]
# generated explanation: <pad> <extra_id_0> The relation is contradiction because the hypothesis describes a man in pants and a t-shirt doing fire tricks, while the premise describes a robed dancer holding fire stick entertains a crowd. The hypothesis states that a man in pants and a t-shirt doing fire tricks, while the premise states that a robed dancer holding fire stick entertains a crowd, which is a different story. The relation is contradiction
# ########
# *******
# hypothesis: The man is walking into a room.
# premise: A man is standing in the doorway of a building.
# answer: 1
# common expl list: ["Just because someone is standing in the doorway does not necessarily mean that he's walking into a room, it could be that he's there to prevent others from walking in."]
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍| 638/640 [13:23<00:02,  1.46s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the man is walking into a room, while the premise states that the man is standing in the doorway of a building, which implies that the man is standing in the doorway of a building, which implies that he is standing in the doorway of a building, which implies that he is walking into a room, which implies that he is walking into a room, but it is not clear
# ########
# *******
# hypothesis: The log is for firewood.
# premise: In a snowy residential environment, a man with a brown jacket and gray mustache and beard places a hand on a felled log while another man in a blue shirt is blurry on the right side of the photo.
# answer: 1
# common expl list: ['The log could be for firewood, but it could also be for a number of other things.', 'While firewood is typically cut logs, just because a log is present does not mean it is for firewood.']
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋| 639/640 [13:25<00:01,  1.47s/it]
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the log is for firewood" and the premise "a man with a brown jacket and mustache and beard places a hand on a felled log" because the premise does not specify whether the log is for firewood or not. The premise does not specify whether the log is for firewood, but it does not specify whether it is for firewood. Therefore, the premise does not provide enough information to
# ########
# *******
# hypothesis: A child uses their imagination.
# premise: A child making a sand castle on the beach.
# answer: 1
# common expl list: ['A child could be using their imagination while building a sand castle, but they could also be building a sand castle without using their imagination.']
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 640/640 [13:26<00:00,  1.26s/it]
# generated explanation: <pad> <extra_id_0> The relation between the hypothesis "a child uses their imagination" and the premise "a child making a sand castle on the beach" is neutral because the premise does not provide enough information to confirm or deny the hypothesis. The premise does not provide enough information to confirm or deny the hypothesis.<extra_id_1> </s>
# ########

# %%
import json
rationale_pair_save_path = os.path.join("./results", "96shots_esnli_t5_base_chatgpt_rationales_generator_test_rationale_pair.json")
with open(rationale_pair_save_path, 'w') as f:
    json.dump(rationale_pair_dev_data, f)
