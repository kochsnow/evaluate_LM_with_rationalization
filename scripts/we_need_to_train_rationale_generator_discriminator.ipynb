# %%
#must fight number 1
id2label={"0":"A", "1":"B", "2":"C", "3":"D", "4":"E"}
alber_result_path="/cognitive_comp/zhangyuxiang/projects/unimc/output/bad_case/q_mode_mrcopenbookqa.txt"
with open(alber_result_path,'r') as f:
    lll=[l.strip().split('\t') for l in f.readlines()]
    lines=[id2label[l.strip().split('\t')[1]] for l in f.readlines()]
import json
inputpath="/cognitive_comp/huangyongfeng/fight_for_something/graph-soft-counter/data/obqa/statement/test.final_hope_fact_mvp_statement.jsonl"
with open(inputpath, 'r') as f:
    test_data=json.load(f)
test_label = [x['answerKey'] for x in test_data]

# %%
acc=0
for x,y in zip(test_label,lines):
    if x==y:
        acc+=1
acc/500
# Out:
# 0.24

# %%
ddd=[[x['id'],x['answerKey']] for x in test_data]

# %%
ddd
# Out:
# [['8-343', 'B'],
#  ['1129', 'A'],
#  ['880', 'C'],
#  ['7-999', 'C'],
#  ['8-464', 'C'],
#  ['9-794', 'C'],
#  ['9-1163', 'C'],
#  ['9-322', 'B'],
#  ['7-1140', 'D'],
#  ['7-903', 'B'],
#  ['7-511', 'C'],
#  ['9-937', 'B'],
#  ['8-201', 'C'],
#  ['1618', 'A'],
#  ['758', 'C'],
#  ['7-414', 'D'],
#  ['9-675', 'C'],
#  ['9-163', 'C'],
#  ['1032', 'A'],
#  ['889', 'B'],
#  ['1160', 'A'],
#  ['9-298', 'A'],
#  ['1189', 'A'],
#  ['8-395', 'B'],
#  ['7-238', 'B'],
#  ['7-372', 'B'],
#  ['8-35', 'D'],
#  ['9-271', 'A'],
#  ['9-409', 'D'],
#  ['530', 'B'],
#  ['1426', 'C'],
#  ['8-466', 'D'],
#  ['1577', 'B'],
#  ['8-257', 'A'],
#  ['378', 'B'],
#  ['8-41', 'A'],
#  ['9-540', 'A'],
#  ['266', 'D'],
#  ['1309', 'D'],
#  ['7-1197', 'A'],
#  ['7-891', 'D'],
#  ['1180', 'D'],
#  ['1204', 'A'],
#  ['7-52', 'D'],
#  ['1759', 'A'],
#  ['9-655', 'A'],
#  ['132', 'A'],
#  ['8-79', 'A'],
#  ['1835', 'B'],
#  ['9-149', 'C'],
#  ['695', 'A'],
#  ['8-179', 'D'],
#  ['7-50', 'A'],
#  ['508', 'D'],
# ...

# %%
lll
# Out:
# [['8-343', '0'],
#  ['1129', '3'],
#  ['880', '3'],
#  ['7-999', '3'],
#  ['8-464', '3'],
#  ['9-794', '3'],
#  ['9-1163', '0'],
#  ['9-322', '3'],
#  ['7-1140', '2'],
#  ['7-903', '2'],
#  ['7-511', '1'],
#  ['9-937', '2'],
#  ['8-201', '3'],
#  ['1618', '2'],
#  ['758', '0'],
#  ['7-414', '1'],
#  ['9-675', '3'],
#  ['9-163', '3'],
#  ['1032', '0'],
#  ['889', '2'],
#  ['1160', '1'],
#  ['9-298', '0'],
#  ['1189', '2'],
#  ['8-395', '1'],
#  ['7-238', '3'],
#  ['7-372', '0'],
#  ['8-35', '1'],
#  ['9-271', '2'],
#  ['9-409', '1'],
#  ['530', '1'],
#  ['1426', '1'],
#  ['8-466', '3'],
#  ['1577', '0'],
#  ['8-257', '3'],
#  ['378', '2'],
#  ['8-41', '1'],
#  ['9-540', '1'],
#  ['266', '0'],
#  ['1309', '0'],
#  ['7-1197', '2'],
#  ['7-891', '1'],
#  ['1180', '2'],
#  ['1204', '3'],
#  ['7-52', '2'],
#  ['1759', '2'],
#  ['9-655', '3'],
#  ['132', '3'],
#  ['8-79', '2'],
#  ['1835', '0'],
#  ['9-149', '2'],
#  ['695', '3'],
#  ['8-179', '2'],
#  ['7-50', '3'],
#  ['508', '2'],
# ...

# %%
#deberta_v3_large_0.914+
test_result_str_1="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_1_1_0_0_1_1_1_0_0_3_1_2_3_1_3_1_0_0_3_3_0_3_1_0_3_0_0_0_0_1_2_3_3_0_3_2_0_2_3_1_0_2_1_0_1_1_2_1_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_2_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_3_2_2_3_2_0_3_0_3_0_1_0_2_0_3_3_0_3_0_0_0_0_2_3_1_2_1_1_0_2_2_1_2_0_1_2_2_0_0_2_2_1_2_0_2_0_1_1_1_0_2_1_2_2_2_2_2_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_1_2_2_3_3_1_0_1_1_3_1_1_2_2_3_3_0_0_3_0_1_1_0_3_1_0_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_2_3_2_0_1_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_0_2_1_2_1_1_0_1_3_1_2_2_0_1_1_0_2_1_3_1_2_0_3_2_3_0_0_3_3_1_3_1_0_1_1_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_2_0_1_3_2_0_2_1_1_2_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_3_0_2_1_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_2_2_1_2_0_0_0_3_2_2_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_1_2_2_0_2_3_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
#aristoRoberta_large_0.876+
test_result_str_2="2_0_2_2_2_2_2_1_3_1_0_1_2_0_2_3_2_2_0_2_0_0_0_1_1_1_1_0_3_1_2_3_3_0_1_0_0_3_3_0_3_2_0_3_2_0_0_0_1_2_2_3_0_3_2_0_2_3_1_0_2_2_0_1_3_2_0_0_0_3_1_0_2_2_2_0_0_2_1_2_2_0_1_1_3_1_3_0_2_0_0_3_2_0_2_2_2_1_0_2_1_1_0_3_1_3_1_0_3_2_0_2_1_2_0_2_3_3_0_1_0_3_0_3_1_0_0_3_3_2_2_3_2_0_3_0_3_3_3_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_0_0_1_1_1_0_1_1_2_2_2_2_2_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_0_2_2_3_3_1_0_1_3_3_1_1_2_1_3_3_0_0_3_2_3_1_0_3_1_0_1_3_1_0_2_2_3_0_3_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_2_2_2_0_0_1_3_3_1_3_3_1_0_3_2_3_1_0_1_3_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_1_2_1_2_1_1_0_1_3_1_2_2_2_1_1_3_3_1_2_3_2_1_3_2_3_0_0_3_3_1_3_1_0_1_0_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_1_0_1_1_1_3_3_1_0_2_3_1_2_1_1_1_2_1_3_3_0_1_2_3_2_1_0_1_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_0_0_0_1_2_0_3_1_0_1_3_3_3_1_1_1_1_0_0_2_0_2_2_2_2_2_0_2_2_2_0_2_0_1_3_2_1_2_0_0_0_3_2_2_0_3_3_1_1_3_3_1_1_1_0_3_1_3_3_1_2_3_1_2_0_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_0_1_0_0_2_2_0_0_2_2_1_2"
#deberta_v2_xxlarge_0.912+
test_result_str_3="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_2_3_0_0_1_1_1_0_0_3_1_2_3_1_0_1_1_0_3_3_0_0_3_0_3_0_0_0_0_1_2_3_3_0_3_2_0_2_3_1_0_1_2_0_1_1_2_0_0_0_2_1_2_2_3_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_3_0_3_1_2_2_3_2_0_3_0_3_1_1_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_0_0_2_2_1_2_0_2_0_1_1_1_0_2_1_2_1_2_2_2_0_3_2_3_2_2_1_3_0_2_1_0_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_1_3_3_0_0_3_0_3_1_0_3_1_0_1_3_1_0_2_2_1_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_0_1_3_3_1_2_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_2_0_3_2_2_0_1_3_3_1_2_1_2_1_3_1_1_0_1_3_1_2_2_0_1_1_0_1_1_2_3_2_0_3_2_3_0_0_3_3_1_3_1_0_1_1_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_1_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_2_0_1_3_2_0_2_1_1_1_0_3_0_2_3_2_0_1_2_0_2_1_0_1_3_1_2_1_1_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_0_2_1_2_0_0_0_3_2_0_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_2_2_2_0_2_0_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
#aristoRoberta_large_0.878+
test_result_str_4="2_0_2_2_2_2_2_1_3_1_0_1_2_0_2_3_2_2_0_2_0_0_0_1_1_1_2_0_3_1_2_3_1_0_1_2_0_3_3_0_3_0_0_3_2_0_0_0_1_2_2_2_0_3_2_0_2_3_1_0_2_2_0_1_3_2_2_0_0_3_1_2_2_2_2_2_0_2_1_2_2_0_1_1_3_1_3_0_2_0_0_3_2_0_2_2_2_1_0_2_1_1_0_3_1_3_1_0_3_2_0_2_1_2_0_1_3_3_0_1_0_3_0_3_1_1_0_1_3_2_1_3_2_0_3_0_3_1_1_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_0_0_1_1_1_0_1_1_2_2_2_2_2_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_0_2_0_2_2_3_3_1_0_1_3_3_1_1_2_1_3_3_0_0_3_2_3_1_0_3_1_0_1_3_1_0_2_2_1_0_2_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_2_0_3_3_1_1_1_1_2_3_0_2_2_2_2_0_1_1_3_3_1_2_3_1_0_3_2_3_1_0_1_3_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_1_2_1_2_1_1_0_1_3_1_2_2_1_1_1_0_3_1_2_3_2_2_3_2_3_0_0_3_3_1_3_1_0_1_0_2_1_0_0_3_1_0_0_0_2_1_3_2_0_1_2_0_1_1_0_3_3_1_0_3_3_1_2_1_1_1_2_1_3_3_0_1_2_3_2_1_0_1_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_1_2_0_1_2_0_3_1_0_1_3_1_2_1_1_1_1_0_0_2_0_2_2_2_2_2_0_0_2_2_0_2_0_1_3_2_1_2_0_0_0_3_2_2_0_3_2_1_1_3_3_1_2_1_0_0_1_3_1_1_2_3_1_2_0_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_1_1_3_1_1_0_0_2_1_0_0_2_2_1_2"
##unimc-deberta-v2-xxlarge 0.91
#test_result_str_5="1_0_2_2_2_2_2_1_0_1_2_1_2_0_2_3_2_2_0_3_0_0_0_1_1_1_0_1_3_2_2_3_1_0_1_1_0_3_3_0_3_1_0_3_0_0_0_0_1_2_0_3_0_3_2_0_2_3_1_0_2_2_0_1_3_2_0_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_2_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_3_2_1_3_2_0_2_0_3_0_1_0_1_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_2_0_1_2_1_0_3_1_2_2_2_2_3_0_3_2_3_2_2_1_2_3_2_1_0_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_2_3_3_0_0_2_0_2_1_2_3_1_1_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_1_1_2_0_0_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_1_3_3_3_1_2_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_3_0_3_2_2_0_1_3_3_1_2_0_2_1_3_1_1_0_1_3_1_2_2_2_1_1_0_3_1_2_1_2_1_3_2_3_0_0_3_3_1_3_1_0_1_0_2_1_2_1_3_1_0_0_0_2_1_3_2_0_2_3_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_2_0_1_3_2_0_2_1_1_1_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_1_3_1_1_1_1_0_0_1_0_2_2_2_2_2_0_2_2_2_0_2_0_1_1_2_1_2_0_0_0_0_2_0_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_2_2_2_0_2_2_2_2_1_2_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_1_0_0_2_2_1_2"
#mvp-tuning unimc-deberta-v2-xxlarge 0.92
test_result_str_5="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_1_1_0_0_1_1_1_2_0_3_2_2_3_1_0_1_0_0_3_3_0_0_1_0_3_0_0_0_0_1_2_3_3_0_3_2_3_2_3_1_0_2_1_0_1_1_2_3_0_0_3_1_2_2_0_2_1_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_1_2_1_3_2_0_3_0_3_0_1_0_2_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_1_2_1_2_0_2_0_1_1_1_0_2_1_2_2_2_2_3_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_0_2_2_3_3_1_0_1_0_3_1_1_2_1_3_3_0_1_3_0_1_1_0_3_1_1_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_0_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_0_2_0_2_1_0_1_1_0_1_3_1_2_2_2_1_1_0_1_1_2_1_2_0_3_2_3_0_0_3_3_1_3_1_0_1_2_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_3_2_1_2_1_1_0_0_2_0_2_2_2_2_2_0_0_2_2_0_2_0_1_1_2_1_2_0_0_0_0_2_1_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_3_2_3_1_2_2_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
##unimc-deberta-v2-xxlarge 0.926
test_result_str_6="1_0_2_2_2_2_2_1_0_1_2_1_2_0_2_3_2_2_0_3_0_0_0_1_1_1_0_0_3_2_2_3_1_0_1_0_0_3_3_0_3_1_0_3_0_0_0_0_1_2_0_3_0_3_2_0_2_3_1_0_2_2_0_1_1_2_1_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_3_1_2_0_2_3_3_0_1_0_3_0_3_1_1_0_3_1_2_1_3_2_0_2_0_3_1_1_0_1_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_2_0_1_2_1_0_3_1_2_2_2_2_3_0_3_2_3_2_2_1_3_3_2_1_0_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_2_3_3_0_0_2_0_3_1_0_3_1_0_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_0_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_1_1_3_3_1_2_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_3_0_3_2_2_0_1_3_3_1_2_0_2_1_3_1_1_0_1_3_1_2_2_2_1_1_0_3_1_2_3_1_0_3_2_3_0_0_3_1_1_3_1_0_1_0_2_1_2_0_3_1_0_0_0_2_1_3_2_0_2_3_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_1_3_1_0_1_1_0_0_1_0_2_2_2_2_2_0_2_2_2_0_2_0_1_1_2_1_2_0_0_0_0_2_2_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_2_2_2_0_2_2_2_2_1_0_1_1_0_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
#deberta-v2-xxlarge 91.4
test_result_str_7="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_2_1_0_0_1_1_1_2_0_3_2_2_3_1_0_1_0_0_3_3_0_3_1_0_3_0_0_0_0_1_2_2_3_0_3_2_3_2_3_1_0_2_1_0_1_1_2_2_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_1_2_1_3_2_0_3_0_3_0_1_0_2_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_1_2_1_2_0_0_0_1_1_1_0_2_1_2_2_2_2_3_0_3_2_3_2_2_1_3_0_2_1_1_0_2_2_3_3_2_0_2_2_3_3_1_0_1_0_3_1_1_2_1_3_3_0_0_3_0_1_1_0_3_1_0_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_1_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_1_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_0_2_1_2_1_1_0_1_3_1_2_2_0_1_1_0_2_1_3_1_2_0_3_2_3_0_0_3_3_1_3_1_0_1_2_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_3_2_1_1_1_1_0_0_2_0_2_2_2_2_2_0_0_2_2_0_2_0_1_0_2_2_2_0_0_0_3_2_1_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_1_2_2_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
#unimc-deberta-v2-xxlarge 0.92
test_result_str_8="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_1_0_0_0_1_1_1_0_0_3_1_2_3_1_0_1_0_0_3_3_0_3_2_0_3_0_0_0_0_1_2_0_3_0_3_2_0_2_3_1_0_2_2_0_1_1_2_1_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_1_0_3_3_2_1_3_2_0_2_0_3_1_1_0_1_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_2_0_1_3_1_0_3_1_2_2_2_2_3_0_3_2_3_2_2_1_1_3_2_1_0_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_2_3_3_0_0_2_0_0_1_0_3_1_1_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_1_1_2_0_0_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_1_3_3_3_1_2_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_0_2_1_2_1_1_0_1_3_1_2_2_2_1_1_0_1_1_2_3_2_0_3_2_3_0_0_3_1_1_3_1_0_1_1_2_1_2_1_3_1_0_0_0_2_1_3_2_0_2_3_2_1_1_1_3_3_1_0_2_3_1_2_1_0_1_2_1_0_3_0_1_2_3_2_1_0_3_0_1_0_1_3_2_0_0_1_1_2_0_3_0_0_3_2_0_1_2_0_3_1_0_1_3_1_3_1_1_1_1_0_0_1_0_2_2_2_2_2_0_2_2_2_0_2_0_1_1_2_1_2_0_0_0_0_2_2_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_2_2_2_0_2_3_2_2_1_2_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_1_0_0_2_2_1_2"
#test_result_str_8="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_1_1_0_0_1_1_1_2_0_3_2_2_3_1_0_1_0_0_3_3_0_0_1_0_3_0_0_0_0_1_2_3_3_0_3_2_3_2_3_1_0_2_1_0_1_1_2_3_0_0_3_1_2_2_0_2_1_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_1_2_1_3_2_0_3_0_3_0_1_0_2_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_1_2_1_2_0_2_0_1_1_1_0_2_1_2_2_2_2_3_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_0_2_2_3_3_1_0_1_0_3_1_1_2_1_3_3_0_1_3_0_1_1_0_3_1_1_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_0_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_0_2_0_2_1_0_1_1_0_1_3_1_2_2_2_1_1_0_1_1_2_1_2_0_3_2_3_0_0_3_3_1_3_1_0_1_2_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_3_2_1_2_1_1_0_0_2_0_2_2_2_2_2_0_0_2_2_0_2_0_1_1_2_1_2_0_0_0_0_2_1_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_3_2_3_1_2_2_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"

# %%
id2label={"0":"A", "1":"B", "2":"C", "3":"D", "4":"E"}
test_predictions_1=[id2label[x] for x in test_result_str_1.split("_")]
test_predictions_2=[id2label[x] for x in test_result_str_2.split("_")]
test_predictions_3=[id2label[x] for x in test_result_str_3.split("_")]
test_predictions_4=[id2label[x] for x in test_result_str_4.split("_")]
test_predictions_5=[id2label[x] for x in test_result_str_5.split("_")]
test_predictions_6=[id2label[x] for x in test_result_str_6.split("_")]
test_predictions_7=[id2label[x] for x in test_result_str_7.split("_")]
test_predictions_8=[id2label[x] for x in test_result_str_8.split("_")]

# %%
S=0
L=500
test_predictions_ensemble = []
for p1,p2,p3,p4,p5,p6,p7,p8 in zip(test_predictions_1[S:L],test_predictions_2[S:L],
                             test_predictions_3[S:L],test_predictions_4[S:L],
                             test_predictions_5[S:L],test_predictions_6[S:L],
                             test_predictions_7[S:L],test_predictions_8[S:L]):
    test_predictions_ensemble.append([p1,p4,p8,p6,p6,p7,p6,p7])

acc=[]
error=[]
ensemble_ans=[]
for kk, (pr,la) in enumerate(zip(test_predictions_ensemble,test_label[S:L])):
    #if la in pr:
    if la==max(pr,key=pr.count):
        acc.append(1)
    else:
        acc.append(0)
        error.append([kk,la,pr])
    ensemble_ans.append(max(pr,key=pr.count))

sum(acc)/len(acc)
# Out:
# 0.952

# %%
"_".join(ensemble_ans)
# Out:
# 'B_A_C_C_C_C_C_B_D_B_C_B_C_A_C_D_C_C_A_D_A_A_A_B_B_B_A_A_D_C_C_D_B_A_B_A_A_D_D_A_D_B_A_D_A_A_A_A_B_C_A_D_A_D_C_A_C_D_B_A_C_C_A_B_B_C_B_A_A_D_B_C_C_A_C_C_A_C_B_C_C_A_A_B_D_B_D_D_C_A_A_D_C_A_C_C_C_B_A_D_B_B_A_D_B_D_B_A_D_C_A_B_B_C_A_C_D_D_A_B_A_D_A_D_B_C_A_D_B_C_B_D_C_A_D_A_D_A_B_A_B_A_D_D_A_D_A_A_A_A_C_D_B_C_A_B_A_C_C_B_C_A_B_C_A_C_A_C_C_B_C_A_C_A_B_B_B_A_D_B_C_C_C_C_D_A_D_C_D_C_C_B_D_A_C_B_A_A_C_C_D_D_C_A_C_C_D_D_B_A_B_B_D_B_B_C_C_D_D_A_A_D_A_D_B_A_D_B_A_B_D_B_A_C_C_D_A_A_C_D_A_D_D_B_A_A_A_C_D_D_D_B_C_A_B_D_D_A_D_D_B_B_B_B_C_D_A_C_D_D_C_A_B_D_D_D_B_C_D_B_A_D_C_D_B_A_B_B_B_A_A_C_C_A_B_A_D_C_C_A_B_D_D_B_C_A_C_B_C_B_B_A_B_D_B_C_C_C_B_B_A_D_B_C_B_C_A_D_C_D_A_A_D_D_B_D_B_A_B_A_C_B_C_A_D_B_A_A_A_C_B_D_C_A_B_D_A_B_B_A_D_D_B_A_C_D_B_C_B_B_B_C_B_A_D_A_B_C_D_C_B_A_D_A_B_A_B_D_C_A_C_B_B_C_A_D_A_C_D_C_A_B_C_A_D_B_A_B_D_B_D_B_B_B_B_A_A_B_A_C_C_C_C_C_A_A_C_C_A_C_A_B_B_C_B_C_A_A_A_D_C_C_A_D_D_B_B_D_D_B_A_B_A_A_B_D_B_B_C_D_B_C_C_A_C_C_C_C_B_A_B_B_C_B_D_D_C_C_B_A_D_A_D_B_C_C_B_D_B_B_A_A_C_C_A_A_C_C_B
# ...

# %%
error
# Out:
# [[19, 'B', ['B', 'C', 'D', 'D', 'D', 'C', 'C', 'D']],
#  [26, 'D', ['A', 'C', 'A', 'A', 'A', 'C', 'C', 'A']],
#  [29, 'B', ['B', 'B', 'C', 'C', 'C', 'C', 'C', 'C']],
#  [41, 'D', ['B', 'A', 'B', 'B', 'B', 'B', 'B', 'B']],
#  [66, 'A', ['B', 'C', 'A', 'B', 'B', 'C', 'C', 'B']],
#  [99, 'C', ['D', 'C', 'D', 'D', 'D', 'D', 'D', 'D']],
#  [110, 'C', ['C', 'A', 'A', 'A', 'A', 'A', 'A', 'A']],
#  [125, 'A', ['C', 'B', 'C', 'B', 'B', 'C', 'C', 'B']],
#  [137, 'B', ['A', 'B', 'A', 'B', 'B', 'A', 'A', 'B']],
#  [140, 'C', ['C', 'D', 'B', 'B', 'B', 'C', 'C', 'B']],
#  [225, 'C', ['A', 'A', 'C', 'A', 'A', 'A', 'A', 'A']],
#  [228, 'B', ['A', 'A', 'B', 'A', 'A', 'A', 'A', 'A']],
#  [235, 'B', ['D', 'B', 'D', 'D', 'D', 'D', 'D', 'D']],
#  [294, 'A', ['B', 'B', 'D', 'D', 'D', 'B', 'B', 'D']],
#  [303, 'A', ['B', 'B', 'B', 'B', 'B', 'B', 'B', 'B']],
#  [317, 'B', ['A', 'B', 'C', 'C', 'C', 'A', 'A', 'C']],
#  [324, 'D', ['B', 'D', 'B', 'D', 'D', 'B', 'B', 'D']],
# ...

# %%
S=0
L=500
test_predictions_ensemble = []
for p1,p2,p3,p4,p5,p6 in zip(test_predictions_1[S:L],test_predictions_2[S:L],
                             test_predictions_3[S:L],test_predictions_4[S:L],
                             test_predictions_5[S:L],test_predictions_6[S:L]):
    test_predictions_ensemble.append([p1,p4,p5,p6])

acc=[]
error=[]
ensemble_ans=[]
for kk, (pr,la) in enumerate(zip(test_predictions_ensemble,test_label[S:L])):
    #if la in pr:
    if la==max(pr,key=pr.count):
        acc.append(1)
    else:
        acc.append(0)
        error.append([kk,la,pr])
    ensemble_ans.append(max(pr,key=pr.count))

sum(acc)/len(acc)
# Out:
# 0.928

# %%
"_".join(ensemble_ans)
# Out:
# 'B_A_C_C_C_C_C_B_D_B_C_B_C_A_C_D_C_C_A_D_A_A_A_B_B_B_A_A_D_B_C_D_B_A_B_A_A_D_D_A_D_B_A_D_A_A_A_A_B_C_A_D_A_D_C_A_C_D_B_A_C_C_A_B_B_C_B_A_A_D_B_C_C_A_C_C_A_C_B_C_C_A_A_B_D_B_D_D_C_A_A_D_C_A_C_C_C_B_A_D_B_B_A_D_B_D_B_A_D_C_A_B_B_C_A_C_D_D_A_B_A_D_A_D_B_C_A_D_D_C_B_D_C_A_D_A_D_A_B_A_B_A_D_D_A_D_A_A_A_A_C_D_B_C_A_B_A_C_C_B_C_A_B_C_A_C_A_C_C_B_C_A_C_A_B_B_B_A_D_B_C_C_C_C_C_A_D_C_D_C_C_B_D_A_C_B_D_A_C_C_D_D_C_A_C_C_D_D_B_A_B_B_D_B_B_C_C_D_D_A_A_D_A_D_B_A_D_B_A_B_D_B_A_C_C_D_A_A_C_D_A_D_D_B_A_A_A_C_D_D_D_B_C_A_B_D_D_A_D_D_B_B_B_B_C_D_A_C_C_D_C_A_B_D_D_D_B_C_D_B_A_D_C_D_B_A_B_B_B_A_A_C_C_A_B_A_D_C_C_A_B_D_D_B_C_A_C_B_C_B_B_A_B_D_B_C_C_C_B_B_A_D_B_C_B_C_A_D_C_D_A_A_D_D_B_D_B_A_B_A_C_B_C_A_D_B_A_A_A_C_B_D_C_A_B_D_A_B_B_A_D_D_B_A_C_D_B_C_B_B_B_C_B_A_D_A_B_C_D_C_B_A_D_A_C_A_B_D_C_A_C_B_B_C_A_D_A_C_D_C_A_B_C_A_D_B_A_B_D_B_D_B_B_B_B_A_A_B_A_C_C_C_C_C_A_A_C_C_A_C_A_B_B_C_B_C_A_A_A_D_C_C_A_D_D_B_B_D_D_B_A_B_A_A_B_D_B_B_C_D_B_C_C_A_C_C_C_C_B_A_B_B_C_B_D_D_C_C_B_A_D_A_D_B_C_C_B_D_B_B_A_A_C_C_A_A_C_C_B
# ...

# %%
# '_'.join(ensemble_ans)
error
# Out:
# [[19, 'B', ['B', 'C', 'D', 'D']],
#  [26, 'D', ['A', 'C', 'A', 'A']],
#  [35, 'A', ['A', 'C', 'B', 'B']],
#  [41, 'D', ['B', 'A', 'B', 'B']],
#  [64, 'B', ['B', 'D', 'D', 'D']],
#  [99, 'C', ['D', 'C', 'D', 'D']],
#  [110, 'C', ['C', 'A', 'A', 'A']],
#  [125, 'A', ['C', 'B', 'C', 'C']],
#  [128, 'B', ['D', 'D', 'D', 'D']],
#  [137, 'B', ['A', 'B', 'A', 'A']],
#  [140, 'C', ['C', 'D', 'B', 'B']],
#  [184, 'D', ['C', 'C', 'D', 'D']],
#  [196, 'A', ['D', 'D', 'A', 'A']],
#  [223, 'D', ['B', 'D', 'C', 'C']],
#  [225, 'C', ['A', 'A', 'C', 'C']],
#  [228, 'B', ['A', 'A', 'B', 'B']],
#  [235, 'B', ['D', 'B', 'D', 'D']],
#  [268, 'D', ['C', 'C', 'D', 'D']],
#  [294, 'A', ['B', 'B', 'D', 'D']],
#  [303, 'A', ['B', 'B', 'B', 'B']],
#  [317, 'B', ['A', 'B', 'C', 'C']],
#  [324, 'D', ['B', 'D', 'B', 'B']],
#  [326, 'A', ['A', 'C', 'B', 'B']],
#  [355, 'A', ['A', 'C', 'D', 'D']],
#  [359, 'B', ['A', 'A', 'A', 'A']],
#  [374, 'C', ['D', 'D', 'D', 'D']],
#  [397, 'A', ['C', 'C', 'C', 'C']],
# ...

# %%
test_result_str_1="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_1_1_0_0_1_1_1_0_0_3_1_2_3_1_3_1_0_0_3_3_0_3_1_0_3_0_0_0_0_1_2_3_3_0_3_2_0_2_3_1_0_2_1_0_1_1_2_1_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_2_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_3_2_2_3_2_0_3_0_3_0_1_0_2_0_3_3_0_3_0_0_0_0_2_3_1_2_1_1_0_2_2_1_2_0_1_2_2_0_0_2_2_1_2_0_2_0_1_1_1_0_2_1_2_2_2_2_2_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_1_2_2_3_3_1_0_1_1_3_1_1_2_2_3_3_0_0_3_0_1_1_0_3_1_0_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_2_3_2_0_1_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_0_2_1_2_1_1_0_1_3_1_2_2_0_1_1_0_2_1_3_1_2_0_3_2_3_0_0_3_3_1_3_1_0_1_1_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_2_0_1_3_2_0_2_1_1_2_0_3_0_2_3_2_0_1_2_0_3_1_0_1_3_3_0_2_1_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_2_2_1_2_0_0_0_3_2_2_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_1_2_2_0_2_3_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
#test_result_str_1="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_2_1_0_0_1_1_1_0_0_3_1_2_3_1_3_1_0_0_3_3_0_3_1_0_3_0_0_0_0_1_2_3_3_0_3_2_0_2_3_1_0_2_1_0_1_1_2_1_0_0_3_1_2_2_0_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_2_0_3_3_2_2_3_2_0_3_0_3_0_1_0_2_0_3_3_0_3_0_0_0_0_2_3_1_2_1_1_0_2_2_1_2_0_1_2_2_0_0_2_2_1_2_0_2_0_1_1_1_0_2_1_2_2_2_2_3_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_1_2_2_3_3_1_0_1_1_3_1_1_2_2_3_3_0_0_3_0_3_1_0_3_1_0_1_3_1_0_2_2_3_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_2_3_2_0_1_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_1_2_1_2_1_1_0_1_3_1_2_2_0_1_1_0_2_1_2_1_2_0_3_2_3_0_0_3_3_1_3_1_0_1_1_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_0_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_2_0_1_3_2_0_2_1_1_2_0_3_0_2_0_2_0_1_2_0_3_1_0_1_3_3_0_1_1_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_0_2_1_2_0_0_0_3_2_2_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_1_2_2_0_2_3_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
test_result_str_2="2_0_2_2_2_2_2_1_3_1_0_1_2_0_2_3_2_2_0_2_0_0_0_1_1_1_1_0_3_1_2_3_3_0_1_0_0_3_3_0_3_2_0_3_2_0_0_0_1_2_2_3_0_3_2_0_2_3_1_0_2_2_0_1_3_2_0_0_0_3_1_0_2_2_2_0_0_2_1_2_2_0_1_1_3_1_3_0_2_0_0_3_2_0_2_2_2_1_0_2_1_1_0_3_1_3_1_0_3_2_0_2_1_2_0_2_3_3_0_1_0_3_0_3_1_0_0_3_3_2_2_3_2_0_3_0_3_3_3_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_0_0_1_1_1_0_1_1_2_2_2_2_2_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_3_2_0_2_2_3_3_1_0_1_3_3_1_1_2_1_3_3_0_0_3_2_3_1_0_3_1_0_1_3_1_0_2_2_3_0_3_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_2_2_2_0_0_1_3_3_1_3_3_1_0_3_2_3_1_0_1_3_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_1_2_1_2_1_1_0_1_3_1_2_2_2_1_1_3_3_1_2_3_2_1_3_2_3_0_0_3_3_1_3_1_0_1_0_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_1_0_1_1_1_3_3_1_0_2_3_1_2_1_1_1_2_1_3_3_0_1_2_3_2_1_0_1_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_0_0_0_1_2_0_3_1_0_1_3_3_3_1_1_1_1_0_0_2_0_2_2_2_2_2_0_2_2_2_0_2_0_1_3_2_1_2_0_0_0_3_2_2_0_3_3_1_1_3_3_1_1_1_0_3_1_3_3_1_2_3_1_2_0_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_0_1_0_0_2_2_0_0_2_2_1_2"
test_result_str_3="1_0_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_2_3_0_0_1_1_1_0_0_3_1_2_3_1_0_1_1_0_3_3_0_0_3_0_3_0_0_0_0_1_2_3_3_0_3_2_0_2_3_1_0_1_2_0_1_1_2_0_0_0_2_1_2_2_3_2_2_0_2_1_2_2_0_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_3_1_1_0_3_1_3_1_0_3_2_0_1_1_2_0_2_3_3_0_1_0_3_0_3_1_3_0_3_1_2_2_3_2_0_3_0_3_1_1_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_0_0_2_2_1_2_0_2_0_1_1_1_0_2_1_2_1_2_2_2_0_3_2_3_2_2_1_3_0_2_1_0_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_1_3_3_0_0_3_0_3_1_0_3_1_0_1_3_1_0_2_2_1_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_0_1_3_3_1_2_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_0_2_0_3_2_2_0_1_3_3_1_2_1_2_1_3_1_1_0_1_3_1_2_2_0_1_1_0_1_1_2_3_2_0_3_2_3_0_0_3_3_1_3_1_0_1_1_2_1_1_0_3_1_0_0_0_2_1_3_2_0_1_0_0_1_1_1_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_1_0_3_0_2_0_1_3_2_0_2_1_1_1_0_3_0_2_3_2_0_1_2_0_2_1_0_1_3_1_2_1_1_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_0_2_1_2_0_0_0_3_2_0_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_2_2_2_0_2_0_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
test_result_str_4="2_0_2_2_2_2_2_1_3_1_0_1_2_0_2_3_2_2_0_2_0_0_0_1_1_1_2_0_3_1_2_3_1_0_1_2_0_3_3_0_3_0_0_3_2_0_0_0_1_2_2_2_0_3_2_0_2_3_1_0_2_2_0_1_3_2_2_0_0_3_1_2_2_2_2_2_0_2_1_2_2_0_1_1_3_1_3_0_2_0_0_3_2_0_2_2_2_1_0_2_1_1_0_3_1_3_1_0_3_2_0_2_1_2_0_1_3_3_0_1_0_3_0_3_1_1_0_1_3_2_1_3_2_0_3_0_3_1_1_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_1_2_0_2_0_2_2_1_2_0_0_0_1_1_1_0_1_1_2_2_2_2_2_0_3_2_3_2_2_1_3_0_2_1_3_0_2_2_3_0_2_0_2_2_3_3_1_0_1_3_3_1_1_2_1_3_3_0_0_3_2_3_1_0_3_1_0_1_3_1_0_2_2_1_0_2_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_2_0_3_3_1_1_1_1_2_3_0_2_2_2_2_0_1_1_3_3_1_2_3_1_0_3_2_3_1_0_1_3_1_0_0_2_2_0_1_0_3_2_2_0_1_3_3_1_2_1_2_1_2_1_1_0_1_3_1_2_2_1_1_1_0_3_1_2_3_2_2_3_2_3_0_0_3_3_1_3_1_0_1_0_2_1_0_0_3_1_0_0_0_2_1_3_2_0_1_2_0_1_1_0_3_3_1_0_3_3_1_2_1_1_1_2_1_3_3_0_1_2_3_2_1_0_1_0_1_0_1_3_2_0_2_1_1_2_0_3_0_2_1_2_0_1_2_0_3_1_0_1_3_1_2_1_1_1_1_0_0_2_0_2_2_2_2_2_0_0_2_2_0_2_0_1_3_2_1_2_0_0_0_3_2_2_0_3_2_1_1_3_3_1_2_1_0_0_1_3_1_1_2_3_1_2_0_0_2_2_2_2_1_0_1_1_2_1_3_3_2_2_1_0_3_0_3_1_2_1_1_3_1_1_0_0_2_1_0_0_2_2_1_2"
#deberta-v-xlarge
test_result_str_5="1_0_2_2_2_2_2_1_1_1_2_1_2_0_2_3_2_2_0_2_3_0_0_1_1_1_0_0_3_1_2_3_1_0_1_1_0_3_3_0_3_3_0_3_0_0_0_0_1_2_3_3_0_3_2_0_2_3_1_0_2_2_0_1_1_2_3_0_0_3_1_2_2_2_2_2_0_2_1_2_2_3_0_1_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_2_1_1_0_3_1_3_1_0_3_2_0_2_1_2_0_2_3_3_0_1_0_0_0_3_1_0_0_3_1_2_2_3_2_0_3_0_3_1_1_0_3_0_3_3_0_3_0_0_0_0_2_3_1_2_0_1_0_2_2_1_2_0_3_2_0_0_0_2_2_3_2_0_0_0_1_1_1_0_2_1_2_1_2_2_2_0_3_2_3_2_2_1_1_0_2_1_2_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_1_3_3_0_0_3_0_1_1_0_3_1_0_1_3_1_0_2_1_1_0_0_2_3_0_3_3_1_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_1_1_2_3_0_2_3_3_2_0_1_1_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_1_1_0_3_2_2_0_1_3_3_3_2_0_2_1_3_1_1_0_1_3_1_2_2_3_1_1_0_1_1_2_3_2_0_3_2_3_0_0_3_3_1_3_1_0_1_2_2_1_0_0_3_1_0_0_0_2_1_3_2_0_1_1_0_1_1_1_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_3_0_3_0_2_0_1_3_2_0_2_1_1_1_0_3_0_2_0_2_0_1_2_0_3_1_0_1_3_1_2_1_1_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_3_2_3_2_0_0_0_0_2_1_0_3_3_1_1_3_3_1_0_1_0_0_1_3_1_1_2_3_1_2_2_0_2_0_2_2_1_0_1_1_2_1_3_3_2_2_1_1_3_0_3_1_2_2_1_3_1_1_0_0_2_2_0_0_2_2_1_2"
#deberta-v2-xlarge
test_result_str_6="1_1_2_2_2_2_2_1_3_1_2_1_2_0_2_3_2_2_0_2_0_0_0_2_1_1_0_0_3_1_2_3_3_0_1_1_0_3_3_0_3_3_0_3_0_0_0_0_1_2_2_3_0_3_2_0_2_3_1_0_2_2_0_1_3_2_1_0_0_3_1_2_2_0_2_1_0_2_1_2_2_0_0_3_3_1_3_3_2_0_0_3_2_0_2_2_2_1_0_2_1_1_0_3_1_3_1_0_3_2_0_3_1_2_0_2_3_3_0_1_0_3_0_3_1_0_0_3_3_2_1_3_2_0_3_0_3_1_1_0_3_0_1_3_0_3_0_0_0_0_2_3_1_2_0_1_0_1_2_1_2_0_0_2_0_2_0_2_2_1_2_0_0_0_1_2_1_0_2_1_2_2_2_2_2_0_3_2_3_2_2_1_2_0_2_1_0_0_2_2_3_3_2_0_2_2_3_3_1_0_1_1_3_1_1_2_1_3_3_0_0_3_2_3_1_0_3_1_0_1_2_1_0_2_3_3_1_2_2_3_0_3_3_3_0_0_0_2_3_3_3_1_2_0_1_3_3_0_3_3_1_1_2_2_2_3_3_2_3_3_2_0_1_3_3_3_1_3_3_1_0_3_2_3_1_0_1_1_1_0_0_2_2_1_2_0_3_2_2_0_1_3_3_0_2_0_2_1_2_1_1_0_1_2_1_2_2_2_1_1_0_1_1_2_3_2_0_3_2_3_0_0_3_1_1_3_1_0_1_2_2_1_1_0_3_1_0_0_0_2_1_3_2_0_0_3_0_1_1_1_3_3_1_0_2_3_1_2_1_1_1_2_1_0_3_0_1_2_3_2_3_0_3_0_1_0_1_3_2_0_2_1_0_2_0_3_0_2_0_2_0_1_2_0_3_1_0_1_3_1_3_2_0_1_1_0_0_1_0_2_2_2_2_2_0_0_2_2_0_2_0_1_1_2_0_2_0_0_0_0_2_1_0_3_3_1_1_3_3_1_0_1_0_3_1_3_1_1_2_3_1_0_2_0_2_3_2_2_1_0_1_0_1_1_3_3_2_2_1_3_3_0_3_1_2_0_1_3_3_1_0_0_2_2_0_0_2_2_1_2"

id2label={"0":"A", "1":"B", "2":"C", "3":"D", "4":"E"}
test_predictions_1=[id2label[x] for x in test_result_str_1.split("_")]
test_predictions_2=[id2label[x] for x in test_result_str_2.split("_")]
test_predictions_3=[id2label[x] for x in test_result_str_3.split("_")]
test_predictions_4=[id2label[x] for x in test_result_str_4.split("_")]
test_predictions_5=[id2label[x] for x in test_result_str_5.split("_")]
test_predictions_6=[id2label[x] for x in test_result_str_5.split("_")]

S=0
L=500
test_predictions_ensemble = []
for p1,p2,p3,p4,p5,p6 in zip(test_predictions_1[S:L],test_predictions_2[S:L],
                             test_predictions_3[S:L],test_predictions_4[S:L],
                             test_predictions_5[S:L],test_predictions_6[S:L]):
    test_predictions_ensemble.append([p1,p2,p4,p3,p3])

acc=[]
error_11=[]
ensemble_ans_11=[]
for kk, (pr,la) in enumerate(zip(test_predictions_ensemble,test_label[S:L])):
    #if la in pr:
    if la==max(pr,key=pr.count):
        acc.append(1)
    else:
        acc.append(0)
        error_11.append([kk,la,pr])
    ensemble_ans_11.append(max(pr,key=pr.count))

sum(acc)/len(acc)
# Out:
# 0.932

# %%
acc_22=[]
test_predictions_ensemble_22=[]
for p1,p2 in zip(ensemble_ans,ensemble_ans_11):
    test_predictions_ensemble_22.append([p1,p2])

    
acc=[]
error=[]
ensemble_ans=[]
for kk, (pr,la) in enumerate(zip(test_predictions_ensemble,test_label[S:L])):
    #if la in pr:
    if la==max(pr,key=pr.count):
        acc.append(1)
    else:
        acc.append(0)
        error.append([kk,la,pr])
    ensemble_ans.append(max(pr,key=pr.count))

sum(acc)/len(acc)
# Out:
# 0.934

# %%
test_result_str_1=""
test_result_str_2=""
test_result_str_3=""
test_result_str_4=""

test_result_str_5=""
#deberta-v2-xlarge
test_result_str_6=""
