# %%
'''
A (hopefully) Simple API for serving explanation score requests.

input_string = (
    f"{question} answer: {gold_label}. "
    + f" explanation: {abstr_expl}."
)

here are some example input strings:

If you feel like everything is spinning while climbing you are experiencing what? answer: vertigo. explanation: Vertigo is often experienced while climbing or at heights.
Where do you get clothes in a shopping bag? answer: retail store. explanation: For any large item where convenience is beneficial, one might go to a retail store, either a regular one or a big-box store like walmart.
Where should a cat be in a house? answer: floor. explanation: A cat should be on the floor, not on a rug.
'''
import pdb
import argparse
import torch
import transformers
import os
import tqdm
import numpy as np

_model, _tokenizer = None, None

model2url = {
    'large': 'https://storage.googleapis.com/ai2-mosaic-public/projects/few-shot-explanations/pretrained_models/commonsense_qa/valloss%3D0.28665~model%3Dt5-large~lr%3D0.0001~seed%3D1~labelagg%3D0_just_weights.pt',
    '3b': 'https://storage.googleapis.com/ai2-mosaic-public/projects/few-shot-explanations/pretrained_models/commonsense_qa/valloss%3D0.28925~model%3Dt5-3b~lr%3D0.0001~seed%3D1~labelagg%3D0_just_weights.pt',
    '11b': 'https://storage.googleapis.com/ai2-mosaic-public/projects/few-shot-explanations/pretrained_models/commonsense_qa/cose_deepspeed_valloss%3D0.00000~model%3Dt5-11b~lr%3D0.00001~seed%3D1~labelagg%3D0.pt',
}

def get_model(model_type, device=None):
    global _model, model2url
    if model_type not in {'11b', '3b', 'large'}:
        raise NotImplementedError('{} is not a valid model please use "3b" or "large"'.format(model_type))

    if _model is None:
        hf_model_name = 't5-' + model_type
        print('Loading model: this will run only once.')

        if model_type == 'large':
            model_path = 'snli_models/t5-large.pt'
        elif model_type == '3b':
            model_path = 'snli_models/valloss=0.24209~model=t5-3b~lr=0.0001~seed=1~labelagg=0_just_weights.pt'
        elif model_type == '11b':
            model_path = 'snli_models/cose_deepspeed_valloss=0.00000~model=t5-11b~lr=0.00001~seed=1~labelagg=0.pt'

        if not os.path.exists(model_path):
            print('Please download weights for {} model and put in current directory.'.format(model_path))
            print('for example, wget {}'.format(model2url[model_type]))
            quit()

        state = torch.load(model_path)
        if 'model_state_dict' in state:
            state = state['model_state_dict']

        _model = transformers.AutoModelForSeq2SeqLM.from_pretrained(hf_model_name)
        if model_type == '11b': # need to resize due to deepspeed, these entires are not accessed.
            _model.resize_token_embeddings(len(transformers.AutoTokenizer.from_pretrained(hf_model_name)))
        _model.load_state_dict(state)
        _model.eval()
        if device is not None:
            _model = _model.to(device)

    return _model


def get_tokenizer(model_type):
    global _tokenizer
    if model_type not in {'3b', 'large', '11b'}:
        raise NotImplementedError('{} is not a valid model please use "3b" or "large" or "11b"'.format(model_type))

    if _tokenizer is None:
        hf_model_name = 't5-' + model_type
        _tokenizer = transformers.T5TokenizerFast.from_pretrained(hf_model_name)

    return _tokenizer


class T5Dataset(torch.utils.data.Dataset):
    def __init__(self, data, tokenizer):
        self.data = data
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        res = self.tokenizer(self.data[idx]['input'], truncation=True)
        res['labels'] = self.tokenizer(self.data[idx]['label']).input_ids
        return res

    def __len__(self):
        return len(self.data)


def get_scores(inputs, model_type, device=None, batch_size=32, verbose=False):
    '''
    Inputs:
      - a list of explanations to score, e.g.,:
        premise: A man getting a tattoo on his back. hypothesis: A woman is getting a tattoo. answer: contradiction. explanation: Because the tattoo artist is a man, the person getting the tattoo is not a woman.
      - model type, either "3b" or "large" or "11b"
      - device: which torch device to load model on, e.g., "cuda:3"
    Outputs:
      - P(good explanation); higher is better
    '''
    assert model_type in {'large', '3b', '11b'}

    if isinstance(inputs, str):
        inputs = [inputs]

    model = get_model(model_type, device=device)
    tokenizer = get_tokenizer(model_type)

    score_itr = T5Dataset([{'input': inp, 'label': 'x'} for inp in inputs], tokenizer) # dummy labels for inference
    data_collator = transformers.DataCollatorForSeq2Seq(
        tokenizer,
        model=model,
        label_pad_token_id=-100,
#         return_tensors='pt'
    )
    score_itr = torch.utils.data.DataLoader(score_itr, shuffle=False, collate_fn=data_collator, batch_size=batch_size)
    score_itr = score_itr if not verbose else tqdm.tqdm(score_itr, total=len(score_itr))

    good_idx, bad_idx = tokenizer('good').input_ids[0], tokenizer('bad').input_ids[0]
    scores = []
    
    with torch.no_grad():
        for batch in score_itr:
            if device is not None:
                input_ids, attention_mask, targets = batch['input_ids'].to(device), batch['attention_mask'].to(device), batch['labels'].to(device)
            model_output = model(input_ids=input_ids, attention_mask=attention_mask, labels=targets)
            logits_pos = model_output['logits'][:, 0, good_idx].cpu().numpy()
            logits_neg = model_output['logits'][:, 0, bad_idx].cpu().numpy()
            exp_logit_pos, exp_logit_neg = np.exp(logits_pos), np.exp(logits_neg)
            score = list([float(x) for x in exp_logit_pos / (exp_logit_pos + exp_logit_neg)])
            #pdb.set_trace()
            scores.extend(score)
    return scores


# def parse_args():
#     '''
#     Optional args for main function, mostly just to test.
#     '''
#     parser = argparse.ArgumentParser()
#     parser.add_argument(
#         'model_type',
#         default='large',
#         choices={'large', '3b', '11b'})
#     parser.add_argument(
#         '--batch_size',
#         default=32,
#         type=int)

#     args = parser.parse_args(['--batch_size', '1'])
#     return args

# %%
# args = parse_args()
# parser = argparse.ArgumentParser()
# parser.add_argument(
#     'model_type',
#     default='large',
#     choices={'large', '3b', '11b'})
# parser.add_argument(
#     '--batch_size',
#     default=32,
#     type=int)

# args = parser.parse_args(["--model_type", "3b"])
# args.device = 'cpu'#'cuda' if torch.cuda.is_available() else 'cpu'
np.random.seed(1)
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# scores = get_scores(
#     ['If you feel like everything is spinning while climbing you are experiencing what? answer: vertigo. explanation: Vertigo is often experienced while climbing or at heights.',
#      'Where do you get clothes in a shopping bag? answer: retail store. explanation: For any large item where convenience is beneficial, one might go to a retail store, either a regular one or a big-box store like walmart.',
#      'Where should a cat be in a house? answer: floor. explanation: A cat should be on the floor, not on a rug.'],
#     'large',
#     device='cuda:0',
#     batch_size=1,
#     verbose=False)
# print(scores)

# %%
import json
from tqdm import tqdm
# with open("../../scripts/results/dev_rationale_pair.json") as f:
#     rationale_pair_dev_data = json.load(f)
import json
file_path = "../../scripts/results/24shots_esnli_t5_3b_chatgpt_rationales_generator_test_rationale_pair.json"
with open(file_path, 'r') as f:
    rationale_pair_dev_data = json.load(f)

# %%
rationale_pair_dev_data[0].keys(), len(rationale_pair_dev_data)
# Out:
# (dict_keys(['premise', 'hypothesis', 'label', 'explanation_1', 'explanation_2', 'explanation_3', 'our_explanation', 'common_expl_list', 'input_ids', 'attention_mask', 'labels', 'decoder_attention_mask', 'question_encoding', 'generated_explanation']),
#  640)

# %%
# answer = wt5_esnli_label_mapping[item["label"]]
# input_string = f'explain why the relation is {answer} between hypothesis: {hypothesis.lower()} and premise: {premise.lower()}'  
# #input_string = f"explain {datasource} question: {question} answer: {answer}" + f" {explanation_sep} <extra_id_0>"
# answer_string = f"<extra_id_0> {item['our_explanation']} <extra_id_1>"
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
for kk, item in enumerate(rationale_pair_dev_data):
    answer = wt5_esnli_label_mapping[item["label"]]
    hypothesis = item['hypothesis']
    premise = item['premise']
    input_string = f'explain why the relation is {answer} between hypothesis: {hypothesis.lower()} and premise: {premise.lower()}' 
    print("#######")
    print(f"sample {kk}: {input_string}")
    print("**")
    print(f"generated explanation: {item['generated_explanation']}")
    print("**")
    print(f"common_expl_list: {item['common_expl_list']}")
    print("**")
    print(f"explanation_1: {item['explanation_1']}")
    print("#######")
# Out:
# #######
# sample 0: explain why the relation is entailment between hypothesis: there is a black dog. and premise: a black dog running really fast with a blond woman running after him in the background.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that there is a black dog, which implies that there is a black dog running really fast with a blond woman running after him. The premise describes a black dog running really fast with a blond woman running after him, which implies that there is a black dog running really fast with a blond woman running after him. The premise does not confirm or deny the hypothesis that there is a black dog, but it does provide additional information about the hypothesis that the hypothesis states that the hypothesis states that the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ["If there's a black dog running really fast, then, yes, there is a black dog.", 'If the dog is black, then it is black.']
# **
# explanation_1: The black is dog is in the act of running
# #######
# #######
# sample 1: explain why the relation is contradiction between hypothesis: people at home and premise: a crowd of people in a subway
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that there are people at home, which implies that they are at home and in their own environment. The premise, on the other hand, states that there are people in a crowd of people in a subway, which implies that they are in a public place. These two statements cannot both be true at the same time, and therefore, they cannot both be true at the same time.<extra_id_1> </s>
# **
# common_expl_list: ['you cannot be at home in a subway. Can you?']
# **
# explanation_1: People can not be in a subway and at home at the same time.
# #######
# #######
# sample 2: explain why the relation is neutral between hypothesis: a busy pizza restaurant sees a lot of people pass on its active street corner in new york city and premise: a busy pizza shop is located on a heavily trafficked street corner.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a busy pizza restaurant sees a lot of people pass on its active street corner in new york city" and the premise "a busy pizza shop is located on a heavily trafficked street corner" because the premise does not provide any information about the location of the restaurant, only that it is located on a street corner. The hypothesis states that the restaurant is located on a street corner, but does not provide any information about the number of people passing by the restaurant or the number of people passing by the premise "a busy pizza shop".<extra_id_1> </s>
# **
# common_expl_list: ["Even though that busy pizza shop may sometimes see a lot of people passing by its active street corner, it does not necessarily mean that it's located in New York City."]
# **
# explanation_1: The heavily trafficked street corner could see a lot of vehicles pass and not necessarily a lot of people. The street corner the pizza shop is on is not necessarily located in New York City.
# #######
# #######
# sample 3: explain why the relation is contradiction between hypothesis: the two boys  were swimming and premise: a shirtless boy and a boy in green and white are playing on a concrete surface by a small stage.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the two boys were swimming, which implies that they were in water, and the premise states that the two boys are playing on a concrete surface by a small stage, which implies that they are on a surface other than water. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['The concrete surface cannot be the one in the pool since they are playing on concrete by a stage.']
# **
# explanation_1: There is either one boy or two.
# #######
# #######
# sample 4: explain why the relation is neutral between hypothesis: two dogs vie for an owners attention. and premise: a terrier dog and a mixed breed dog playing.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that two dogs vie for an owners attention, which implies that they are competing for the owners attention. The premise, on the other hand, states that two dogs are playing, which implies that they are playing together and not competing for an owners attention. These two statements cannot both be true at the same time, which means that the hypothesis is neutral.<extra_id_1> </s>
# **
# common_expl_list: ['Dogs playing does not necessary indicate vying for attention, as dogs can play anytime, anywhere, not necessarily to get attention.', "Dogs can play with each other without the owner's attention."]
# **
# explanation_1: Playing dogs does not imply they are trying to vie for an owners attention.
# #######
# #######
# sample 5: explain why the relation is entailment between hypothesis: a group of men spend time together and premise: several men dressed in cowboy boots and hats are hanging around, and one man is getting his shoes shined.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a group of men spend time together" and the premise "several men dressed in cowboy boots are hanging around, and one man is getting his shoes shined" because the premise provides specific details about the men's activities and clothing. The hypothesis states that the men are spending time together, which implies that they are socializing and having fun. The premise provides additional details about the men's activities and clothing, which confirms the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ['If men are hanging around together, then they spend time together. Men dressed in cowboy boots and hats are a subset of all the men on the street corner.', 'A group of men hanging around together is spending time together. Men wearing cowboy boots and hats are a type of men. A cowboy is a kind of man.']
# **
# explanation_1: group of men is another way to say several men.
# #######
# #######
# sample 6: explain why the relation is contradiction between hypothesis: an empty karate hall. and premise: during karate practice, one student kicks through a wooden plank while another individual holds it at face-height.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that there is an empty karate hall, which implies that there is no karate practice taking place. The premise, on the other hand, states that a student kicks through a wooden plank while another individual holds a wooden plank while another individual holds face-to-face. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['It is unlikely that a hall would be empty during karate practice, which involves using many wooden boards.']
# **
# explanation_1: An empty karate hall can not have even one student in it.
# #######
# #######
# sample 7: explain why the relation is contradiction between hypothesis: the man is sitting on the grass. and premise: a woman is standing on a road.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the man is sitting on the grass, which implies that he is in motion, and the premise states that a woman is standing on a road, which implies that she is stationary and not moving. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['If someone is sitting on grass, they are almost certainly not on a road.']
# **
# explanation_1: woman and man are different genders.
# #######
# #######
# sample 8: explain why the relation is neutral between hypothesis: a band is playing before a large audience and premise: performers making music on a guitar and keyboard.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a band is playing before a large audience" and the premise "performers making music on a guitar and keyboard" because the premise does not provide any information about the band's size or the audience's size. The hypothesis simply states that the band is playing before a large audience, which implies that there is a large audience, and the premise does not provide any information about the band's size or the audience's size.<extra_id_1> </s>
# **
# common_expl_list: ['Making music does not necessarily mean playing for a large audience. If a band were playing for a friend, that would also count as making music.']
# **
# explanation_1: The performers aren't necessarily part of a band and they aren't necessarily playing the same piece.
# #######
# #######
# sample 9: explain why the relation is contradiction between hypothesis: the woman is driving a car. and premise: a woman is reading a book on the subway.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the woman is driving a car, which implies that she is engaged in a motor activity, such as steering or accelerating, and the premise states that the woman is reading a book on the subway, which implies that she is not engaged in motor activities, such as steering or accelerating. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['If the woman is reading a book on the subway, then she is not driving a car.', "If the woman is on a subway, it isn't possible to be driving a car simultaneously."]
# **
# explanation_1: Car and subway are different.
# #######
# #######
# sample 10: explain why the relation is neutral between hypothesis: the girl is captain of the soccer team. and premise: a young girl wearing a pink top and shin guards kicking a ball in the grass.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the girl is captain of the soccer team, which implies that she is the leader of the team and is responsible for the team's performance. The premise describes a young girl wearing a pink top wearing shin guards kicking a ball in the grass, which is a very general description of a soccer player. The premise does not provide any information about the girl's role in the team or her position on the team.<extra_id_1> </s>
# **
# common_expl_list: ['The girl could certainly be captain of the team, but from this perspective she could also be playing with her brother.', 'A girl wearing a pink top and shin guards kicking a ball in the grass does not necessarily mean that she is captain of the soccer team.']
# **
# explanation_1: There is nothing to indicate the girl is the captain of the soccer team.
# #######
# #######
# sample 11: explain why the relation is neutral between hypothesis: the young girl playing in playground is lonely. and premise: a little girl in a blue shirt and jeans, sitting on a swing smiling.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the young girl playing in playground is lonely" and the premise "a little girl in a blue and white dress sitting on a swing smiling" because the premise does not provide any information about the girl's feelings. The hypothesis states that the girl is playing alone, which implies that she is feeling lonely, while the premise describes a little girl sitting on a swing smiling, which implies that she is happy. The premise does not provide any information about the girl's feelings, which means that the hypothesis "the young girl's loneliness".<extra_id_1> </s>
# **
# common_expl_list: ['Even if someone is playing on a swing all by themselves, they may not necessarily be lonely.', 'The girl is not necessarily lonely, she could be playing with other people.']
# **
# explanation_1: A little girl is not necessarily a young girl or playing lonely.
# #######
# #######
# sample 12: explain why the relation is contradiction between hypothesis: a guy is spraying paint on a brick wall. and premise: a man is riding in a boat on the water.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that a guy is spraying paint on a brick wall, which implies that he is doing something physical, such as painting, and the premise states that a man is riding in a boat on the water, which implies that he is doing something physical, such as riding in a boat. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['It does not make sense to spray paint on a brick wall while at a boat. This especially because the brick wall is not even in the boat.', 'If a man is riding in a boat, he is not spraying paint on a brick wall.', 'It could make sense to spray paint on brick walls, but it does not make sense that one would be doing that in water.']
# **
# explanation_1: If a man is riding in a boat on the water, he is probably too far away from a brick wall to be spraying paint on it.
# #######
# #######
# sample 13: explain why the relation is neutral between hypothesis: the woman is eating from a bowl. and premise: an asian woman eating with a spoon.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the woman is eating from a bowl, while the premise states that the woman is eating with a spoon. The two statements cannot both be true at the same time, and neither can they both be true at the same time.<extra_id_1> </s>
# **
# common_expl_list: ['Eating with a spoon does not necessarily mean eating from a bowl.', 'Eating with a spoon could occur before or after eating from a bowl, and besides, eating with a spoon does not necessaily entail eating from a bowl.']
# **
# explanation_1: spoon doesn't imply  bowl
# #######
# #######
# sample 14: explain why the relation is neutral between hypothesis: the employee is actually a bartender. and premise: at maruga's diner, a male employee stands in the background behind a coca-cola machine.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the employee is actually a bartender, while the premise states that the employee is actually a diner employee. The hypothesis states that the employee is actually a bartender, while the premise states that the employee is actually a diner employee. The hypothesis states that the employee is actually a bartender, while the premise states that the employee is actually a diner employee. The hypothesis does not specify whether the employee is a bartender or a diner, therefore, the premise confirms or deny the hypothesis that the employee is actually a bart if the employee is actually a diner or not. The employee is actually a bart a bart a bart a bart a bart a bart a bart a bart a bartender.</s>
# **
# common_expl_list: ['The employee could be a bartender, but he could also be a waiter, or a cook, or a dishwasher, or a busboy, or a host, or a hostess, or a manager, or a cashier, or a customer']
# **
# explanation_1: Just because a male employee stands in the background behind a Coca-Cola machine doesn't imply that he is a bartender.
# #######
# #######
# sample 15: explain why the relation is entailment between hypothesis: the woman is touching the harp. and premise: a woman playing a harp.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that the woman is touching the harp, which implies that she is touching the harp in some way. The premise, on the other hand, states that a woman is playing a harp, which implies that she is playing the harp and touching it, which implies that she is playing the harp. These two statements are mutually exclusive and cannot both be true at the same time.<extra_id_1> </s>
# **
# common_expl_list: ["One has to touch a string in order to play a harp. Although her body doesn't necessarily have to make physical contact with the harp, since the harp has strings"]
# **
# explanation_1: The woman is playing her harp by touching it.
# #######
# #######
# sample 16: explain why the relation is neutral between hypothesis: the violin sounds beatuful. and premise: a young woman is playing the violin.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the violin sounds beatuful" and the premise "a young woman is playing the violin" because the premise does not provide any information about the violin player. The hypothesis states that the violin sounds beatuful, which implies that it is being played by a woman, which implies that she is playing the violin. The premise does not provide any information about the violin player, which would indicate that the violin is being played by a woman.<extra_id_1> </s>
# **
# common_expl_list: ['Someone playing the violin does not necessarily mean that it is being played well, or that any sound is being made from playing the instrument. The violin might be silent.', 'Beauty is subjective; Someone might not think the violin sounds beatiful (because taste varies). How the sound can be falsified would be if it was not making any sound at all.', 'Someone playing the violin indicates that the violin is playing (and therefore making sounds, which might or might not be pleasing).']
# **
# explanation_1: You can not infer it sound beatuful.
# #######
# #######
# sample 17: explain why the relation is entailment between hypothesis: people are standing by a car. and premise: four men standing near a yellow car.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "people are standing by a car" and the premise "four men standing near a yellow car" because the premise confirms the hypothesis that people are standing by a car, which implies that they are in a public place. The premise provides additional information that confirms the hypothesis that people are standing by a car, which is a public place.<extra_id_1> </s>
# **
# common_expl_list: ['People standing near a car are standing by the car.']
# **
# explanation_1: Four men are people and yellow car is a car
# #######
# #######
# sample 18: explain why the relation is neutral between hypothesis: a girl in a pink swimsuit is about to do a swan dive. and premise: a young person wearing a pink one-piece swimsuit and goggles about to complete a leap into a swimming pool.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a girl in a pink swimsuit is about to do a swan dive" and the premise "a young person wearing a pink one-piece swimsuit and goggles about to complete a leap into a swimming pool" because the premise does not provide any information about the person's appearance or clothing, but only describes the person's appearance and clothing, which is neutral.<extra_id_1> </s>
# **
# common_expl_list: ['A girl in a pink swimsuit is not necessarily about to do a swan dive. She could be about to do a backflip, a handstand, or a cartwheel.']
# **
# explanation_1: A young person does not mean it is a girl.Just because a young person is going to leap into a swimming pool does not mean it is going to do a swan dive.
# #######
# #######
# sample 19: explain why the relation is entailment between hypothesis: the woman is moving her mouth. and premise: a young woman in a white shirt and glasses talks to a group of people.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "the woman is moving her mouth" and the premise "a young woman in a white shirt and glasses talks to a group of people" because the premise provides additional information that confirms the hypothesis. The hypothesis states that the woman is moving her mouth, which implies that she is speaking, and the premise describes a scene in which the woman is talking to a group of people. The premise provides additional information that confirms the hypothesis, which is that the woman is talking. The hypothesis "moving her mouth" because the hypothesis "the woman is moving her mouth"<extra_id_1> </s>
# **
# common_expl_list: ["Moving one's mouth mostly (but not only) happens when talking and communicating and is, therefore, related to talking and communicating."]
# **
# explanation_1: When one talks, it is implied that they are moving their mouth.
# #######
# #######
# sample 20: explain why the relation is neutral between hypothesis: three women with different colored shirts are sitting in an office that also has a bookshelf in it. and premise: three people, one with a black shirt, one with a navy blue jacket, and one with a red t-shirt, working in an office with a large messy bookshelf.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "three women with different colored shirts are sitting in an office that also has a bookshelf" and the premise "three people, one with a black shirt, one with a navy blue jacket, and one with a red t-shirt, working in an office with a large messy bookshelf" because the premise does not provide any information about the people's clothing or clothing colors, but only their location in the office and the bookshelf.<extra_id_1> </s>
# **
# common_expl_list: ['Three people does not necessarily mean women, and three people']
# **
# explanation_1: Not all people are women. The fact that  three people, one with a black shirt, one with a navy blue jacket, and one with a red t-shirt, working in an office with a large messy bookshelf does not imply that they are sitting in an office that also has a bookshelf in it.
# #######
# #######
# sample 21: explain why the relation is entailment between hypothesis: the woman has long hair. and premise: a woman with long dark hair standing in front of a window.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that the woman has long hair, while the premise describes a woman with long dark hair standing in front of a window. The premise confirms the hypothesis that the woman has long hair by describing a woman with long dark hair standing in front of a window.<extra_id_1> </s>
# **
# common_expl_list: ['Long dark hair is a good indication of having long hair.']
# **
# explanation_1: A woman with long hair therefore has long hair.
# #######
# #######
# sample 22: explain why the relation is neutral between hypothesis: a chemistry teacher measures carefully to show the class how to do it. and premise: a man uses a dropper to conduct an experiment.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a chemistry teacher measures carefully to show the class how to do it" and the premise "a man uses a dropper to conduct an experiment" because the premise does not provide any information about the teacher's actions. The hypothesis states that the teacher measures carefully, which implies that he is a teacher, and the premise does not provide any information about the man's actions, which would indicate that he is conducting an experiment. The premise does not provide any information about the teacher's actions.<extra_id_1> </s>
# **
# common_expl_list: ["The dropper is used to conduct an experiment, but it doesn't necessarily mean the man is a chemistry teacher."]
# **
# explanation_1: Just because a man has a dropper to conduct an experiment does not mean he will measure carefully like a Chemistry teacher who shows his class to do it correctly.
# #######
# #######
# sample 23: explain why the relation is entailment between hypothesis: the man is asian and premise: an asian man is going over some paperwork that is sitting on a table with a pink carnation to two other men and a woman all of which are wearing glasses.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that the man is asian, while the premise states that the man is going over some paperwork that is sitting on a table with a pink carnation to two other men and a woman all of which are wearing glasses. The two statements are related because the hypothesis states that the man is asian, while the premise states that the man is going over paperwork that is sitting on a table with a pink carnation to two other men and a woman all of which is asian.<extra_id_1> </s>
# **
# common_expl_list: ['An Asian man is a person of Asian ethnicity.']
# **
# explanation_1: What the man is doing, who the man is with, what they are wearing and the items that adorn a room all point to the main character; an Asian male.
# #######
# #######
# sample 24: explain why the relation is neutral between hypothesis: runner number 236 wins the marathon. and premise: runner number 236 races ahead while two other runners fall behind.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "runner number 236 wins the marathon" and the premise "runner number 236 races ahead while two other runners fall behind" because the premise does not provide any information about the runner's performance in the marathon. The hypothesis states that runner number 236 races ahead while two other runners fall behind, but it does not provide any information about the runner's performance in the marathon.<extra_id_1> </s>
# **
# common_expl_list: ["A race is over when the race is over, so it's possible that while runner number 236 appears to be winning, he could also be losing. As there are at least two runners on the screen, it is possible for numbers 237, 238,", 'The runner could be in the lead, but it is also possible that the runner is not in the lead.']
# **
# explanation_1: Racing ahead of two other runners doesn't imply runner 236 wins the marathon.
# #######
# #######
# sample 25: explain why the relation is contradiction between hypothesis: puppy lying on the floor asleep and premise: puppy running on the floor
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the puppy is sleeping on the floor, which implies that it is resting, which implies that it is sleeping. The premise, on the other hand, states that the puppy is running, which implies that it is active and not resting. These two statements cannot both be true at the same time, which is why the hypothesis and the premise cannot both be true at the same time.<extra_id_1> </s>
# **
# common_expl_list: ['A puppy cannot be running and lying down at the same time.', 'sleeping on the floor is different from running on the floor. The position of puppy is different.', "A puppy can't run on the floor and be asleep simultaneously because these both require movement and sleep requires a lack of movement."]
# **
# explanation_1: Lying is not running.
# #######
# #######
# sample 26: explain why the relation is neutral between hypothesis: a lady reaches in a guys pocket to steal his wallet. and premise: middle-aged female wearing a white sunhat and white jacket, slips her hand inside a man's pants pocket.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a lady reaches in a guy's pocket to steal his wallet. The premise states that a middle-aged female wearing a white sunhat, slips her hand inside a man's pants pocket, but the premise does not specify whether the lady is trying to steal the wallet or not. The premise does not provide any information about the woman's age, gender, or clothing, but it does describe her appearance.<extra_id_1> </s>
# **
# common_expl_list: ["A lady reaching into a guy's pocket does not necessarily mean she is stealing his wallet.", "The female's hand is slipping into the pocket, but that does not mean that she is stealing from the man.", 'There is no way to tell the intent of the lady, since she could also be putting something, other than grabbing a wallet, in the guys pocket.']
# **
# explanation_1: A lady does not have to be a middle-aged female or slipping her hand inside a man's pants pocket is not the same to reach in a guys pocket to steal his wallet.
# #######
# #######
# sample 27: explain why the relation is contradiction between hypothesis: a woman is gathering fruit in a field. and premise: a woman is handing out fruit.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that a woman is gathering fruit in a field, which implies that she is gathering fruit from a tree, which implies that she is handing out fruit. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['A woman handing out fruit is not gathering fruit in a field.']
# **
# explanation_1: The person cannot be handing out fruit and gathering fruit from the field at the same time.
# #######
# #######
# sample 28: explain why the relation is contradiction between hypothesis: a young person is playing soccer and premise: a young person doing a skateboard trick on a cement raling over cement stairs.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that a young person is playing soccer, which implies that the person is engaged in a sport activity. The premise, on the other hand, describes a young person doing a skateboard trick on a cement raling over cement stairs, which is a form of exercise that requires agility and balance. These two statements cannot both be true at the same time, and therefore, they contradict each other.<extra_id_1> </s>
# **
# common_expl_list: ['The person is doing a skateboard trick and not playing soccer.']
# **
# explanation_1: Soccer is played on a field with a ball and cleats while skateboarding requires a smooth surface like cement.
# #######
# #######
# sample 29: explain why the relation is contradiction between hypothesis: the women are going to madison square gardens to do finger painting. and premise: a group of women dance on a wooden floor.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the women are going to madison square gardens to do finger painting, which implies that they are going to a place where they can paint their fingers. The premise, on the other hand, states that a group of women dance on a wooden floor, which implies that they are not going to a place where they can paint their fingers, which is a contradiction. The two statements cannot both be true at the same time, which is why the relation is a contradiction. The premise is a contradiction. The premise cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['Dancing is not the same as finger painting.']
# **
# explanation_1: Women either dance or are finger painting.
# #######
# #######
# sample 30: explain why the relation is contradiction between hypothesis: the firetruck is red. and premise: a yellow firetruck is parked next to a fire with a man on a ladder pouring water on it
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the firetruck is red, while the premise states that the firetruck is yellow. The two statements cannot both be true at the same time, and therefore, they cannot both be true at the same time.<extra_id_1> </s>
# **
# common_expl_list: ['A firetruck cannot possibly be both red and yellow at the same time.']
# **
# explanation_1: the firetruck can either be red or yellow.
# #######
# #######
# sample 31: explain why the relation is entailment between hypothesis: the man is riding on a boat. and premise: a man sits and reads a newspaper on a boat going through the water.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that the man is riding on a boat, which implies that the man is sitting on a boat going through the water. The premise states that the man is sitting on a boat, which implies that the man is reading a newspaper on a boat going through the water. The premise provides additional information that supports the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ["We don't know the contextual situation of the individual, but generally seeing someone traveling on a boat means that they are indeed riding the boat.", 'If the man is sitting on a boat, and the boat is going through the water, then the man is riding on a boat.']
# **
# explanation_1: A man on a boat is riding a boat.
# #######
# #######
# sample 32: explain why the relation is neutral between hypothesis: a man in a white shirt is standing in front of a tire shop. and premise: a man in a hat standing in front of a tire shop.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a man in a white shirt is standing in front of a tire shop" and the premise "a man in a hat standing in front of a tire shop" because the premise does not provide any information about the man's appearance, which would indicate whether he is wearing a shirt or hat. The hypothesis does not provide any information about the man's appearance, which would indicate whether he is wearing a hat or a shirt, which would indicate whether the man is wearing a hat.<extra_id_1> </s>
# **
# common_expl_list: ['A man in a hat does not necessarily wear a white shirt.']
# **
# explanation_1: Does not state that the man is wearing a white shirt.
# #######
# #######
# sample 33: explain why the relation is neutral between hypothesis: a woman likes children and premise: a woman stands with two children near a decorated bull statue.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a woman likes children, while the premise states that a woman stands with two children near a decorated bull statue. The hypothesis states that a woman likes children, but the premise does not specify whether or not the woman likes children. The premise does not provide any information about the woman's personality or her interests, and it does not provide any information about the woman's interests or hobbies. The premise does not provide any information about the woman's age or whether the children.<extra_id_1> </s>
# **
# common_expl_list: ['Just because a woman is standing with two children near a decorated bull statue does not mean she likes children.', "A woman enjoying the company of children does not necessarily mean that she likes children. She just enjoys a moment of a child's company.", "Whether she likes children could be true or false altogether; there isn't enough information to draw any conclusions about whether she specifically likes her children that she is standing with."]
# **
# explanation_1: A woman stands with two children
# #######
# #######
# sample 34: explain why the relation is neutral between hypothesis: two men tell a fish seller he has a great stock of fish. and premise: a fish sellers stock is looked upon by two old men.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "two men tell a fish seller he has a great stock of fish" and the premise "a fish sellers stock is looked upon by two old men" because the hypothesis states that the men tell the seller that he has a great stock of fish, while the premise states that the men look at the fish seller's stock and that the fish seller has a great stock of fish. The two statements cannot both be true at the same time, and neither can they both be true at the same time. The premise "the men" and the premise "the men" and the premise "the men" and the hypothesis "the men"<extra_id_1> </s>
# **
# common_expl_list: ["Just because two men are looking at a fish seller's stock doesn't mean that they are telling him he has a great stock of fish. They could be looking at the fish for any number of reasons.", 'Just because two men look at fish sellers stock does not mean they are telling the fish seller that he has a great stock of fish. The sellers stock might be unimpressive, and the men might be mad at the person for something, rather than']
# **
# explanation_1: The fact that two old men look upon a fish seller's stock, doesn't necessarily mean that they tell something to the fish seller.
# #######
# #######
# sample 35: explain why the relation is neutral between hypothesis: a hispanis woman is a fashion designer. and premise: a hispanic woman is presenting her fabric design.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a hispanis woman is a fashion designer" and the premise "a hispanic woman is presenting her fabric design" because the premise does not provide any information about the woman's profession or experience as a fashion designer. The hypothesis states that the woman is a fashion designer, but the premise does not provide any information about the woman's experience as a fashion designer or her fabric design. The premise does not provide any information about the woman's profession or experience, but the premise does not confirm or deny the hypothesis "a hispanic woman's fashion designer"<extra_id_1> </s>
# **
# common_expl_list: ['The act of presenting a fabric design does not necessarily mean that the person is a fashion designer.']
# **
# explanation_1: Not all Hispanis presenting her fabric design is a fashion designer.
# #######
# #######
# sample 36: explain why the relation is neutral between hypothesis: two men are giving a presentation. and premise: a man speaks into a microphone being held by another man.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "two men are giving a presentation" and the premise "a man speaks into a microphone being held by another man" because the premise does not provide any information about the presentation itself, only that a man speaks into a microphone being held by another man. The hypothesis does not provide any information about the presentation itself, only that a man speaks into a microphone being held by another man. The premise does not provide any information about the presentation itself, only that a man speaks into a microphone being held by another man.<extra_id_1> </s>
# **
# common_expl_list: ['A man speaking into a microphone does not necessarily indicate that he is giving a presentation. He could be giving a speech, or just talking to someone.']
# **
# explanation_1: Two men with a microphone are not necessarily giving a presentation. They could be doing an interview, they could be checking the sound equipment to see if it works.
# #######
# #######
# sample 37: explain why the relation is neutral between hypothesis: a girl is walking across the grass to go home. and premise: a little girl wearing a dress walks across a green lawn on a summer day with a home and trees in the background.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a girl is walking across the grass to go home, while the premise describes a little girl wearing a dress walking across a green lawn on a summer day with a home and trees in the background. The premise does not provide any information that would contradict the hypothesis, and it does not provide any information that would contradict the hypothesis. The hypothesis states that a girl is walking across the grass to go home, while the premise describes a little girl wearing a dress walking across the grass to go home. The premise does not provide any information about the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity of the girl's identity. The premise does not provide any information about the girl's identity. The premise does not confirm or deny the hypothesis.</s>
# **
# common_expl_list: ['The girl could be walking to go to a different location, or she could be walking to go to her home.']
# **
# explanation_1: Just because the girl is walking does not mean that she is walking to go home.  She could be walking to go anywhere.
# #######
# #######
# sample 38: explain why the relation is neutral between hypothesis: a woman sitting with her baby in a group in a bus and premise: a woman sitting with her baby in a group, while other women breastfeed in the background.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a woman sitting with her baby in a group in a bus" and the premise "a woman sitting with her baby in a group while other women breastfeed in the background" because the premise describes a situation that is not a bus, but rather a group of women sitting with their babies in a group. The hypothesis states that the women are sitting with their babies in a group, but the premise does not specify whether the women are breastfeeding or not. The premise does not specify whether the premise confirms or deny the hypothesis, but the premise does not confirm or deny the hypothesis. The premise does not confirm or deny the hypothesis. The premise does not confirm or deny the hypothesis "a woman sitting with their babies in a bus, but the premise does not confirm or deny the woman in a bus.<extra_id_1> </s>
# **
# common_expl_list: ['A woman sitting with her baby in a group does not necessarily mean that they are on a bus.', "Because the only thing going on is a large group of women sitting together, it's not enough information to make a determination of a bus trip."]
# **
# explanation_1: Sitting with her baby does not imply being in a bus.
# #######
# #######
# sample 39: explain why the relation is neutral between hypothesis: the men are members of a rock band. and premise: a man on the left speaks into a microphone, while a man on the right plays an unidentified instrument with a drum set in the background.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the men are members of a rock band, while the premise describes a scene that does not provide any information about the band's identity or affiliation. The premise does not provide any information that would indicate whether the men are members of a rock band or not. The premise does not provide any information that would indicate whether the men are members of a rock band or not. The premise does not provide any information that would indicate whether the men are members of a rock band or not. Therefore, the premise does not confirm or deny the hypothesis that the hypothesis that the men are members of the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that would confirm or deny the hypothesis. Therefore, the hypothesis "the hypothesis" or deny the hypothesis, therefore, the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ['The men could be members of a rock band, but they could also be members of a jazz band, or a band that plays other types of music.']
# **
# explanation_1: Just because a man is speaking into a microphone and another plays an unidentified instrument does not mean they are members of a rock band.
# #######
# #######
# sample 40: explain why the relation is entailment between hypothesis: a little boy is riding outside. and premise: a little boy rides a bike down a hill on a miniature dirt bike.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a little boy is riding outside" and the premise "a little boy rides a bike down a miniature dirt bike on a miniature dirt bike" because the premise confirms the hypothesis. The hypothesis states that a little boy is riding outside, which implies that he is outside, and that he is outside on a dirt bike. The premise describes a little boy riding a bike down a miniature dirt bike on a miniature dirt bike, which confirms the hypothesis. The premise confirms the hypothesis. The hypothesis "a little boy is outside, which implies that the premise confirms the hypothesis "a little boy is outside, which implies that the premise confirms the fact that the hypothesis "a little boy is outside, which implies that the boy is outside, and therefore, the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ['Riding a bike down a hill is an activity that is almost always done outside.']
# **
# explanation_1: The boy rides on a hill on a dirt bike so he is riding outside.
# #######
# #######
# sample 41: explain why the relation is entailment between hypothesis: the man is wet and premise: man in white shirt getting sprayed by water.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "the man is wet" and the premise "man in white shirt getting sprayed by water" because the premise confirms the hypothesis that the man is wet. The hypothesis states that the man is wet, which implies that he is getting sprayed by water. The premise provides additional information that confirms the hypothesis that the man is wet.<extra_id_1> </s>
# **
# common_expl_list: ['If the man is getting sprayed by water, then he is wet.', 'If the man is getting sprayed by water, then he is wet. Although two distinct events, an event of wetness is dependent on an event of getting spray by water.']
# **
# explanation_1: if he is getting sprayed by water, he is wet.
# #######
# #######
# sample 42: explain why the relation is contradiction between hypothesis: the group is having a food fight. and premise: a man in a black shirt is holding a microphone on stage with a drummer and guitarist.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that the group is having a food fight, which implies that they are fighting each other, and the premise states that a man in a black shirt is holding a microphone on stage with a drummer and guitarist. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ["The person holding the microphone isn't standing on the floor but on the stage. People having a food fight wouldn't be on stage. The man is holding the microphone, not kicking & throwing food; & two other people (a guitarist & drummer)", 'The man is holding a microphone, not food. The group is not having a food fight, but rather performing on stage.']
# **
# explanation_1: The man is holding a microphone on stage with a drummer and guitarist, which implies that the group is performing music, and not having a food fight.
# #######
# #######
# sample 43: explain why the relation is entailment between hypothesis: a dog is outside. and premise: the dog is carrying a toy through the grass.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a dog is outside" and the premise "the dog is carrying a toy through the grass" because the premise confirms the hypothesis. The hypothesis states that a dog is outside, which implies that it is outside, and that it is carrying a toy through the grass. The premise provides additional information about the dog's activity, which confirms the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ['the dog is carrying a toy in the grass, which usually is an activity only done outside.']
# **
# explanation_1: To carry the toy through the grass, the dog must be outside.
# #######
# #######
# sample 44: explain why the relation is neutral between hypothesis: a man likes dance and premise: a hispanic man wearing black is holding the hand of a dancing women who is dancing.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a man likes dance, while the premise describes a man holding the hand of a dancing woman who is dancing. The hypothesis states that a man likes dance, while the premise describes a man holding the hand of a dancing woman who is dancing. The two statements cannot both be true at the same time, and neither can they both be true at the same time.<extra_id_1> </s>
# **
# ...
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment because the hypothesis states that a woman sits outside on the dock, while the premise states that a woman in a bathing suit is sitting on a dock over a body of water. The premise provides additional information that confirms the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ['If a woman is sitting on the end of a dock over the water, she is almost certainly outside.']
# **
# explanation_1: Sitting on a dock is outside.
# #######
# #######
# sample 626: explain why the relation is contradiction between hypothesis: three young giraffes are playing soccer in the beach wearing shorts and premise: three young men are playing soccer in the beach wearing shorts and beach attire while some people watch
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that three young giraffes are playing soccer in the beach wearing shorts and beach attire while some people watch. The premise states that three young men are playing soccer in the beach wearing shorts and beach attire while some people watch. The two statements cannot both be true at the same time, as the premise states that three young men are playing soccer in the beach wearing shorts and beach attire while some people watch.<extra_id_1> </s>
# **
# common_expl_list: ['Giraffes are not people, and soccer is not played by giraffes.', 'The are not men wearing shorts and playing soccer in the beach. Giraffes cannot be men.']
# **
# explanation_1: Men are not giraffes.
# #######
# #######
# sample 627: explain why the relation is neutral between hypothesis: the dog is a shitzu. and premise: a woman plays in the wind, with a furry brown dog.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "the dog is a shitzu" and the premise "a woman plays in the wind, with a furry brown dog" because the premise does not provide any information about the dog's breed or color. The hypothesis simply states that the dog is brown and furry, which is a common description of a shitzu. The premise does not provide any information about the dog's breed or color, which would indicate whether the dog is a shitzu. The premise does not confirm or deny the hypothesis that the dog's furry brown and furry brown and furry brown and a description, therefore, the hypothesis "a woman"<extra_id_1> </s>
# **
# common_expl_list: ['Being either furry or a dog is not enough to be a specific dog breed.']
# **
# explanation_1: A furry brown dog may not be a shitzu.
# #######
# #######
# sample 628: explain why the relation is neutral between hypothesis: a dog runs after a squirrel. and premise: tan dog running through long grass in a park-like setting.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a dog runs after a squirrel, which implies that the dog is running after a squirrel, but the premise describes a tan dog running through long grass in a park. The premise does not provide any information about the dog's location or activity, which would indicate whether the dog is running after a squirrel or not.<extra_id_1> </s>
# **
# common_expl_list: ['A dog could be running after a feather, chipmunk, or his master without running after a squirrel.', 'A dog running through long grass does not imply that the dog is chasing a squirrel.']
# **
# explanation_1: A running dog does not mean there is a squirrel.
# #######
# #######
# sample 629: explain why the relation is neutral between hypothesis: two wrestlers are competing and are brothers. and premise: two wrestlers in an intense match.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that two wrestlers are competing and are brothers, while the premise states that two wrestlers are competing and are brothers. The two statements cannot both be true at the same time, because the premise does not provide any information about the brothers' relationship. The hypothesis states that the two wrestlers are competing and are brothers, but the premise does not provide any information about the brothers' relationship.<extra_id_1> </s>
# **
# common_expl_list: ['The two wrestlers do not have to be brothers. They might be in an act together for a show, for example. People who compete do not have to be related.']
# **
# explanation_1: You can have a wrestling match and not be competing, you can wrestle with someone that is not your brother.
# #######
# #######
# sample 630: explain why the relation is entailment between hypothesis: the child is upside down. and premise: the child is hanging upside down with his legs over a pole.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "the child is upside down" and the premise "the child is hanging upside down with his legs over a pole" because the premise confirms the hypothesis. The hypothesis states that the child is hanging upside down with his legs over a pole, which implies that the child is hanging upside down with his legs over a pole. The premise confirms the hypothesis that the child is hanging upside down with his legs over a pole, which implies that the child is hanging upside down with his legs over a pole. The premise confirms the hypothesis that the premise confirms the hypothesis that the premise confirms the hypothesis that the premise confirms the hypothesis that the premise confirms the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the hypothesis that the child is hanging upside down with his legs over a pole.<extra_id_1> </s>
# **
# common_expl_list: ['If a child is hanging upside down with his legs over a pole, then the child is upside down.', 'If the child is hanging upside down, then he is upside down.']
# **
# explanation_1: Upside down is a rephrasing of hanging upside down.
# #######
# #######
# sample 631: explain why the relation is contradiction between hypothesis: a young boy is playing in the grass. and premise: a young boy is playing in the sandy water.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that a young boy is playing in the grass, which implies that he is in the grass, which implies that he is in the grass, and the premise states that he is in the sand, which implies that he is in the sand, which implies that he is in the sand. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['The boy is not playing in the grass, he is playing in the sand.']
# **
# explanation_1: A person cannot be playing in the water and in the grass simultaneously.
# #######
# #######
# sample 632: explain why the relation is neutral between hypothesis: a father and daughter swim together and premise: a man and a young girl swimming.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "a father and daughter swim together" and the premise "a man and a young girl swimming" because the premise does not provide any information about the father or daughter. The hypothesis simply states that a man and a young girl are swimming, which is not specific enough to confirm or deny the hypothesis.<extra_id_1> </s>
# **
# common_expl_list: ['Swimming is not inherently a relationship-affirming activity between a father and daughter. It could be a parent and child, two friends, et cetera. The text "and" separates the subjects, so it cannot be a single subject.']
# **
# explanation_1: man and a young girl doesn't always mean father and daughter
# #######
# #######
# sample 633: explain why the relation is neutral between hypothesis: someone is sitting outside waiting for a friend to arrive. and premise: the young man in the plaid shirt is sitting on a chair that is out in the yard.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral between the hypothesis "someone is sitting outside waiting for a friend to arrive" and the premise "the young man in the plaid shirt is sitting on a chair that is out in the yard" because the premise does not provide any information about the person's activity or location. The hypothesis states that the person is waiting for a friend to arrive, which implies that the person is waiting for someone to arrive, which implies that the person is waiting for someone to arrive. The premise does not provide any information about the person's activity, but it does not specify the person's activity, but it does not specify the person's activity, but does not specify the person's activity, but does not specify the person's sitting outside, therefore, the hypothesis "someone is sitting outside, however, the person's activity, and therefore, the person's activity, and therefore, the young man's activity, and therefore, the young man's position, however, whether the person is waiting for a friend's arrival, or the person's activity, or the person's activity, or the person's activity, or the person's activity, or the
# **
# common_expl_list: ['While someone could be sitting outside waiting for a friend to arrive, it is also possible that they are sitting outside for other reasons, such as to enjoy the weather.']
# **
# explanation_1: one isn't always waiting for a friend when sitting out in the yard
# #######
# #######
# sample 634: explain why the relation is entailment between hypothesis: dog is running and being chased by another dog and premise: dog running with pet toy being chased by another dog.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "dog is running and being chased by another dog" and the premise "dog running with pet toy being chased by another dog" because the premise confirms the hypothesis. The hypothesis states that the dog is running and being chased by another dog, which implies that the dog is running and being chased by another dog. The premise states that the dog is running with pet toy and being chased by another dog, which confirms the hypothesis that the dog is running and being chased by another dog. The premise confirms the hypothesis that the dog is running and being chased by another dog. The premise confirms the hypothesis. The premise confirms the dog is running and being chased by another dog. The hypothesis that the dog is running with pet toy, which implies that the dog is being chased by another dog is being chased by another dog is being chased by another dog. The premise provides additional information about the dog's behavior.<extra_id_1> </s>
# **
# common_expl_list: ['If a dog is running and being chased by another dog, then a dog is running and being chased by another dog.']
# **
# explanation_1: Dog running indicates that a dog is running; being basically involves running by definition, but 'and' is necessary because the fact that the dog is running was already repeated and the first sentence was incomplete anyway.  Oh, wait, so is the second one.
# #######
# #######
# sample 635: explain why the relation is entailment between hypothesis: a man with glasses and premise: an elderly man with glasses, a red ball cap and backpack is standing in front of an open doorway.
# **
# generated explanation: <pad> <extra_id_0> The relation is entailment between the hypothesis "a man with glasses" and the premise "an elderly man with glasses, a red ball cap and backpack is standing in front of an open door" because the premise confirms the hypothesis. The hypothesis states that a man with glasses is a man with glasses, a red ball cap and backpack is standing in front of an open door. The premise confirms the hypothesis that a man with glasses is a man with glasses, a red ball cap and backpack is standing in front of the hypothesis "an elderly man with glasses is entails that the premise confirms the hypothesis that the premise confirms the premise. The premise confirms the premise provides additional information about the man's the hypothesis that the man's the hypothesis that the man's identity.<extra_id_1> </s>
# **
# common_expl_list: ['The man is wearing glasses, and so he is a man with glasses.']
# **
# explanation_1: A man with glasses is rephrased as man with glasses.
# #######
# #######
# sample 636: explain why the relation is contradiction between hypothesis: a man in pants and a t-shirt doing fire tricks. and premise: a robed dancer holding fire stick entertains a crowd.
# **
# generated explanation: <pad> <extra_id_0> The relation is a contradiction because the hypothesis states that a man in pants and a t-shirt is doing fire tricks, which implies that the man is wearing a t-shirt and pants. The premise, on the other hand, states that a robed dancer holding a fire stick entertains a crowd. These two statements cannot both be true at the same time, which is a contradiction.<extra_id_1> </s>
# **
# common_expl_list: ['A robed dancer is not necessarily the same as a man in pants and a t-shirt doing fire tricks.']
# **
# explanation_1: A robed dancer cannot be wearing pants.
# #######
# #######
# sample 637: explain why the relation is neutral between hypothesis: the man is walking into a room. and premise: a man is standing in the doorway of a building.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the man is walking into a room, which implies that he is moving into a room, but the premise states that the man is standing in the doorway of a building, which implies that he is standing in the doorway of a building. These two statements cannot both be true at the same time, which is why the relation is neutral.<extra_id_1> </s>
# **
# common_expl_list: ["Just because someone is standing in the doorway does not necessarily mean that he's walking into a room, it could be that he's there to prevent others from walking in."]
# **
# explanation_1: standing doesn't mean walking
# #######
# #######
# sample 638: explain why the relation is neutral between hypothesis: the log is for firewood. and premise: in a snowy residential environment, a man with a brown jacket and gray mustache and beard places a hand on a felled log while another man in a blue shirt is blurry on the right side of the photo.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that the log is for firewood, which implies that it is being used for firewood. The premise, on the other hand, states that a man is holding a felled log, which implies that it is being used for firewood. The premise does not provide any information about the log’s use or purpose, which would indicate whether it is being used for firewood or not.<extra_id_1> </s>
# **
# common_expl_list: ['While firewood is typically cut logs, just because a log is present does not mean it is for firewood.', 'The log could be for firewood, but it could also be for a number of other things.']
# **
# explanation_1: Not all logs are for firewood.
# #######
# #######
# sample 639: explain why the relation is neutral between hypothesis: a child uses their imagination. and premise: a child making a sand castle on the beach.
# **
# generated explanation: <pad> <extra_id_0> The relation is neutral because the hypothesis states that a child uses their imagination, while the premise describes a child making a sand castle on the beach. The premise does not provide any information about the child’s imagination, which would indicate that the child is using their imagination. The hypothesis does not provide any information about the child’s imagination, which would indicate that the child is using their imagination.<extra_id_1> </s>
# **
# common_expl_list: ['A child could be using their imagination while building a sand castle, but they could also be building a sand castle without using their imagination.']
# **
# explanation_1: It is not clear that the child is using their imagination in rather than just making a standard sandcastle with the tools they have available.
# #######

# %%
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
from tqdm import tqdm
import pdb
qae_list = []
score_list = []
for da in tqdm(rationale_pair_dev_data[0:200], total=len(rationale_pair_dev_data[0:200])):
    qae = ["premise: {} hypothesis: {} answer: {}, explanation: {}".format(da['premise'], 
                                                 da['hypothesis'], 
                                                wt5_esnli_label_mapping[da['label']],
                                                expl) for expl in da['common_expl_list']]

    scores = get_scores(
        qae,
        '3b',
        device='cuda:0',
        batch_size=1,
        verbose=False)
    score_list.append(scores[0])
np.mean(score_list), np.median(score_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:15<00:00, 13.12it/s]
# (0.8201008582115173, 0.8638935983181)

# %%
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
from tqdm import tqdm
import pdb
qae_list = []
score_list = []
for da in tqdm(rationale_pair_dev_data[0:200], total=len(rationale_pair_dev_data[0:200])):
    qae = "premise: {} hypothesis: {} answer: {}, explanation: {}".format(da['premise'], 
                                                 da['hypothesis'], 
                                                wt5_esnli_label_mapping[da['label']],
                                                da['explanation_1'])

    scores = get_scores(
        [qae],
        '3b',
        device='cuda:0',
        batch_size=1,
        verbose=False)
    score_list.append(scores[0])
np.mean(score_list), np.median(score_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:09<00:00, 21.53it/s]
# (0.5679544609179721, 0.6270546019077301)

# %%
from tqdm import tqdm
import pdb
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
qae_list = []
score_list = []
for da in tqdm(rationale_pair_dev_data[0:200], total=len(rationale_pair_dev_data[0:200])):
    qae = "premise: {} hypothesis: {} answer: {}, explanation: {}".format(da['premise'], 
                                                 da['hypothesis'], 
                                                wt5_esnli_label_mapping[da['label']],
                                                da['generated_explanation'])

    scores = get_scores(
        [qae],
        '3b',
        device='cuda:0',
        batch_size=1,
        verbose=False)
    score_list.append(scores[0])
#     if scores[0] > 0.7 or scores[0] < 0.2:
#         print("question: {}".format(da['question']))
#         print("answer: {}".format(da['answer']))
#         print("common_expl_list: {}".format(da['common_expl_list']))
#         print("generated_explanation: {}".format(da['generated_explanation']))
#         print("score: {}".format(scores[0]))\
np.mean(score_list), np.median(score_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:17<00:00, 11.51it/s]
# (0.3917398187145591, 0.38663966953754425)

# %% [markdown]
# ## evaluate generated rationale with bert-score

# %%
score_list
# Out:
# [0.4052284061908722,
#  0.5191667079925537,
#  0.2200496792793274,
#  0.6166287660598755,
#  0.23566164076328278,
#  0.23137959837913513,
#  0.4726582467556,
#  0.44587987661361694,
#  0.3216574192047119,
#  0.5206500887870789,
#  0.374889075756073,
#  0.3831893503665924,
#  0.39179790019989014,
#  0.23738797008991241,
#  0.3433012068271637,
#  0.4466983675956726,
#  0.1248847022652626,
#  0.23148657381534576,
#  0.29242706298828125,
#  0.43564972281455994,
#  0.24475640058517456,
#  0.5609840154647827,
#  0.20569974184036255,
#  0.33773431181907654,
#  0.7527338862419128,
#  0.5272515416145325,
#  0.6047167778015137,
#  0.22808103263378143,
#  0.4841300845146179,
#  0.5092390179634094,
#  0.6105713844299316,
#  0.39877912402153015,
#  0.2403331995010376,
#  0.4602493643760681,
#  0.2712806761264801,
#  0.3767451047897339,
#  0.4169318675994873,
#  0.3975336253643036,
#  0.2173650860786438,
#  0.41740041971206665,
#  0.3692389130592346,
#  0.5197189450263977,
#  0.4667205512523651,
#  0.4045630395412445,
#  0.18840569257736206,
#  0.36257457733154297,
#  0.5066966414451599,
#  0.5434831380844116,
#  0.6222059726715088,
#  0.4641484320163727,
#  0.35610806941986084,
#  0.36895424127578735,
#  0.5060877799987793,
#  0.2504364848136902,
#  0.2549154758453369,
#  0.36247196793556213,
#  0.28698039054870605,
#  0.3996577858924866,
#  0.4715018570423126,
#  0.24798083305358887,
#  0.3999579846858978,
#  0.5949535369873047,
#  0.4727192223072052,
#  0.369602769613266,
#  0.5916022062301636,
#  0.15172460675239563,
#  0.18640388548374176,
#  0.6163924336433411,
#  0.5901542901992798,
#  0.35113880038261414,
#  0.38531073927879333,
#  0.43592047691345215,
#  0.49948549270629883,
#  0.35807088017463684,
#  0.32135045528411865,
#  0.23122002184391022,
#  0.13154998421669006,
#  0.5757285356521606,
#  0.36724215745925903,
#  0.46040549874305725,
#  0.20018185675144196,
#  0.6370958089828491,
#  0.3456253707408905,
#  0.5608186721801758,
#  0.5030788779258728,
#  0.6076309084892273,
#  0.18781070411205292,
#  0.5659143924713135,
#  0.30222928524017334,
#  0.31833523511886597,
#  0.5235123038291931,
#  0.6068321466445923,
#  0.23020249605178833,
#  0.5227280855178833,
#  0.4081699848175049,
#  0.6213501691818237,
#  0.6290147304534912,
#  0.49989354610443115,
#  0.24614211916923523,
#  0.512096107006073,
#  0.29990851879119873,
#  0.45445516705513,
#  0.31953710317611694,
#  0.5589436292648315,
#  0.5049543380737305,
#  0.48530513048171997,
#  0.20518529415130615,
#  0.3631806969642639,
#  0.2650047838687897,
#  0.36311835050582886,
#  0.38383692502975464,
#  0.3077157437801361,
#  0.20877300202846527,
#  0.3844220042228699,
#  0.475339412689209,
#  0.21918535232543945,
#  0.2773076891899109,
#  0.28401654958724976,
#  0.25412940979003906,
#  0.47909751534461975,
#  0.4923161268234253,
#  0.2609064280986786,
#  0.17922139167785645,
#  0.36572808027267456,
#  0.31545549631118774,
#  0.6295533776283264,
#  0.6326461434364319,
#  0.4168664515018463,
#  0.5122179388999939,
#  0.4935808777809143,
#  0.5737080574035645,
#  0.29133766889572144,
#  0.23395846784114838,
#  0.4845719337463379,
#  0.42710697650909424,
#  0.4159185290336609,
#  0.3193843364715576,
#  0.3686027526855469,
#  0.376205176115036,
#  0.5443673133850098,
#  0.1900431513786316,
#  0.3163864016532898,
#  0.10158112645149231,
#  0.48957714438438416,
#  0.23955661058425903,
#  0.40009447932243347,
#  0.5523318648338318,
#  0.19016949832439423,
#  0.3606308698654175,
#  0.28867873549461365,
#  0.5529397130012512,
#  0.3564395010471344,
#  0.25043654441833496,
#  0.5034043788909912,
#  0.2199779897928238,
#  0.5724901556968689,
#  0.32532161474227905,
#  0.4058498740196228,
#  0.21932178735733032,
#  0.4766693413257599,
#  0.09198835492134094,
#  0.3168512284755707,
#  0.2226075530052185,
#  0.5453656911849976,
#  0.26887133717536926,
#  0.17488594353199005,
#  0.6631544828414917,
#  0.4428752362728119,
#  0.5131805539131165,
#  0.44898083806037903,
#  0.5143211483955383,
#  0.44964832067489624,
#  0.19299419224262238,
#  0.5258002281188965,
#  0.23637670278549194,
#  0.542185366153717,
#  0.14903080463409424,
#  0.38796859979629517,
#  0.5865784287452698,
#  0.2989481985569,
#  0.37448662519454956,
#  0.4968299865722656,
#  0.5083785057067871,
#  0.3739764094352722,
#  0.2237195521593094,
#  0.3794389069080353,
#  0.1469278782606125,
#  0.25624197721481323,
#  0.4256499707698822,
#  0.6071449518203735,
#  0.41453784704208374,
#  0.23765921592712402,
#  0.3892876207828522,
#  0.5127691030502319,
#  0.35344868898391724,
#  0.5991389155387878,
#  0.4366164803504944,
#  0.14572034776210785,
#  0.568449854850769,
#  0.30032017827033997]

# %%
import datasets
import numpy as np
bertscore_metric = datasets.load_metric("bertscore")
rouge_metric = datasets.load_metric('rouge')
bleu_metric = datasets.load_metric('sacrebleu')

# %%
import pdb

bert_scores = []
bleu_scores = []
rouge1_scores = []
rouge2_scores = []
rougeL_scores = []

for da in tqdm(rationale_pair_dev_data, total=len(rationale_pair_dev_data)):
    generated_expl = da['generated_explanation']
    common_expl_list = da['common_expl_list']
    pred_expl = generated_expl.split("<extra_id_0> ")[1].split("<extra_id_1>")[0]
    list_gold_expl = [l.lower() for l in common_expl_list]
    
    bert_score = bertscore_metric.compute(predictions=[pred_expl.lower()], references=[list_gold_expl], lang="en")["f1"][0]*100
    bleu_score = bleu_metric.compute(predictions=[pred_expl.lower()], references=[list_gold_expl])['score']
    rouge_score = rouge_metric.compute(predictions=[pred_expl.lower()]*len(list_gold_expl), references=list_gold_expl)
    rouge1_score = rouge_score["rouge1"].mid.fmeasure
    rouge2_score = rouge_score["rouge2"].mid.fmeasure
    rougeL_score = rouge_score["rougeL"].mid.fmeasure
    bert_scores.append(bert_score)
    bleu_scores.append(bleu_score)
    rouge1_scores.append(rouge1_score)
    rouge2_scores.append(rouge2_score)
    rougeL_scores.append(rougeL_score)
    
    
#     #print(generated_expl)
#     #print(generated_expl.split("<extra_id_0> ")[1].split("<extra_id_1>")[0])
#     instance_bertscores = []
#     for gold_expl in list_gold_expl: 
#         score = bertscore_metric.compute(predictions=[pred_expl.lower()]*len(), references=[gold_expl.lower()], lang="en")["f1"][0]*100
#         instance_bertscores.append(score)
#     bertscores.append(np.mean(instance_bertscores))
    
#     bleuscore = bleu_score(pred_expl, list_gold_expl)
#     bleuscores.append(bleuscore)
    
#     rougescore = rouge(pred_expl, list_gold_expl)
#     rouge1_scores.append(rougescore['rouge1_fmeasure'].numpy()[0])
#     rouge2_scores.append(rougescore['rouge2_fmeasure'].numpy()[0])
#     rougeL_scores.append(rougescore['rougeL_fmeasure'].numpy()[0])
    
    


    #pdb.set_trace()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 640/640 [02:43<00:00,  3.91it/s]

# %%
print("bert_score: {}".format(np.mean(bert_scores)))
print("bleu_score: {}".format(np.mean(bleu_scores)))
print("rouge1_score: {}".format(np.mean(rouge1_scores)))
print("rouge2_score: {}".format(np.mean(rouge2_scores)))
print("rougeL_score: {}".format(np.mean(rougeL_scores)))
# Out:
# bert_score: 86.09047032892704
# bleu_score: 6.661188993161209
# rouge1_score: 0.23278395041583275
# rouge2_score: 0.11325451058290263
# rougeL_score: 0.19008936096033716

# %%
rouge_score
# Out:
# {'rouge1': AggregateScore(low=Score(precision=0.18309859154929578, recall=0.52, fmeasure=0.27083333333333337), mid=Score(precision=0.18309859154929578, recall=0.52, fmeasure=0.27083333333333337), high=Score(precision=0.18309859154929578, recall=0.52, fmeasure=0.27083333333333337)),
#  'rouge2': AggregateScore(low=Score(precision=0.11428571428571428, recall=0.3333333333333333, fmeasure=0.1702127659574468), mid=Score(precision=0.11428571428571428, recall=0.3333333333333333, fmeasure=0.1702127659574468), high=Score(precision=0.11428571428571428, recall=0.3333333333333333, fmeasure=0.1702127659574468)),
#  'rougeL': AggregateScore(low=Score(precision=0.16901408450704225, recall=0.48, fmeasure=0.25), mid=Score(precision=0.16901408450704225, recall=0.48, fmeasure=0.25), high=Score(precision=0.16901408450704225, recall=0.48, fmeasure=0.25)),
#  'rougeLsum': AggregateScore(low=Score(precision=0.16901408450704225, recall=0.48, fmeasure=0.25), mid=Score(precision=0.16901408450704225, recall=0.48, fmeasure=0.25), high=Score(precision=0.16901408450704225, recall=0.48, fmeasure=0.25))}

# %%
bertscore
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1438329/4021306630.py in <module>
# ----> 1 bertscore
#
# NameError: name 'bertscore' is not defined

# %%
bertscores

# %%
np.mean(score_list)
