# %%
'''
A (hopefully) Simple API for serving explanation score requests.

input_string = (
    f"{question} answer: {gold_label}. "
    + f" explanation: {abstr_expl}."
)

here are some example input strings:

If you feel like everything is spinning while climbing you are experiencing what? answer: vertigo. explanation: Vertigo is often experienced while climbing or at heights.
Where do you get clothes in a shopping bag? answer: retail store. explanation: For any large item where convenience is beneficial, one might go to a retail store, either a regular one or a big-box store like walmart.
Where should a cat be in a house? answer: floor. explanation: A cat should be on the floor, not on a rug.
'''
import pdb
import argparse
import torch
import transformers
import os
import tqdm
import numpy as np

_model, _tokenizer = None, None

model2url = {
    'large': 'https://storage.googleapis.com/ai2-mosaic-public/projects/few-shot-explanations/pretrained_models/commonsense_qa/valloss%3D0.28665~model%3Dt5-large~lr%3D0.0001~seed%3D1~labelagg%3D0_just_weights.pt',
    '3b': 'https://storage.googleapis.com/ai2-mosaic-public/projects/few-shot-explanations/pretrained_models/commonsense_qa/valloss%3D0.28925~model%3Dt5-3b~lr%3D0.0001~seed%3D1~labelagg%3D0_just_weights.pt',
    '11b': 'https://storage.googleapis.com/ai2-mosaic-public/projects/few-shot-explanations/pretrained_models/commonsense_qa/cose_deepspeed_valloss%3D0.00000~model%3Dt5-11b~lr%3D0.00001~seed%3D1~labelagg%3D0.pt',
}

def get_model(model_type, device=None):
    global _model, model2url
    if model_type not in {'11b', '3b', 'large'}:
        raise NotImplementedError('{} is not a valid model please use "3b" or "large"'.format(model_type))

    if _model is None:
        hf_model_name = 't5-' + model_type
        print('Loading model: this will run only once.')

        if model_type == 'large':
            model_path = 'snli_models/t5-large.pt'
        elif model_type == '3b':
            model_path = 'snli_models/valloss=0.24209~model=t5-3b~lr=0.0001~seed=1~labelagg=0_just_weights.pt'
        elif model_type == '11b':
            model_path = 'snli_models/cose_deepspeed_valloss=0.00000~model=t5-11b~lr=0.00001~seed=1~labelagg=0.pt'

        if not os.path.exists(model_path):
            print('Please download weights for {} model and put in current directory.'.format(model_path))
            print('for example, wget {}'.format(model2url[model_type]))
            quit()

        state = torch.load(model_path)
        if 'model_state_dict' in state:
            state = state['model_state_dict']

        _model = transformers.AutoModelForSeq2SeqLM.from_pretrained(hf_model_name)
        if model_type == '11b': # need to resize due to deepspeed, these entires are not accessed.
            _model.resize_token_embeddings(len(transformers.AutoTokenizer.from_pretrained(hf_model_name)))
        _model.load_state_dict(state)
        _model.eval()
        if device is not None:
            _model = _model.to(device)

    return _model


def get_tokenizer(model_type):
    global _tokenizer
    if model_type not in {'3b', 'large', '11b'}:
        raise NotImplementedError('{} is not a valid model please use "3b" or "large" or "11b"'.format(model_type))

    if _tokenizer is None:
        hf_model_name = 't5-' + model_type
        _tokenizer = transformers.T5TokenizerFast.from_pretrained(hf_model_name)

    return _tokenizer


class T5Dataset(torch.utils.data.Dataset):
    def __init__(self, data, tokenizer):
        self.data = data
        self.tokenizer = tokenizer

    def __getitem__(self, idx):
        res = self.tokenizer(self.data[idx]['input'], truncation=True)
        res['labels'] = self.tokenizer(self.data[idx]['label']).input_ids
        return res

    def __len__(self):
        return len(self.data)


def get_scores(inputs, model_type, device=None, batch_size=32, verbose=False):
    '''
    Inputs:
      - a list of explanations to score, e.g.,:
        premise: A man getting a tattoo on his back. hypothesis: A woman is getting a tattoo. answer: contradiction. explanation: Because the tattoo artist is a man, the person getting the tattoo is not a woman.
      - model type, either "3b" or "large" or "11b"
      - device: which torch device to load model on, e.g., "cuda:3"
    Outputs:
      - P(good explanation); higher is better
    '''
    assert model_type in {'large', '3b', '11b'}

    if isinstance(inputs, str):
        inputs = [inputs]

    model = get_model(model_type, device=device)
    tokenizer = get_tokenizer(model_type)

    score_itr = T5Dataset([{'input': inp, 'label': 'x'} for inp in inputs], tokenizer) # dummy labels for inference
    data_collator = transformers.DataCollatorForSeq2Seq(
        tokenizer,
        model=model,
        label_pad_token_id=-100,
#         return_tensors='pt'
    )
    score_itr = torch.utils.data.DataLoader(score_itr, shuffle=False, collate_fn=data_collator, batch_size=batch_size)
    score_itr = score_itr if not verbose else tqdm.tqdm(score_itr, total=len(score_itr))

    good_idx, bad_idx = tokenizer('good').input_ids[0], tokenizer('bad').input_ids[0]
    scores = []
    
    with torch.no_grad():
        for batch in score_itr:
            if device is not None:
                input_ids, attention_mask, targets = batch['input_ids'].to(device), batch['attention_mask'].to(device), batch['labels'].to(device)
            model_output = model(input_ids=input_ids, attention_mask=attention_mask, labels=targets)
            logits_pos = model_output['logits'][:, 0, good_idx].cpu().numpy()
            logits_neg = model_output['logits'][:, 0, bad_idx].cpu().numpy()
            exp_logit_pos, exp_logit_neg = np.exp(logits_pos), np.exp(logits_neg)
            score = list([float(x) for x in exp_logit_pos / (exp_logit_pos + exp_logit_neg)])
            #pdb.set_trace()
            scores.extend(score)
    return scores


# def parse_args():
#     '''
#     Optional args for main function, mostly just to test.
#     '''
#     parser = argparse.ArgumentParser()
#     parser.add_argument(
#         'model_type',
#         default='large',
#         choices={'large', '3b', '11b'})
#     parser.add_argument(
#         '--batch_size',
#         default=32,
#         type=int)

#     args = parser.parse_args(['--batch_size', '1'])
#     return args

# %%
# args = parse_args()
# parser = argparse.ArgumentParser()
# parser.add_argument(
#     'model_type',
#     default='large',
#     choices={'large', '3b', '11b'})
# parser.add_argument(
#     '--batch_size',
#     default=32,
#     type=int)

# args = parser.parse_args(["--model_type", "3b"])
# args.device = 'cpu'#'cuda' if torch.cuda.is_available() else 'cpu'
np.random.seed(1)
import os 
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
# scores = get_scores(
#     ['If you feel like everything is spinning while climbing you are experiencing what? answer: vertigo. explanation: Vertigo is often experienced while climbing or at heights.',
#      'Where do you get clothes in a shopping bag? answer: retail store. explanation: For any large item where convenience is beneficial, one might go to a retail store, either a regular one or a big-box store like walmart.',
#      'Where should a cat be in a house? answer: floor. explanation: A cat should be on the floor, not on a rug.'],
#     'large',
#     device='cuda:0',
#     batch_size=1,
#     verbose=False)
# print(scores)

# %%
import json
from tqdm import tqdm
# with open("../../scripts/results/dev_rationale_pair.json") as f:
#     rationale_pair_dev_data = json.load(f)
import json
file_path = "../../scripts/results/24shots_esnli_t5_3b_authorwritten_rationales_generator_test_rationale_pair.json"
with open(file_path, 'r') as f:
    rationale_pair_dev_data = json.load(f)

# %%
rationale_pair_dev_data[0].keys(), len(rationale_pair_dev_data)
# Out:
# (dict_keys(['premise', 'hypothesis', 'label', 'explanation_1', 'explanation_2', 'explanation_3', 'our_explanation', 'common_expl_list', 'input_ids', 'attention_mask', 'labels', 'decoder_attention_mask', 'question_encoding', 'generated_explanation']),
#  640)

# %%
# answer = wt5_esnli_label_mapping[item["label"]]
# input_string = f'explain why the relation is {answer} between hypothesis: {hypothesis.lower()} and premise: {premise.lower()}'  
# #input_string = f"explain {datasource} question: {question} answer: {answer}" + f" {explanation_sep} <extra_id_0>"
# answer_string = f"<extra_id_0> {item['our_explanation']} <extra_id_1>"
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
for kk, item in enumerate(rationale_pair_dev_data):
    answer = wt5_esnli_label_mapping[item["label"]]
    hypothesis = item['hypothesis']
    premise = item['premise']
    input_string = f'explain why the relation is {answer} between hypothesis: {hypothesis.lower()} and premise: {premise.lower()}' 
    print(f"sample {kk}: {input_string}")
    print(item['generated_explanation'])
# Out:
# sample 0: explain why the relation is entailment between hypothesis: there is a black dog. and premise: a black dog running really fast with a blond woman running after him in the background.
# <pad> <extra_id_0> There is a blond woman running after a black dog, and there is a black dog.<extra_id_1> </s>
# sample 1: explain why the relation is contradiction between hypothesis: people at home and premise: a crowd of people in a subway
# <pad> <extra_id_0> A crowd of people in a subway is not a crowd at home.<extra_id_1> </s>
# sample 2: explain why the relation is neutral between hypothesis: a busy pizza restaurant sees a lot of people pass on its active street corner in new york city and premise: a busy pizza shop is located on a heavily trafficked street corner.
# <pad> <extra_id_0> A busy pizza restaurant is not necessarily located on a street corner that is heavily trafficked.<extra_id_1> </s>
# sample 3: explain why the relation is contradiction between hypothesis: the two boys  were swimming and premise: a shirtless boy and a boy in green and white are playing on a concrete surface by a small stage.
# <pad> <extra_id_0> A boy cannot be playing on a concrete surface while he is swimming.<extra_id_1> </s>
# sample 4: explain why the relation is neutral between hypothesis: two dogs vie for an owners attention. and premise: a terrier dog and a mixed breed dog playing.
# <pad> <extra_id_0> A dog can play with another dog, but not necessarily for an owner’s attention.<extra_id_1> </s>
# sample 5: explain why the relation is entailment between hypothesis: a group of men spend time together and premise: several men dressed in cowboy boots and hats are hanging around, and one man is getting his shoes shined.
# <pad> <extra_id_0> Cowboys are social animals. They hang out together, and they spend time together.<extra_id_1> </s>
# sample 6: explain why the relation is contradiction between hypothesis: an empty karate hall. and premise: during karate practice, one student kicks through a wooden plank while another individual holds it at face-height.
# <pad> <extra_id_0> The karate hall is not empty, and there are no students in the karate room.<extra_id_1> </s>
# sample 7: explain why the relation is contradiction between hypothesis: the man is sitting on the grass. and premise: a woman is standing on a road.
# <pad> <extra_id_0> The man is sitting on the grass, and the woman is standing on the road.<extra_id_1> </s>
# sample 8: explain why the relation is neutral between hypothesis: a band is playing before a large audience and premise: performers making music on a guitar and keyboard.
# <pad> <extra_id_0> A band is playing before an audience, but it is not necessarily playing before an audience.<extra_id_1> </s>
# sample 9: explain why the relation is contradiction between hypothesis: the woman is driving a car. and premise: a woman is reading a book on the subway.
# <pad> <extra_id_0> If the woman is reading a book, she is not driving a car.<extra_id_1> </s>
# sample 10: explain why the relation is neutral between hypothesis: the girl is captain of the soccer team. and premise: a young girl wearing a pink top and shin guards kicking a ball in the grass.
# <pad> <extra_id_0> The girl is not a member of the soccer team.<extra_id_1> </s>
# sample 11: explain why the relation is neutral between hypothesis: the young girl playing in playground is lonely. and premise: a little girl in a blue shirt and jeans, sitting on a swing smiling.
# <pad> <extra_id_0> The young girl playing in the playground could be playing alone, but she could also be playing with friends.<extra_id_1> </s>
# sample 12: explain why the relation is contradiction between hypothesis: a guy is spraying paint on a brick wall. and premise: a man is riding in a boat on the water.
# <pad> <extra_id_0> A boat is not a boat. A boat is not a boat.<extra_id_1> </s>
# sample 13: explain why the relation is neutral between hypothesis: the woman is eating from a bowl. and premise: an asian woman eating with a spoon.
# <pad> <extra_id_0> The woman could be eating with a spoon or a bowl, but it is possible that she is eating from a bowl.<extra_id_1> </s>
# sample 14: explain why the relation is neutral between hypothesis: the employee is actually a bartender. and premise: at maruga's diner, a male employee stands in the background behind a coca-cola machine.
# <pad> <extra_id_0> The employee could be a bartender, but he could also be a waiter.<extra_id_1> </s>
# sample 15: explain why the relation is entailment between hypothesis: the woman is touching the harp. and premise: a woman playing a harp.
# <pad> <extra_id_0> If a woman is playing a harp, then she is playing it while she is touching it.<extra_id_1> </s>
# sample 16: explain why the relation is neutral between hypothesis: the violin sounds beatuful. and premise: a young woman is playing the violin.
# <pad> <extra_id_0> The violin is a musical instrument, and playing the violin makes it sound like it is being played.<extra_id_1> </s>
# sample 17: explain why the relation is entailment between hypothesis: people are standing by a car. and premise: four men standing near a yellow car.
# <pad> <extra_id_0> If people are standing by a car, then they are almost certainly standing by a car.<extra_id_1> </s>
# sample 18: explain why the relation is neutral between hypothesis: a girl in a pink swimsuit is about to do a swan dive. and premise: a young person wearing a pink one-piece swimsuit and goggles about to complete a leap into a swimming pool.
# <pad> <extra_id_0> A swan dive is a swan dive, and a person can do a swan dive while in the water.<extra_id_1> </s>
# sample 19: explain why the relation is entailment between hypothesis: the woman is moving her mouth. and premise: a young woman in a white shirt and glasses talks to a group of people.
# <pad> <extra_id_0> The woman is talking to a group of people. She is moving her mouth.<extra_id_1> </s>
# sample 20: explain why the relation is neutral between hypothesis: three women with different colored shirts are sitting in an office that also has a bookshelf in it. and premise: three people, one with a black shirt, one with a navy blue jacket, and one with a red t-shirt, working in an office with a large messy bookshelf.
# <pad> <extra_id_0> A bookshelf is a common object in offices, and if you have a bookshelf in your office, you are in the right place.<extra_id_1> </s>
# sample 21: explain why the relation is entailment between hypothesis: the woman has long hair. and premise: a woman with long dark hair standing in front of a window.
# <pad> <extra_id_0> If the woman has long hair, then the woman must be standing in front of a window.<extra_id_1> </s>
# sample 22: explain why the relation is neutral between hypothesis: a chemistry teacher measures carefully to show the class how to do it. and premise: a man uses a dropper to conduct an experiment.
# <pad> <extra_id_0> A hispanic woman is not necessarily a fashion designer.<extra_id_1> </s>
# sample 36: explain why the relation is neutral between hypothesis: two men are giving a presentation. and premise: a man speaks into a microphone being held by another man.
# <pad> <extra_id_0> A man speaking into a microphone being held by another man is not necessarily speaking into the microphone. A man could be giving a presentation to another man.<extra_id_1> </s>
# sample 37: explain why the relation is neutral between hypothesis: a girl is walking across the grass to go home. and premise: a little girl wearing a dress walks across a green lawn on a summer day with a home and trees in the background.
# <pad> <extra_id_0> A girl walking across the grass could be walking to go home, or to school.<extra_id_1> </s>
# sample 38: explain why the relation is neutral between hypothesis: a woman sitting with her baby in a group in a bus and premise: a woman sitting with her baby in a group, while other women breastfeed in the background.
# <pad> <extra_id_0> A woman sitting with her baby in a group in a bus does not necessarily indicate that she is breastfeeding.<extra_id_1> </s>
# sample 39: explain why the relation is neutral between hypothesis: the men are members of a rock band. and premise: a man on the left speaks into a microphone, while a man on the right plays an unidentified instrument with a drum set in the background.
# <pad> <extra_id_0> The men are playing an unidentified instrument, but it is not clear if they are members of a rock band.<extra_id_1> </s>
# sample 40: explain why the relation is entailment between hypothesis: a little boy is riding outside. and premise: a little boy rides a bike down a hill on a miniature dirt bike.
# <pad> <extra_id_0> A bike is a vehicle that is used for transportation, and a bike is a vehicle that is used for transportation.<extra_id_1> </s>
# sample 41: explain why the relation is entailment between hypothesis: the man is wet and premise: man in white shirt getting sprayed by water.
# <pad> <extra_id_0> The man is getting sprayed with water, so he is getting wet.<extra_id_1> </s>
# sample 42: explain why the relation is contradiction between hypothesis: the group is having a food fight. and premise: a man in a black shirt is holding a microphone on stage with a drummer and guitarist.
# <pad> <extra_id_0> The group is not having a food fight, unless they are eating together.<extra_id_1> </s>
# sample 43: explain why the relation is entailment between hypothesis: a dog is outside. and premise: the dog is carrying a toy through the grass.
# <pad> <extra_id_0> A dog is carrying a toy, so if the dog is carrying a toy, it is probably carrying it.<extra_id_1> </s>
# sample 44: explain why the relation is neutral between hypothesis: a man likes dance and premise: a hispanic man wearing black is holding the hand of a dancing women who is dancing.
# <pad> <extra_id_0> A dancing woman is not necessarily a dancing man, but she could be a woman who is dancing if she is dancing.<extra_id_1> </s>
# sample 45: explain why the relation is entailment between hypothesis: 4 players are in the grass and premise: three members of the red team are in the grass with a member of the yellow team.
# <pad> <extra_id_0> If the players are in the grass, they are in the field.<extra_id_1> </s>
# sample 46: explain why the relation is entailment between hypothesis: the dog is outside and premise: the brown and white dog is running through the grass.
# <pad> <extra_id_0> The dog is running through the grass, so it must be outside.<extra_id_1> </s>
# sample 47: explain why the relation is contradiction between hypothesis: the woman has a black coat. and premise: a woman in a white coat pushes a cart.
# <pad> <extra_id_0> The woman in the white coat does not have a black coat.<extra_id_1> </s>
# sample 48: explain why the relation is neutral between hypothesis: these musicians have been friends for 45 years. and premise: a guitarist, a trumpet player and two saxophonists take the stage.
# <pad> <extra_id_0> The musicians could be friends, but they could also be rivals.<extra_id_1> </s>
# <pad> <extra_id_0> A bicyclist is not a runner. A bicyclist is not a runner.<extra_id_1> </s>
# sample 63: explain why the relation is contradiction between hypothesis: a bird is swimming in the water. and premise: a white crane flies over water.
# <pad> <extra_id_0> A bird cannot fly over water.<extra_id_1> </s>
# sample 64: explain why the relation is contradiction between hypothesis: the couple was on the bed. and premise: two people in lavish costumes standing on the street.
# <pad> <extra_id_0> The couple was not on the bed. The couple was standing on the street.<extra_id_1> </s>
# sample 65: explain why the relation is neutral between hypothesis: a man is walking. and premise: a man approaches a street corner with carrying a basket of fruit on his head.
# <pad> <extra_id_0> A man can be walking or standing.<extra_id_1> </s>
# sample 66: explain why the relation is neutral between hypothesis: a restuarant server takes a nap before his shift. and premise: a man wearing a black shirt and white pants stretches out on a bench in the shade of trees.
# <pad> <extra_id_0> A man could be napping for a variety of reasons, including for relaxation, to avoid being woken up, or to avoid being seen.<extra_id_1> </s>
# sample 67: explain why the relation is contradiction between hypothesis: the boy is inside and premise: a young boy wearing a yellow shirt walking on the beach carrying a surfboard
# <pad> <extra_id_0> The boy is not on the beach.<extra_id_1> </s>
# sample 68: explain why the relation is contradiction between hypothesis: a group of small boys are holding signs. and premise: a group of small girls holding up painted glass cups.
# <pad> <extra_id_0> A group of small boys cannot be holding signs.<extra_id_1> </s>
# sample 69: explain why the relation is entailment between hypothesis: a man is doing a job. and premise: a worker is working in an elevator.
# <pad> <extra_id_0> A worker is a person who is doing<extra_id_1> </s>
# sample 70: explain why the relation is contradiction between hypothesis: the two people are running around the brick building. and premise: two people sleep in an alleyway in the shadow of a brick building.
# <pad> <extra_id_0> The alleyway is not a place to be run around, so it is not possible to sleep in an alleyway.<extra_id_1> </s>
# sample 71: explain why the relation is neutral between hypothesis: the woman is white and premise: a woman on a shoreline wearing pale jeans and multicolored jacket, is squinting through a telescope.
# <pad> <extra_id_0> The woman is probably white, but she could be any color.<extra_id_1> </s>
# sample 72: explain why the relation is entailment between hypothesis: this child is happy to fill his tummy. and premise: a child smiles while eating some food.
# <pad> <extra_id_0> A child is likely to smile while eating food if he is happy.<extra_id_1> </s>
# sample 73: explain why the relation is entailment between hypothesis: a dog is wet and premise: a black dog crosses a puddle of water with a ball in its mouth while a brown dog looks the other way.
# <pad> <extra_id_0> A dog is wet when it is soaked through.<extra_id_1> </s>
# sample 74: explain why the relation is neutral between hypothesis: a girl running. and premise: a toddler runs toward the camera at a park.
# <pad> <extra_id_0> A toddler running is not necessarily a girl running, but it could be a boy running or a girl running.<extra_id_1> </s>
# sample 75: explain why the relation is contradiction between hypothesis: the two old men are playing chess at the park. and premise: two old men playing instruments on the street.
# <pad> <extra_id_0> The two old men are playing chess at the park, not in the park.<extra_id_1> </s>
# sample 76: explain why the relation is neutral between hypothesis: people fight for the best bicycles and premise: a varied crowd mills about (or rough-houses) on a public street, with lots of bicycles on display.
# <pad> <extra_id_0> People don't necessarily fight for the best bicycles.<extra_id_1> </s>
# sample 77: explain why the relation is entailment between hypothesis: a parade has flags. and premise: a veteran's parade with three of the flag bearers presenting their flags.
# <pad> <extra_id_0> A parade has flags.<extra_id_1> </s>
# sample 78: explain why the relation is entailment between hypothesis: there are people waving a flag in the bleachers. and premise: people are sitting on bleachers waving american flags.
# <pad> <extra_id_0> If people are waving an american flag, they are also waving it in the bleachers.<extra_id_1> </s>
# sample 79: explain why the relation is contradiction between hypothesis: there are men digging a hole for a pool. and premise: a man wearing overalls, a man wearing an orange hat backwards, and a man wearing a yellow shirt walk on yellow scaffolding connected to the outside of a building.
# <pad> <extra_id_0> A man digging a hole for a pool is not doing any digging.<extra_id_1> </s>
# sample 80: explain why the relation is neutral between hypothesis: the cup has water in it. and premise: a person holding a red cup sitting next to a woman wearing a black shirt.
# <pad> <extra_id_0> The cup could have water in it, but it also could have been empty.<extra_id_1> </s>
# sample 81: explain why the relation is contradiction between hypothesis: a child is indoors. and premise: small child playing peek-a-boo behind a tree in a park.
# <pad> <extra_id_0> A child cannot be outdoors and still be playing peek-a-boo, unless the child is playing in a building or a park.<extra_id_1> </s>
# sample 82: explain why the relation is contradiction between hypothesis: girl eats pineapple and premise: a baseball player in gray is getting ready to catch the ball.
# <pad> <extra_id_0> A girl cannot eat a pineapple.<extra_id_1> </s>
# sample 83: explain why the relation is contradiction between hypothesis: a man is running on a treadmill. and premise: a man wearing an orange scarf is sitting on the grass with his legs crossed and his eyes closed
# <pad> <extra_id_0> A man cannot be sitting on a treadmill at the same time as running on it.<extra_id_1> </s>
# sample 84: explain why the relation is entailment between hypothesis: two women are running. and premise: two young women running on a track.
# <pad> <extra_id_0> Running on a track is a common activity, and it is possible to run on a track while also walking.<extra_id_1> </s>
# sample 85: explain why the relation is contradiction between hypothesis: a man is holding a flute. and premise: a person in a gold shirt is holding a guitar, by the neck, that has many religious stickers on it.
# <pad> <extra_id_0> A guitar is not a flute, and a guitar is not a flute.<extra_id_1> </s>
# sample 86: explain why the relation is neutral between hypothesis: a woman is people watching at the harbor while her husband shops. and premise: a woman sits next to a harbor where boats are docked near people shopping
# <pad> <extra_id_0> A woman can be people watching at a harbor while her husband is shopping, or vice versa.<extra_id_1> </s>
# sample 87: explain why the relation is neutral between hypothesis: a married couple are admiring the view. and premise: two people taking pictures and looking at a beautiful scene by the water.
# <pad> <extra_id_0> A couple taking a picture could be admiring the view, or they could be admiring the scene.<extra_id_1> </s>
# sample 88: explain why the relation is neutral between hypothesis: two redheads dance on stage for a talent competition. and premise: a redheaded man wearing a kilt dancing with a redheaded woman wearing a green skirt in the spotlight of a darkened stage.
# <pad> <extra_id_0> A redhead is a person who is redheaded. A redhead dancing on stage is not necessarily a sign of dancing, but could be a sign of dancing for fun or for a performance.<extra_id_1> </s>
# sample 89: explain why the relation is neutral between hypothesis: the woman is a tourist and premise: a woman in a purple dress plays with her hair while waiting in a lobby.
# <pad> <extra_id_0> The woman could be a tourist, but she could also be a waitress, a worker, or even a cab driver.<extra_id_1> </s>
# sample 90: explain why the relation is contradiction between hypothesis: the woman are running to the door. and premise: women are seated on benches facing the aisle and holding poles.
# <pad> <extra_id_0> The women are not sitting on the benches, they are running to the door.<extra_id_1> </s>
# sample 91: explain why the relation is neutral between hypothesis: he is the pitcher for the red sox. and premise: a pitcher wearing a red shirt and white pants is standing on the mound.
# <pad> <extra_id_0> The pitcher is standing on the mound, but he could be any pitcher.<extra_id_1> </s>
# sample 92: explain why the relation is entailment between hypothesis: there is a tractor outside and premise: a tractor is pulling something down a dirt road with lengths measured in increments of ten meters.
# <pad> <extra_id_0> If there is a tractor, then there is a tractor outside.<extra_id_1> </s>
# sample 93: explain why the relation is entailment between hypothesis: a man is swinging and premise: a man is swinging a cricket bat.
# <pad> <extra_id_0> A cricket bat is a swinging object, and if a man is swinging a cricket bat, he is swinging it.<extra_id_1> </s>
# sample 94: explain why the relation is entailment between hypothesis: a man is in yellow pants. and premise: a muscular man in yellow pants.
# <pad> <extra_id_0> A man in yellow pants is a man, and a man in yellow pants is a man.<extra_id_1> </s>
# sample 95: explain why the relation is contradiction between hypothesis: the woman is mexican and premise: an asian woman and three children.
# <pad> <extra_id_0> The children are asian, not mexican.<extra_id_1> </s>
# sample 96: explain why the relation is entailment between hypothesis: the barrel is round and premise: a sign on a brown barrel.
# <pad> <extra_id_0> A sign on a brown barrel is a sign on a brown barrel, so it must be round.<extra_id_1> </s>
# sample 97: explain why the relation is entailment between hypothesis: a woman is playing a musical instrument. and premise: a woman in a red shirt plays a cello.
# <pad> <extra_id_0> A musical instrument is a musical instrument, and a cello is a musical instrument.<extra_id_1> </s>
# sample 98: explain why the relation is neutral between hypothesis: the dog is pooping. and premise: a brown dog squats in a deep pile of snow.
# <pad> <extra_id_0> A dog squatting in a pile of snow does not necessarily indicate that it is pooping, but it could be pooping.<extra_id_1> </s>
# sample 99: explain why the relation is entailment between hypothesis: the lady is on the bus and premise: a woman is on a public bus riding through a town.
# <pad> <extra_id_0> The bus is a public one, and the lady is on the bus.<extra_id_1> </s>
# sample 100: explain why the relation is contradiction between hypothesis: the woman is flying a kite. and premise: a person, who appears to be male, is riding a dirt bike on a gravelly course.
# <pad> <extra_id_0> A kite is a flying object, and a dirt bike is a motorized vehicle.<extra_id_1> </s>
# sample 101: explain why the relation is entailment between hypothesis: a lady grasping an instrument. and premise: a happy woman holding a guitar.
# <pad> <extra_id_0> A guitar is an instrument, and if you are holding an instrument, you are probably a lady.<extra_id_1> </s>
# sample 102: explain why the relation is neutral between hypothesis: a dog is playing and premise: a brown dog is splashing water in a yard.
# <pad> <extra_id_0> A dog could be playing, but it also could be splashing water.<extra_id_1> </s>
# sample 103: explain why the relation is neutral between hypothesis: an older man is on his way home from the laundramat. and premise: a older man on a bike carrying a laundry basket of clothes.
# <pad> <extra_id_0> A person on a bike can be on his way home from a laundramat, but he could also be on his way home.<extra_id_1> </s>
# sample 104: explain why the relation is contradiction between hypothesis: the group is synchronize swimming. and premise: a group of people wearing orange and black play various types of drums as others watch.
# <pad> <extra_id_0> The group is not playing any drums, but it is swimming.<extra_id_1> </s>
# sample 105: explain why the relation is contradiction between hypothesis: a man falls of a wall near the street. and premise: a man is performing a physical feat as people walk by and watch his performance.
# <pad> <extra_id_0> A man cannot fall off a wall if he is performing a physical feat.<extra_id_1> </s>
# sample 106: explain why the relation is entailment between hypothesis: humans outside and premise: a group of people riding red clad camels down a beach.
# <pad> <extra_id_0> The camels are<extra_id_1> </s>
# sample 107: explain why the relation is contradiction between hypothesis: a family at a swimming meet. and premise: a person on a bmx bike, running a course.
# <pad> <extra_id_0> A person cannot be a family at a swimming meet and be a bmx biker.<extra_id_1> </s>
# sample 108: explain why the relation is entailment between hypothesis: there are people outside. and premise: people in black walking on a street.
# <pad> <extra_id_0> If there are people outside, then there are people in black walking on a street.<extra_id_1> </s>
# sample 109: explain why the relation is neutral between hypothesis: there is a small boy in the picture. and premise: a woman in a black dress and black heels carries a shopping bag while leaning against a green bar while her child plays with a toy truck on the ground.
# <pad> <extra_id_0> A small boy could be playing with a toy truck, but he could also be a woman.<extra_id_1> </s>
# sample 110: explain why the relation is entailment between hypothesis: an army man is showing a child film on a camera. and premise: a military man holding a camera, showing a child the film on the camera.
# <pad> <extra_id_0> A military man holding a camera is likely to be holding a film camera, which is likely to be a camera.<extra_id_1> </s>
# sample 111: explain why the relation is entailment between hypothesis: a shirtless male is skating outdoors. and premise: shirtless male skateboarded doing trick at a skate park.
# <pad> <extra_id_0> Skating is an activity that is done outdoors, so it is natural for a skateboarder to be outdoors.<extra_id_1> </s>
# sample 112: explain why the relation is entailment between hypothesis: a man is shading himself. and premise: a man is sitting on a bench shading himself with an umbrella.
# <pad> <extra_id_0> A man is shading himself with an umbrella if he is sitting on a bench and has an umbrella.<extra_id_1> </s>
# sample 113: explain why the relation is entailment between hypothesis: two men are sitting and its a nighttime. and premise: two men are sitting and its a nighttime.
# <pad> <extra_id_0> If two men are sitting and its a nighttime, then it must be a nighttime.<extra_id_1> </s>
# sample 114: explain why the relation is entailment between hypothesis: the man and woman are looking at something and premise: a man and a woman stare at the ground.
# <pad> <extra_id_0> The woman and man are staring at something, and the man and woman are looking at something.<extra_id_1> </s>
# sample 115: explain why the relation is contradiction between hypothesis: two girls with mouthguards and one is holding a football while the other reaches for her. and premise: two boys with mouthguards and one is holding a football while the other reaches for him.
# <pad> <extra_id_0> A football is a ball, and if you are a player, you are a football.<extra_id_1> </s>
# sample 116: explain why the relation is entailment between hypothesis: people are outside and premise: people are dressed in costumes while on a boardwalk.
# <pad> <extra_id_0> People are on a boardwalk, so they are probably outside.<extra_id_1> </s>
# sample 117: explain why the relation is neutral between hypothesis: a baby is learning to play games and premise: a baby in an arcade tiptoeing to see the screen of a video game.
# <pad> <extra_id_0> A baby can be learning to play video games without actually playing them.<extra_id_1> </s>
# sample 118: explain why the relation is contradiction between hypothesis: a man is painting. and premise: a blond woman in a black jacket walks in front of a wall with wall art pushing a red cart.
# <pad> <extra_id_0> A woman cannot be painting a wall, unless she is a painter.<extra_id_1> </s>
# <pad> <extra_id_0> A girl cannot be a newspaper vendor.<extra_id_1> </s>
# sample 133: explain why the relation is contradiction between hypothesis: a woman is using a computer and premise: a man operates a small piece of equipment.
# <pad> <extra_id_0> A computer is a large piece of equipment, and a small piece of equipment is not a computer.<extra_id_1> </s>
# sample 134: explain why the relation is entailment between hypothesis: the woman is wearing a dress. and premise: lady in a pretty bright yellow dress is being asked to dance, while children look on.
# <pad> <extra_id_0> The dress is a dress, so the woman is dancing in a dress.<extra_id_1> </s>
# sample 135: explain why the relation is neutral between hypothesis: the thirsty girls ran to the fountain. and premise: three girls in white dresses running towards a fountain.
# <pad> <extra_id_0> The girls could be thirsty, but they could also be running for other reasons.<extra_id_1> </s>
# sample 136: explain why the relation is neutral between hypothesis: a group of people playing soccer are trying out for the team. and premise: 4 people play soccer
# <pad> <extra_id_0> A group of people playing soccer could be trying out for a team, or they could be just playing for fun.<extra_id_1> </s>
# sample 137: explain why the relation is entailment between hypothesis: kayaks are in a river. and premise: many two-person kayaks fill a river surrounded by trees.
# <pad> <extra_id_0> A river is a body of water, and kayaks are part of a body of water.<extra_id_1> </s>
# sample 138: explain why the relation is entailment between hypothesis: two fancy women are observing. and premise: two brightly dressed women with hats are looking at something.
# <pad> <extra_id_0> Two fancy women are observing something, so they are observing something.<extra_id_1> </s>
# sample 139: explain why the relation is contradiction between hypothesis: three dogs are sitting on the couch. and premise: three dogs chasing each other in the snow.
# <pad> <extra_id_0> The dogs are chasing each other, not sitting on the couch.<extra_id_1> </s>
# sample 140: explain why the relation is neutral between hypothesis: a man barbecues in his yard on the 4th of july. and premise: a man in shorts is using a barbecue grill in a yard.
# <pad> <extra_id_0> A man can barbecue in his yard on any day, but he can also do it on the 4th of July.<extra_id_1> </s>
# sample 141: explain why the relation is neutral between hypothesis: the man is cooking dinner. and premise: a man in a green shirt holds a rolling pin while smoking a cigarette in a cluttered kitchen.
# <pad> <extra_id_0> The man could be doing anything, including cooking dinner.<extra_id_1> </s>
# sample 142: explain why the relation is neutral between hypothesis: a couple is watching a movie together on the couch. and premise: a couple cuddles under a blanket on a couch.
# <pad> <extra_id_0> A couple cuddling on a couch could be for a variety of reasons, including to watch a movie, to relax, or to be romantic.<extra_id_1> </s>
# sample 143: explain why the relation is entailment between hypothesis: two army guys next to a boy. and premise: two man in the army with a small boy from the area.
# <pad> <extra_id_0> A boy can’t be an army guy and be a boy at the same time.<extra_id_1> </s>
# sample 144: explain why the relation is entailment between hypothesis: the dog is grey and premise: the gray dog is jumping through the grass with water in the background.
# <pad> <extra_id_0> The dog is a dog, so it is a dog.<extra_id_1> </s>
# sample 145: explain why the relation is entailment between hypothesis: an elderly man holds a can behind his back. and premise: a elderly man holds a can behind his back as he strolls by a beautiful flower market.
# <pad> <extra_id_0> A can is a container, and a can is a container.<extra_id_1> </s>
# sample 146: explain why the relation is contradiction between hypothesis: a boy is sleeping. and premise: catholic boy standing at a podium.
# sample 160: explain why the relation is contradiction between hypothesis: a man in uniform riding in the back of a truck. and premise: a military man drives a boat.
# ...
# <pad> <extra_id_0> A sled is a movable object, and a sled is a movable object.<extra_id_1> </s>
# sample 588: explain why the relation is contradiction between hypothesis: a young girl does aerobics. and premise: a young girl with blond-hair eating a peach.
# <pad> <extra_id_0> A young girl cannot be an aerobics athlete.<extra_id_1> </s>
# sample 589: explain why the relation is neutral between hypothesis: a man and woman are getting eloped and premise: a man and wife stand at the alter as they get married.
# <pad> <extra_id_0> A man and woman could be getting married, but they could also be eloping.<extra_id_1> </s>
# sample 590: explain why the relation is entailment between hypothesis: dog runs outside. and premise: the german shepherd runs happily in the park.
# <pad> <extra_id_0> The german shepherd runs outside, so the dog runs outside.<extra_id_1> </s>
# sample 591: explain why the relation is neutral between hypothesis: man coaches players and premise: an asian man in a black tracksuit is watching students doing exercised on basketball court.
# <pad> <extra_id_0> A coach is a person who watches a group of people doing an activity, such as exercising, and may or may not be coaching the students.<extra_id_1> </s>
# sample 592: explain why the relation is entailment between hypothesis: a truck driving and premise: a blue truck is driving on a desert road carrying several people and lots of assorted cargo.
# <pad> <extra_id_0> A truck driving implies a person riding in the truck.<extra_id_1> </s>
# sample 593: explain why the relation is entailment between hypothesis: the man has two cameras. and premise: a man wearing red sunglasses is carrying two cameras.
# <pad> <extra_id_0> A camera is an object that is carried, so a camera is an object that is carried.<extra_id_1> </s>
# sample 594: explain why the relation is neutral between hypothesis: the women are older and premise: several women wearing dresses dance in the forest.
# <pad> <extra_id_0> The women are older, so the dance is not likely to be performed by older women.<extra_id_1> </s>
# sample 595: explain why the relation is entailment between hypothesis: the young man is standing. and premise: a young man is standing near his bike outside a shop called, 'sara's old fashioned ice cream.'
# <pad> <extra_id_0> The young man is standing near his bike, and the shop sells ice cream.<extra_id_1> </s>
# sample 596: explain why the relation is neutral between hypothesis: a tall person with hair and premise: a man with medium length curly hair, wearing a button down shirt and bracelets, sings into a microphone while he plays a guitar.
# <pad> <extra_id_0> A man with hair is a tall person, but a tall person does not necessarily have long hair.<extra_id_1> </s>
# sample 597: explain why the relation is neutral between hypothesis: a group of people and a dog are waiting for the plumber. and premise: a group of people and a dog sitting on the steps.
# <pad> <extra_id_0> The dog is not the one who is waiting for the plumber.<extra_id_1> </s>
# sample 598: explain why the relation is entailment between hypothesis: people walking outside and premise: a couple walking down the street.
# <pad> Essai d'induction entaile : l'instance d'un événement ne peut être exclue d'un autre événement.</s>
# sample 599: explain why the relation is contradiction between hypothesis: two girls stand around the vending machines. and premise: two girls are kneeling on the ground.
# <pad> <extra_id_0> One can’t be kneeling on the ground and standing at the same time.<extra_id_1> </s>
# sample 600: explain why the relation is contradiction between hypothesis: two men playing with a basketball. and premise: two men and a frisbee
# <pad> <extra_id_0> A frisbee is not a basketball. A frisbee is a ball.<extra_id_1> </s>
# sample 601: explain why the relation is contradiction between hypothesis: there are some people doing the limbo. and premise: a man in a blue shirt and a woman in a pink skirt sit around other people in the background.
# sample 628: explain why the relation is neutral between hypothesis: a dog runs after a squirrel. and premise: tan dog running through long grass in a park-like setting.
# <pad> <extra_id_0> A dog running through long grass could be a dog running after a squirrel, but it could also be a dog running through long grass.<extra_id_1> </s>
# sample 629: explain why the relation is neutral between hypothesis: two wrestlers are competing and are brothers. and premise: two wrestlers in an intense match.
# <pad> <extra_id_0> The brothers are competing, but they are not brothers.<extra_id_1> </s>
# sample 630: explain why the relation is entailment between hypothesis: the child is upside down. and premise: the child is hanging upside down with his legs over a pole.
# <pad> <extra_id_0> If the child is hanging upside down, then the child is hanging upside down.<extra_id_1> </s>
# sample 631: explain why the relation is contradiction between hypothesis: a young boy is playing in the grass. and premise: a young boy is playing in the sandy water.
# <pad> <extra_id_0> A young boy cannot be playing in the grass at the same time.<extra_id_1> </s>
# sample 632: explain why the relation is neutral between hypothesis: a father and daughter swim together and premise: a man and a young girl swimming.
# <pad> <extra_id_0> A father and daughter swimming together does not necessarily indicate a father and daughter swimming together.<extra_id_1> </s>
# sample 633: explain why the relation is neutral between hypothesis: someone is sitting outside waiting for a friend to arrive. and premise: the young man in the plaid shirt is sitting on a chair that is out in the yard.
# <pad> <extra_id_0> The young man in the plaid shirt could be sitting on the chair waiting for a friend to arrive, or he could be waiting for a friend to arrive.<extra_id_1> </s>
# sample 634: explain why the relation is entailment between hypothesis: dog is running and being chased by another dog and premise: dog running with pet toy being chased by another dog.
# <pad> <extra_id_0> A dog running with a toy is a sign that it is being chased by another dog.<extra_id_1> </s>
# sample 635: explain why the relation is entailment between hypothesis: a man with glasses and premise: an elderly man with glasses, a red ball cap and backpack is standing in front of an open doorway.
# <pad> <extra_id_0> A man with glasses is standing in front of an open doorway.<extra_id_1> </s>
# sample 636: explain why the relation is contradiction between hypothesis: a man in pants and a t-shirt doing fire tricks. and premise: a robed dancer holding fire stick entertains a crowd.
# <pad> <extra_id_0> A fire stick is not a man, he is a fire stick. A fire stick is not a man.<extra_id_1> </s>
# sample 637: explain why the relation is neutral between hypothesis: the man is walking into a room. and premise: a man is standing in the doorway of a building.
# <pad> <extra_id_0> A man could be walking into a room or standing in a doorway.<extra_id_1> </s>
# sample 638: explain why the relation is neutral between hypothesis: the log is for firewood. and premise: in a snowy residential environment, a man with a brown jacket and gray mustache and beard places a hand on a felled log while another man in a blue shirt is blurry on the right side of the photo.
# <pad> <extra_id_0> The log is not for firewood, but it is for storage.<extra_id_1> </s>
# sample 639: explain why the relation is neutral between hypothesis: a child uses their imagination. and premise: a child making a sand castle on the beach.
# <pad> <extra_id_0> Children use their imagination to create things, such as sand castles, but they can also use their imagination to create other things, such as a sandcastle.<extra_id_1> </s>

# %%
from tqdm import tqdm
import pdb
wt5_esnli_label_mapping = {0: 'entailment', 1: 'neutral', 2: 'contradiction'} 
qae_list = []
score_list = []
for da in tqdm(rationale_pair_dev_data[0:200], total=len(rationale_pair_dev_data[0:200])):
    qae = "premise: {} hypothesis: {} answer: {}, explanation: {}".format(da['premise'], 
                                                 da['hypothesis'], 
                                                wt5_esnli_label_mapping[da['label']],
                                                da['generated_explanation'])

    scores = get_scores(
        [qae],
        '3b',
        device='cuda:0',
        batch_size=1,
        verbose=False)
    score_list.append(scores[0])
#     if scores[0] > 0.7 or scores[0] < 0.2:
#         print("question: {}".format(da['question']))
#         print("answer: {}".format(da['answer']))
#         print("common_expl_list: {}".format(da['common_expl_list']))
#         print("generated_explanation: {}".format(da['generated_explanation']))
#         print("score: {}".format(scores[0]))\
np.mean(score_list), np.median(score_list)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 200/200 [00:38<00:00,  5.14it/s]
# (0.4638814156129956, 0.4362713545560837)

# %%
np.mean(score_list), np.median(score_list)

# %% [markdown]
# ## evaluate generated rationale with bert-score

# %%
import datasets
import numpy as np
bertscore_metric = datasets.load_metric("bertscore")
rouge_metric = datasets.load_metric('rouge')
bleu_metric = datasets.load_metric('sacrebleu')

# %%
import pdb

bert_scores = []
bleu_scores = []
rouge1_scores = []
rouge2_scores = []
rougeL_scores = []

for da in tqdm(rationale_pair_dev_data, total=len(rationale_pair_dev_data)):
    generated_expl = da['generated_explanation']
    common_expl_list = da['common_expl_list']
    pred_expl = generated_expl.split("<extra_id_0> ")[1].split("<extra_id_1>")[0]
    list_gold_expl = [l.lower() for l in common_expl_list]
    
    bert_score = bertscore_metric.compute(predictions=[pred_expl.lower()], references=[list_gold_expl], lang="en")["f1"][0]*100
    bleu_score = bleu_metric.compute(predictions=[pred_expl.lower()], references=[list_gold_expl])['score']
    rouge_score = rouge_metric.compute(predictions=[pred_expl.lower()]*len(list_gold_expl), references=list_gold_expl)
    rouge1_score = rouge_score["rouge1"].mid.fmeasure
    rouge2_score = rouge_score["rouge2"].mid.fmeasure
    rougeL_score = rouge_score["rougeL"].mid.fmeasure
    bert_scores.append(bert_score)
    bleu_scores.append(bleu_score)
    rouge1_scores.append(rouge1_score)
    rouge2_scores.append(rouge2_score)
    rougeL_scores.append(rougeL_score)
    
    
#     #print(generated_expl)
#     #print(generated_expl.split("<extra_id_0> ")[1].split("<extra_id_1>")[0])
#     instance_bertscores = []
#     for gold_expl in list_gold_expl: 
#         score = bertscore_metric.compute(predictions=[pred_expl.lower()]*len(), references=[gold_expl.lower()], lang="en")["f1"][0]*100
#         instance_bertscores.append(score)
#     bertscores.append(np.mean(instance_bertscores))
    
#     bleuscore = bleu_score(pred_expl, list_gold_expl)
#     bleuscores.append(bleuscore)
    
#     rougescore = rouge(pred_expl, list_gold_expl)
#     rouge1_scores.append(rougescore['rouge1_fmeasure'].numpy()[0])
#     rouge2_scores.append(rougescore['rouge2_fmeasure'].numpy()[0])
#     rougeL_scores.append(rougescore['rougeL_fmeasure'].numpy()[0])
    
    


    #pdb.set_trace()

# %%
print("bert_score: {}".format(np.mean(bert_scores)))
print("bleu_score: {}".format(np.mean(bleu_scores)))
print("rouge1_score: {}".format(np.mean(rouge1_scores)))
print("rouge2_score: {}".format(np.mean(rouge2_scores)))
print("rougeL_score: {}".format(np.mean(rougeL_scores)))

# %%
rouge_score

# %%
bertscore

# %%
bertscores

# %%
np.mean(score_list)
